# %% [markdown]
# # Cleaning the repeated and repetitive questions from the dataset

# %%
import pandas as pd
import numpy as np
import faiss, random

from langchain_openai import OpenAIEmbeddings

test_brut = pd.read_csv("first_test_dataset_with_fragments.csv")

# openai api key
openai_api_key = input("Enter the OpenAI API key: ")
model_embeddings = "text-embedding-3-small"

# %%
# for the lines that have repeated questions, we will let only the first one
test_clean_dupl = test_brut.drop_duplicates(subset=["question"])
test_clean_dupl
# Out:
#       fragment                                           question  \
# 0            1  What kind of information can be found in the '...
# 1            1  What is the purpose of the 'Accountability' ca...
# 2            1  What type of discussions take place in the 'Re...
# 3            1  What is the focus of the 'Governance Design' c...
# 4            1  What can be found in the 'General Discussions'...
# ...        ...                                                ...
# 1544       462  Why did Matters Town migrate to Optimism from ...
# 1545       462  What unique challenges does Matters Town face ...
# 1546       462  How does Matters Town aim to sustain valuable ...
# 1547       462  What is the broader vision for Optimism accord...
# 1548       462   What kind of content does Matters Town focus on?
#
#                                                  answer  \
# 0     Information about community calls, weekly gove...
# 1     To increase transparency and accountability ar...
# 2     Discussions relating to the allocation of Retr...
# 3     The Collective’s metagovernance strategy, whic...
# 4     General and public discussions that don’t fit ...
# ...                                                 ...
# 1544  Matters Town migrated to Optimism to leverage ...
# 1545  Matters Town faces challenges such as finding ...
# 1546  Matters Town uses a combination of ActivityPub...
# 1547  Guo envisions Optimism evolving beyond a finan...
# 1548  Matters Town focuses on a wide range of valuab...
#
#                                           fragment_text
# 0     Board: Get  Started 🌱\nThread: How to Navigate...
# 1     Board: Get  Started 🌱\nThread: How to Navigate...
# 2     Board: Get  Started 🌱\nThread: How to Navigate...
# 3     Board: Get  Started 🌱\nThread: How to Navigate...
# 4     Board: Get  Started 🌱\nThread: How to Navigate...
# ...                                                 ...
# 1544  Board: General  Discussions ✨ \nThread: Bringi...
# 1545  Board: General  Discussions ✨ \nThread: Bringi...
# 1546  Board: General  Discussions ✨ \nThread: Bringi...
# 1547  Board: General  Discussions ✨ \nThread: Bringi...
# 1548  Board: General  Discussions ✨ \nThread: Bringi...
#
# [1537 rows x 4 columns]

# %%
# questions df
questions = test_clean_dupl["question"].tolist()

# %%
# project into the embedding space
embeddings = OpenAIEmbeddings(model=model_embeddings, openai_api_key=openai_api_key)
questions_emb = embeddings.embed_documents(questions)
questions_emb = np.array(questions_emb)

# %%
# given a treeshold (in terms of faiss distance in the emb space), we will remove the questions that are too similar
def rm_too_similar_questions(questions, questions_emb, tresh):
    # faiss index
    index = faiss.IndexFlatL2(questions_emb.shape[1])
    index.add(questions_emb)

    # get the 100 nearest neighbors for each question
    dist, ind = index.search(questions_emb, 100)
    dist, ind

    indexes_to_remove = []
    # for each question
    for n in range(len(ind)):
        # closest neighbors indexes
        i = ind[n]
        # closest neighbors distances
        d = dist[n]
        # if the question is not removed yet
        if not i[0] in indexes_to_remove:
            # the too close questions
            small = i[d < tresh]

            if len(small) > 1:
                for s in small:
                    print(questions[s])
                print("----")
                indexes_to_remove.extend(small[1:])
        
    # questions without indexes_to_remove
    questions_clean = [questions[i] for i in range(len(questions)) if i not in indexes_to_remove]
    # questions embeddings without indexes_to_remove
    questions_emb_clean = np.array([questions_emb[i] for i in range(len(questions_emb)) if i not in indexes_to_remove])

    return questions_clean, questions_emb_clean

# remove the questions that are too similar
cleaned_questions, cleaned_questions_emb = rm_too_similar_questions(questions, questions_emb, tresh = 0.4)

# select questions in the cleaned_questions list
test_clean = test_clean_dupl[test_clean_dupl["question"].isin(cleaned_questions)]
test_clean
# Out:
# What kind of information can be found in the 'Updates and Announcements' section?
# What should topics in the Updates and Announcements category generally contain?
# ----
# What is the Optimism Collective?
# What are some of the ongoing goals of the Optimism Collective?
# How is the Optimism Collective governed?
# ----
# But what do the Token House and Citizens' House really do?
# What are the responsibilities of the Token House and the Citizens’ House?
# ----
# How did the Grants Council handle the increase in applications during Season 5?
# What challenges did the Grants Council face in Season 5?
# ----
# What was the overall outcome of the Grants Council's work in Season 5?
# What were some key achievements of the Grants Council in Season 5?
# What challenges did the Grants Council face in Season 5?
# What are some of the key changes in the scope of the Grants Council for Season 5?
# How will the Grants Council be renewed for Season 5?
# How did the Grants Council perform in terms of reviewing mission requests and maintaining a finalist rate in Season 5?
# ----
# What is the enforcement mechanism for violations of the grant policies?
# What are the reporting mechanisms for violations of grant policies?
# ----
# What is the primary goal of the DeNotify project?
# What are the critical milestones for the DeNotify project?
# ----
# What should applicants do if they want to make edits to their applications based on reviewer feedback?
# What should proposers do if they want to make edits to their proposals based on reviewer feedback?
# ----
# How did the Grants Council improve the grants process in Cycle 10?
# How did the Grants Council improve the review process during Cycle 11?
# ----
# What is the significance of the grants program for the Optimism ecosystem?
# What is the purpose of the Grants Council in the Optimism ecosystem?
# What is the significance of the sustained elevation in proposals for Optimism grants?
# ----
# How are Mission Requests ranked and funded in the Optimism Governance system?
# How does the Optimism Governance Forum suggest Mission Requests should be structured?
# ----
# What is a potential issue with the current approval-ranking system for Mission Requests?
# How does the approval ranking mechanism work for Mission Requests?
# ----
# When does the voting for RetroPGF 3 end?
# When is the voting deadline for RetroPGF 3 and when will the results be announced?
# ----
# How many proposals were submitted for Cycle 13, and how many were selected for Final Review?
# How did the number and quality of proposals in Cycle 13 compare to previous cycles?
# How many proposals were submitted in Cycle 14, and how does this compare to previous cycles?
# ----
# What was the pass rate for the Intake Filter for Builders and Experiments proposals in Cycle 13?
# What was the pass rate for Builders Grants proposals during the Intake Filter for Cycle 11?
# What is the pass rate for Builders and Experiments proposals in Cycle 15?
# ----
# What suggestion was made to improve the grant review process?
# What improvements were suggested for the grant review process?
# ----
# What steps will the Grants Council take moving forward in Season 4?
# What are the key dates and activities for the Grants Council in Season 4?
# How will the Grants Council be structured in Season 3?
# How will the Grants Council be renewed for Season 5?
# How is the Grants Council for Season 4 renewed?
# ----
# Why is the Grants Council proposing to repurpose 2.5M OP for Intent 2?
# Why does the Grants Council believe it is necessary to increase the budget for Intent 2?
# ----
# What changes were made to the review process in Cycle 14?
# What change was made to the Preliminary Review process in Cycle 11 compared to Cycle 10?
# ----
# Who are the founders of the Unifra Network–Solidity Now project and what makes them well-positioned to accomplish their goals?
# Why is the Unifra Network–Solidity Now project likely to succeed?
# ----
# How long does the Special Voting Cycle #23b last?
# How long does the Special Voting Cycle #23a last?
# When does Special Voting Cycle #12b take place?
# What is the duration of Special Voting Cycle #16a?
# When does Special Voting Cycle #16b take place?
# ----
# What are some of the proposals being voted on in Special Voting Cycle #23b?
# What are some of the proposals included in the Special Voting Cycle #23a?
# What are some of the proposals eligible for voting in Special Voting Cycle #16a?
# What are the key proposals eligible for voting in Special Voting Cycle #12b?
# What are the key proposals eligible for voting in Special Voting Cycle #16b?
# What proposals are eligible for voting in Special Voting Cycle #16c?
# ----
# Where will the voting for Special Voting Cycle #23b take place?
# Where will the voting for Special Voting Cycle #16b take place?
# Where can delegates cast their votes for the Special Voting Cycle #23a?
# Where can voting for Special Voting Cycle #16a take place?
# Where can voting for the Special Voting Cycle #16c take place?
# ----
# What is the role of the Citizens’ House in the voting process?
# What is the role of the Citizens' House in the voting process?
# ----
# Why was the advanced delegation feature built?
# How does the advanced delegation feature work?
# ----
# What initiatives has Liliop.eth undertaken to promote governance and participation within the Optimism community?
# What efforts has Liliop.eth made to include non-English speakers in the Optimism governance process?
# ----
# What are some of the key features and improvements that have been added to Agora based on user feedback?
# What are the upcoming features and improvements planned for Agora?
# ----
# What is advanced delegation and its current limitations?
# How does the advanced delegation feature work?
# ----
# What is the process for approving Mission Requests in Season 6?
# How will Mission Requests be managed and ranked in Season 6?
# When does voting take place for Mission Requests in Season 6?
# ----
# What are the main challenges faced by delegates in Optimism Governance?
# What are some of the challenges faced by the Optimism governance process?
# What is the role of individual delegates in Optimism governance?
# Why is it important to have active and committed delegates in Optimism Governance?
# What qualities or actions are considered valuable for delegates in the Optimism governance community?
# ----
# What are some proposed solutions to improve delegate participation and incentives?
# What are some proposed solutions to improve delegate engagement and accountability?
# What are some proposed solutions to improve delegate engagement and participation in the governance process?
# What are some proposed methods to incentivize the re-evaluation of delegates?
# ----
# What is the role of the Code of Conduct Councils introduced in Season 5?
# Why was the Code of Conduct Council (CoCC) created in Season 5?
# ----
# How long does Cycle 19 of the Optimism Governance voting period last?
# How long does Cycle 17 of the Optimism Governance voting period last?
# ----
# How are Mission Requests ranked and approved during the voting cycle?
# How does the approval ranking mechanism work for Mission Requests?
# ----
# What are Polynya's concerns regarding the decentralization of Optimism?
# What are Polynya's thoughts on the governance structure and processes of Optimism?
# ----
# How does a non-grant proposal proceed to a vote in the Optimism Governance Forum?
# How does the voting process work for Optimism Governance proposals?
# How does a non-Foundation proposal proceed to a vote in Season 5 of Optimism Governance?
# What is the process for submitting a proposal in the Optimism Governance Voting Cycle?
# How does a non-grant proposal proceed to Week 4 in the Optimism Governance Cycle?
# ----
# What is the voting period for Special Voting Cycle #16c?
# What is the duration of Special Voting Cycle #16a?
# When does Special Voting Cycle #16b take place?
# Where can voting for the Special Voting Cycle #16c take place?
# Where will the voting for Special Voting Cycle #16b take place?
# What is the timeline and focus for the upcoming Special Voting Cycles #16b and #16c?
# Where can voting for Special Voting Cycle #16a take place?
# What proposals are eligible for voting in Special Voting Cycle #16c?
# ----
# What is the process for the Token House Code of Conduct Council's decisions to be approved?
# What are the requirements for Token House Code of Conduct Council members?
# ----
# How does Base plan to contribute to the Optimism Collective?
# How is Base contributing financially to the Optimism Collective?
# How will Base contribute to public goods and the Optimism Collective?
# ----
# What are Base's objectives in participating in Optimism governance?
# What unique perspectives can Base bring to Optimism governance?
# ----
# How can delegates endorse others in the Optimism Governance system?
# What is the role of individual delegates in Optimism governance?
# Who are some of the delegates highlighted for their contributions to Optimism governance?
# ----
# How does the proposed budget for Season 5 compare to Season 4 for each Intent?
# Why was the budget for Intent 4 reduced in Season 5?
# How is the proposed budget for Season 5 different from Season 4?
# What is the rationale behind the increase in the budget for Intent 1 in Season 5?
# ----
# What changes were made to the budget proposal based on community feedback?
# What changes were made to the initial proposal based on community feedback?
# ----
# Who is the proposed lead for the Season 5 Grants Council?
# Who is the proposed Council Lead for the Season 6 Grants Council?
# Who has been appointed as the new Lead of the Grants Council for the remainder of Season 5?
# Who are some of the nominees for the Season 5 Grants Council?
# ----
# What is the proposed operating budget for the Season 5 Grants Council?
# What is the proposed operating budget for the Season 6 Grants Council?
# How is the Grants Council's operating budget for Season 6 determined?
# ----
# What are the new roles introduced in the Season 5 Grants Council?
# What are some of the new roles introduced in the Season 6 Grants Council?
# What are the new responsibilities of the Grants Council in Season 6?
# What are some of the key changes in the scope of the Grants Council for Season 5?
# What changes in scope will the Grants Council undergo in Season 5?
# ----
# What criteria were used for selecting candidates for the Grants Council?
# What are some of the qualifications and experiences of the nominees for the Grants Council?
# What are the requirements for being nominated to the grants council?
# What are some common qualifications or experiences shared by the nominees for the Grants Council?
# ----
# How should Token House delegates measure the Council’s progress towards its intent?
# How should the Council's progress towards its Intent be measured by Token House delegates?
# How should Token House delegates ensure the Council is executing on its Charter?
# ----
# What are the key performance indicators (KPIs) for measuring the Council’s impact?
# What are the key performance indicators (KPIs) suggested for measuring the Council’s impact?
# What are some suggested KPIs for measuring the Grants Council's impact?
# ----
# How does the Optimism Collective plan to align the community in Season 4?
# How does Season 4 aim to align the different entities within the Optimism Collective?
# ----
# What is the purpose of the Collective Trust Tiers and Attestations introduced in Season 4?
# How will the Trust Tiers and Attestations work in Season 4?
# ----
# How long does Voting Cycle #14 run?
# When does voting for Cycle #14 begin?
# ----
# What type of proposals have received delegate approvals for Cycle #14?
# Can you name a specific proposal that will move to a vote in Cycle #14?
# ----
# Why is it important to recognize delegates with less visibility in the Optimism governance community?
# How can smaller or less visible delegates improve their discoverability in the Optimism governance system?
# Why is it important to have active and committed delegates in Optimism Governance?
# ----
# Is the consolidation of voting power among the top 20% of delegates in the Optimism governance system a concern?
# Why is there concern about centralization of voting power in the Optimism governance?
# ----
# How can voter apathy in Optimism governance be addressed?
# What are some suggested methods to increase voter turnout in Optimism governance?
# ----
# What are some alternative approaches to incentivizing governance participation besides monetary rewards?
# What are some alternative methods to incentivize governance participation mentioned in the discussion?
# ----
# What are some proposed solutions to the issue of self-delegation of grant tokens?
# What are the main concerns regarding self-delegation of grant tokens?
# ----
# What are the proposed changes to improve the grant process in Season 3?
# What improvements are being made to the grant application process in Season 6?
# ----
# What is the purpose of the Protocol Delegation Program proposal?
# What is the Protocol Delegation Program?
# ----
# What is the current state of delegate voting power distribution in the Optimism governance system?
# Is it possible to delegate voting power to multiple people in the current Optimism governance system?
# ----
# How can the Optimism Quests be leveraged to increase participation in Optimism Governance?
# How can Optimism improve community participation in governance?
# ----
# How does a proposal qualify for review by committees in the Optimism Governance Voting Cycle?
# What are the different committees that review proposals in the Optimism Governance Voting Cycle?
# What is the process for submitting a proposal in the Optimism Governance Voting Cycle?
# ----
# How does the governance proposal process work in the Optimism Collective?
# What are the valid types of governance proposals in the Optimism Collective?
# How is the Optimism Collective governed?
# How does the two-house governance system of the Optimism Collective function?
# What is the suggested approach to ensure the proposal aligns with the Optimism Collective's governance structure?
# How does the voting process work for Optimism Governance proposals?
# What are the primary tools used for governance in the Optimism Collective?
# What is the process for submitting a proposal in the Optimism Governance Voting Cycle?
# ----
# What role does the Optimism Foundation play in the governance process?
# How does the Optimism Foundation plan to transition governance responsibilities to the community?
# ----
# How does Retro Funding 4 differ from previous rounds?
# How has the application process for Retro Funding evolved from Round 3 to Round 4?
# ----
# What are the key areas of focus for the impact metrics in Retro Funding 4?
# What are the key impact metrics for Retro Funding 4?
# What is the role of impact metrics in Retro Funding 4?
# What are the guidelines and concerns for impact metrics in Retro Funding 4?
# ----
# What is the deliberative process being used in Retro Funding 4?
# What steps will be taken in the Retro Funding 4 deliberative experiment?
# ----
# What is the process if an applicant believes their application was wrongfully excluded?
# What happens if an applicant believes their application was wrongfully excluded?
# ----
# What are some of the rules that could lead to an application being excluded from Retro Funding?
# What are the key rules for Retro Funding applications?
# What are some of the main application rules for Retro Funding 4?
# ----
# What are the eligibility criteria for builders to participate in Retro Funding 4?
# What are the key eligibility criteria for Retro Funding 4?
# ----
# Is it necessary for a project to be on OP Mainnet to be eligible for Retro Funding 4?
# Do projects need to be deployed on OP Mainnet to be eligible for Retro Funding?
# ----
# What are the concerns raised by the community regarding the new Retro Funding design?
# What are some concerns raised about the proposed changes in Retro Funding 4?
# ----
# Who is eligible to apply for Retro Funding 4?
# Who is eligible to apply for Retro Funding Round 4?
# What are the key eligibility criteria for Retro Funding 4?
# ----
# How will the voting process work in Retro Funding 4?
# How does Retro Funding 4 aim to improve the voting process compared to Retro Funding 3?
# ----
# What are the key components involved in the implementation of Retro Funding 4's voting experience?
# How does Retro Funding 4 aim to improve the voting process compared to Retro Funding 3?
# ----
# How has the application review process for Retro Funding evolved from Retro Funding 3 to Retro Funding 4?
# What steps are involved in the application review process for Retro Funding 4?
# How has the application process for Retro Funding evolved from Round 3 to Round 4?
# ----
# What is the role of badgeholders in the application review process?
# What is the role of Badgeholder Reviewers in the application review process?
# ----
# What is the process for addressing violations of the Code of Conduct in the Optimism governance system?
# How are severe violations of the Code of Conduct handled in the Optimism community?
# ----
# What are some community concerns regarding the enforcement of the Code of Conduct?
# What are the main concerns raised by community members regarding the current process for handling Code of Conduct violations?
# ----
# How can individuals signal their intention to become a badgeholder in the Optimism ecosystem?
# What are some common reasons individuals want to become badgeholders in the Optimism ecosystem?
# What is the role of a badgeholder in the Optimism ecosystem?
# Where can new badgeholders find official information about the Optimism ecosystem?
# ----
# What are the potential issues with using sequencer revenue as the sole metric for RPGF fund distribution?
# Why is it important to consider other impact metrics beyond sequencer revenue for RPGF fund distribution?
# ----
# How does JobStash propose to support the Optimism ecosystem and RetroPGF3 recipients?
# What are the benefits of using JobStash for the Optimism ecosystem?
# ----
# How will future citizenship selection criteria be determined in the Optimism Collective?
# What is the future of citizenship selection in the Optimism Collective?
# ----
# How can community members provide feedback for RetroPGF 3?
# How can the community provide feedback on RetroPGF rounds?
# What are some of the concerns raised by the community regarding RetroPGF 3?
# ----
# How do badgeholders decide which projects to vote for in the RetroPGF rounds?
# How can projects get in front of badgeholders for future RetroPGF rounds?
# How are badgeholders for RetroPGF2 selected?
# ----
# What role does community input play in the voting process for RetroPGF rounds?
# How can the community provide feedback on RetroPGF rounds?
# ----
# What are the criticisms regarding the RetroPGF funding process?
# What are the concerns regarding the fairness of the RetroPGF funding allocation?
# What are some suggested improvements for the RetroPGF funding process?
# ----
# What is the role of the community and voters in the Optimism governance process?
# What responsibilities do Citizens have in the Optimism governance system?
# Who are the Citizens in the Optimism governance system?
# How are Citizens selected in the Optimism governance system?
# How can Optimism improve community participation in governance?
# ----
# How is the curation process for Pairwise Planets being conducted?
# What role does community feedback play in the Pairwise Planets curation process?
# ----
# How many badgeholders are there in RetroPGF 3?
# How are badgeholders for RetroPGF2 selected?
# How were the new badgeholders for RetroPGF 3 selected?
# ----
# What are the key categories used to define impact in RetroPGF?
# Why is defining impact precisely important for RetroPGF?
# ----
# What steps were taken to create the Impact Evaluation Framework?
# Who created the Impact Evaluation Framework and who supported its creation?
# What are some key elements of the Impact Evaluation Framework?
# ----
# What were the outcomes of the first two rounds of RetroPGF?
# What is the purpose of the RetroPGF round 2?
# ----
# What is the current status of RetroPGF Round 3?
# What is the timeline for RetroPGF round 2?
# What is the purpose of the RetroPGF round 2?
# Who can submit an application for RetroPGF Round 3?
# ----
# What are some of the rules that applications must adhere to in RetroPGF Round 3?
# What are the requirements for projects to participate in RetroPGF round 2?
# Who can submit an application for RetroPGF Round 3?
# ----
# How are voting badges for RetroPGF 3 distributed?
# What is the purpose of the voting badges distributed as part of retroPGF 2?
# How were the new badgeholders for RetroPGF 3 selected?
# ----
# How does SEED Latam ensure transparency and decentralization in the selection of new badgeholders?
# How does SEED Latam justify the selection of specific individuals as new badgeholders?
# How does SEED Latam address accusations of cronyism and sybil attacks in the badgeholder selection process?
# ----
# What are the main criteria for selecting new badgeholders for RetroPGF3?
# How were the new badgeholders for RetroPGF 3 selected?
# How are badgeholders for RetroPGF2 selected?
# ----
# What are some key features of the proposed RetroPGF mechanism by the user 'connor'?
# What are the potential benefits of the new RetroPGF mechanism proposed by 'connor'?
# ----
# How can projects be nominated for the Tooling & Utilities category in RetroPGF round 2?
# What is the scope of RetroPGF round 2 for the Tooling & Utilities category?
# How can projects be nominated for the Infrastructure and Dependencies category of RetroPGF round 2?
# What should be included in a project nomination for RetroPGF round 2?
# ----
# What are the key timelines for RetroPGF round 2?
# What is the timeline for RetroPGF round 2?
# ----
# What are the requirements for projects to be eligible for RetroPGF round 2?
# What are the requirements for projects to participate in RetroPGF round 2?
# How can projects participate in RetroPGF round 2?
# What should be included in a project nomination for RetroPGF round 2?
# What types of projects are eligible for the Education category in RetroPGF round 2?
# Who can submit an application for RetroPGF Round 3?
# ----
# Why is the Code of Conduct Council (CoCC) considered relevant for the Optimism community?
# How has the Code of Conduct (CoC) evolved in the Optimism governance framework?
# ----
# What are the requirements for self-nominating for the Grants Council?
# What are the requirements for being nominated to the grants council?
# What is required to nominate oneself for a Grants Council Reviewer position?
# ----
# What is the voting mechanism used for electing Grants Council Reviewers?
# What is the process for electing Reviewers for the Grants Council?
# ----
# What are some suggested measures to ensure adequate assessment of candidates?
# What additional measures are being considered to ensure adequate assessment of candidates?
# ----
# Who are some of the nominees for the Season 6 Developer Advisory Board?
# What is the deadline for self-nominations for the Season 6 Developer Advisory Board?
# ----
# What are the roles and responsibilities of the Developer Advisory Board?
# What are the main responsibilities of the Developer Advisory Board?
# What are the additional roles within the Developer Advisory Board, and what do they entail?
# What are the main responsibilities of the Developer Advisory Board as outlined in the proposed charter?
# What are the qualifications of the initial members of the Developer Advisory Board?
# Why is the Developer Advisory Board being established?
# How will the members of the Developer Advisory Board be selected?
# ----
# What is required for nominees to receive Council rewards at the end of Season 6?
# What is required to receive Council rewards at the end of Season 6?
# ----
# What is the commitment expected from members of the Grants Council?
# What is the expected commitment for serving on the Grants Council?
# What are the responsibilities of the Grants Council members?
# What are some of the key responsibilities and expectations for the Grants Council members?
# What are the main responsibilities of the Grants Council members?
# ----
# Why was the Developer Advisory Board (DAB) created in Season 5?
# What is the purpose of the Developer Advisory Board (DAB) in Season 6?
# What was the role of the Developer Advisory Board (DAB) in Season 5, and how will it change in Season 6?
# ----
# What will happen if the DAB is successfully renewed in Season 6?
# What are some of the proposed changes to the DAB's scope in Season 6?
# ----
# Who is the proposed lead for the Developer Advisory Board and what is the proposed operating budget?
# Who proposed the Developer Advisory Board’s operating budget and what is the proposed budget amount?
# What is the proposed budget for the Developer Advisory Board?
# Who is the proposed lead for the Developer Advisory Board in this proposal?
# What is the total proposed operating budget for the Developer Advisory Board in this proposal?
# ----
# What are the new roles introduced in the Developer Advisory Board for Season 6, and what are their responsibilities?
# What are some of the new responsibilities for the Developer Advisory Board in Season 6?
# What are the additional roles within the Developer Advisory Board, and what do they entail?
# ----
# What is the purpose of the Grants Council?
# How has the Grants Council evolved since its inception?
# What is the structure of the proposed Grants Council?
# ----
# Who has been engaged to develop a comprehensive Grant Council framework for Season 6?
# Who is the proposed Council Lead for the Season 6 Grants Council?
# ----
# What are the responsibilities and commitments expected from the Code of Conduct Council Members?
# What are the membership requirements and responsibilities for the Code of Conduct Council?
# What steps are being taken to ensure the accountability of Code of Conduct Council members?
# ----
# What adjustments to the Grants Council Charter were suggested to improve its structure and functionality?
# What suggestions have been made to further improve the Grants Council's processes?
# ----
# How does Giveth plan to integrate its donation platform with the Optimism network?
# How does Giveth plan to ensure long-term engagement of users on the Optimism network?
# ----
# What are the responsibilities of members and the Lead within the Anticapture Commission?
# What responsibilities do members of the Anticapture Commission have?
# What are some of the key responsibilities of the Anticapture Commission Lead?
# Who is responsible for electing the Anticapture Commission Lead?
# What is the role of the Anticapture Commission Lead?
# ----
# Who are the initial members of the Optimism Security Council?
# Why is Optimism establishing a Security Council?
# ----
# What is the timeline for the election of the Anticapture Commission Lead?
# Who is responsible for electing the Anticapture Commission Lead?
# ----
# What are some common themes or goals mentioned by the nominees for the Season 5 Grants Council?
# Who are some of the nominees for the Season 5 Grants Council?
# ----
# How are Grants Council Reviewers elected in Optimism Governance?
# How are Council Reviewers elected for the Optimism Grants Council?
# ----
# What are the key responsibilities and commitments for a Grants Council Reviewer?
# What are some of the key responsibilities and expectations for the Grants Council members?
# What are the responsibilities of the Grants Council members?
# What are the main responsibilities of the Grants Council members?
# ----
# What is the general philosophy on what makes a good Governance Fund grant according to the nominees?
# What are some key qualities of a good Governance Fund grant according to the nominees?
# ----
# What is required to nominate oneself for a Council Reviewer position?
# What is required to nominate oneself for a Grants Council Reviewer position?
# What information must be included in the Council Reviewer self-nomination template?
# ----
# How are the internal procedures of the Grants Council structured?
# What are some of the key responsibilities and structures of the Grants Council?
# ----
# What is the expected commitment for Grant Council reviewers?
# What is the expected commitment for serving on the Grants Council?
# ----
# How are protocols selected for the Protocol Delegation Program?
# What criteria are used to select protocols for the Protocol Delegation Program?
# What is the voting process for selecting protocols in the Protocol Delegation Program?
# What criteria must protocols meet to participate in the Protocol Delegation Program?
# What is the Protocol Delegation Program?
# What are the conditions for protocols to maintain their delegation in the Protocol Delegation Program?
# ----
# What key elements should be included in the executive summary of a proposal?
# How should the executive summary of a proposal be structured?
# ----
# What details are necessary in the 'Specifications' section of a proposal?
# What details should be included in the specifications section of a proposal?
# ----
# How does the proposed protocol upgrade aim to enhance the security and decentralization of the Optimism ecosystem?
# How does the proposed protocol upgrade aim to enhance the security and decentralization of the Optimism Superchain?
# ----
# What are the implications for users and node operators if this upgrade is implemented?
# What is the impact of the proposed upgrade on node operators and existing contracts?
# ----
# Why are Blockspace Charters being introduced in Season 6 of Optimism Governance?
# What is the purpose of the Blockspace Charters introduced in Season 6?
# ----
# What is the impact of the MCP L1 upgrade on node operators and existing contracts?
# What is the impact of the proposed upgrade on node operators and existing contracts?
# ----
# What are the main features introduced by the Ecotone network upgrade?
# What are the security considerations for the Ecotone network upgrade?
# ----
# Will the Ecotone network upgrade result in any downtime?
# What are the security considerations for the Ecotone network upgrade?
# ----
# Where can I find more information about the upcoming advanced delegation feature?
# How does the advanced delegation feature work?
# ----
# What are the concerns raised by some members regarding the proposal?
# What are some concerns raised about the proposal?
# ----
# Who proposed the Canyon Network Upgrade and what does it include?
# What are the key features of the Canyon Network Upgrade?
# ----
# What are the security considerations mentioned for the Canyon Network Upgrade?
# What are the key features of the Canyon Network Upgrade?
# What impact is expected from the Canyon Network Upgrade?
# ----
# How does the Optimism Foundation handle Code of Conduct violation reports?
# How are severe violations of the Code of Conduct handled in the Optimism community?
# ----
# What are the consequences of a Code of Conduct violation in the Optimism community?
# How are severe violations of the Code of Conduct handled in the Optimism community?
# ----
# Why did Hundred Finance request an amendment to the distribution of their OP token grant?
# What was the outcome of Hundred Finance's request to amend the distribution of their OP token grant?
# ----
# Why is the proposal suggesting setting the inflation rate of $OP's total token supply to 0%?
# Why do some community members support the proposal to set $OP inflation to 0%?
# ----
# What is the expected impact of setting the $OP inflation rate to 0%?
# What are the arguments against setting $OP inflation to 0%?
# ----
# What are the concerns raised by community members regarding $OP's tokenomics?
# What are some of the concerns raised by community members regarding the use of OP tokens by L2DAO?
# ----
# Why is the Bedrock upgrade significant for the Optimism ecosystem?
# Why is the Bedrock upgrade significant for the Optimism Collective?
# What is the Bedrock Protocol Upgrade in the context of the Optimism Collective?
# ----
# What security measures have been taken for the Bedrock upgrade?
# What security measures are being taken for the Bedrock upgrade?
# ----
# What are the expected performance improvements with the Bedrock upgrade?
# What are the expected impacts of the Bedrock upgrade on performance and user experience?
# ----
# What checks and balances will be in place for the Grants Council?
# What is the structure of the proposed Grants Council?
# ----
# What is the proposed budget for the Grants Council in Season 3?
# How will the Grants Council be structured in Season 3?
# What are the main goals of the Grants Council for Season 3?
# Has a Grants Council been approved for Season 3?
# ----
# Who will propose the Intents for Season 6 in the Optimism Collective?
# What are the main goals outlined in the Season 6 Intents Ratification for the Optimism Collective?
# ----
# Why should people use the Updates and Announcements category?
# How is the Updates and Announcements category different from other categories?
# ----
# What are the key changes in the Season 6 governance structure?
# What are the key changes in the governance structure for Season 6?
# ----
# How is the Optimism community addressing the issue of undisclosed financial interests within the governance process?
# If there is a financial interest, has it been properly disclosed to Optimism Governance?
# ----
# What are the key updates and proposals discussed in the recent Optimism Governance Forum?
# What are some of the key topics discussed in the recent Optimism community governance call?
# ----
# What are some of the key events and initiatives happening in the Optimism community?
# Are there any upcoming important dates for the Optimism community?
# What are the key principles for engaging in the Optimism community?
# ----
# Has the ATX DAO completed the milestones for the Reputation & Roles project?
# What is the purpose of the Reputation & Roles project by ATX DAO?
# ----
# What is the mechanism of a backstop grant in relation to Retro Funding?
# How are backstop grants and Retro Funding related in terms of project assessment?
# ----
# How were the OP tokens distributed in the EthernautDAO Cycle 8 grant?
# What was the total amount of OP tokens returned by EthernautDAO after the Cycle 8 grant distribution?
# ----
# What were some of the key proposals that passed in Special Voting Cycle #16a?
# What are some of the proposals eligible for voting in Special Voting Cycle #16a?
# What are the key proposals eligible for voting in Special Voting Cycle #16b?
# What proposals are eligible for voting in Special Voting Cycle #16c?
# What are some of the proposals included in the Special Voting Cycle #23a?
# What are the key proposals eligible for voting in Special Voting Cycle #12b?
# ----
# Why is the Optimism Badgeholder Speed Networking Event being organized?
# When will the Optimism Badgeholder Speed Networking Event take place?
# What is the format of the Optimism Badgeholder Speed Networking Event?
# ----
# What measures are in place to limit Base's voting power in Optimism governance?
# What are some concerns regarding Base's voting power in Optimism governance?
# ----
# What topics are expected to be prioritized in the future of Optimism Governance?
# What are some of the key topics discussed in the recent Optimism community governance call?
# ----
# What changes are being considered to improve the Mission proposal process?
# What improvements are suggested for the mission request process?
# ----
# How can community members stay updated on planned Optimism governance calls?
# How can the community stay engaged and participate in future Optimism governance calls?
# ----
# How can community members provide feedback on delegate discovery improvements?
# What feedback have users provided about the delegate discovery process, and what suggestions have been made?
# ----
# What was the main focus of the 20th OP Community Governance Call?
# What were the main topics discussed during the 20th OP Community Governance Call?
# What was a key topic discussed during the 17th OP Community Governance Call?
# What are some of the key topics discussed in the 18th OP Community Governance Call?
# What topics are expected to be discussed in the 8th OP Community Governance Call?
# What was a key topic of discussion related to governance during the 13th Op Community Governance Call?
# ----
# Is there a way to access the recordings of the 20th OP Community Governance Call?
# Where can the recording of the 20th OP Community Governance Call be found?
# Where can the recording of the 18th OP Community Governance Call be found?
# Is there a recording available for the 8th OP Community Governance Call?
# Where can the recording of the 17th OP Community Governance Call be found?
# Is there a recording available for the 13th Op Community Governance Call?
# ----
# How does Optimism's bi-cameral governance system help prevent plutocratic governance?
# What is the significance of the bi-cameral governance system in Optimism?
# ----
# How can community members contribute to OP Rewards Analytics?
# What resources are available for community members to contribute to OP rewards analytics?
# ----
# When is the next OP Community Governance Call scheduled?
# Are there any updates on the time for the 8th OP Community Governance Call?
# ----
# What is RetroPGF 2 and when will it take place?
# What is the timeline for RetroPGF round 2?
# What is the purpose of the RetroPGF round 2?
# ----
# What is the purpose of the Citizens' House in the Optimism governance structure?
# What is the role of the Citizens' House in Optimism's governance, and why might it be insufficient?
# Who are the Citizens in the Optimism governance system?
# ----
# What are the expectations for Season 2 of Optimism Collective governance?
# When will Season 2 of Optimism governance begin?
# ----
# What improvements are being considered for the governance process based on community feedback?
# How will community feedback be incorporated into the governance design process?
# ----
# What is the protocol delegation program's duration?
# What is the Protocol Delegation Program?
# ----
# What is the proposed method for splitting DeFi proposals between committees A and C?
# What are the proposed methods for splitting DeFi proposals among committees?
# ----
# Who comprises the Anticapture Commission and what are the membership criteria?
# Who comprises the Anticapture Commission and what are the criteria for membership?
# What responsibilities do members of the Anticapture Commission have?
# ----
# What are the new eligibility criteria for OP Chains to receive delegation in the amended Chain Delegation Program?
# What are the qualification criteria for OP Chains to receive delegation in the Chain Delegation Program?
# What are the participation requirements for OP Chains in the Chain Delegation Program?
# What are the expectations for OP Chains participating in the Chain Delegation Program?
# What is the maximum delegation cap for OP Chains under the amended Chain Delegation Program?
# ----
# How does the Chain Delegation Program support the onboarding of OP Chains to Optimism Governance?
# How does the onboarding of new OP Chains benefit the Optimism ecosystem?
# ----
# What is the role of the Collective Feedback Commission (CFC) in the governance design process?
# How will the Collective Feedback Commission (CFC) function and what are its main responsibilities?
# ----
# What are the expectations for OP Chain delegates in terms of governance participation?
# What are the expectations for OP Chains participating in the Chain Delegation Program?
# ----
# What's the main purpose of the Seed Fund administered by the OP Foundation?
# What is the main purpose of the Partner Fund administered by the OP Foundation?
# ----
# What are the primary goals of Optimism’s governance system?
# What are the key design principles guiding Optimism’s governance system?
# ----
# What are the phases involved in the initiation of the Security Council?
# What procedural steps are required for the initiation of the Security Council?
# ----
# Why is there a need to move from a token-based voting system to a person-based voting system for Optimism?
# What is the proposed solution to transition away from token-based voting in Optimism?
# ----
# Why is there a push for transitioning from Snapshot to on-chain voting for Optimism governance?
# Why is Optimism transitioning to an on-chain voting system?
# ----
# What are the potential benefits of on-chain voting mentioned in the discussion?
# What are the benefits of on-chain voting as highlighted by the community members?
# ----
# What steps are being taken to implement on-chain voting for Optimism?
# Why is Optimism transitioning to an on-chain voting system?
# Who has been contracted to build the on-chain voting MVP for Optimism, and what is the expected timeline?
# ----
# What are the main responsibilities of committees in the Optimism governance process?
# What responsibilities do Citizens have in the Optimism governance system?
# ----
# Why is the NFT & Gaming Committee important for the Optimism ecosystem?
# What additional value does the NFT & Gaming Committee bring to the Optimism ecosystem?
# ----
# What are some of the proposed changes to improve the RetroPGF application process?
# What are some suggested improvements for the RetroPGF funding process?
# ----
# How can the RetroPGF process ensure that projects receive meaningful feedback from badgeholders?
# How can the RetroPGF process be adjusted to better recognize and reward the efforts of badgeholders?
# ----
# What are some challenges faced by developers in the Optimism ecosystem regarding grant funding?
# What are some challenges faced by projects in the Optimism ecosystem?
# ----
# What is the purpose of RetroPGF?
# What is the purpose of the RetroPGF round 2?
# ----
# What are some issues with the current committee system in Optimism governance?
# What are some of the challenges faced by the Optimism governance process?
# ----
# What are the roles and responsibilities of the NumbaNERDs in the grant misuse reporting process?
# What are the incentives for reporters and NumbaNERDs in the grant misuse reporting process?
# ----
# How does the Optimism Governance Forum distinguish between harassment and valid criticism?
# What is considered private harassment in the context of the Optimism Governance Forum?
# ----
# What constitutes public harassment according to the Optimism Governance Forum?
# What is considered private harassment in the context of the Optimism Governance Forum?
# ----
# How was the Governance Fund allocated for Warden Swap?
# What concerns have been raised regarding Warden Swap's use of the Governance Fund?
# ----
# What steps should be taken to address the concerns about Warden Swap's fund usage?
# What concerns have been raised regarding Warden Swap's use of the Governance Fund?
# ----
# How has Velodrome's grant performance impacted the Optimism ecosystem?
# How has Velodrome contributed to long-term investment in the Optimism ecosystem?
# What are some key metrics that demonstrate Velodrome's success in the Optimism ecosystem?
# ----
# What were the allegations made by the Velodrome team against Layer2DAO and NFT Earth?
# How did Layer2DAO respond to the allegations made by the Velodrome team?
# ----
# What steps were suggested to resolve the conflict between Layer2DAO and the Velodrome team?
# How did Layer2DAO respond to the allegations made by the Velodrome team?
# ----
# Why did Decentragora decide to cut ties with L2DAO?
# What actions is Decentragora considering in response to the allegations against L2DAO?
# ----
# Should projects be allowed to use tokens allocated to them for governance purposes?
# What are some proposed solutions to address the issue of projects using allocated tokens for governance?
# What are the potential risks of projects using their allocated tokens for governance?
# ----
# Should protocols be allowed to self-delegate tokens received from grants?
# How can protocols participate in governance without self-delegation of grant tokens?
# ----
# How does $REGEN aim to promote and reward regenerative activities?
# What are the main goals of the $REGEN project?
# ----
# What concerns have been raised about the $REGEN project?
# What are the main goals of the $REGEN project?
# ----
# What are the main goals of the Grants Council as outlined for Season 6?
# What are the main goals of the Grants Council for Season 3?
# What are the new responsibilities of the Grants Council in Season 6?
# ----
# What are the responsibilities of the Grants Council Lead?
# What are the responsibilities of the Grants Council members?
# What are the main responsibilities of the Grants Council members?
# ----
# Who is organizing the 'Optimistic Connection' online conference?
# When and where will the 'Optimistic Connection' online conference take place?
# What are the main objectives of the 'Optimistic Connection' online conference?
# What are the key elements of the 'Optimistic Connection' online conference?
# ----
# What is the identified issue that the 'Optimistic Connection' conference aims to address?
# What are the main objectives of the 'Optimistic Connection' online conference?
# ----
# What impact has the Grants Council had on the number of grant applications and beneficiaries?
# How has the Grants Council evolved since its inception?
# ----
# How does Matters Town aim to sustain valuable public content?
# What kind of content does Matters Town focus on?
# ----
#       fragment                                           question  \
# 0            1  What kind of information can be found in the '...
# 1            1  What is the purpose of the 'Accountability' ca...
# 2            1  What type of discussions take place in the 'Re...
# 3            1  What is the focus of the 'Governance Design' c...
# 4            1  What can be found in the 'General Discussions'...
# ...        ...                                                ...
# 1543       461  What was the resolution for the issue of not s...
# 1544       462  Why did Matters Town migrate to Optimism from ...
# 1545       462  What unique challenges does Matters Town face ...
# 1546       462  How does Matters Town aim to sustain valuable ...
# 1547       462  What is the broader vision for Optimism accord...
#
#                                                  answer  \
# 0     Information about community calls, weekly gove...
# 1     To increase transparency and accountability ar...
# 2     Discussions relating to the allocation of Retr...
# 3     The Collective’s metagovernance strategy, whic...
# 4     General and public discussions that don’t fit ...
# ...                                                 ...
# 1543  The issue was resolved by ensuring that applic...
# 1544  Matters Town migrated to Optimism to leverage ...
# 1545  Matters Town faces challenges such as finding ...
# 1546  Matters Town uses a combination of ActivityPub...
# 1547  Guo envisions Optimism evolving beyond a finan...
#
#                                           fragment_text
# 0     Board: Get  Started 🌱\nThread: How to Navigate...
# 1     Board: Get  Started 🌱\nThread: How to Navigate...
# 2     Board: Get  Started 🌱\nThread: How to Navigate...
# 3     Board: Get  Started 🌱\nThread: How to Navigate...
# 4     Board: Get  Started 🌱\nThread: How to Navigate...
# ...                                                 ...
# 1543  Board: General  Discussions ✨ \nThread: Missin...
# 1544  Board: General  Discussions ✨ \nThread: Bringi...
# 1545  Board: General  Discussions ✨ \nThread: Bringi...
# 1546  Board: General  Discussions ✨ \nThread: Bringi...
# 1547  Board: General  Discussions ✨ \nThread: Bringi...
#
# [1254 rows x 4 columns]

# %% [markdown]
# # Clustering questions using OpenAI Chat

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
model_chat = "gpt-3.5-turbo-0125"

# select the model
llm = ChatOpenAI(
    model = model_chat,
    temperature = 0,
    max_tokens = None,
    timeout = None,
    max_retries = 2,
    api_key = openai_api_key
)

# create the template for interactions
def answer_template():
    return f""" I'll give you a question about Optimism Documentation. You don't need to answer it, just categorize it (just return the number, one character) into one of the following categories:

1. project support;
2. governance;
3. dev;
4. tech documentation;
5. general documentation;
6. marketing / promotion / ambassadors / events / PR;
7. other.

Question: {{question}}
"""

prompt = ChatPromptTemplate.from_template(answer_template())

chain = prompt | llm

# %%
clusters = {}
for q in cleaned_questions:
    cat = chain.invoke({"question": q})
    clusters[q] = cat.content
    print(f"Question: {q}")
    print(f"Category: {cat.content}")

# add a column with the cluster to df
test_clean['cluster'] = [clusters[q] for q in test_clean['question']]
test_clean
# Out:
# Question: What kind of information can be found in the 'Updates and Announcements' section?
# Category: 5
# Question: What is the purpose of the 'Accountability' category?
# Category: 5
# Question: What type of discussions take place in the 'Retro Funding' category?
# Category: 2
# Question: What is the focus of the 'Governance Design' category?
# Category: 2
# Question: What can be found in the 'General Discussions' category?
# Category: 5
# Question: What is the Optimism Collective?
# Category: 6
# Question: What is the Token House?
# Category: 4
# Question: What is the Citizens' House?
# Category: 5
# Question: But what do the Token House and Citizens' House really do?
# Category: 5
# Question: Are Optimists expected to avoid conflicts of interest and disclose any potential conflicts?
# Category: 2
# Question: What is the expectation regarding the communication style of Optimists within the community?
# Category: 5
# Question: How should Optimists handle personal attacks and unsubstantiated claims in governance activities?
# Category: 2
# Question: What is expected of Optimists in terms of their knowledge and participation in governance?
# Category: 2
# Question: What are the core values that Optimists are expected to uphold?
# Category: 5
# Question: How did the Grants Council handle the increase in applications during Season 5?
# Category: 2
# Question: What were some of the key projects that became finalists in Cycle 22?
# Category: 1
# Question: What was the overall outcome of the Grants Council's work in Season 5?
# Category: 2
# Question: What feedback did applicants provide regarding the grant selection process?
# Category: 2
# Question: Are there any restrictions on selling OP tokens received through grants?
# Category: 2
# Question: What should grant recipients do if they want to change the use of their grant from what is outlined in the proposal?
# Category: 2
# Question: What are the consequences of not completing critical milestones for a grant?
# Category: 2
# Question: Do the Collective Grant Policies apply to Retroactive Public Goods Funding (Retro Funding) grants?
# Category: 2
# Question: What is the enforcement mechanism for violations of the grant policies?
# Category: 2
# Question: How do Missions relate to Retro Funding?
# Category: 4
# Question: What are the key dates and deadlines for Season 6 Mission applications?
# Category: 5
# Question: Who can apply for a Mission grant?
# Category: 2
# Question: What is a Mission in the context of Optimism Governance?
# Category: 2
# Question: How do you apply for a Foundation Mission Grant?
# Category: 2
# Question: How can users easily access and analyze data about Optimism grants?
# Category: 4
# Question: What features does the Optimism Grantee database offer for filtering data?
# Category: 4
# Question: What resources are available for statistical and analytical insights on Optimism?
# Category: 4
# Question: What is the purpose of the OP Contribution ideas database?
# Category: 2
# Question: Where can users find updates and detailed information about specific grant cycles and RetroPGF grantees?
# Category: 4
# Question: How do the Collective Trust Tiers help establish standards for contribution and grant eligibility?
# Category: 2
# Question: What are the criteria for the Phoenix Tier in the Collective Trust Tiers?
# Category: 4
# Question: What changes were made to the Collective Trust Tiers for Season 5 based on delegate feedback?
# Category: 3
# Question: Can a Fledgling tier contributor apply for multiple grants, and is there an aggregate limit to the amount they can receive?
# Category: 2
# Question: What suggestions were made by delegates to improve the Collective Trust Tiers?
# Category: 4
# Question: How does Infinity Keys plan to enhance community engagement and retention on the Optimism ecosystem?
# Category: 6
# Question: What are the key milestones and objectives for Infinity Keys within the first year on Optimism?
# Category: 1
# Question: How does Infinity Keys differentiate itself from competitors in the web3 gaming space?
# Category: 6
# Question: What challenges has Infinity Keys faced in achieving its milestones, and how have they addressed them?
# Category: 1
# Question: What are the future plans for Infinity Keys in terms of governance and community involvement?
# Category: 2
# Question: How are the rubrics for reviewing Mission applications in Season 5 structured?
# Category: 4
# Question: What are some reasons a Growth Experiments submission might be declined during the intake review?
# Category: 3
# Question: What feedback did users provide regarding the rubrics and their accessibility?
# Category: 4
# Question: What changes were suggested to the rubrics for the Layerwide new project support mission?
# Category: 2
# Question: What modifications were made to the rubrics based on community feedback?
# Category: 3
# Question: Who are the founders of DeNotify and what are their backgrounds?
# Category: 5
# Question: What is the primary goal of the DeNotify project?
# Category: 1
# Question: How does DeNotify plan to attract new builders to the Optimism ecosystem?
# Category: 6
# Question: What is the proposed use of the OP token after the 1-year lock-up period?
# Category: 3
# Question: How many submissions did the Grants Council receive in Cycle 22?
# Category: 2
# Question: What is the significance of the finalists from Cycle 19 in Cycle 22?
# Category: 6
# Question: When will the grantees for Cycle 22 be announced?
# Category: 1
# Question: What is the trend in the quality of submissions in Cycle 22 compared to previous cycles?
# Category: 2
# Question: What proposal is the Grants Council planning to address potential budget constraints?
# Category: 2
# Question: Are the proposed solutions for the various projects feasible according to the reviewers?
# Category: 2
# Question: Do the proposed solutions address the Developer Mission Requests (DMRs)?
# Category: 3
# Question: Is the experience and capability of the teams behind the proposals generally supported by the reviewers?
# Category: 2
# Question: Are there any technical demerits or concerns highlighted by the reviewers?
# Category: 4
# Question: How do the reviewers suggest improving the proposals?
# Category: 2
# Question: How many applications were received and scored during Cycle 19 Preliminary Review?
# Category: 2
# Question: What are the three possible statuses for mission requests in the Grants Council review process?
# Category: 2
# Question: What is the next step for the 106 proposals that passed the preliminary review?
# Category: 2
# Question: What is required for Experiments grants greater than 150k OP to pass?
# Category: 2
# Question: What should applicants do if they want to make edits to their applications based on reviewer feedback?
# Category: 3
# Question: Who is responsible for assessing and tracking milestones for grants that have reached the Final Review?
# Category: 2
# Question: What is the purpose of the Milestone Hub?
# Category: 4
# Question: What are the two types of milestones that must be included in a grant application to be considered as a finalist?
# Category: 2
# Question: What happens if a project fails to complete its critical milestones within the allotted time?
# Category: 2
# Question: What metrics will be used to ensure grant council reviewers are accountable for their work in Season 5?
# Category: 2
# Question: How did the Grants Council improve the grants process in Cycle 10?
# Category: 2
# Question: What are some of the key projects that received grants in Cycle 10?
# Category: 1
# Question: What resources are available for proposers in Cycle 11 to help them present their best proposals?
# Category: 1
# Question: What is the purpose of the milestone tracker mentioned in the thread?
# Category: 3
# Question: What is the significance of the grants program for the Optimism ecosystem?
# Category: 6
# Question: How many Mission Request applications were received during Cycle 19?
# Category: 5
# Question: How does the number of applications in Cycle 19 compare to the entire Season 4?
# Category: 5
# Question: What is the purpose of the new type of roundup report introduced by the Grants Council?
# Category: 2
# Question: Where can one find the detailed data of the Cycle 19 submissions?
# Category: 4
# Question: How are Mission Requests ranked and funded in the Optimism Governance system?
# Category: 2
# Question: What factors should be considered when ranking Mission Proposals?
# Category: 2
# Question: Where can delegates cast their votes and find a list of proposals?
# Category: 3
# Question: What is a potential issue with the current approval-ranking system for Mission Requests?
# Category: 2
# Question: Why are public reporting requirements for grantees important in the context of Optimism governance?
# Category: 2
# Question: What are the proposed reporting fields for Growth Experiment Grants?
# Category: 4
# Question: How is the data from the reporting requirements intended to be used?
# Category: 4
# Question: Where can the public access the data collected from the reporting requirements?
# Category: 4
# Question: What steps are suggested to ensure the effectiveness of the public reporting requirements before they are enforced?
# Category: 2
# Question: How often is the Optimism Grants Changelog updated?
# Category: 4
# Question: What new features were added to the Optimism Grants website in September 2023?
# Category: 4
# Question: What is the purpose of the Requests for Grants (RFG) process introduced in Season 4?
# Category: 2
# Question: What significant changes are expected in Season 5 of the Optimism Grants program?
# Category: 6
# Question: When does the voting for RetroPGF 3 end?
# Category: 7
# Question: How many proposals were submitted for Cycle 13, and how many were selected for Final Review?
# Category: 2
# Question: What are the two sub-committees involved in the Final Review process, and how do they determine which proposals receive grants?
# Category: 2
# Question: What was the pass rate for the Intake Filter for Builders and Experiments proposals in Cycle 13?
# Category: 4
# Question: What steps should be taken by proposers who have completed their critical milestones and are seeking the remaining grant funds?
# Category: 2
# Question: How many total proposals were received by the Council in Season 4?
# Category: 2
# Question: What is the deadline for submitting a Request for Grants (RFG) for Cycle 15?
# Category: 2
# Question: What is the trend observed in the types of proposals received in Cycle 15?
# Category: 2
# Question: What suggestion was made to improve the grant review process?
# Category: 2
# Question: How many total grant applicants were there in Cycle 14?
# Category: 2
# Question: What was the focus of the reviewers during Cycle 14?
# Category: 2
# Question: What improvements are being made for Cycle 15?
# Category: 3
# Question: What was the pass rate for Builders in Cycle 14 compared to Cycle 13?
# Category: 3
# Question: What is the next step for the finalists after being selected?
# Category: 1
# Question: What are the main objectives of the Builders and Experiments Sub-Committees?
# Category: 2
# Question: What is the grant rate for the Builders and Experiments Sub-Committees in Cycle 13?
# Category: 2
# Question: What steps will the Grants Council take moving forward in Season 4?
# Category: 2
# Question: Is there a platform where milestones for Cycle 13 can be viewed?
# Category: 4
# Question: Why are grants from the GovFund required to be locked for a year?
# Category: 2
# Question: Why is there a 'no-sale' rule for growth experiments?
# Category: 3
# Question: Why is the Grants Council proposing to repurpose 2.5M OP for Intent 2?
# Category: 2
# Question: What was the initial budget allocation for Season 4 Intents, and how much remains undistributed?
# Category: 2
# Question: How has the number and quality of proposals changed from Season 3 to Season 4?
# Category: 2
# Question: What measures has the Grants Council taken to manage the limited budget for Experiments proposals?
# Category: 2
# Question: What changes were made to the review process in Cycle 14?
# Category: 2
# Question: What was the pass rate for proposals in Cycle 14's Preliminary Review?
# Category: 2
# Question: What are some of the new Requests for Grants (RFGs) published in Cycle 14?
# Category: 1
# Question: Why were the maximum points for certain project traits like 'Opensource' or 'Optimism Relationship' reduced in the Cycle 14 rubrics?
# Category: 2
# Question: What changes were made to the scoring for projects requesting large grants in Cycle 14?
# Category: 2
# Question: What new incentives were introduced to encourage earlier submission of proposals?
# Category: 2
# Question: What are the new proposer conduct deductions, and how can they affect a proposal?
# Category: 2
# Question: Why is it important to establish transparent standards for measuring the impact of content creation?
# Category: 5
# Question: What are some key performance indicators (KPIs) that can be used to measure the impact of content?
# Category: 4
# Question: How can content creators ensure their work is aligned with strategic purposes and objectives?
# Category: 5
# Question: What is the difference between measuring impact and measuring time spent on content creation?
# Category: 4
# Question: Why might there be a need to balance both time spent and impact generated in funding proposals?
# Category: 2
# Question: What types of projects were selected as finalists in the Builders category for Cycle 11?
# Category: 1
# Question: What types of projects were selected as finalists in the Growth Experiments category for Cycle 11?
# Category: 1
# Question: What disclaimer did the Grants Council provide regarding the conferral of grants?
# Category: 2
# Question: How will reviewers in Season 4 evaluate grant proposals?
# Category: 2
# Question: What is the deadline for community feedback on the draft rubrics for Season 4?
# Category: 2
# Question: When will the rubrics for Season 4 be finalized?
# Category: 3
# Question: Where can the draft proposal forms for Cycle 13 be found?
# Category: 3
# Question: How are proposals evaluated during the final review stage of the Optimism Grants Cycle?
# Category: 2
# Question: What are the primary reasons for proposal attrition between the Intake Filter and Preliminary Review stages?
# Category: 2
# Question: What support is available for proposers who did not reach the final review in Cycle 10?
# Category: 1
# Question: What is the no sale rule in the context of the Optimism Grants, and how does it apply to operational costs?
# Category: 2
# Question: What resources are available for understanding the grants process and preparing for future cycles?
# Category: 5
# Question: Who are the founders of the Unifra Network–Solidity Now project and what makes them well-positioned to accomplish their goals?
# Category: 6
# Question: What is the primary purpose of the Solidity Now tool being developed by Unifra Network?
# Category: 4
# Question: How does the L2 Notify tool benefit developers in the Optimism ecosystem?
# Category: 4
# Question: How does the Unifra Network–Solidity Now project plan to use the OP tokens after the 1-year lock-up period?
# Category: 2
# Question: Why are grants being distributed from the community governance fund considered to have disappointing results?
# Category: 2
# Question: What is the proposed alternative to grants for better utilizing funds?
# Category: 2
# Question: What are some examples of competitions that could be implemented to enhance the Optimism ecosystem?
# Category: 6
# Question: What are the potential benefits of running competitions instead of providing liquidity incentives?
# Category: 6
# Question: What measures can be taken to ensure the integrity and effectiveness of community-run competitions?
# Category: 2
# Question: How long does the Special Voting Cycle #23b last?
# Category: 4
# Question: What is the role of the Citizens’ House in the Special Voting Cycle #23b?
# Category: 5
# Question: What are some of the proposals being voted on in Special Voting Cycle #23b?
# Category: 2
# Question: Where will the voting for Special Voting Cycle #23b take place?
# Category: 2
# Question: When will the Citizens’ House veto vote take place?
# Category: 5
# Question: What is the role of the Citizens’ House in the voting process?
# Category: 2
# Question: Why was the advanced delegation feature built?
# Category: 3
# Question: When was the advanced delegation feature rolled out to different groups?
# Category: 4
# Question: How can someone get involved in the advanced delegation beta testing?
# Category: 3
# Question: Why is Linda Xie stepping down as an Optimism delegate?
# Category: 7
# Question: What did Linda Xie do with the compensation she received as a delegate?
# Category: 7
# Question: What is Linda Xie's future involvement with the Optimism ecosystem?
# Category: 6
# Question: How did the community respond to Linda Xie's resignation?
# Category: 6
# Question: Who is Liliop.eth and what is her background in the web3 world?
# Category: 6
# Question: What are the main goals of Liliop.eth as a delegate for Optimism?
# Category: 2
# Question: What initiatives has Liliop.eth undertaken to promote governance and participation within the Optimism community?
# Category: 6
# Question: What specific proposals did Liliop.eth and her community vote on, and what were the outcomes?
# Category: 2
# Question: Who is Brichis and what motivated her to become a delegate for Optimism?
# Category: 6
# Question: What is the Protocol Delegation Program and what was Brichis' stance on its renewal?
# Category: 5
# Question: What criteria did Brichis use to evaluate mission proposals during Cycle #13?
# Category: 2
# Question: What was Brichis' reasoning for voting in favor of the Season 5 Intent Budgets during Special Voting Cycle #16b?
# Category: 2
# Question: What are some of the key governance roles and structures that Brichis has supported or participated in?
# Category: 2
# Question: How has the Agora team responded to feedback from the community regarding the Optimism Agora Beta?
# Category: 2
# Question: What are some of the key features and improvements that have been added to Agora based on user feedback?
# Category: 3
# Question: What are the concerns raised by users regarding delegate discoverability on Agora?
# Category: 4
# Question: What is the community's stance on enabling vote editing in Agora?
# Category: 2
# Question: Why is a well-defined resignation process important for Optimism delegates?
# Category: 2
# Question: What should a delegate include in their resignation communication?
# Category: 5
# Question: What should large delegates do to prevent blocking quorum during their absence?
# Category: 2
# Question: What is advanced delegation and its current limitations?
# Category: 4
# Question: What additional steps should be taken for long-term resignations?
# Category: 5
# Question: What are the key considerations for delegates when casting votes on Mission Requests?
# Category: 2
# Question: What is the process for approving Mission Requests in Season 6?
# Category: 2
# Question: What should be assessed if an Intent Budget is over or under-allocated?
# Category: 2
# Question: How can delegates prepare for the voting periods in Season 6?
# Category: 2
# Question: What is the process for a delegate to run for election as a Lead representative in Season 6?
# Category: 2
# Question: What are the key dates and activities during the Season 6 reflection and voting periods?
# Category: 5
# Question: What are some of the proposals that require voting in Season 6?
# Category: 2
# Question: What happens after the Token House votes on proposals?
# Category: 2
# Question: How can individual contribution logs improve decision-making in Web3 ecosystems?
# Category: 4
# Question: What are some advantages of using individual contribution logs over group-based approaches?
# Category: 4
# Question: What are some potential challenges or downsides of maintaining individual contribution logs?
# Category: 4
# Question: What opportunities do individual contribution logs present for the adoption of self-sovereign identity (SSI) solutions?
# Category: 3
# Question: What are some existing tools or projects that could support the implementation of individual contribution logs?
# Category: 4
# Question: How has Fractal Visions' outlook on the Optimism network changed over time?
# Category: 5
# Question: What is the main focus of Fractal Visions' new NFT marketplace?
# Category: 6
# Question: What steps has Fractal Visions taken to educate others about blockchain technology?
# Category: 6
# Question: What funding mechanisms is Fractal Visions using to support public goods?
# Category: 1
# Question: What are some of the key features and tools used in the development of Fractal Visions' platform?
# Category: 4
# Question: How can Optimism promote its unique vision and attract a more diverse audience?
# Category: 6
# Question: What strategies can be employed to onboard people who don't normally interact with Web3?
# Category: 3
# Question: What are some proposed intents to support the growth and innovation of the Optimism ecosystem?
# Category: 2
# Question: How can Optimism ensure political decentralization within its governance?
# Category: 2
# Question: What role can educational institutions play in the development of the Optimism ecosystem?
# Category: 6
# Question: How has the workload for delegates evolved across different seasons of Optimism Governance?
# Category: 2
# Question: What are the main challenges faced by delegates in Optimism Governance?
# Category: 2
# Question: What are some proposed solutions to improve delegate participation and incentives?
# Category: 2
# Question: What are some suggestions to attract new delegates and reengage existing ones?
# Category: 6
# Question: How does Season 5 build upon the initiatives introduced in Season 4?
# Category: 1
# Question: What are the main governance structures introduced in Season 5?
# Category: 2
# Question: What is the purpose of the Intent Setting Workshop in Season 5?
# Category: 2
# Question: What is the role of the Code of Conduct Councils introduced in Season 5?
# Category: 2
# Question: Why is there a longer break between December 22nd and January 4th in the Season 5 timeline?
# Category: 5
# Question: How long does Cycle 19 of the Optimism Governance voting period last?
# Category: 2
# Question: What are the two protocol upgrades being voted on in Cycle 19?
# Category: 2
# Question: Did the Code of Conduct Council make any enforcement decisions during Cycle 19?
# Category: 2
# Question: How are Mission Requests ranked and approved during the voting cycle?
# Category: 2
# Question: What happens after a Protocol Upgrade proposal is approved by the Token House?
# Category: 2
# Question: What was the outcome of Protocol Upgrade #4 in Voting Cycle #18?
# Category: 4
# Question: What was the administrative error mentioned in the Voting Cycle #18 roundup?
# Category: 5
# Question: What are some examples of Mission Requests under Intent #2 in Voting Cycle #18?
# Category: 3
# Question: How does Polynya evaluate proposals for the Optimism Governance Fund?
# Category: 2
# Question: What are Polynya's concerns regarding the decentralization of Optimism?
# Category: 2
# Question: What is Polynya's stance on repeat grants for projects?
# Category: 2
# Question: What are Polynya's views on the effectiveness of current grants and incentives?
# Category: 2
# Question: How did the recent upgrades to the Optimism Governor contract impact various analytics websites?
# Category: 4
# Question: What steps are being taken to improve communication and transparency regarding future governance contract upgrades?
# Category: 2
# Question: What are the key features introduced in the recent upgrade to the Optimism Governor contract?
# Category: 2
# Question: What is the proposed approach to decentralizing the governance contract ownership?
# Category: 2
# Question: What suggestions were made to improve coordination and support for governance tooling providers?
# Category: 2
# Question: How does a non-grant proposal proceed to a vote in the Optimism Governance Forum?
# Category: 2
# Question: What is the voting period for Special Voting Cycle #16c?
# Category: 2
# Question: What are some of the non-grant proposals moving to a vote in Cycle 17?
# Category: 2
# Question: What is the process for the Token House Code of Conduct Council's decisions to be approved?
# Category: 2
# Question: How does Base plan to contribute to the Optimism Collective?
# Category: 6
# Question: What are Base's objectives in participating in Optimism governance?
# Category: 2
# Question: How will Base approach voting on governance proposals?
# Category: 2
# Question: What is Base's plan for delegating voting power?
# Category: 2
# Question: What is the significance of the Law of Chains for Base?
# Category: 4
# Question: Why is there a focus on TVL (Total Value Locked) in Phase 0 of the Governance Fund?
# Category: 2
# Question: How will Phase 1 of the Governance Fund differ from Phase 0?
# Category: 2
# Question: What are some suggested metrics to consider for Phase 1 instead of TVL?
# Category: 4
# Question: Is there a potential conflict of interest for OP Team members building on the platform?
# Category: 2
# Question: Did OP Airdrop 2 increase governance engagement?
# Category: 2
# Question: What were the key findings of the analysis on OP Airdrop 2?
# Category: 4
# Question: What are some challenges associated with using airdrops to incentivize governance participation?
# Category: 2
# Question: What unique features of OP Airdrop 2 might explain its positive effects?
# Category: 4
# Question: What are some future considerations for designing effective airdrop incentives?
# Category: 6
# Question: How does the new feature launched by Optimism Governance aim to address voting power concentration?
# Category: 2
# Question: What is the purpose of onchain endorsements in the Optimism Governance system?
# Category: 2
# Question: How can delegates endorse others in the Optimism Governance system?
# Category: 2
# Question: What is the intended effect of nudging token holders to delegate to endorsees?
# Category: 2
# Question: How does the proposed budget for Season 5 compare to Season 4 for each Intent?
# Category: 2
# Question: What is the purpose of the unallocated budget in the Season 5 proposal?
# Category: 2
# Question: What changes were made to the budget proposal based on community feedback?
# Category: 2
# Question: How does Michael determine his voting decisions for mission proposals?
# Category: 2
# Question: What was Michael's stance on the suspension of Carlos Melgar?
# Category: 7
# Question: Who did Michael support for the Code of Conduct Council and why?
# Category: 2
# Question: What is Michael's opinion on the Law of Chains?
# Category: 7
# Question: Who did Michael vote for in the Grants Council and why?
# Category: 2
# Question: Who is the proposed lead for the Season 5 Grants Council?
# Category: 2
# Question: What is the proposed operating budget for the Season 5 Grants Council?
# Category: 2
# Question: What are the new roles introduced in the Season 5 Grants Council?
# Category: 2
# Question: How does Oxytocin view the sustainability of current grant reward structures?
# Category: 2
# Question: What are Oxytocin's thoughts on the Bedrock update?
# Category: 4
# Question: What concerns does Oxytocin have about delegate centralization?
# Category: 2
# Question: What is Oxytocin's stance on the Protocol Delegation Programme Renewal?
# Category: 2
# Question: What feedback does Oxytocin provide regarding the Agora voting system?
# Category: 4
# Question: How has the delegate's voting guidelines evolved over time?
# Category: 2
# Question: What criteria were used for selecting candidates for the Grants Council?
# Category: 2
# Question: What is the delegate's stance on funding educational and marketing proposals?
# Category: 2
# Question: How will the Grants Council fulfill its intent to innovate on novel applications?
# Category: 2
# Question: What are the major proposed changes for the Season 4 Council Charter?
# Category: 2
# Question: How should Token House delegates measure the Council’s progress towards its intent?
# Category: 2
# Question: What were some of the outcomes and feedback from Season 3 of the Grants Council?
# Category: 2
# Question: What are the key performance indicators (KPIs) for measuring the Council’s impact?
# Category: 2
# Question: How does the Optimism Collective plan to align the community in Season 4?
# Category: 6
# Question: What are Missions in the context of the Optimism Collective?
# Category: 5
# Question: What role do Alliances play in the Optimism Collective?
# Category: 2
# Question: What new proposal types will the Foundation vote on in Season 4?
# Category: 2
# Question: What is the purpose of the Collective Trust Tiers and Attestations introduced in Season 4?
# Category: 4
# Question: How long does Voting Cycle #14 run?
# Category: 4
# Question: What is the URL for voting in Cycle #14?
# Category: 3
# Question: What type of proposals have received delegate approvals for Cycle #14?
# Category: 2
# Question: Why is it important to recognize delegates with less visibility in the Optimism governance community?
# Category: 2
# Question: What are some specific contributions made by highlighted delegates that were mentioned in the thread?
# Category: 2
# Question: How can token holders use the information in this thread to make informed delegation decisions?
# Category: 3
# Question: Is the consolidation of voting power among the top 20% of delegates in the Optimism governance system a concern?
# Category: 2
# Question: What are some proposed solutions to address the concentration of voting power among a few delegates?
# Category: 2
# Question: How does the current governance structure of Optimism compare to traditional democratic systems?
# Category: 2
# Question: What role do large token holders play in the Optimism governance system?
# Category: 2
# Question: What are the potential benefits and drawbacks of allowing users to veto decisions in the Optimism governance system?
# Category: 2
# Question: Why did jackanorak vote for the grants council and the protocol delegation program?
# Category: 2
# Question: What was jackanorak's reasoning for voting for certain DeFi proposals in Cycle 6?
# Category: 7
# Question: What are some of the key points jackanorak made about the Intent #3 Budget Proposal?
# Category: 2
# Question: What was jackanorak's stance on the Protocol Delegation Renewal and why?
# Category: 2
# Question: What concerns did jackanorak express about some of the missions under Intent 3?
# Category: 2
# Question: What are the two main categories of current delegation issues identified in the discussion?
# Category: 2
# Question: What is the new sorting feature introduced to improve delegate discoverability?
# Category: 4
# Question: What are some potential risks associated with delegation that need to be mitigated?
# Category: 3
# Question: How does the Optimism Collective plan to achieve technical decentralization?
# Category: 2
# Question: What is the purpose of Intent 2: Innovate on Novel Applications?
# Category: 3
# Question: Why is spreading awareness of the Optimistic Vision important for the Optimism Collective?
# Category: 6
# Question: What does governance accessibility entail in the context of the Optimism Collective?
# Category: 2
# Question: What is the role of the Token House in the budgeting process for the Collective Intents?
# Category: 2
# Question: Who are the nominees for the Builders Council Reviewer in Special Voting Cycle #12b?
# Category: 2
# Question: Who are the nominees for the Growth Experiments Council Reviewer in Special Voting Cycle #12b?
# Category: 2
# Question: What is the requirement for a non-grant proposal to proceed to a vote in Special Voting Cycle #12b?
# Category: 2
# Question: What are the key components introduced in Season 4 to bridge the Token House and the Citizens' House?
# Category: 4
# Question: What is the purpose of the Governance Fund in Season 4?
# Category: 2
# Question: What are the new experimental structures introduced in Season 4 to avoid challenges of fixed working group structures?
# Category: 3
# Question: How many proposals were received for Cycle 11?
# Category: 1
# Question: What are the two types of grants mentioned in the Cycle 11 Preliminary Review?
# Category: 2
# Question: What will the Grants Council focus on during the reflection period after Cycle 11?
# Category: 2
# Question: How can voter apathy in Optimism governance be addressed?
# Category: 2
# Question: What are some potential drawbacks of incentivizing voting in DAOs?
# Category: 2
# Question: What are the challenges associated with implementing token-based incentives for governance participation?
# Category: 2
# Question: What are some alternative approaches to incentivizing governance participation besides monetary rewards?
# Category: 2
# Question: Why did the Synthetix Ambassadors receive a delegation of 2 million OP tokens?
# Category: 6
# Question: What issues did the Synthetix Ambassadors face with their original wallet?
# Category: 6
# Question: Why is there controversy around the self-delegation of OP tokens by the Synthetix Ambassadors?
# Category: 6
# Question: What are some proposed solutions to the issue of self-delegation of grant tokens?
# Category: 2
# Question: What are the broader implications of the self-delegation issue for Optimism governance?
# Category: 2
# Question: Why is delegate overload a concern in Optimism's governance?
# Category: 2
# Question: What issues are proposers facing with the current grant process?
# Category: 2
# Question: How does the current governance culture conflict with the Collective's values?
# Category: 2
# Question: What are the proposed changes to improve the grant process in Season 3?
# Category: 2
# Question: What is the purpose of the Protocol Delegation Program proposal?
# Category: 2
# Question: What are some concerns raised by delegates regarding the voting cycles?
# Category: 2
# Question: What was the outcome of Voting Cycle #3 for the proposals?
# Category: 2
# Question: What are some issues faced by delegates using Gnosis Safe for voting?
# Category: 4
# Question: What suggestions were made to improve the voting process?
# Category: 2
# Question: How can limiting delegate voting power promote decentralization and new delegate inclusion?
# Category: 2
# Question: What are some potential drawbacks of implementing a delegate voting cap?
# Category: 2
# Question: What are some alternative ideas to promote delegate diversification without sub-delegation?
# Category: 6
# Question: Why is it important to respect the token holder's delegation in any voting power modification?
# Category: 2
# Question: What is the current state of delegate voting power distribution in the Optimism governance system?
# Category: 2
# Question: How can the Optimism Quests be leveraged to increase participation in Optimism Governance?
# Category: 6
# Question: What are some proposed tasks for the 'OP Governooooor NFT' Optimism Quest?
# Category: 6
# Question: What feedback is being sought for the proposed 'OP Governooooor NFT' quest?
# Category: 6
# Question: What additional suggestion was made to improve the delegation process?
# Category: 3
# Question: How does a proposal qualify for review by committees in the Optimism Governance Voting Cycle?
# Category: 2
# Question: What are the key deadlines and dates for Voting Cycle #7 in the Optimism Governance process?
# Category: 2
# Question: What is required from grant recipients to receive their grant in the Optimism Governance process?
# Category: 2
# Question: How does the governance proposal process work in the Optimism Collective?
# Category: 2
# Question: What role does the Optimism Foundation play in the governance process?
# Category: 2
# Question: What happens if a governance proposal fails to pass?
# Category: 2
# Question: Is there a potential conflict between OP holders' incentives and Optimism's mission to reduce transaction fees?
# Category: 2
# Question: How are transaction fees on Optimism currently paid, and does this impact OP holders?
# Category: 4
# Question: What are some proposed ideas to align OP holders' incentives with the growth of the Optimism ecosystem?
# Category: 2
# Question: Why is it important for Optimism to remain competitive on transaction fees?
# Category: 2
# Question: How can DAOs incentivize more thoughtful participation in governance votes?
# Category: 2
# Question: What are some potential issues with retroactive rewards for governance voting?
# Category: 2
# Question: How might the success of a proposal be evaluated in a retroactive reward system?
# Category: 2
# Question: How can the concept of retroactive public goods funding be integrated into DAO governance?
# Category: 2
# Question: How does Retro Funding 4 differ from previous rounds?
# Category: 4
# Question: What are the key areas of focus for the impact metrics in Retro Funding 4?
# Category: 2
# Question: What concerns were raised by the community regarding the impact metrics?
# Category: 2
# Question: What steps are being taken to refine and implement the impact metrics?
# Category: 2
# Question: What is the next step in the Retro Funding 4 process?
# Category: 2
# Question: How does the Pairwise voting system work in the context of RetroPGF?
# Category: 4
# Question: What are the major improvements in the Pairwise V2 update?
# Category: 4
# Question: What are the concerns regarding the Pairwise voting algorithm?
# Category: 4
# Question: What are the proposed modifications to the scoring algorithms in Pairwise?
# Category: 4
# Question: Why is Reputation-based Weighted Voting (RWV) being explored by TE Academy?
# Category: 2
# Question: What are some of the key achievements and activities in the first few weeks of the TE Academy's RWV project?
# Category: 6
# Question: What are the benefits of using Reputation-based Weighted Voting in DAO decision-making?
# Category: 4
# Question: What kind of NFTs has TE Academy issued to track community members' achievements?
# Category: 3
# Question: What is the current status of the RWV project at TE Academy?
# Category: 1
# Question: Why is the definition of profit being collectively defined in Retro Funding 4 instead of individually by each badgeholder?
# Category: 2
# Question: What is the deliberative process being used in Retro Funding 4?
# Category: 2
# Question: What information must projects provide during the Retro Funding 4 application process?
# Category: 2
# Question: What are the steps involved in applying the definition of profit in Retro Funding 4?
# Category: 4
# Question: What feedback was received from the first session of the deliberative process?
# Category: 5
# Question: Who can volunteer to participate in the Retro Funding application review process?
# Category: 2
# Question: What happens if an application does not meet the eligibility criteria?
# Category: 5
# Question: What is the process if an applicant believes their application was wrongfully excluded?
# Category: 2
# Question: What are some of the rules that could lead to an application being excluded from Retro Funding?
# Category: 2
# Question: What are the eligibility criteria for builders to participate in Retro Funding 4?
# Category: 2
# Question: What are the new sign-up improvements introduced in Retro Funding 4?
# Category: 4
# Question: Why is Farcaster being used for the sign-up process in Retro Funding 4?
# Category: 4
# Question: What are the benefits of creating a project before submitting an application in Retro Funding 4?
# Category: 1
# Question: What are some of the concerns raised about using Farcaster for authentication?
# Category: 4
# Question: Is it necessary for a project to be on OP Mainnet to be eligible for Retro Funding 4?
# Category: 2
# Question: What should be considered when calculating gas usage for Retro Funding 4?
# Category: 4
# Question: Can service companies that do not deploy contracts on OP chains apply for Retro Funding 4?
# Category: 2
# Question: Where can participants ask further questions or seek support regarding Retro Funding 4?
# Category: 1
# Question: How is the scope of Retro Funding rounds changing in 2024?
# Category: 2
# Question: What are the main categories of contributions being evaluated in Retro Funding?
# Category: 2
# Question: What are the two main experiments being introduced in Retro Funding 2024?
# Category: 3
# Question: Why are some contributions like consumer-facing tools and education initiatives excluded from the upcoming Retro Funding rounds?
# Category: 2
# Question: What are the concerns raised by the community regarding the new Retro Funding design?
# Category: 2
# Question: Who is eligible to apply for Retro Funding 4?
# Category: 2
# Question: What is the timeline for Retro Funding 4?
# Category: 1
# Question: How will the voting process work in Retro Funding 4?
# Category: 2
# Question: What is the KYC and grant delivery process for Retro Funding 4?
# Category: 4
# Question: What are the key components involved in the implementation of Retro Funding 4's voting experience?
# Category: 4
# Question: How does Retro Funding 4 plan to reward the use of Open Source licenses?
# Category: 2
# Question: When will the grant disbursements for Retro Funding Round 4 happen?
# Category: 1
# Question: Can individuals apply for Retro Funding or is it limited to projects?
# Category: 2
# Question: How has the application review process for Retro Funding evolved from Retro Funding 3 to Retro Funding 4?
# Category: 4
# Question: What is the role of badgeholders in the application review process?
# Category: 2
# Question: Who is the founder of the 'Women in Web3' bootcamp and what is her background?
# Category: 6
# Question: What is the main goal of the 'Women in Web3' bootcamp?
# Category: 6
# Question: What tools from the Optimism community are integrated into the bootcamp?
# Category: 3
# Question: What are the two main areas of focus for the hackathon that will culminate the bootcamp?
# Category: 6
# Question: What are some of the benefits and impacts mentioned by participants of the bootcamp?
# Category: 5
# Question: How does the Optimism Foundation handle conflicts of interest among badgeholders?
# Category: 2
# Question: What are the consequences for badgeholders who do not participate in voting rounds?
# Category: 2
# Question: What is the process for addressing violations of the Code of Conduct in the Optimism governance system?
# Category: 2
# Question: What are some community concerns regarding the enforcement of the Code of Conduct?
# Category: 2
# Question: What is the eligibility for reinstatement of voting badges after a suspension?
# Category: 2
# Question: How did Hedgey plan to use the 50k OP received from the last round of RPGF?
# Category: 6
# Question: What was the process for selecting the top four projects to receive funding?
# Category: 2
# Question: What were some of the key criteria for the types of projects Hedgey was looking to fund?
# Category: 2
# Question: What feedback did participants and community members provide about the program?
# Category: 5
# Question: What were some of the challenges faced by participants during the program?
# Category: 5
# Question: How can individuals signal their intention to become a badgeholder in the Optimism ecosystem?
# Category: 3
# Question: What areas of expertise do potential badgeholders often highlight?
# Category: 5
# Question: How do potential badgeholders typically provide their contact information?
# Category: 4
# Question: Who is the team behind the project for private, on-chain voting for RetroPGF rounds?
# Category: 3
# Question: What are the main security properties that any voting system must have according to Vitalik's blog post?
# Category: 4
# Question: Why is the current RPGF process seen as lacking in terms of security properties?
# Category: 4
# Question: What are the key requirements for future versions of the RPGF stack as mentioned by the OP foundation?
# Category: 4
# Question: What are the advantages of integrating MACI into the RPGF voting process?
# Category: 4
# Question: Why is the Optimism Collective transitioning from broad to narrow scoped rounds for Retroactive Public Goods Funding?
# Category: 2
# Question: What are the expected benefits of implementing narrow scoped rounds in Retroactive Public Goods Funding?
# Category: 4
# Question: What challenges were identified with broad scoped rounds in previous Retro Funding iterations?
# Category: 2
# Question: What steps will the Optimism Collective take to ensure transparency in the new narrow scoped rounds?
# Category: 2
# Question: What concerns might arise from the transition to narrow scoped rounds, and how does the Collective plan to address them?
# Category: 2
# Question: How many OP tokens were rewarded to builders in Retro Funding 3?
# Category: 3
# Question: What are the criteria for receiving retroactive rewards in Retro Funding 3?
# Category: 2
# Question: What is the purpose of retroactive rewards in the Optimism Collective?
# Category: 3
# Question: What concerns were raised by participants regarding the reward allocation criteria?
# Category: 2
# Question: When will citizens be contacted with instructions on how to claim their rewards?
# Category: 5
# Question: How does the impact metric based voting system differ from the current Retroactive Public Goods Funding (Retro Funding) process?
# Category: 2
# Question: What are some challenges associated with implementing a metrics based voting system for all types of contributions to the Optimism Collective?
# Category: 2
# Question: What features does the prototype of the impact calculator include?
# Category: 4
# Question: What concerns have been raised about the potential for gaming the impact metrics?
# Category: 2
# Question: How can the impact metrics be improved to ensure they deliver real value to the Optimism ecosystem?
# Category: 2
# Question: Which voting algorithms have been used in previous RetroPGF rounds?
# Category: 4
# Question: What are some pros and cons of the 'Median with quorum' voting algorithm?
# Category: 4
# Question: What are some suggestions to improve the effectiveness of 0 votes in the RetroPGF process?
# Category: 3
# Question: What are some proposed changes to the voting process to handle a large number of projects?
# Category: 2
# Question: What are the arguments for and against using a ranking system instead of assigning OP amounts in the voting process?
# Category: 3
# Question: How are the results of RetroPGF 3 votes calculated and verified?
# Category: 4
# Question: What measures are taken to protect the privacy of badgeholders' votes in RetroPGF 3?
# Category: 4
# Question: What analyses have been conducted on the RetroPGF 3 results?
# Category: 3
# Question: What is the purpose of the ZK proofs being developed by EZKL for RetroPGF results?
# Category: 4
# Question: What is the process for delivering RetroPGF grants to recipients?
# Category: 2
# Question: How did Joanbp approach the evaluation of applications for RPGF3?
# Category: 3
# Question: What suggestions did Joanbp make for improving the RPGF process?
# Category: 3
# Question: What were some of the challenges Joanbp faced regarding transparency and privacy during the RPGF3 process?
# Category: 2
# Question: What was Joanbp's stance on the issue of a controversial project being allowed to participate in RPGF3?
# Category: 7
# Question: What improvements did FractalVisions suggest to prevent issues like the controversial project from happening again?
# Category: 2
# Question: How can LLMs assist badgeholders in evaluating project applications for RetroPGF?
# Category: 3
# Question: What are some potential methods to prevent gaming or manipulation of LLM scoring systems?
# Category: 4
# Question: How can the effectiveness of LLMs in evaluating project applications be tested?
# Category: 2
# Question: What are the benefits of using multiple LLMs for scoring project applications?
# Category: 4
# Question: How can LLMs be integrated into the iterative nature of RPGF experiments?
# Category: 4
# Question: How can the Collective gather more high-quality data for the evaluation of impact and profit?
# Category: 2
# Question: How can we scale badgeholders’ impact evaluation to accurately assess the impact and profit of all nominated projects?
# Category: 3
# Question: How do we provide better mental models and definitions for impact evaluation?
# Category: 5
# Question: How can the Collective provide a better voting experience to Badgeholders?
# Category: 2
# Question: How can the Optimism community create tooling that improves the RetroPGF system for all types of participants?
# Category: 3
# Question: How does the proposed ranking system aim to improve the governance distribution process on the Optimism network?
# Category: 2
# Question: What educational initiatives are planned to help badge holders understand the new ranking system?
# Category: 2
# Question: What steps are required to implement the new ranking system for badge holders?
# Category: 3
# Question: How can the community measure progress towards the adoption of the new ranking system?
# Category: 2
# Question: What indicators can badge holders use to measure the impact of the new ranking system?
# Category: 4
# ...
# Category: 3
# Question: Why is there a debate about the 800-character limit in the RetroPGF application form?
# Category: 3
# Question: Are users experiencing issues with notifications for new or unread posts after the forum UI change?
# Category: 4
# Question: How are users currently finding unread posts in the redesigned forum?
# Category: 4
# Question: How can the quorum and participation rules for citizen vetoing be improved?
# Category: 2
# Question: What are some proposed changes to the approval-ranking voting system to improve resource utilization?
# Category: 2
# Question: What are the benefits and drawbacks of requiring at least one new member on the grants council each season?
# Category: 2
# Question: What initiatives are being considered to promote turnover and new entrance in governance councils?
# Category: 6
# Question: How can the RetroPGF process be improved to better handle the large number of project applications?
# Category: 2
# Question: What are some proposed solutions to address the issue of popularity bias and nepotism in the RetroPGF voting process?
# Category: 2
# Question: How can the RetroPGF process ensure that projects receive meaningful feedback from badgeholders?
# Category: 2
# Question: What are the benefits of using a ranking system instead of assigning OP amounts to projects in the RetroPGF process?
# Category: 4
# Question: How can the grant application process be improved to better support developers?
# Category: 2
# Question: What are some challenges faced by developers in the Optimism ecosystem regarding grant funding?
# Category: 2
# Question: What issues were identified with the distribution and categorization of mission proposals?
# Category: 2
# Question: What are the concerns regarding the involvement of certain organizations in multiple grant proposals?
# Category: 2
# Question: What is the purpose of RetroPGF?
# Category: 4
# Question: How can spam filters be improved to reward real users in future airdrops?
# Category: 3
# Question: What are some positive behaviors that should be rewarded in future airdrops?
# Category: 6
# Question: What logistical aspects of airdrops were discussed for improvement?
# Category: 3
# Question: What were some criticisms regarding the criteria used for Airdrop #2?
# Category: 3
# Question: What changes in token allocation were noted and questioned by the community?
# Category: 2
# Question: What are some issues with the current committee system in Optimism governance?
# Category: 2
# Question: What are the concerns regarding the distribution and accountability of OP grants?
# Category: 2
# Question: What are some suggestions to enhance the governance process and reduce negativity?
# Category: 2
# Question: Are there concerns about delegate centralization across multiple DAOs?
# Category: 2
# Question: What are some suggestions to improve the diversity of delegates?
# Category: 2
# Question: How can one technically delegate OP tokens or choose a delegate?
# Category: 4
# Question: What are the qualifications or traits desired in new delegates?
# Category: 2
# Question: Is it possible to change or remove a delegate after initially choosing one?
# Category: 3
# Question: How does the Optimism Grant Misuse Reporting Process ensure the anonymity of reporters?
# Category: 4
# Question: What are the criteria for a valid grant misuse report in the Optimism ecosystem?
# Category: 2
# Question: What protections are in place for reporters and accused parties in the grant misuse reporting process?
# Category: 2
# Question: What are the roles and responsibilities of the NumbaNERDs in the grant misuse reporting process?
# Category: 2
# Question: What are the expectations for Optimist behavior and how are they enforced?
# Category: 2
# Question: What is the process for removing a Collective Representative for violating their charter?
# Category: 2
# Question: When can the Code of Conduct and associated documents be updated?
# Category: 2
# Question: Are there any severe violations that can result in immediate suspension from Optimism community spaces?
# Category: 2
# Question: What should you do if you see harassment or discrimination in the Optimism community?
# Category: 2
# Question: What is the process for updating the Rules of Engagement and associated documents?
# Category: 2
# Question: What happens if someone repeatedly violates the Rules of Engagement?
# Category: 2
# Question: Why is the Monitoring category important in the Optimism Governance Forum?
# Category: 2
# Question: What should be included in posts within the Monitoring category?
# Category: 4
# Question: What is the general sentiment towards the efforts in the Monitoring category?
# Category: 5
# Question: How does the Optimism Governance Forum distinguish between harassment and valid criticism?
# Category: 2
# Question: What constitutes public harassment according to the Optimism Governance Forum?
# Category: 2
# Question: What actions are classified as doxxing under the Optimism Governance Forum's rules?
# Category: 2
# Question: What is the process for updating the Rules of Engagement in the Optimism Governance Forum?
# Category: 2
# Question: What are the main components of the rescoping proposal for the Code of Conduct in Season 6?
# Category: 3
# Question: How will self-dealing be managed in the Token House and Citizens' House under the new rescoping?
# Category: 2
# Question: What are the options for enforcing the Rules of Engagement in Season 6?
# Category: 2
# Question: What is the rationale behind minimizing governance in the new Code of Conduct rescoping?
# Category: 2
# Question: How was the Governance Fund allocated for Warden Swap?
# Category: 2
# Question: What recent developments have occurred with Warden Swap?
# Category: 4
# Question: What steps should be taken to address the concerns about Warden Swap's fund usage?
# Category: 2
# Question: How has the 1inch Network utilized its OP grant?
# Category: 6
# Question: What issues have been identified with the Celer Network's OP grant distribution?
# Category: 2
# Question: What are the main concerns regarding the Kromatika OP grant?
# Category: 2
# Question: What is the status of the OP grants for projects like Aave, Chainlink, and 0x?
# Category: 1
# Question: What actions have been taken regarding the Synapse Protocol's OP grant?
# Category: 2
# Question: How did Layer2DAO allegedly misuse the OP grants?
# Category: 7
# Question: What evidence suggests that Layer2DAO controlled the multisigs receiving the OP grants?
# Category: 3
# Question: What were the intended purposes of the grants given to Layer2DAO?
# Category: 1
# Question: What actions were taken by the wallets that received funds from the multisigs?
# Category: 3
# Question: What steps have been suggested to prevent similar misuse of grants in the future?
# Category: 2
# Question: How has Karma improved the delegate dashboard for Optimism governance?
# Category: 4
# Question: What issues have users reported with the delegate dashboard, and how has Karma addressed them?
# Category: 4
# Question: What new features has Karma introduced to improve delegate onboarding and management?
# Category: 4
# Question: What challenges has Karma faced in integrating new features, and how have they planned to address them?
# Category: 3
# Question: How has Velodrome's grant performance impacted the Optimism ecosystem?
# Category: 2
# Question: What strategies has Velodrome employed to ensure the sustainability and efficiency of their incentive programs?
# Category: 2
# Question: What lessons or insights did Velodrome gain from their grant performance analysis?
# Category: 1
# Question: How are the OP distributions being tracked and shared with the community?
# Category: 2
# Question: What are some of the key metrics used to evaluate the performance of growth experiment programs?
# Category: 2
# Question: What is the current status of growth experiment proposals?
# Category: 2
# Question: What are some of the top-performing incentivized DEX pools?
# Category: 4
# Question: How was the OPIncubator program structured and what was its main goal?
# Category: 5
# Question: What were the allegations made by the Velodrome team against Layer2DAO and NFT Earth?
# Category: 7
# Question: What steps were suggested to resolve the conflict between Layer2DAO and the Velodrome team?
# Category: 2
# Question: What evidence was presented to support the claims of misappropriation of funds by Layer2DAO?
# Category: 2
# Question: Why did Decentragora decide to cut ties with L2DAO?
# Category: 2
# Question: What is the 'no sale' rule mentioned in the thread, and how does it relate to the use of OP tokens?
# Category: 4
# Question: What broader values of the Optimism community are highlighted by Decentragora's decision to potentially return the OP tokens?
# Category: 6
# Question: Should projects be allowed to use tokens allocated to them for governance purposes?
# Category: 2
# Question: How can the governance process ensure transparency and prevent misuse of allocated tokens?
# Category: 2
# Question: Should protocols be allowed to self-delegate tokens received from grants?
# Category: 2
# Question: What is the current expectation regarding self-delegation in the grant proposal template?
# Category: 2
# Question: What are the potential benefits of allowing self-delegation for protocols?
# Category: 2
# Question: How does the OP Passport project enhance privacy and security for governance participants?
# Category: 2
# Question: What are the core components of the OP Passport system?
# Category: 4
# Question: What incentives are provided to attract community members to participate in the OP Passport platform?
# Category: 6
# Question: What are the criteria for earning badges in the OP Passport system?
# Category: 4
# Question: What is the purpose of the smart account wallet in the OP Passport system?
# Category: 4
# Question: How does $REGEN aim to promote and reward regenerative activities?
# Category: 6
# Question: How does $REGEN plan to ensure the initial token distribution is fair and impactful?
# Category: 2
# Question: What concerns have been raised about the $REGEN project?
# Category: 2
# Question: How does $REGEN align with the principles of Retroactive Public Goods Funding (RPGF)?
# Category: 4
# Question: Who are the main stakeholders in the Superchain ecosystem and what are their primary concerns regarding interoperability?
# Category: 2
# Question: What are the different approaches to interoperability discussed in the Superchain report?
# Category: 4
# Question: What is the difference between shared validity sequencing and shared sequencer networks?
# Category: 4
# Question: What are the potential limitations for dApp developers on Superchain with asynchronous composability?
# Category: 4
# Question: What is the concept of based sequencing and how does it address the Ethereum interoperability problem?
# Category: 4
# Question: How is the Optimism community engaging with Latin American communities?
# Category: 6
# Question: What initiatives are being taken to empower women in the Web3 space in Latin America?
# Category: 6
# Question: What are some of the key events and activities mentioned in the thread that are aimed at promoting blockchain and Web3 in Latin America?
# Category: 6
# Question: What role do educational platforms and newsletters play in the Latin American Web3 community?
# Category: 6
# Question: What are some of the collaborative efforts mentioned in the thread to support public goods and governance in the Optimism ecosystem?
# Category: 2
# Question: Who manages the Governance Fund grants process in Season 6?
# Category: 2
# Question: What are the main goals of the Grants Council as outlined for Season 6?
# Category: 2
# Question: What is the role of the Milestones and Metrics Team?
# Category: 2
# Question: What are the responsibilities of the Grants Council Lead?
# Category: 2
# Question: What measures are in place to ensure accountability of the Grants Council members?
# Category: 2
# Question: Who is organizing the 'Optimistic Connection' online conference?
# Category: 6
# Question: What is the identified issue that the 'Optimistic Connection' conference aims to address?
# Category: 6
# Question: What impact has the Grants Council had on the number of grant applications and beneficiaries?
# Category: 2
# Question: How does the Grants Council ensure the responsible allocation of funds?
# Category: 2
# Question: Who is Cryptoversidad and what is their mission?
# Category: 6
# Question: What are the core values of Cryptoversidad?
# Category: 5
# Question: What has been Cryptoversidad's relationship with Optimism?
# Category: 6
# Question: What kind of impact has Cryptoversidad had through their participation in events like Ethereum Lima Day and ETH Salvador?
# Category: 6
# Question: What are some of the initiatives Cryptoversidad is focusing on for 2024?
# Category: 6
# Question: Why is feedback important for grant applicants?
# Category: 5
# Question: What are the challenges faced by reviewers in providing detailed feedback?
# Category: 3
# Question: How can applicants access feedback and scores for their grant applications?
# Category: 4
# Question: What was the resolution for the issue of not seeing comments from reviewers?
# Category: 4
# Question: Why did Matters Town migrate to Optimism from Polygon?
# Category: 3
# Question: What unique challenges does Matters Town face in the Web3 world?
# Category: 5
# Question: How does Matters Town aim to sustain valuable public content?
# Category: 5
# Question: What is the broader vision for Optimism according to Guo from Matters Town?
# Category: 6
# /var/folders/k0/xzzz067529g7g_xcf607pyx00000gn/T/ipykernel_14524/2761392749.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_clean['cluster'] = [clusters[q] for q in test_clean['question']]
#       fragment                                           question  \
# 0            1  What kind of information can be found in the '...
# 1            1  What is the purpose of the 'Accountability' ca...
# 2            1  What type of discussions take place in the 'Re...
# 3            1  What is the focus of the 'Governance Design' c...
# 4            1  What can be found in the 'General Discussions'...
# ...        ...                                                ...
# 1543       461  What was the resolution for the issue of not s...
# 1544       462  Why did Matters Town migrate to Optimism from ...
# 1545       462  What unique challenges does Matters Town face ...
# 1546       462  How does Matters Town aim to sustain valuable ...
# 1547       462  What is the broader vision for Optimism accord...
#
#                                                  answer  \
# 0     Information about community calls, weekly gove...
# 1     To increase transparency and accountability ar...
# 2     Discussions relating to the allocation of Retr...
# 3     The Collective’s metagovernance strategy, whic...
# 4     General and public discussions that don’t fit ...
# ...                                                 ...
# 1543  The issue was resolved by ensuring that applic...
# 1544  Matters Town migrated to Optimism to leverage ...
# 1545  Matters Town faces challenges such as finding ...
# 1546  Matters Town uses a combination of ActivityPub...
# 1547  Guo envisions Optimism evolving beyond a finan...
#
#                                           fragment_text cluster
# 0     Board: Get  Started 🌱\nThread: How to Navigate...       5
# 1     Board: Get  Started 🌱\nThread: How to Navigate...       5
# 2     Board: Get  Started 🌱\nThread: How to Navigate...       2
# 3     Board: Get  Started 🌱\nThread: How to Navigate...       2
# 4     Board: Get  Started 🌱\nThread: How to Navigate...       5
# ...                                                 ...     ...
# 1543  Board: General  Discussions ✨ \nThread: Missin...       4
# 1544  Board: General  Discussions ✨ \nThread: Bringi...       3
# 1545  Board: General  Discussions ✨ \nThread: Bringi...       5
# 1546  Board: General  Discussions ✨ \nThread: Bringi...       5
# 1547  Board: General  Discussions ✨ \nThread: Bringi...       6
#
# [1254 rows x 5 columns]

# %%
test_clean['cluster'].value_counts()
# Out:
# cluster
# 2    719
# 4    225
# 6     96
# 3     88
# 5     71
# 1     38
# 7     17
# Name: count, dtype: int64

# %%
"""
1. project support;
2. governance;
3. dev;
4. tech documentation;
5. general documentation;
6. marketing / promotion / ambassadors / events / PR;
7. other.
"""
labels_dict = {
    "1": "project support",
    "2": "governance",
    "3": "dev",
    "4": "tech documentation",
    "5": "general documentation",
    "6": "marketing / promotion / ambassadors / events / PR",
    "7": "other"
}

test_clean['cluster'] = test_clean['cluster'].map(labels_dict)
test_clean
# Out:
# /var/folders/k0/xzzz067529g7g_xcf607pyx00000gn/T/ipykernel_14524/3295243717.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_clean['cluster'] = test_clean['cluster'].map(labels_dict)
#       fragment                                           question  \
# 0            1  What kind of information can be found in the '...
# 1            1  What is the purpose of the 'Accountability' ca...
# 2            1  What type of discussions take place in the 'Re...
# 3            1  What is the focus of the 'Governance Design' c...
# 4            1  What can be found in the 'General Discussions'...
# ...        ...                                                ...
# 1543       461  What was the resolution for the issue of not s...
# 1544       462  Why did Matters Town migrate to Optimism from ...
# 1545       462  What unique challenges does Matters Town face ...
# 1546       462  How does Matters Town aim to sustain valuable ...
# 1547       462  What is the broader vision for Optimism accord...
#
#                                                  answer  \
# 0     Information about community calls, weekly gove...
# 1     To increase transparency and accountability ar...
# 2     Discussions relating to the allocation of Retr...
# 3     The Collective’s metagovernance strategy, whic...
# 4     General and public discussions that don’t fit ...
# ...                                                 ...
# 1543  The issue was resolved by ensuring that applic...
# 1544  Matters Town migrated to Optimism to leverage ...
# 1545  Matters Town faces challenges such as finding ...
# 1546  Matters Town uses a combination of ActivityPub...
# 1547  Guo envisions Optimism evolving beyond a finan...
#
#                                           fragment_text  \
# 0     Board: Get  Started 🌱\nThread: How to Navigate...
# 1     Board: Get  Started 🌱\nThread: How to Navigate...
# 2     Board: Get  Started 🌱\nThread: How to Navigate...
# 3     Board: Get  Started 🌱\nThread: How to Navigate...
# 4     Board: Get  Started 🌱\nThread: How to Navigate...
# ...                                                 ...
# 1543  Board: General  Discussions ✨ \nThread: Missin...
# 1544  Board: General  Discussions ✨ \nThread: Bringi...
# 1545  Board: General  Discussions ✨ \nThread: Bringi...
# 1546  Board: General  Discussions ✨ \nThread: Bringi...
# 1547  Board: General  Discussions ✨ \nThread: Bringi...
#
#                                                 cluster
# 0                                 general documentation
# 1                                 general documentation
# 2                                            governance
# 3                                            governance
# 4                                 general documentation
# ...                                                 ...
# 1543                                 tech documentation
# 1544                                                dev
# 1545                              general documentation
# 1546                              general documentation
# 1547  marketing / promotion / ambassadors / events / PR
#
# [1254 rows x 5 columns]

# %%
# save csv
test_clean.to_csv("forum_test_dataset_with_clusters.csv", index=False)
