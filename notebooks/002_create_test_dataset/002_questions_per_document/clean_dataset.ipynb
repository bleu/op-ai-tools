# %% [markdown]
# # Cleaning the repeated and repetitive questions from the dataset

# %%
import pandas as pd
import numpy as np
import faiss, random

from langchain_openai import OpenAIEmbeddings

test_brut = pd.read_csv("first_test_dataset_with_fragments.csv")

# openai api key
openai_api_key = input("Enter the OpenAI API key: ")
model_embeddings = "text-embedding-3-small"

# %%
# for the lines that have repeated questions, we will let only the first one
test_clean_dupl = test_brut.drop_duplicates(subset=["question"])
test_clean_dupl
# Out:
#      fragment                                           question  \
# 0           0  How can I get developer support for my project...
# 1           0  How can I promote my project once it's deploye...
# 2           0  What should I do if I want to apply for a Gove...
# 3           1  How can I get involved in the Optimism Collect...
# 4           1  What is RetroPGF and why is it important for O...
# ..        ...                                                ...
# 291       102  What is the difference between push oracles an...
# 292       102  What is the role of the Gas Price Oracle on OP...
# 293       103  Which API providers offer free access to Optim...
# 294       103  Are there any API providers that support both ...
# 295       103  Which API provider offers the highest number o...
#
#                                                 answer  \
# 0    To get developer support for your project on O...
# 1    Once your project is deployed on the Superchai...
# 2    If you want to apply for a Governance Grant, f...
# 3    You can get involved in the Optimism Collectiv...
# 4    RetroPGF is a core part of Optimism’s vision a...
# ..                                                 ...
# 291  Push oracles are updated continuously and alwa...
# 292  The Gas Price Oracle on OP Mainnet provides in...
# 293  Several API providers offer free access to Opt...
# 294  Yes, several API providers support both OP Mai...
# 295  BlockPI offers the highest number of free API ...
#
#                                          fragment_text
# 0    ---\ntitle: How do I get project support (mark...
# 1    ---\ntitle: How do I get project support (mark...
# 2    ---\ntitle: How do I get project support (mark...
# 3    ---\ntitle: Contribute to Optimism\nlang: en-U...
# 4    ---\ntitle: Contribute to Optimism\nlang: en-U...
# ..                                                 ...
# 291  ---\ntitle: Oracles\nlang: en-US\n---  \n[Orac...
# 292  ---\ntitle: Oracles\nlang: en-US\n---  \n[Orac...
# 293  ---\ntitle: Node & API Providers\nlang: en-US\...
# 294  ---\ntitle: Node & API Providers\nlang: en-US\...
# 295  ---\ntitle: Node & API Providers\nlang: en-US\...
#
# [289 rows x 4 columns]

# %%
# questions df
questions = test_clean_dupl["question"].tolist()

# %%
# project into the embedding space
embeddings = OpenAIEmbeddings(model=model_embeddings, openai_api_key=openai_api_key)
questions_emb = embeddings.embed_documents(questions)
questions_emb = np.array(questions_emb)

# %%
# given a treeshold (in terms of faiss distance in the emb space), we will remove the questions that are too similar
def rm_too_similar_questions(questions, questions_emb, tresh):
    # faiss index
    index = faiss.IndexFlatL2(questions_emb.shape[1])
    index.add(questions_emb)

    # get the 100 nearest neighbors for each question
    dist, ind = index.search(questions_emb, 100)
    dist, ind

    indexes_to_remove = []
    # for each question
    for n in range(len(ind)):
        # closest neighbors indexes
        i = ind[n]
        # closest neighbors distances
        d = dist[n]
        # if the question is not removed yet
        if not i[0] in indexes_to_remove:
            # the too close questions
            small = i[d < tresh]

            if len(small) > 1:
                for s in small:
                    print(questions[s])
                print("----")
                indexes_to_remove.extend(small[1:])
        
    # questions without indexes_to_remove
    questions_clean = [questions[i] for i in range(len(questions)) if i not in indexes_to_remove]
    # questions embeddings without indexes_to_remove
    questions_emb_clean = np.array([questions_emb[i] for i in range(len(questions_emb)) if i not in indexes_to_remove])

    return questions_clean, questions_emb_clean

# remove the questions that are too similar
cleaned_questions, cleaned_questions_emb = rm_too_similar_questions(questions, questions_emb, tresh = 0.4)

# select questions in the cleaned_questions list
test_clean = test_clean_dupl[test_clean_dupl["question"].isin(cleaned_questions)]
test_clean
# Out:
# What should I do if I want to apply for a Governance Grant?
# How can I apply for grant funding from the Governance Fund?
# ----
# How can I get involved in the Optimism Collective?
# What is the Optimism Collective?
# How can I stay updated on current events and opportunities within the Optimism Collective?
# Who are the members of the Optimism Collective?
# What is the main goal of the Optimism Collective?
# ----
# How can I start the process of becoming an Optimism Ambassador?
# What are the main responsibilities of an Optimism Ambassador?
# ----
# How does the Optimism Collective plan to handle identity and reputation?
# What approach should developers take when building within the identity and reputation space in the Optimism Collective?
# ----
# How can I get involved in running local events for the Optimism community?
# What should I do if I want to run an event for the Optimism community now?
# ----
# Where can I find more information about the NumbaNERDs program?
# How can I participate in the NumbaNERDs program?
# ----
# How can I get involved in the TechNERDs program?
# What is the purpose of the TechNERDs program?
# ----
# How can I participate in Optimism's Demo Day?
# When does Optimism's Demo Day take place?
# ----
# How can I start contributing to the Optimism codebase?
# What skills are needed to contribute to the Optimism codebase?
# ----
# Are there any rewards for contributing to the Optimism project?
# How does Optimism plan to reward users and contributors?
# ----
# Where can I find a guide to deploy a basic contract on OP Mainnet?
# Where can I find a guide to start deploying a basic contract on OP Mainnet?
# ----
# How does Bedrock improve transaction fees?
# How does Bedrock reduce transaction fees?
# How does the Bedrock upgrade affect transaction fees?
# What changes have been made to transaction fees in the Bedrock release?
# ----
# What are the benefits of Bedrock for deposit times?
# What improvements does Bedrock bring to deposit times?
# ----
# How does the Bedrock upgrade affect transaction fees on OP Mainnet?
# How does the Bedrock upgrade affect transaction fees?
# ----
# How can I move tokens between OP Mainnet and Ethereum?
# How can users transfer assets between Ethereum and OP Mainnet?
# ----
# What are the components of the transaction fees on OP Mainnet?
# How do transaction fees work on OP Mainnet?
# How are transaction fees calculated on OP Mainnet?
# How do transaction fees on OP Mainnet compare to those on Ethereum?
# How can I estimate the total transaction fee on OP Mainnet?
# What are the two main costs associated with transactions on OP Mainnet?
# ----
# Why would I need to run a local development environment for OP Mainnet?
# When should I use a local development environment for testing my dapp on OP Mainnet?
# How do I start and stop the local development environment for OP Mainnet?
# What tools and components do I need to install to set up a local development environment for OP Mainnet?
# ----
# Are there any differences in transaction costs between Ethereum and OP Mainnet?
# What are the two main costs associated with transactions on OP Mainnet?
# How do transaction fees on OP Mainnet compare to those on Ethereum?
# ----
# Why might my transaction get stuck on the Optimism network?
# What can I do if my transaction is stuck on the Optimism network?
# ----
# Who was eligible for Optimism's Airdrop #1?
# Who is eligible for Airdrop #4 from Optimism?
# ----
# Do I need to claim my tokens for Airdrop #2?
# Do I need to claim my tokens for Airdrop 3?
# ----
# What are Retroactive Public Goods Funding (RetroPGF) rounds?
# What is Retroactive Public Goods Funding (RetroPGF) and how does it work?
# What is Retroactive Public Goods Funding (Retro Funding) and how does it work?
# ----
# How does the Optimism Collective generate value for its ecosystem?
# What is the Optimism Collective?
# ----
# Why should I delegate my OP tokens?
# How can I choose a delegate for my OP tokens?
# ----
# How many projects were awarded funding in the first round of Retro Funding?
# What was the median amount of funding received by a project in Retro Funding 1?
# ----
# How were the badgeholders for RetroPGF Round 2 selected?
# How were the recipients of RetroPGF Round 3 chosen?
# ----
# What is the main purpose of the Optimism Foundation?
# What is the main goal of the Optimism Collective?
# ----
# Why should I consider using the Standard bridge before developing a custom bridge?
# When would I need to build a custom bridge instead of using the Standard bridge?
# ----
# How do I connect to the OP Mainnet?
# How can I connect my wallet to OP Mainnet?
# ----
# How can I get test tokens on the OP Goerli network?
# How can I get NFT tokens for testing on OP Goerli?
# ----
# How does the AttestationStation contribute to decentralized identity?
# What's an attestation in the context of decentralized identity?
# ----
# How can I read and write attestations on the Optimism network?
# Is there a way to index attestations on the Optimism network?
# ----
# What's the purpose of schemas in Optimism Governance?
# Can you give an example of a schema used in Optimism Governance?
# ----
# Why am I being redirected when I try to access the sequencing documentation on Optimism's website?
# What is the new URL for the sequencing documentation on Optimism's website?
# ----
# How does a withdrawal work in Optimism?
# What are the steps involved in initiating a withdrawal on Optimism?
# What happens during the withdrawal proving transaction on Optimism?
# ----
# Is there an SDK available for Optimism through Alchemy?
# Are there any examples available for using the Alchemy SDK with Optimism?
# ----
#      fragment                                           question  \
# 0           0  How can I get developer support for my project...
# 1           0  How can I promote my project once it's deploye...
# 2           0  What should I do if I want to apply for a Gove...
# 3           1  How can I get involved in the Optimism Collect...
# 4           1  What is RetroPGF and why is it important for O...
# ..        ...                                                ...
# 291       102  What is the difference between push oracles an...
# 292       102  What is the role of the Gas Price Oracle on OP...
# 293       103  Which API providers offer free access to Optim...
# 294       103  Are there any API providers that support both ...
# 295       103  Which API provider offers the highest number o...
#
#                                                 answer  \
# 0    To get developer support for your project on O...
# 1    Once your project is deployed on the Superchai...
# 2    If you want to apply for a Governance Grant, f...
# 3    You can get involved in the Optimism Collectiv...
# 4    RetroPGF is a core part of Optimism’s vision a...
# ..                                                 ...
# 291  Push oracles are updated continuously and alwa...
# 292  The Gas Price Oracle on OP Mainnet provides in...
# 293  Several API providers offer free access to Opt...
# 294  Yes, several API providers support both OP Mai...
# 295  BlockPI offers the highest number of free API ...
#
#                                          fragment_text
# 0    ---\ntitle: How do I get project support (mark...
# 1    ---\ntitle: How do I get project support (mark...
# 2    ---\ntitle: How do I get project support (mark...
# 3    ---\ntitle: Contribute to Optimism\nlang: en-U...
# 4    ---\ntitle: Contribute to Optimism\nlang: en-U...
# ..                                                 ...
# 291  ---\ntitle: Oracles\nlang: en-US\n---  \n[Orac...
# 292  ---\ntitle: Oracles\nlang: en-US\n---  \n[Orac...
# 293  ---\ntitle: Node & API Providers\nlang: en-US\...
# 294  ---\ntitle: Node & API Providers\nlang: en-US\...
# 295  ---\ntitle: Node & API Providers\nlang: en-US\...
#
# [244 rows x 4 columns]

# %% [markdown]
# # Clustering questions using OpenAI Chat

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
model_chat = "gpt-3.5-turbo-0125"

# select the model
llm = ChatOpenAI(
    model = model_chat,
    temperature = 0,
    max_tokens = None,
    timeout = None,
    max_retries = 2,
    api_key = openai_api_key
)

# create the template for interactions
def answer_template():
    return f""" I'll give you a question about Optimism Documentation. You don't need to answer it, just categorize it (just return the number, one character) into one of the following categories:

1. project support;
2. governance;
3. dev;
4. tech documentation;
5. general documentation;
6. marketing / promotion / ambassadors / events / PR;
7. other.

Question: {{question}}
"""

prompt = ChatPromptTemplate.from_template(answer_template())

chain = prompt | llm

# %%
clusters = {}
for q in cleaned_questions:
    cat = chain.invoke({"question": q})
    clusters[q] = cat.content
    print(f"Question: {q}")
    print(f"Category: {cat.content}")

# add a column with the cluster to df
test_clean['cluster'] = [clusters[q] for q in test_clean['question']]
test_clean
# Out:
# Question: How can I get developer support for my project on Optimism?
# Category: 1
# Question: How can I promote my project once it's deployed on the Superchain?
# Category: 6
# Question: What should I do if I want to apply for a Governance Grant?
# Category: 2
# Question: How can I get involved in the Optimism Collective?
# Category: 6
# Question: What is RetroPGF and why is it important for Optimism?
# Category: 4
# Question: How can I start the process of becoming an Optimism Ambassador?
# Category: 6
# Question: What actions can lead to losing your Ambassador status?
# Category: 6
# Question: How can I become a support NERD in the Optimism community?
# Category: 3
# Question: What are the main responsibilities of a support NERD?
# Category: 1
# Question: What actions can lead to losing my NERD status?
# Category: 3
# Question: How does the Optimism Collective plan to handle identity and reputation?
# Category: 2
# Question: What are attestations and when are they useful?
# Category: 4
# Question: How can I get involved in running local events for the Optimism community?
# Category: 6
# Question: Where can I sign up to be informed about the Local Optimists program?
# Category: 6
# Question: How does the NumbaNERDs program help with grant spending in Optimism governance?
# Category: 2
# Question: Where can I find more information about the NumbaNERDs program?
# Category: 5
# Question: How can I get involved in the TechNERDs program?
# Category: 6
# Question: Is there a beginner-friendly version of the TechNERD training?
# Category: 3
# Question: How can I contribute to translating Optimism's User Docs?
# Category: 4
# Question: Is there any reward for translating documents for Optimism?
# Category: 6
# Question: Why does Optimism emphasize translations?
# Category: 5
# Question: How can I participate in Optimism's Demo Day?
# Category: 6
# Question: What should I do if I want to showcase a new feature of my dApp during Demo Day?
# Category: 6
# Question: What is the Superchain in the context of Optimism?
# Category: 4
# Question: What is the OP token and how should it be discussed?
# Category: 4
# Question: How can I start contributing to the Optimism codebase?
# Category: 3
# Question: Are there any rewards for contributing to the Optimism project?
# Category: 6
# Question: Where can I find a guide to deploy a basic contract on OP Mainnet?
# Category: 4
# Question: Is deploying a contract on OP Mainnet different from deploying on Ethereum?
# Category: 4
# Question: Where can I get help if I can't find the content I'm looking for in the documentation?
# Category: 4
# Question: What's Bedrock in the context of Optimism?
# Category: 4
# Question: How does Bedrock improve transaction fees?
# Category: 4
# Question: What are the benefits of Bedrock for deposit times?
# Category: 4
# Question: What's the latest major release of OP Mainnet called?
# Category: 4
# Question: What is the block production time in the Bedrock network?
# Category: 4
# Question: What are some key changes introduced in the Bedrock upgrade?
# Category: 4
# Question: What's the main purpose of the Bedrock release in the Optimism OP Stack?
# Category: 4
# Question: What's the main purpose of the Bedrock upgrade for OP Mainnet?
# Category: 4
# Question: How does the Bedrock upgrade affect transaction fees on OP Mainnet?
# Category: 4
# Question: What is the new process for withdrawing funds from OP Mainnet after the Bedrock upgrade?
# Category: 4
# Question: How can I enable metrics for my `op-node` in Optimism?
# Category: 4
# Question: What is the default endpoint for accessing `op-node` metrics?
# Category: 4
# Question: What should I monitor to ensure my `op-node` is syncing properly?
# Category: 4
# Question: How do the Rollup Node and Execution Engine communicate in an Optimism Bedrock deployment?
# Category: 4
# Question: What are the minimum system requirements to run Bedrock?
# Category: 4
# Question: Do I need to run Legacy Geth for all Optimism networks?
# Category: 4
# Question: Where can I find information about the Optimism Goerli network?
# Category: 4
# Question: Where can I find more detailed information about Bedrock Mission Control for Optimism?
# Category: 4
# Question: How has the Bedrock release affected transaction statuses in Optimism?
# Category: 4
# Question: What should I do if a JSON RPC method I used before is no longer available in Bedrock?
# Category: 4
# Question: How can I move tokens between OP Mainnet and Ethereum?
# Category: 4
# Question: Is it possible to send data between OP Mainnet and Ethereum?
# Category: 4
# Question: What is bridging in the context of OP Mainnet and Ethereum?
# Category: 4
# Question: How can I ensure the L2 state is correct before the fault challenge period passes?
# Category: 4
# Question: What are the trade-offs of using a fully centralized communication strategy for my dapp?
# Category: 2
# Question: What is the process for sending messages from L2 to L1?
# Category: 4
# Question: How can apps on OP Mainnet interact with apps on Ethereum?
# Category: 4
# Question: What are the 'messenger' contracts used for in Optimism?
# Category: 4
# Question: How long does it take for transactions to be sent from OP Mainnet to Ethereum?
# Category: 4
# Question: How can I transfer my ERC20 tokens between Layer 1 and Layer 2 on Optimism?
# Category: 4
# Question: What should I be aware of when using the Standard Bridge for ERC20 tokens?
# Category: 4
# Question: Can I use the Standard Bridge to transfer ETH between Layer 1 and Layer 2?
# Category: 4
# Question: How does the cost of using a decentralized application on OP Mainnet compare to using one on L1 Ethereum?
# Category: 4
# Question: What are the components of the transaction fees on OP Mainnet?
# Category: 4
# Question: Why is it important to optimize the ABI (application binary interface) when using OP Mainnet?
# Category: 4
# Question: Why would I need to run a local development environment for OP Mainnet?
# Category: 4
# Question: Are there any differences in transaction costs between Ethereum and OP Mainnet?
# Category: 4
# Question: What is address aliasing and why is it important on OP Mainnet?
# Category: 4
# Question: How can I access information from the latest L1 block while working on OP Mainnet?
# Category: 4
# Question: Where can I find information about setting up nodes for Optimism?
# Category: 4
# Question: How can I find the addresses of OP Mainnet contracts?
# Category: 4
# Question: How do I install the package needed to interact with OP Mainnet contracts in a JavaScript or TypeScript project?
# Category: 4
# Question: How is testing decentralized applications on OP Mainnet different from testing on Ethereum?
# Category: 4
# Question: What should I do if my decentralized application relies on other contracts like Uniswap?
# Category: 3
# Question: Why might my transaction get stuck on the Optimism network?
# Category: 4
# Question: Why don't deposit transactions on Optimism have a chainID?
# Category: 4
# Question: Where can I find videos to help me get started with developing on OP Mainnet?
# Category: 4
# Question: What topics were covered by OP Labs' CEO Liam Horne at ETHDenver 2023?
# Category: 6
# Question: What is the OP Stack and what does the Bedrock release enable?
# Category: 4
# Question: How much RAM is recommended for building an Optimism node?
# Category: 4
# Question: What storage capacity is needed for an OP Mainnet node?
# Category: 4
# Question: What software do I need to install to build an Optimism node?
# Category: 4
# Question: How much storage space do I need to download the data directory for `op-geth`?
# Category: 4
# Question: Why is it important to check the validity of the downloaded data directory?
# Category: 4
# Question: What should I do if I want to reduce the chance of my data directory being corrupted during download?
# Category: 4
# Question: What is the difference between migrated and non-migrated networks in Optimism?
# Category: 4
# Question: How can I estimate the time it will take to synchronize my node?
# Category: 4
# Question: Where can I find the latest releases for Optimism?
# Category: 4
# Question: How does the Optimism Collective plan to fund public goods?
# Category: 2
# Question: Who was eligible for Optimism's Airdrop #1?
# Category: 5
# Question: When was the snapshot for Airdrop #1 taken?
# Category: 4
# Question: What should I do if I missed out on Airdrop #1?
# Category: 3
# Question: How many OP tokens were distributed in Optimism's Airdrop #2?
# Category: 4
# Question: Do I need to claim my tokens for Airdrop #2?
# Category: 3
# Question: What are the criteria for receiving rewards in Airdrop #2?
# Category: 4
# Question: How many unique addresses received tokens in Airdrop 3?
# Category: 4
# Question: What are the eligibility criteria for receiving tokens in Airdrop 3?
# Category: 3
# Question: How can I claim my Airdrop #4 rewards?
# Category: 3
# Question: What are the bonus attributes for Airdrop #4 and how do they affect the rewards?
# Category: 4
# Question: What is the purpose of the Ecosystem Fund in Optimism?
# Category: 2
# Question: What are Retroactive Public Goods Funding (RetroPGF) rounds?
# Category: 4
# Question: How does the Citizens' House contribute to the governance of the Optimism Collective?
# Category: 2
# Question: How is the scope and voting process for Retro Funding determined?
# Category: 2
# Question: How does the Citizens' House in Optimism differ from the Token House?
# Category: 4
# Question: What is the purpose of the AttestationStation in Optimism's governance?
# Category: 2
# Question: How is Citizenship in the Citizens' House expected to evolve over time?
# Category: 5
# Question: How can I find out who my current delegate is and see their voting record?
# Category: 3
# Question: Where can I find information about specific delegates, such as their share of the votes?
# Category: 4
# Question: How can I participate in Token House governance without a significant time commitment?
# Category: 2
# Question: What should I be familiar with before deciding to become a delegate?
# Category: 2
# Question: What is the first step to becoming a delegate?
# Category: 2
# Question: How does the Optimism Collective generate value for its ecosystem?
# Category: 6
# Question: How does funding public goods drive demand for blockspace in the Optimism ecosystem?
# Category: 2
# Question: How can I participate in general governance discussions for Optimism?
# Category: 2
# Question: What should I do if I am a Top 100 delegate in Optimism?
# Category: 2
# Question: When do the community calls for Optimism governance take place?
# Category: 2
# Question: How can I get funding for a project I want to build on Optimism?
# Category: 1
# Question: What are the different types of grants available through Optimism?
# Category: 4
# Question: How do I apply for a Mission Grant on Optimism?
# Category: 1
# Question: How much of the total initial token supply is allocated to the Governance Fund?
# Category: 2
# Question: What is the main goal of the Governance Fund?
# Category: 2
# Question: Can projects that have already received a grant apply for more funding?
# Category: 2
# Question: Why should I delegate my OP tokens?
# Category: 6
# Question: What should I do if I want to vote myself?
# Category: 2
# Question: Is the Law of Chains a legally binding contract?
# Category: 7
# Question: What should I do if I believe Participant Protections have been violated?
# Category: 2
# Question: Does the Law of Chains create any formal relationships among participants?
# Category: 2
# Question: Where can I find videos related to Optimism governance?
# Category: 4
# Question: What is 'The Iterative Nature of Optimism Governance' video about?
# Category: 2
# Question: What is 'The Collective DAO Archive' and where can I access it?
# Category: 4
# Question: Do I need to hold a minimum amount of tokens to submit a proposal?
# Category: 2
# Question: What types of proposals can I submit besides grant proposals?
# Category: 2
# Question: How much funding was allocated in the first round of Retroactive Public Goods Funding by the Optimism Collective?
# Category: 2
# Question: How many projects were awarded funding in the first round of Retro Funding?
# Category: 1
# Question: Can you explain what RetroPGF Round 2 is?
# Category: 4
# Question: How were the badgeholders for RetroPGF Round 2 selected?
# Category: 5
# Question: What was the process for nominating and evaluating projects in RetroPGF Round 2?
# Category: 2
# Question: What types of contributions are eligible for RetroPGF?
# Category: 3
# Question: Do Retro Funding rewards have a lock-up period?
# Category: 4
# Question: How does the voting schedule work in Optimism's Token House governance?
# Category: 2
# Question: What happens during the Reflection Periods in Optimism's governance?
# Category: 2
# Question: Where can I find up-to-date information about the seasons and voting cycles in Optimism's governance?
# Category: 2
# Question: How long will the Working Constitution of the Optimism Collective remain in effect?
# Category: 2
# Question: What will happen after the Working Constitution's period ends?
# Category: 2
# Question: Where can I find the current governance processes for the Token House?
# Category: 2
# Question: Who oversees the activities of the Optimism Foundation?
# Category: 2
# Question: What is the main purpose of the Optimism Foundation?
# Category: 2
# Question: How does the Optimism Foundation ensure it remains accountable to the community?
# Category: 2
# Question: Where can I get testnet ETH for OP Mainnet?
# Category: 3
# Question: Why should I consider using the Standard bridge before developing a custom bridge?
# Category: 4
# Question: What are the requirements for adding a custom bridge for ERC20 tokens to the Superchain token list?
# Category: 4
# Question: How do I connect to the OP Mainnet?
# Category: 4
# Question: Are the token addresses on OP Mainnet the same as on Ethereum?
# Category: 4
# Question: Can I create NFTs on the OP Mainnet without knowing how to code?
# Category: 3
# Question: What are some popular marketplaces where I can buy or sell NFTs on the OP Mainnet?
# Category: 4
# Question: Are there any tools available to use NFTs as collateral on the OP Mainnet?
# Category: 4
# Question: How can I get test tokens on the OP Goerli network?
# Category: 3
# Question: What are the different states a transaction can be in on OP Mainnet?
# Category: 4
# Question: Why is decentralized identity important?
# Category: 4
# Question: What role does decentralized identity play in the Optimism Collective?
# Category: 2
# Question: How does the AttestationStation contribute to decentralized identity?
# Category: 4
# Question: Can you give me an example of an application that uses the AttestationStation on Optimism?
# Category: 4
# Question: What is the purpose of the Citizen Attestations application?
# Category: 4
# Question: What can I do with the Attest Fest application?
# Category: 3
# Question: Can I still use AttestationStation v0 for my project?
# Category: 4
# Question: What information do I need to search for an attestation?
# Category: 4
# Question: Where can I find the AttestationStation v0 contract?
# Category: 4
# Question: How can I read and write attestations on the Optimism network?
# Category: 4
# Question: Where can I find the Attestation Contract address for OP Mainnet?
# Category: 4
# Question: What are the privacy considerations when using attestations?
# Category: 4
# Question: Are attestations a replacement for verifiable credentials or proof of personhood?
# Category: 4
# Question: What is the role of the AttestationStation?
# Category: 4
# Question: What does Sybil-resistance mean?
# Category: 4
# Question: Can anyone create an Optimist Profile?
# Category: 3
# Question: What is the purpose of the Optimist Profile?
# Category: 4
# Question: What kind of data is used to build an Optimist Profile?
# Category: 4
# Question: What's the purpose of schemas in Optimism Governance?
# Category: 2
# Question: What is the Ethereum Attestation Service used for in Optimism?
# Category: 4
# Question: Why is simplicity important in the design of Optimism?
# Category: 4
# Question: How does pragmatism influence the development of Optimism?
# Category: 3
# Question: What is the long-term vision for sustainability in Optimism?
# Category: 2
# Question: How does Optimism ensure the security of its blockchain?
# Category: 4
# Question: What is the role of the sequencer in Optimism?
# Category: 4
# Question: How does Optimism plan to improve its fault proof mechanism?
# Category: 4
# Question: What steps is Optimism taking to decentralize the sequencer?
# Category: 2
# Question: Can Optimism currently censor user transactions?
# Category: 4
# Question: How does a deposit transaction work in Optimism?
# Category: 4
# Question: What happens if a deposit transaction fails on L2?
# Category: 4
# Question: How does Optimism prevent denial of service (DoS) attacks with deposit transactions?
# Category: 4
# Question: How does the Optimism blockchain handle communication between Layer 1 and Layer 2?
# Category: 4
# Question: What is the purpose of the L2OutputOracle contract in Optimism?
# Category: 4
# Question: What is the function of the SequencerFeeVault contract?
# Category: 4
# Question: Why am I being redirected when I try to access the sequencing documentation on Optimism's website?
# Category: 4
# Question: How does a rollup transaction get written to Ethereum (L1)?
# Category: 4
# Question: What happens after a rollup transaction is executed?
# Category: 4
# Question: When is a transaction considered finalized and irrevocable?
# Category: 4
# Question: How does a withdrawal work in Optimism?
# Category: 4
# Question: How does Optimism's gas cost estimation differ from Ethereum's?
# Category: 4
# Question: What are the ways to access Optimism services?
# Category: 4
# Question: How can I report a bug or suggest a feature for the Optimism SDK?
# Category: 3
# Question: Is there an SDK available for Optimism through Alchemy?
# Category: 4
# Question: Where can I find a quickstart guide for the Alchemy SDK?
# Category: 4
# Question: How can the OP Stack Client SDK help me with gas costs on OP Mainnet?
# Category: 4
# Question: Can I use the OP Stack Client SDK with multiple OP Chains?
# Category: 4
# Question: Where can I find tutorials for using the OP Stack Client SDK?
# Category: 4
# Question: Who manages the security of OP Mainnet?
# Category: 4
# Question: Are there any risks associated with using OP Mainnet?
# Category: 4
# Question: Does OP Mainnet currently have fault proofs?
# Category: 4
# Question: How does Optimism handle security and bug reporting?
# Category: 4
# Question: Where can I find detailed information about Optimism's bug bounty program?
# Category: 4
# Question: What should I do if I find a bug that is not covered by Optimism's existing bug bounty programs?
# Category: 3
# Question: Why are there still privileged roles in OP Mainnet?
# Category: 2
# Question: What is the role of the Batcher in OP Mainnet?
# Category: 4
# Question: What happens if the MintManager Owner account is compromised?
# Category: 2
# Question: How can I connect to an Optimism node?
# Category: 4
# Question: Where can I get ETH for deployment gas fees on OP Mainnet?
# Category: 3
# Question: What tools are available for monitoring my app on OP Mainnet?
# Category: 4
# Question: How does account abstraction improve user experience in dapps?
# Category: 4
# Question: Is it cheaper to deploy a contract wallet on Optimism compared to Ethereum Mainnet?
# Category: 4
# Question: What tools are available on OP Mainnet to support account abstraction?
# Category: 4
# Question: Can I use standard Ethereum debugging tools with OP Mainnet?
# Category: 4
# Question: What is Tenderly and how can it help me with transactions on OP Mainnet?
# Category: 4
# Question: Where can I see events and revert messages for transactions on OP Mainnet?
# Category: 4
# Question: Where can I find detailed transaction information for the Optimism network?
# Category: 4
# Question: How can I access older transaction history on Optimism?
# Category: 4
# Question: What tools are available for debugging transactions on Optimism?
# Category: 4
# Question: How can I get testnet ETH to deploy a smart contract on OP Sepolia?
# Category: 3
# Question: Do testnet tokens have any real value?
# Category: 4
# Question: What are some additional faucets where I can get testnet ETH for OP Goerli?
# Category: 4
# Question: Can you explain what meta-transactions are?
# Category: 4
# Question: Why is OP Mainnet a good place for meta-transactions?
# Category: 4
# Question: What is the Gas Station Network (OpenGSN) and how does it work?
# Category: 4
# Question: Where can I check the current status of the OP Mainnet?
# Category: 4
# Question: How can I find detailed information about transactions on OP Mainnet?
# Category: 4
# Question: Is there a way to monitor gas prices on Optimism?
# Category: 4
# Question: Can I use the public HTTP endpoint for production systems on Optimism Mainnet?
# Category: 4
# Question: What is the Chain ID for the Optimism Goerli test network?
# Category: 4
# Question: Where can I find the list of contract addresses for the OP Sepolia test network?
# Category: 4
# Question: How do oracles help blockchain applications access offchain data?
# Category: 4
# Question: What is the difference between push oracles and pull oracles?
# Category: 4
# Question: What is the role of the Gas Price Oracle on OP Mainnet?
# Category: 4
# Question: Which API providers offer free access to Optimism Mainnet nodes?
# Category: 4
# Question: Are there any API providers that support both OP Mainnet and OP Goerli?
# Category: 4
# Question: Which API provider offers the highest number of free API calls per month?
# Category: 4
# /var/folders/k0/xzzz067529g7g_xcf607pyx00000gn/T/ipykernel_5700/2761392749.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_clean['cluster'] = [clusters[q] for q in test_clean['question']]
#      fragment                                           question  \
# 0           0  How can I get developer support for my project...
# 1           0  How can I promote my project once it's deploye...
# 2           0  What should I do if I want to apply for a Gove...
# 3           1  How can I get involved in the Optimism Collect...
# 4           1  What is RetroPGF and why is it important for O...
# ..        ...                                                ...
# 291       102  What is the difference between push oracles an...
# 292       102  What is the role of the Gas Price Oracle on OP...
# 293       103  Which API providers offer free access to Optim...
# 294       103  Are there any API providers that support both ...
# 295       103  Which API provider offers the highest number o...
#
#                                                 answer  \
# 0    To get developer support for your project on O...
# 1    Once your project is deployed on the Superchai...
# 2    If you want to apply for a Governance Grant, f...
# 3    You can get involved in the Optimism Collectiv...
# 4    RetroPGF is a core part of Optimism’s vision a...
# ..                                                 ...
# 291  Push oracles are updated continuously and alwa...
# 292  The Gas Price Oracle on OP Mainnet provides in...
# 293  Several API providers offer free access to Opt...
# 294  Yes, several API providers support both OP Mai...
# 295  BlockPI offers the highest number of free API ...
#
#                                          fragment_text cluster
# 0    ---\ntitle: How do I get project support (mark...       1
# 1    ---\ntitle: How do I get project support (mark...       6
# 2    ---\ntitle: How do I get project support (mark...       2
# 3    ---\ntitle: Contribute to Optimism\nlang: en-U...       6
# 4    ---\ntitle: Contribute to Optimism\nlang: en-U...       4
# ..                                                 ...     ...
# 291  ---\ntitle: Oracles\nlang: en-US\n---  \n[Orac...       4
# 292  ---\ntitle: Oracles\nlang: en-US\n---  \n[Orac...       4
# 293  ---\ntitle: Node & API Providers\nlang: en-US\...       4
# 294  ---\ntitle: Node & API Providers\nlang: en-US\...       4
# 295  ---\ntitle: Node & API Providers\nlang: en-US\...       4
#
# [244 rows x 5 columns]

# %%
test_clean['cluster'].value_counts()
# Out:
# cluster
# 4    156
# 2     42
# 3     21
# 6     14
# 1      5
# 5      5
# 7      1
# Name: count, dtype: int64

# %%
"""
1. project support;
2. governance;
3. dev;
4. tech documentation;
5. general documentation;
6. marketing / promotion / ambassadors / events / PR;
7. other.
"""
labels_dict = {
    "1": "project support",
    "2": "governance",
    "3": "dev",
    "4": "tech documentation",
    "5": "general documentation",
    "6": "marketing / promotion / ambassadors / events / PR",
    "7": "other"
}

test_clean['cluster'] = test_clean['cluster'].map(labels_dict)
test_clean
# Out:
# /var/folders/k0/xzzz067529g7g_xcf607pyx00000gn/T/ipykernel_5700/3295243717.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_clean['cluster'] = test_clean['cluster'].map(labels_dict)
#      fragment                                           question  \
# 0           0  How can I get developer support for my project...
# 1           0  How can I promote my project once it's deploye...
# 2           0  What should I do if I want to apply for a Gove...
# 3           1  How can I get involved in the Optimism Collect...
# 4           1  What is RetroPGF and why is it important for O...
# ..        ...                                                ...
# 291       102  What is the difference between push oracles an...
# 292       102  What is the role of the Gas Price Oracle on OP...
# 293       103  Which API providers offer free access to Optim...
# 294       103  Are there any API providers that support both ...
# 295       103  Which API provider offers the highest number o...
#
#                                                 answer  \
# 0    To get developer support for your project on O...
# 1    Once your project is deployed on the Superchai...
# 2    If you want to apply for a Governance Grant, f...
# 3    You can get involved in the Optimism Collectiv...
# 4    RetroPGF is a core part of Optimism’s vision a...
# ..                                                 ...
# 291  Push oracles are updated continuously and alwa...
# 292  The Gas Price Oracle on OP Mainnet provides in...
# 293  Several API providers offer free access to Opt...
# 294  Yes, several API providers support both OP Mai...
# 295  BlockPI offers the highest number of free API ...
#
#                                          fragment_text  \
# 0    ---\ntitle: How do I get project support (mark...
# 1    ---\ntitle: How do I get project support (mark...
# 2    ---\ntitle: How do I get project support (mark...
# 3    ---\ntitle: Contribute to Optimism\nlang: en-U...
# 4    ---\ntitle: Contribute to Optimism\nlang: en-U...
# ..                                                 ...
# 291  ---\ntitle: Oracles\nlang: en-US\n---  \n[Orac...
# 292  ---\ntitle: Oracles\nlang: en-US\n---  \n[Orac...
# 293  ---\ntitle: Node & API Providers\nlang: en-US\...
# 294  ---\ntitle: Node & API Providers\nlang: en-US\...
# 295  ---\ntitle: Node & API Providers\nlang: en-US\...
#
#                                                cluster
# 0                                      project support
# 1    marketing / promotion / ambassadors / events / PR
# 2                                           governance
# 3    marketing / promotion / ambassadors / events / PR
# 4                                   tech documentation
# ..                                                 ...
# 291                                 tech documentation
# 292                                 tech documentation
# 293                                 tech documentation
# 294                                 tech documentation
# 295                                 tech documentation
#
# [244 rows x 5 columns]

# %% [markdown]
# # Remove questions that are too similar to the ones we had

# %%
# load csv
old_questions = pd.read_csv("../001_questions_per_section/cleaned_test_dataset_with_clusters.csv").question.to_list()

new_questions = test_clean.question.to_list()

# all
all_questions = old_questions + new_questions

# %%
# embeddings
all_questions_emb = embeddings.embed_documents(all_questions)
all_questions_emb = np.array(all_questions_emb)

# remove the new questions that are too similar to the old ones
cleaned_all_questions, cleaned_all_questions_emb = rm_too_similar_questions(all_questions, all_questions_emb, tresh = 0.2)

cleaned_all_questions
# Out:
# How can I get support for my project on Optimism?
# How can I get developer support for my project on Optimism?
# ----
# How can I get involved in the Optimism Collective?
# How can I get involved in the Optimism Collective?
# ----
# What is the Optimism Collective's approach to building public goods?
# How does the Optimism Collective plan to fund public goods?
# ----
# What is RetroPGF and why is it important to Optimism?
# What is RetroPGF and why is it important for Optimism?
# ----
# How can I contribute directly to the Optimism codebase?
# How can I start contributing to the Optimism codebase?
# ----
# How can I become a support NERD for Optimism?
# How can I become a support NERD in the Optimism community?
# ----
# Why are schemas important in Optimism Governance?
# What's the purpose of schemas in Optimism Governance?
# ----
# Where can I find more information about the NumbaNERDs program?
# Where can I find more information about the NumbaNERDs program?
# ----
# How can I participate in the TechNERDs program?
# How can I get involved in the TechNERDs program?
# ----
# How can I contribute to translating Optimism's User Docs?
# How can I contribute to translating Optimism's User Docs?
# ----
# Is there any reward for translating Optimism's documents?
# Is there any reward for translating documents for Optimism?
# ----
# Why does Optimism emphasize translations?
# Why does Optimism emphasize translations?
# ----
# Are there any rewards for contributing to the Optimism project?
# Are there any rewards for contributing to the Optimism project?
# ----
# Where can I find resources to deploy a basic contract on OP Mainnet?
# Where can I find a guide to deploy a basic contract on OP Mainnet?
# ----
# Is deploying a contract on OP Mainnet different from deploying on Ethereum?
# Is deploying a contract on OP Mainnet different from deploying on Ethereum?
# ----
# How can I move tokens from Ethereum to OP Mainnet?
# How can I move tokens between OP Mainnet and Ethereum?
# ----
# What's Bedrock in the context of Optimism?
# What's Bedrock in the context of Optimism?
# ----
# How does Bedrock reduce transaction fees?
# How does Bedrock improve transaction fees?
# ----
# How does a deposited transaction work in Optimism?
# How does a deposit transaction work in Optimism?
# ----
# What's the role of a sequencer in the Optimism network?
# What is the role of the sequencer in Optimism?
# ----
# What is the `L2OutputOracle` contract in Optimism?
# What is the purpose of the L2OutputOracle contract in Optimism?
# ----
# What are the minimum system requirements to run Bedrock?
# What are the minimum system requirements to run Bedrock?
# ----
# Do I need to run Legacy Geth for all Optimism networks?
# Do I need to run Legacy Geth for all Optimism networks?
# ----
# Where can I find information about the Optimism Goerli network?
# Where can I find information about the Optimism Goerli network?
# ----
# Where can I find more detailed information about Bedrock Mission Control for Optimism?
# Where can I find more detailed information about Bedrock Mission Control for Optimism?
# ----
# How are transaction fees structured in OP Mainnet?
# What are the components of the transaction fees on OP Mainnet?
# ----
# What is bridging in the context of OP Mainnet and Ethereum?
# What is bridging in the context of OP Mainnet and Ethereum?
# ----
# What should I do if I need to rely on the L2 state before the fault challenge period ends?
# How can I ensure the L2 state is correct before the fault challenge period passes?
# ----
# How can apps on OP Mainnet interact with apps on Ethereum?
# How can apps on OP Mainnet interact with apps on Ethereum?
# ----
# How can I deposit ERC20 tokens into Optimism Layer 2?
# How can I transfer my ERC20 tokens between Layer 1 and Layer 2 on Optimism?
# ----
# How does the cost of using a decentralized application on OP Mainnet compare to using one on L1 Ethereum?
# How does the cost of using a decentralized application on OP Mainnet compare to using one on L1 Ethereum?
# ----
# Why are transaction costs on OP Mainnet different from those on Ethereum?
# Are there any differences in transaction costs between Ethereum and OP Mainnet?
# ----
# Why should I use a local development environment for OP Mainnet?
# Why would I need to run a local development environment for OP Mainnet?
# ----
# Are there any differences in testing decentralized applications on OP Mainnet compared to Ethereum?
# How is testing decentralized applications on OP Mainnet different from testing on Ethereum?
# ----
# Why don't deposit transactions on Optimism's L2 have a chainID?
# Why don't deposit transactions on Optimism have a chainID?
# ----
# Where can I find governance videos for Optimism?
# Where can I find videos related to Optimism governance?
# ----
# How much storage space do I need to download the data directory for `op-geth`?
# How much storage space do I need to download the data directory for `op-geth`?
# ----
# What should I do if I want to reduce the chance of my data directory being corrupted during the download?
# What should I do if I want to reduce the chance of my data directory being corrupted during download?
# ----
# What's the difference between Migrated and Non-Migrated Networks in Optimism?
# What is the difference between migrated and non-migrated networks in Optimism?
# ----
# Where can I find the latest releases for Optimism?
# Where can I find the latest releases for Optimism?
# ----
# Who is eligible for the Optimism Foundation’s Airdrop #1?
# Who was eligible for Optimism's Airdrop #1?
# ----
# What should I do if I missed Airdrop #1?
# What should I do if I missed out on Airdrop #1?
# ----
# How many OP tokens were distributed in Optimism’s Airdrop #1 and to how many users?
# How many OP tokens were distributed in Optimism's Airdrop #2?
# ----
# Who was eligible to receive tokens in Airdrop 3?
# What are the eligibility criteria for receiving tokens in Airdrop 3?
# ----
# How can I claim Airdrop #4?
# How can I claim my Airdrop #4 rewards?
# ----
# What is the purpose of the Ecosystem Fund in the Optimism Collective?
# What is the purpose of the Ecosystem Fund in Optimism?
# ----
# How many unique addresses received tokens in Airdrop 3?
# How many unique addresses received tokens in Airdrop 3?
# ----
# How often are Retroactive Public Goods Funding (RetroPGF) rounds expected to occur?
# What are Retroactive Public Goods Funding (RetroPGF) rounds?
# ----
# How does the Citizens' House in Optimism differ from the Token House?
# How does the Citizens' House in Optimism differ from the Token House?
# ----
# How can I find out who my current delegate is and see their voting record?
# How can I find out who my current delegate is and see their voting record?
# ----
# Where can I find information about specific delegates, such as their share of the votes?
# Where can I find information about specific delegates, such as their share of the votes?
# ----
# How can I participate in Token House governance without a significant time commitment?
# How can I participate in Token House governance without a significant time commitment?
# ----
# How does the Optimism Collective generate value for tokenholders?
# How does the Optimism Collective generate value for its ecosystem?
# ----
# When and where do community calls for Optimism governance take place?
# When do the community calls for Optimism governance take place?
# ----
# Is the Law of Chains a legally binding contract?
# Is the Law of Chains a legally binding contract?
# ----
# What should I do if I believe Participant Protections have been violated?
# What should I do if I believe Participant Protections have been violated?
# ----
# Do I need to hold a minimum amount of tokens to submit a proposal?
# Do I need to hold a minimum amount of tokens to submit a proposal?
# ----
# Who were the badgeholders in RetroPGF Round 1?
# How were the badgeholders for RetroPGF Round 2 selected?
# ----
# What's the reflection period in Optimism governance?
# What happens during the Reflection Periods in Optimism's governance?
# ----
# How long will the Working Constitution of the Optimism Collective be in effect?
# How long will the Working Constitution of the Optimism Collective remain in effect?
# ----
# What will happen after the Working Constitution's period ends?
# What will happen after the Working Constitution's period ends?
# ----
# Where can I find the current governance processes for the Token House?
# Where can I find the current governance processes for the Token House?
# ----
# Where can I get testnet ETH for OP Mainnet?
# Where can I get testnet ETH for OP Mainnet?
# ----
# Why should I consider using the standard bridge before developing a custom bridge solution?
# Why should I consider using the Standard bridge before developing a custom bridge?
# ----
# What are the states a transaction can be in on OP Mainnet?
# What are the different states a transaction can be in on OP Mainnet?
# ----
# What is the role of the AttestationStation in decentralized identity?
# How does the AttestationStation contribute to decentralized identity?
# ----
# What information do I need to look for a specific attestation?
# What information do I need to search for an attestation?
# ----
# What is the purpose of the AttestationStation?
# What is the role of the AttestationStation?
# ----
# Can anyone create an Optimist Profile?
# Can anyone create an Optimist Profile?
# ----
# What is the purpose of an Optimist Profile?
# What is the purpose of the Optimist Profile?
# ----
# Can Optimism censor user transactions?
# Can Optimism currently censor user transactions?
# ----
# What is the plan for decentralizing the sequencer on Optimism?
# What steps is Optimism taking to decentralize the sequencer?
# ----
# How does Optimism handle communication between Layer 1 and Layer 2?
# How does the Optimism blockchain handle communication between Layer 1 and Layer 2?
# ----
# Why am I being redirected when I try to access the sequencing documentation on Optimism's website?
# Why am I being redirected when I try to access the sequencing documentation on Optimism's website?
# ----
# How is a rollup transaction written to the Ethereum blockchain?
# How does a rollup transaction get written to Ethereum (L1)?
# ----
# How does gas cost estimation differ between Ethereum and Optimism?
# How does Optimism's gas cost estimation differ from Ethereum's?
# ----
# What are the ways to access Optimism-specific services?
# What are the ways to access Optimism services?
# ----
# How can I report a bug or suggest a feature for the Optimism SDK?
# How can I report a bug or suggest a feature for the Optimism SDK?
# ----
# Is there a quickstart guide available for the Alchemy SDK?
# Where can I find a quickstart guide for the Alchemy SDK?
# ----
# Does the OP Stack Client SDK support multiple OP Chains?
# Can I use the OP Stack Client SDK with multiple OP Chains?
# ----
# How is the security of OP Mainnet managed?
# Who manages the security of OP Mainnet?
# ----
# Are there any risks associated with using OP Mainnet?
# Are there any risks associated with using OP Mainnet?
# ----
# Are there any privileged roles in OP Mainnet?
# Why are there still privileged roles in OP Mainnet?
# ----
# Is it cheaper to deploy a contract wallet on Optimism compared to Ethereum Mainnet?
# Is it cheaper to deploy a contract wallet on Optimism compared to Ethereum Mainnet?
# ----
# How can account abstraction improve the user experience for dapps and wallets?
# How does account abstraction improve user experience in dapps?
# ----
# Can I use the same debugging tools on OP Mainnet that I use on Ethereum?
# Can I use standard Ethereum debugging tools with OP Mainnet?
# ----
# Where can I find detailed transaction information for Optimism testnets?
# Where can I find detailed transaction information for the Optimism network?
# ----
# How can I get testnet Ether (ETH) for deploying a smart contract on OP Sepolia?
# How can I get testnet ETH to deploy a smart contract on OP Sepolia?
# ----
# How do meta-transactions work?
# Can you explain what meta-transactions are?
# ----
# Why is OP Mainnet a good place for meta-transactions?
# Why is OP Mainnet a good place for meta-transactions?
# ----
# Where can I check the status of the OP Mainnet?
# Where can I check the current status of the OP Mainnet?
# ----
# What's the difference between push oracles and pull oracles?
# What is the difference between push oracles and pull oracles?
# ----
# Why am I being redirected when I try to access the sequencing documentation on Optimism's website?
# Why am I being redirected when I try to access the sequencing documentation on Optimism's website?
# ----
# How can I report a bug or suggest a feature for the Optimism SDK?
# How can I report a bug or suggest a feature for the Optimism SDK?
# ----
# Are there any risks associated with using OP Mainnet?
# Are there any risks associated with using OP Mainnet?
# ----
# Is it cheaper to deploy a contract wallet on Optimism compared to Ethereum Mainnet?
# Is it cheaper to deploy a contract wallet on Optimism compared to Ethereum Mainnet?
# ----
# Why is OP Mainnet a good place for meta-transactions?
# Why is OP Mainnet a good place for meta-transactions?
# ----
# ['How can I get support for my project on Optimism?',
#  'What should I do before deploying my project on OP Mainnet?',
#  'Where can I find tutorials for developing on Optimism?',
#  'Is there a Discord channel for developer support for Optimism?',
#  'How can I get my project listed on the Superchain apps page?',
#  "Is there a way to promote my app launch through Superchain's marketing channels?",
#  'How does Optimism support projects that align with its values?',
#  'How does Optimism decide which tweets to retweet?',
#  'Can I submit my tweet to Optimism for retweeting?',
#  'What other interactions does Optimism have with tweets besides retweeting?',
#  'How can I participate in OP Radio?',
#  'What is the format of OP Radio?',
#  'How can I apply for a grant from Optimism?',
#  'What should I do to deploy my project on Optimism?',
#  'How can I learn about the origins of Optimism?',
#  'What are some upcoming changes to the Optimism protocol?',
#  'Is there a way for developers to deploy their own app-specific rollup on Optimism?',
#  'How can I get involved in the Optimism Collective?',
#  "What is the Optimism Collective's approach to building public goods?",
#  'What is RetroPGF and why is it important to Optimism?',
#  'How can I contribute to Optimism if I speak more than one language?',
#  'Is there a way to help improve the Optimism documentation?',
#  'Are there any community events for Optimism enthusiasts?',
#  'Where can I find data that Optimism uses for decision making?',
#  'How can I get involved if I am good with numbers?',
#  'Are there any resources to help me understand how to contribute to OP rewards analytics?',
#  "How can I start developing on Optimism if I'm a dapp developer?",
#  'Where can I find ideas for projects to build on Optimism?',
#  'How can I contribute directly to the Optimism codebase?',
#  "How can I start getting involved in Optimism's governance?",
#  "What is the Citizens House in Optimism's governance?",
#  'How can I contribute to the Optimism Vision if I have skills in writing or design?',
#  'What options do I have to market my project within the Optimism community?',
#  'Who can become an Ambassador for Optimism?',
#  'Is the Ambassador program documentation final?',
#  'What kind of content do Optimism Ambassadors create?',
#  'What sustainability initiatives do Optimism Ambassadors support?',
#  'What should I do to get up to speed as a wannabe-ambassador?',
#  'How can I advance to the `ambassador-in-training` role?',
#  'How does one progress through the ambassador roles in Optimism Governance?',
#  'What kind of content do I need to create to become an ambassador?',
#  'Where do I submit my application and content for the ambassador role?',
#  'How long do you need to be an active ambassador-in-training before becoming an ambassador?',
#  'What kind of contributions are reviewed when voting on a new ambassador?',
#  'Can I discuss the price of the OP token in my content?',
#  'What types of content can I create to demonstrate my understanding of Optimism?',
#  'Is there a requirement for non-English content submissions?',
#  'How long can I be inactive before being removed from the program?',
#  'What happens if I receive multiple warnings?',
#  'What are the consequences of severe violations?',
#  'Are there any specific rules for ambassadors in the Optimism community?',
#  'What happens if an ambassador in the Optimism community gets three warnings?',
#  "Can I share someone else's content in the Optimism community?",
#  'Can Optimism Ambassadors share sensitive information they receive before it becomes public?',
#  'What happens if an Optimism Ambassador impersonates a creator or team member?',
#  'Is it acceptable for Optimism Ambassadors to engage in pump and dump schemes?',
#  'How can becoming a support NERD benefit the community?',
#  'Is the document on becoming a support NERD final and unchanging?',
#  'Will becoming a support NERD make me famous?',
#  'How can I become a support NERD for Optimism?',
#  'What are the key values a support NERD should believe in?',
#  'How should support NERDs interact with users on Discord?',
#  'What should I do if I find outdated information or broken links in the Optimism documentation?',
#  'What are some ways I can offer support in the Optimism Discord?',
#  'What information should I include when introducing myself to the Optimism community?',
#  'What should I include in my message when posting proof of meeting the requirements in the `#wannabe-NERD` channel?',
#  'How long do I need to offer support before becoming a `support-NERD`?',
#  'Can a NERD lose their role for scamming or spamming?',
#  'What happens if a NERD is rude to users?',
#  'Are NERDs given sensitive information?',
#  'How does the Optimism Foundation view identity and reputation within its community?',
#  'What is the purpose of the document on identity and attestations?',
#  'Why is robust user and project identity important for the Optimism Collective?',
#  'What are some pitfalls to avoid when building an identity/reputation network for the Optimism Collective?',
#  'What is the approach towards defining Citizenship in Optimism Governance?',
#  'What should be considered when issuing attestations in Optimism Governance?',
#  'What is important to avoid when aggregating data in Optimism Governance?',
#  'How does the identity stack framework help in understanding identity and reputation in Optimism?',
#  'What is the role of the data interpretation layer in the identity stack framework?',
#  'Why is the identity layer considered the narrowest point in the identity stack framework?',
#  'How should developers approach building identity solutions in the Optimism ecosystem?',
#  "What should developers do if they have an idea that fits within the Optimism identity framework but isn't listed in the current channels?",
#  'Where can developers find specific input and ideas on valuable work within the Optimism Collective?',
#  'How does the Optimism Collective capture important data?',
#  'Who is currently the issuer of attestations about Badgeholders in the Optimism Collective?',
#  'How can attestations be useful when dealing with off-chain data?',
#  'What should I consider if I want to make my attestation private?',
#  'How can I ensure that the data I generate is verifiable by others?',
#  'Do all types of data need to be turned into attestations in Optimism?',
#  'Why is it important to issue relevant attestations in the Collective?',
#  'When is a good moment to issue an attestation?',
#  "What should you consider if you're unsure about issuing an attestation?",
#  'Why is the issuer important in an attestation?',
#  'Who can be an issuer of an attestation?',
#  'Why are schemas important in Optimism Governance?',
#  'What should I do before creating a new schema?',
#  'What are some tips for designing a schema according to the EAS recommendations?',
#  "What's the difference between onchain and offchain attestations?",
#  'Can onchain attestations be deleted?',
#  'Are there any costs associated with onchain attestations?',
#  'When will the program to support local Optimism events be available?',
#  'How does the NumbaNERDs program contribute to the Optimism governance?',
#  'Where can I find more information about the NumbaNERDs program?',
#  'How can I participate in the TechNERDs program?',
#  'Is there a beginner-friendly version of the Optimism curriculum available?',
#  'What is the first step I need to take in the Optimism curriculum?',
#  'How long does it take to sync an OP Goerli Node?',
#  "How can I contribute to translating Optimism's User Docs?",
#  "Is there any reward for translating Optimism's documents?",
#  'Why does Optimism emphasize translations?',
#  "What's the title of the document?",
#  'What language is the document written in?',
#  'How can I see the latest dApps on Optimism?',
#  "How can I apply to showcase my dApp on Optimism's Demo Day?",
#  'Is there a way to get more visibility for my project on Optimism besides Demo Day?',
#  'What should I do before applying for a demo spot?',
#  'Are demo spots limited?',
#  'What should I do if I have never presented in a Discord channel before?',
#  'When should I be available for an audio/video check before Demo Day?',
#  'How can I apply for a slot to present my demo?',
#  'Can I do a giveaway or lotto during my demo?',
#  'Where can I ask specific questions about Optimism?',
#  'Who should I contact for press and media inquiries about Optimism?',
#  'What is the Superchain in Optimism Governance?',
#  'How does the Superchain benefit public goods?',
#  'How does Optimism generate revenue?',
#  'Why is funding public goods important for Optimism?',
#  'What principle does the Optimism Collective follow?',
#  'Where can I find the old brand kit for Optimism?',
#  'What is the Optimism ecosystem?',
#  'What do I need to know to understand the Superchain?',
#  'Which networks have opted into the Superchain as of August 1, 2023?',
#  'Is the Superchain currently operational?',
#  "What's an OP Chain?",
#  'What is the Superchain in the context of OP Chains?',
#  'Who maintains the OP Stack?',
#  'Is the OP Stack open source?',
#  "What's an OP Stack Fork?",
#  'Do OP Stack Forks share security with OP Chains in the Superchain?',
#  "What's OP Mainnet?",
#  'Can I refer to the OP token as $OP?',
#  'Can I refer to OP token grants in terms of their USD value?',
#  'What skills are needed to maintain and evolve the Optimism codebase?',
#  'Are there any rewards for contributing to the Optimism project?',
#  'Where can I find resources to deploy a basic contract on OP Mainnet?',
#  'Are there any tools available to make building on OP Mainnet easier?',
#  'Can I find information on building cross-chain apps in the OP Mainnet developer docs?',
#  'Is deploying a contract on OP Mainnet different from deploying on Ethereum?',
#  'Are there any resources for someone who is already familiar with OP Mainnet and Ethereum?',
#  'How can I deploy my contracts to OP Mainnet or OP Goerli?',
#  'Are there any resources to help me run a local development environment for Optimism?',
#  'Can I run my own OP Mainnet node?',
#  'How can I move tokens from Ethereum to OP Mainnet?',
#  'Is there a way to send data between different chains?',
#  'Does Optimism use the same infrastructure for its own operations?',
#  "What should I do first if I can't find the content I'm looking for in the Optimism documentation?",
#  "What's Bedrock in the context of Optimism?",
#  'Where can I find guidelines to contribute to the OP Stack?',
#  'How does Bedrock reduce transaction fees?',
#  'What improvements does Bedrock make in handling L1 transactions?',
#  'What are some of the technical improvements in Bedrock?',
#  'How does Bedrock help in reducing data costs?',
#  'What is the impact of removing L1 execution gas in Bedrock?',
#  'How long did it take to confirm deposits in earlier versions of the Optimism protocol?',
#  'What improvement does Bedrock bring to the deposit confirmation time in Optimism?',
#  'Does Bedrock support L1 re-orgs in the node software?',
#  'How does Bedrock handle proof systems in the OP Stack?',
#  'What is the purpose of abstracting the proof system in Bedrock?',
#  'What is an example of a system that can be used with Bedrock to prove faults?',
#  'How has the performance of the node software been improved in the latest version?',
#  'What changes have been made to reduce technical debt in the new version of the protocol?',
#  'How does the new model of executing several transactions in a single rollup block benefit the system?',
#  'How does Bedrock compare to Ethereum?',
#  'Why was Bedrock built to be modular and upgradeable?',
#  'Does Bedrock use any existing code from Ethereum?',
#  'How does Bedrock ensure flexibility in the OP Stack?',
#  'What are some examples of the modular design in Bedrock?',
#  'How does Bedrock ensure security in its design?',
#  'How does Bedrock ensure compatibility with the existing Ethereum developer experience?',
#  'What is the purpose of the fault proof in Bedrock?',
#  'How do rollups derive their data?',
#  'What are deposits and withdrawals in the context of rollups?',
#  'What is the role of proof systems in rollups?',
#  "What's a deposit in the context of Optimism?",
#  'How does a deposited transaction work in Optimism?',
#  'Where can I find more details about the deposit contract in Optimism?',
#  "How does the gas burn mechanism work in Optimism's Bedrock?",
#  "What is 'guaranteed gas' in the context of Optimism's Bedrock?",
#  "Why is there a hard cap on the amount of gas provided to deposits in a single L1 block in Optimism's Bedrock?",
#  'How are withdrawals initiated in the Optimism network?',
#  'How does the Bedrock release improve the security of withdrawals in Optimism?',
#  'What is the purpose of the 7-day period in the new withdrawal process?',
#  'Why are withdrawal proof validation bugs significant in the context of bridge hacks?',
#  'How does Bedrock handle messaging between L1 and L2?',
#  'Why is the wire format in Bedrock important?',
#  'How does Optimism optimize data compression for transactions?',
#  'What is the maximum size of a channel in Optimism?',
#  'How are channels submitted to the L1 in Optimism?',
#  "How does Optimism handle large amounts of data when sending it to Ethereum's Layer 1?",
#  "Why is it beneficial for Optimism to send transactions in parallel to Ethereum's Layer 1?",
#  'How does Bedrock handle execution gas for L1 system transactions?',
#  'What happens to invalid batches or individual transactions within a batch in the Bedrock system?',
#  "What is the impact of Ethereum's upcoming EIP-4844 upgrade on posting data to L1?",
#  'How does the Bedrock protocol ensure the timing of deposits on L1 is respected in the L2 chain?',
#  'What is a pure function in the context of the Bedrock protocol?',
#  'How often are L2 blocks created in the Bedrock release?',
#  "What is a sequencing epoch in the context of Optimism's Bedrock?",
#  'How does the protocol ensure that deposits are processed in a logical temporal order?',
#  'What is a sequencing window in the context of Bedrock?',
#  'What is the purpose of the max sequencer drift in Bedrock?',
#  'How does the canonical L2 chain process data from the L1 chain?',
#  'What is the role of channels in the L2 chain processing?',
#  'Why is data decompressed during the L2 chain processing?',
#  'How does Optimism ensure trustless execution of L2-to-L1 messaging?',
#  "What is the purpose of output roots in Optimism's Bedrock?",
#  'What future upgrades are planned for the OP Stack regarding output roots?',
#  'How does Bedrock handle the separation of concerns in the Optimism network?',
#  "What's an execution client in the context of Optimism?",
#  "How does Bedrock in the OP Stack relate to Ethereum's execution client?",
#  'Why does Bedrock have any modifications at all to the Ethereum execution client?',
#  'What standard does the new transaction type for deposited transactions follow?',
#  'How are sequencer fees determined in Optimism rollups?',
#  'What are data availability fees in Optimism rollups?',
#  'How is the data availability fee determined in Bedrock?',
#  "How does Bedrock achieve consensus if it doesn't use proof-of-stake like Ethereum?",
#  'What is a rollup node in Bedrock?',
#  'How does the rollup node communicate with the execution client in Bedrock?',
#  'How does a rollup node verify output roots?',
#  'What is the purpose of the simplest mode of running a rollup node?',
#  "What does 'finalized' mean in the context of a rollup node?",
#  'How do rollup nodes participate in a network?',
#  'What is the difference between the safe L2 head and the unsafe L2 head?',
#  'When do nodes in the L2 network refer to the unsafe L2 head?',
#  'How does a rollup node sequence transactions?',
#  'How many sequencers are there per OP Stack network?',
#  "What is the sequencer's responsibility in relation to L1?",
#  "What's the role of a sequencer in the Optimism network?",
#  'What is a batcher in the context of Optimism?',
#  "How does the bridging process work in Optimism's Bedrock?",
#  'Where can I find more details about the standard bridges in Optimism?',
#  'Where is fault proof construction and verification implemented in Optimism?',
#  "What are the future milestones for Optimism's fault proof system?",
#  'Where can I find the technical details of the OP Stack?',
#  'What is the most up-to-date source for understanding the inner workings of the Optimism protocol?',
#  'Where can I find detailed information about the differences between Bedrock and previous versions of the protocol?',
#  'What does the Bedrock release include?',
#  'Which sections of the Optimism Governance Documentation should a wallet developer focus on?',
#  'What information is important for a Dapp frontend developer in the Optimism Governance Documentation?',
#  'What should an infrastructure provider know from the Optimism Governance Documentation?',
#  'How often are blocks produced in the Bedrock network?',
#  'What is a system transaction in the Bedrock network?',
#  'What should I do if my Ethereum client library cannot parse the `null` signature fields in system transactions?',
#  'How does EIP-1559 affect transaction fees on the Optimism network?',
#  'What are the main differences between Ethereum and OP Mainnet regarding EIP-1559 parameters?',
#  'What new features does EIP-1559 introduce for application developers on Optimism?',
#  'Why was the `L1BLOCKNUMBER` opcode removed in the Bedrock upgrade?',
#  'How were ETH balances represented in the previous version of the Optimism system?',
#  'What will happen to the `OVM_ETH` balances during the migration to the Bedrock network?',
#  'Will the methods on the `OVM_ETH` contract still work after the migration?',
#  'How does Bedrock handle block reorganization?',
#  'What are the different states of blocks in Bedrock?',
#  'How can I query the current state of blocks in Bedrock?',
#  'Can Bedrock nodes provide information about blocks, transactions, and receipts from before the Bedrock update?',
#  'Do I need to run any additional software to access historical execution traces?',
#  'Have any fields been removed from pre-Bedrock JSON-RPC transaction responses?',
#  'How can I get the gas price on Bedrock?',
#  'What should I use instead of the `eth_getBlockRange` method on Bedrock?',
#  'How can I check the sync status of `op-node` on Bedrock?',
#  'How does Bedrock handle pending transactions?',
#  "Why is Bedrock's mempool private?",
#  "How are transactions processed in Bedrock's mempool?",
#  'How long does it take to finalize a withdrawal on the legacy network?',
#  'What is the main security improvement introduced by Bedrock for withdrawals?',
#  'Is the new Bedrock withdrawal process backwards-compatible with the old network?',
#  'Will the changes in the new network be compatible with the old network?',
#  "What happens to deposits on the legacy network that haven't been replayed?",
#  'How many transactions on the mainnet are affected by this change?',
#  'What is the `L2OutputOracle` contract in Optimism?',
#  'How can I send messages between L1 and L2 in Optimism?',
#  'What is the purpose of the OptimismPortal contract?',
#  'Do I need to modify my dapp to run on Bedrock?',
#  'What is the purpose of the L1CrossDomainMessenger contract?',
#  'How does the L1StandardBridge contract transfer assets?',
#  'How can I find the address of the `L1Block` contract in Optimism?',
#  'What kind of information can I get from the `L1Block` contract?',
#  'Why is there a delay in the L1 information provided by the `L1Block` contract?',
#  'How does the SequencerFeeVault contract fund the sequencer on L1?',
#  'How does the `L2ToL1MessagePasser` contract function within the Optimism network?',
#  "What is the purpose of the legacy contract in Optimism's Bedrock version?",
#  'Why are some contracts kept even if they are no longer relevant?',
#  'What was the purpose of the DeployerWhitelist contract?',
#  'What did the OVM_ETH contract do?',
#  'Do deposits in Optimism always involve transferring assets?',
#  'What does a withdrawal mean in the context of Optimism?',
#  'Will the gas costs for communication between layers change?',
#  'Where can I find more information about the new gas costs?',
#  "How can I ensure my deposit transaction on Optimism doesn't run out of gas?",
#  'What happens if the sequencer is down when I make a deposit on Optimism?',
#  'Why do I need to add a buffer to the gas limit for L1 to L2 transactions on Optimism?',
#  'Can you explain what this section of the Optimism documentation is about?',
#  'How are L2 blocks saved to the Ethereum blockchain now?',
#  'Where can I find more information about batch submission addresses for L2 blocks?',
#  'Is the block and transaction format the same as before?',
#  'What should I do if my application needs legacy fields from pre-Bedrock JSON-RPC transaction responses?',
#  'Where can I find more information about running a Legacy Geth instance for historical execution traces?',
#  'How can I get the gas price for transactions on Optimism?',
#  'Is there a way to check the synchronization status of an Optimism node?',
#  'Do I need to configure anything to submit transactions in Bedrock?',
#  'Will the changes in the new Bedrock network be compatible with the old network?',
#  'How many transactions on the mainnet are affected by the need to replay deposits before the migration?',
#  'Where can I find the code for the `L2ToL1MessagePasser` contract?',
#  'Where can I find more technical details about how messages are transferred in Optimism?',
#  'How long does it take for a deposit to be confirmed on Optimism?',
#  'Are there any recent changes in the internal workings of Optimism?',
#  'How can I start developing on OP Mainnet after the Bedrock release?',
#  'How does Bedrock affect L1 execution gas fees?',
#  'How long does it take for deposits to confirm with the new Bedrock update?',
#  'What changes have been made to reduce the technical debt in the node software?',
#  'What are some of the features Bedrock adds to align with Ethereum?',
#  'What deviations from Ethereum were removed in Bedrock?',
#  'What are the primary sources of information for a canonical L2 chain in rollup protocols?',
#  'Are deposits guaranteed to be included in the Layer 2 chain?',
#  'What happens if an invalid withdrawal proof is detected?',
#  'Why is there a 7-day waiting period for withdrawals in the Bedrock release?',
#  'What happens to the channels after they are created in Optimism?',
#  'Why is it beneficial for channel frames to be mutually independent?',
#  "What is the role of the sequencer in Optimism's data submission process?",
#  'What is the batch inbox address in the context of Bedrock?',
#  "What are the key components involved in the Bedrock protocol's block derivation process?",
#  'What is the role of L1 blocks in the L2 chain?',
#  "How are the fees structured in Optimism's Bedrock?",
#  'What is the purpose of the optimism_outputAtBlock method?',
#  'Who is responsible for producing batches in the Optimism network?',
#  'How does the bridge in Optimism work?',
#  'What are the addresses of the legacy and new `L2ToL1MessagePasser` contracts in Bedrock?',
#  'What does the WETH9 contract do?',
#  'How can I monitor the health of the Bedrock `op-node` system?',
#  'How do I enable metrics for the Bedrock `op-node`?',
#  'How can I tell if my node is not syncing properly?',
#  'Why is it important to monitor the number of peers my node is connected to?',
#  "What should I look at if my node's sync performance is slow?",
#  'How can I know if the op node has finished starting up?',
#  "What does the metric 'op_node_default_rpc_server_requests_total' represent?",
#  "What information does the metric 'op_node_default_refs_number' provide?",
#  'How can I learn more about how Bedrock works and its motivations?',
#  'Where can I find instructions to build and run an OP node from source?',
#  'Can you explain the core components of a Bedrock deployment in Optimism?',
#  "Is there any additional component needed for OP Mainnet and OP Goerli in Optimism's Bedrock deployment?",
#  'What are the minimum system requirements to run Bedrock?',
#  'How can I run `op-geth` and `op-node` for Optimism?',
#  'Is it possible to compile `op-geth` and `op-node` from source?',
#  'What version of the old `l2geth` image does Legacy Geth use?',
#  'How should I configure `op-node` and `op-geth` instances?',
#  'What are the steps to configure my node?',
#  'How do I initialize `op-geth` for OP Sepolia?',
#  'What is the difference between initializing `op-geth` with a Genesis File and a Data Directory?',
#  'How much disk space do I need for running an OP Mainnet or OP Goerli node?',
#  'What are the CLI flag requirements for running `op-node` and `op-geth` on OP Sepolia?',
#  'Is the genesis information for OP Sepolia included in the `op-geth` binary?',
#  'What format is the preconfigured data directory exported as?',
#  'What is the purpose of the `--rollup.sequencerhttp` flag?',
#  'How do I generate a JWT secret file for `op-geth`?',
#  'How can I control which hosts are allowed to access the authenticated RPC endpoint in Optimism?',
#  'How do I enable and configure the unauthenticated RPC endpoint in Optimism?',
#  'What is the purpose of the `--verbosity` flag in Optimism?',
#  "Where can I find more information on customizing `op-geth`'s behavior?",
#  'What is the purpose of the `--network` flag in the `op-node` configuration?',
#  'Can I use environment variables instead of command-line flags to configure `op-node`?',
#  'How does the `op-node` participate in the network?',
#  'What is the recommended network setup for running `op-node`?',
#  'What port needs to be open for the peer-to-peer network, and what protocols should it support?',
#  'Do I need to run Legacy Geth for all Optimism networks?',
#  'What is the purpose of the `USING_OVM=true` environment variable?',
#  'Can I customize the configuration of Legacy Geth?',
#  'Do I need to run Legacy Geth for all types of RPC methods?',
#  "What is meant by 'historical execution' in the context of Optimism Governance?",
#  "If I don't need historical data, do I still need to use Legacy Geth?",
#  "Why am I seeing a '401 Unauthorized: signature is invalid' error in my `op-node` logs?",
#  "What should I do if my `op-node` can't find the finalized L2 block?",
#  "Why am I seeing a '403 Forbidden: invalid host specified' error in `op-node` logs?",
#  "How can I fix the 'error getting latest header' in `op-node`?",
#  "Why is my `op-node` application failing with a 'permission denied' error?",
#  "How can I fix the 'failed to open discovery db: mkdir /p2p: permission denied' error in `op-node`?",
#  'How can I tell if my `op-node` is pointing to the wrong chain?',
#  'Where can I find information on what to expect during an upgrade of the Optimism testnet and mainnet?',
#  'Where can I find information about the Optimism Goerli network?',
#  'Where can I find more detailed information about Bedrock Mission Control for Optimism?',
#  'How has the Bedrock release affected wallets?',
#  'What are the new statuses a transaction can have after the Bedrock release?',
#  'Do transaction fees need to account for any new standards after the Bedrock release?',
#  'How can I get the block range information in Optimism?',
#  'How can I estimate the cost of a transaction in Optimism?',
#  'How can I check the status of a specific block in Optimism?',
#  "What do the terms 'unsafe', 'safe', and 'finalized' mean in the context of Optimism blocks?",
#  'How are transaction fees structured in OP Mainnet?',
#  'How can I estimate the total cost of a transaction on OP Mainnet?',
#  'What components make up the L2 execution fee in Bedrock?',
#  'How often are blocks produced on the OP Mainnet?',
#  'Why should I specify a higher base fee than the current value when making a transaction?',
#  'Where can I find the current L2 base fee for Optimism?',
#  'How low can I set the Max Priority Fee on OP Chains?',
#  'What is the typical priority fee on OP Mainnet?',
#  'Why do app developers need to move data and assets between OP Mainnet and Ethereum?',
#  'What is bridging in the context of OP Mainnet and Ethereum?',
#  'Is it possible to create L2 representations of existing tokens on Ethereum?',
#  'Can I send data other than tokens between Ethereum and OP Mainnet?',
#  'How can I trigger a contract function on OP Mainnet from Ethereum?',
#  'Is the API for cross-chain function calls difficult to use?',
#  'Why is the L2 state vulnerable in Optimism?',
#  'What should I do if I need to rely on the L2 state before the fault challenge period ends?',
#  "What are the main trade-offs in Dapps' inter-layer communication strategies in Optimism?",
#  'How can I connect my dapp to both Ethereum and OP Mainnet?',
#  'What are the benefits of using a centralized server for my dapp?',
#  'Is it possible for users to run a different client that pretends to be the legitimate one?',
#  'When can you trust the client for inter-layer communication?',
#  'How does Optimism ensure decentralization similar to OP Mainnet and Ethereum?',
#  'Can I trust the messaging infrastructure used by Optimism?',
#  'How long does it take for an L1 transaction to update L2 code in Optimism?',
#  'Why is sending messages from L2 to L1 more difficult?',
#  'How long does it take to send a message from L2 to L1?',
#  'How do incentives work in Optimism governance?',
#  'How can apps on OP Mainnet interact with apps on Ethereum?',
#  "What is a 'call' in the context of Ethereum smart contracts?",
#  'What is ABI in Solidity and why is it important?',
#  'How do contracts on Ethereum communicate with contracts on Optimism?',
#  'What is the `sendMessage` function and how is it used?',
#  'Where can I find the addresses of the messenger contracts on Optimism?',
#  'Are transactions between Ethereum and OP Mainnet instantaneous?',
#  'Do calls between contracts on the same blockchain take the same amount of time as calls between Ethereum and OP Mainnet?',
#  'Why do transactions from L1 to L2 take about a minute?',
#  'What is the fault challenge period in Optimism?',
#  'How do contracts typically restrict access to certain functions?',
#  'What is the role of the `msg.sender` in contracts?',
#  'What is the `xDomainMessageSender` function used for?',
#  'How is the cost of an L1 to L2 transaction determined?',
#  'What happens if my L1 to L2 transaction requires more than 1.92 million gas on L2?',
#  'Where can I find the current values for the free L2 gas amount and the L1 to L2 gas exchange rate?',
#  'Why is the L1 proof transaction considered expensive?',
#  'What is the transaction challenge period for finalizing an L2 to L1 transaction on Optimism?',
#  'Why do messages sent from Layer 2 to Layer 1 take a week to be relayed?',
#  'What is the purpose of the challenge period in Optimistic Rollups?',
#  'Can the length of the challenge period be changed?',
#  'How can I transfer ETH and ERC20 tokens between Layer 1 and Layer 2 networks?',
#  'What are the main components of the Standard Bridge?',
#  'Where can I find a step-by-step tutorial for using the Standard Bridge?',
#  'Can I use a smart contract wallet to deposit ETH on OP Mainnet?',
#  'Are there any restrictions on depositing ERC20 tokens using a smart contract wallet on OP Mainnet?',
#  'Why are smart contract wallets blocked from calling certain deposit functions on OP Mainnet?',
#  'How can I deposit ERC20 tokens into Optimism Layer 2?',
#  'Are there any ERC20 tokens that are not supported by the Optimism bridge?',
#  'How can I check if a token can use the standard bridge on Optimism?',
#  'What happens after I deposit ETH into L2 on Optimism?',
#  "What's the difference between USDC and USDC.e on the OP Mainnet?",
#  'Why is it important to know the difference between USDC and USDC.e when using deposit functions?',
#  'Will native USDC liquidity replace bridged USDC liquidity over time?',
#  'How can I trigger ERC20 withdrawals on Optimism?',
#  'Where can I find an example of how to use the L2StandardBridge contract for deposits and withdrawals?',
#  'What address should I use as the L2 token address when withdrawing ETH on Optimism?',
#  'How can I add my token to the Superchain token list?',
#  'What is the main portal for moving assets between Layer 1 and Layer 2 on Optimism?',
#  'Is there a one-to-one mapping between L1 and L2 tokens in the Superchain token list?',
#  'How does the cost of using a decentralized application on OP Mainnet compare to using one on L1 Ethereum?',
#  'How can I optimize my contracts for the OP Mainnet environment?',
#  'Why can the cost of gas on L1 be unpredictable?',
#  'Where can I find the current gas costs for transactions on OP Mainnet?',
#  'Why are transaction costs on OP Mainnet different from those on Ethereum?',
#  'How much does it cost to write one byte to L1 on OP Mainnet?',
#  'Is it cheaper to write data to storage or to transaction call data on OP Mainnet?',
#  'Why is the standard ABI not optimal for OP Mainnet?',
#  'Can I still use the standard ABI for some functions on OP Mainnet?',
#  'Why should I avoid using `uint256` for storing ETH balances?',
#  'How can I optimize the storage of values in my smart contracts?',
#  'What is the benefit of using smaller data types in my smart contracts?',
#  'Why should I use a local development environment for OP Mainnet?',
#  'What does the default development environment for OP Mainnet include?',
#  'Can I use a hosted development node instead of setting up a local environment?',
#  'Why should I use the local development environment for my application?',
#  "What should I do if I'm not sure whether to use the local development environment?",
#  'How do I install the necessary command line utilities for Optimism on Ubuntu 20.04 LTS?',
#  'How do I start the development network for Optimism?',
#  'What are the chain IDs for the development node compared to the real-world networks?',
#  'How is the `block.difficulty` value determined on Optimism?',
#  'What happens to `tx.origin` in an L1 to L2 transaction on Optimism?',
#  'What is the behavior of the `CALLER` opcode in an L1 to L2 transaction on Optimism?',
#  'How can I get information about the latest L1 block in Optimism?',
#  'How does the `CREATE` opcode behavior affect contract addresses on L1 and L2?',
#  'What is the difference in the value of `tx.origin` between L1 and L2?',
#  'Why should `tx.origin` generally not be used for authorization?',
#  'Why is it a problem to have two identical source addresses for L1 and L2 contracts?',
#  'How does OP Mainnet protect users like Nimrod from potential scams?',
#  'What is the significance of the allowance in the context of the Hackswap example?',
#  'What are the components of the gas cost in Optimism?',
#  'What are some differences in EIP-1559 parameters between Optimism and Ethereum?',
#  'How does Optimism minimize MEV (Miner Extractable Value)?',
#  "How are transactions processed in Optimism's mempool?",
#  'How often are blocks produced on Optimism Bedrock compared to L1 Ethereum?',
#  'What is the target size for blocks on Optimism Bedrock?',
#  'Is there a difference in the maximum block size between L1 Ethereum and Optimism Bedrock?',
#  'Does OP Mainnet use the same API as Ethereum?',
#  'Are there any additional methods specific to OP Mainnet?',
#  'Where can I find more information about the custom JSON-RPC methods for OP Mainnet?',
#  'Are the addresses for infrastructure contracts the same on L1 Ethereum and OP Mainnet?',
#  'Does Optimism have an RPC API?',
#  "What's the name of the rollup node implementation for the OP Mainnet?",
#  "What does the 'op-node' component do?",
#  'What information is included in the synchronization status response?',
# ...
#  'How do contributors and builders benefit from the Optimism ecosystem?',
#  'How is the OP economy funded?',
#  'What is the role of The Optimism Foundation in the funding process?',
#  "What is the sustainable source of revenue for OP's economic model?",
#  'How is governance structured in the Optimism Foundation?',
#  'What should I do if I am a Top 100 delegate and want to approve a non-grant proposal?',
#  'When and where do community calls for Optimism governance take place?',
#  'How does the Optimism Collective support builders with grants?',
#  'What are Collective Grants?',
#  'How can I find a list of available Mission Requests for Optimism?',
#  'Who evaluates and selects the Mission Applications for Optimism?',
#  'Where can I ask questions if I have any doubts about Delegate Mission Requests?',
#  'How can projects or teams get initial funding to start building on Optimism?',
#  'What types of projects have been rewarded in past rounds of Retro Funding?',
#  'Where can I discuss the Governance Fund for Optimism?',
#  'How much of the total initial token supply is allocated to Optimism projects and communities?',
#  'Where can I find more information about the total allocation of OP tokens?',
#  'How were the grants distributed in Phase 1 of the Optimism ecosystem?',
#  'Can a project apply for more grants after getting an initial proposal approved?',
#  'How can projects strengthen their case for future proposals?',
#  'How were the projects rewarded in Phase 0 of Optimism Governance chosen?',
#  'Where can I find live tracking information on the Gov Fund allocations for Optimism?',
#  'How can I delegate my tokens in Optimism?',
#  'Can I delegate my voting power in Optimism governance to someone else?',
#  "What if I don't want to delegate my voting power to someone else?",
#  'Is participating in Optimism governance time-consuming?',
#  'How do I choose a delegate for my OP tokens?',
#  'Can I change my delegate after I have chosen one?',
#  'How can I vote with my OP tokens?',
#  'Is there a minimum amount of OP tokens required to vote?',
#  'When is the delegate voting power measured?',
#  'Is the Law of Chains a legally binding contract?',
#  'What should I do if I believe Participant Protections have been violated?',
#  'Does the Law of Chains create any formal relationships like partnerships or employment?',
#  'Are there any videos available for developers?',
#  'Is there a video available about Optimism at ETHDenver 2023?',
#  'What is the main theme of the video about Optimism governance?',
#  "Where can I find Justine's research on DAO governance and policy?",
#  'Who is Ben Jones and what is his role in the Optimism ecosystem?',
#  'How can I learn more about the OP Stack and its role in the Ethereum ecosystem?',
#  'Where can I find the official guidelines for submitting proposals in Optimism governance?',
#  'Is the information in the documentation fragment the most reliable source for governance processes?',
#  'How can I apply for grant funding from the Governance Fund?',
#  'Do I need to hold a minimum amount of tokens to submit a proposal?',
#  'What is required for a non-grant proposal to move to a vote?',
#  'Where can I find the process for submitting non-grant proposals?',
#  'What was the median funding amount received by a project in Retro Funding 1?',
#  'Where can I find a detailed list of all projects and their funding allocations for Retro Funding 1?',
#  'Who were the badgeholders in RetroPGF Round 1?',
#  'How could someone nominate a project for RetroPGF Round 1?',
#  'When did the voting for RetroPGF Round 1 take place?',
#  'When did the second round of Retroactive Public Goods Funding take place?',
#  'How many OP tokens were allocated in RetroPGF Round 2?',
#  'What was the median OP received by a project in RetroPGF 2?',
#  'How are badgeholders selected for RetroPGF Round 2 in Optimism Governance?',
#  'Where can I find information about the learnings and reflections from round 2 of Optimism Governance?',
#  'How long is the project application period for Optimism Governance?',
#  'When will the results and token disbursement be announced for Optimism Governance?',
#  'Where can I find the announcement for the RetroPGF Round 3 recipients?',
#  'What should Retro Funding recipients do if they have questions or problems with the KYC & grant delivery process?',
#  'Is there a place where I can read about the learnings and reflections on RetroPGF 3?',
#  'What tools were available for badgeholders to vote in RetroPGF 3?',
#  'Where can badgeholders find more information relevant to voting?',
#  'Where can I see applications for voting on Retro Funding?',
#  'Where can badgeholders find resources and stay updated?',
#  'Can I apply for RetroPGF 3 if my project received funding from venture capital or the Optimism Token House?',
#  'Do I need to have made my contribution between specific rounds to be considered for RetroPGF 3?',
#  "What's the title of the section that talks about the history of the Token House?",
#  'How often does Token House voting occur?',
#  'What happens during Reflection Periods in Token House governance?',
#  'When do Voting Cycles begin and end?',
#  'How does Optimism handle the budget for the Developer Advisory Board?',
#  'What is the purpose of the Code of Conduct Council in Optimism?',
#  'What is the Grants Council and what are its functions?',
#  'How often does Optimism have voting cycles?',
#  'Where can I find the results or summaries of the grants given during each voting cycle?',
#  'Where can I find the budget proposals for different intents in Optimism Governance?',
#  'How can I participate in the Grants Council Elections for Builders and Growth Experiments in Optimism?',
#  'Is there a proposal for the renewal of the Protocol Delegation Program in Optimism?',
#  'What is the Bedrock Upgrade Proposal?',
#  'What are Grants Cycle Roundups?',
#  'How can I participate in the Protocol Delegation Elections for Optimism?',
#  'What are the different types of Grants Council Elections available?',
#  'What is the Badgeholder Nomination Voting?',
#  'Where can I find information about the results of previous voting cycles for Optimism?',
#  'When did Voting Cycle #8 for Optimism take place?',
#  "What's the reflection period in Optimism governance?",
#  'Where can I find the updated operating manual for Optimism governance?',
#  'What are governance committees in Optimism?',
#  'How many voting cycles have been documented in the Optimism governance forum?',
#  'How long will the Working Constitution of the Optimism Collective be in effect?',
#  "What will happen after the Working Constitution's period ends?",
#  'Where can I find the current governance processes for the Token House?',
#  'Who or what is the Optimism Foundation?',
#  'Can the Optimism Foundation enter into legal contracts with other companies?',
#  'What kind of activities can the Optimism Foundation perform due to its legal status?',
#  'How does the Optimism Foundation support the technical development of the protocol?',
#  'Who are the current members of the Board of Directors for the Optimism Foundation?',
#  'What is the role of the Supervisor in the Optimism Foundation?',
#  'How is the Foundation legally accountable in its operations?',
#  "What types of governance proposals ensure the Foundation's accountability?",
#  "What is the purpose of the 'Rights protections' proposal type?",
#  'How long is the Collective’s Working Constitution intended to last?',
#  "What is the Foundation's plan during the transition period of the Working Constitution?",
#  'What is the ultimate goal of the Foundation and the Collective during the transition period?',
#  'Where can I find guides for using the OP Mainnet?',
#  'Where can I get testnet ETH for OP Mainnet?',
#  'Where can I find information on integrating OP Mainnet with my wallet?',
#  'Is there a guide for getting my token onto the standard bridge?',
#  'Are there resources for writing a custom bridge for OP Mainnet?',
#  'How can I suggest a new use case for Optimism?',
#  'Why should I consider using the standard bridge before developing a custom bridge solution?',
#  'What are some reasons why the standard bridge might not work for me?',
#  'How can I add OP Mainnet to my centralized exchange?',
#  'Should I use public or private endpoints for my project?',
#  'How is ETH used in Optimism compared to L1 Ethereum?',
#  'Are the ERC-20 contract addresses for tokens the same on OP Mainnet and Ethereum?',
#  'How do I get the total SNX balance of a user on OP Mainnet?',
#  'Can I use my existing Ethereum code for transactions on OP Mainnet?',
#  'If I charge my users for withdrawals on OP Mainnet, what should I consider?',
#  'How can I transfer assets from Ethereum mainnet to Optimism Mainnet?',
#  'Why does it take a week to move assets from Optimism back to Ethereum?',
#  'What can I do if an ERC-20 token does not have an equivalent on Optimism Mainnet?',
#  'Where can I find the audit reports for Optimism?',
#  'How is the NFT ecosystem structured on the OP Mainnet?',
#  'Where can I find statistics about NFTs on the OP Mainnet?',
#  'Which tools are available on the OP Mainnet for NFTs?',
#  'Which platforms support ERC-1155 tokens?',
#  'Do any of these platforms offer no-code deployment?',
#  'What are the pricing models for these platforms?',
#  'Where can I find resources or APIs related to NFTs on Optimism?',
#  'What is a good starting point for using the NFT API from Alchemy?',
#  'Where can I find the documentation for using Reservoir with Optimism?',
#  'Where can I buy or trade NFTs on the Optimism network?',
#  'What are some marketplaces that support Optimism for NFT transactions?',
#  'Who or what is Bluesweep?',
#  'Can I use NFTs as collateral on Optimism?',
#  'How can I find the chain ID and supporting information for the OP Goerli test network?',
#  'What additional testing utilities are available for the OP Goerli network?',
#  'How can I get test tokens for testing on Optimism?',
#  'Is there a specific address for WETH on Optimism?',
#  'Where can I find the contract address for the token OUT-1 on Optimism?',
#  'What is the decimal precision for the token OUT-2 on Optimism?',
#  'Is the `OUTb` token supported by the bridge on Goerli?',
#  'Where can I find a tutorial on how to use the `OUTb` token with the bridge?',
#  'How can I obtain NFT tokens on OP Goerli?',
#  'What is the address of the ERC-721 token contract on OP Goerli?',
#  'Why are there fee discrepancies on OP Mainnet?',
#  'What is the purpose of this guide?',
#  'How can I find the ERC-20 contract address for a token on the OP Mainnet?',
#  'How can I know if my transaction on OP Mainnet is final?',
#  'What are the states a transaction can be in on OP Mainnet?',
#  'Is there a way to easily detect when a transaction has been published to Ethereum?',
#  'Can I use my existing code for estimating fees on L1 Ethereum for OP Mainnet?',
#  "How do I ensure my transaction doesn't fail when sending the maximum amount of ETH from my wallet?",
#  'Why do I need to consider both L2 execution fee and L1 data fee when sending ETH?',
#  'Why is decentralized identity important in the context of Optimism?',
#  'What benefits does decentralized identity provide to individuals?',
#  'How does decentralized identity work on the Superchain?',
#  'What is the role of the AttestationStation in decentralized identity?',
#  'Which applications use the AttestationStation?',
#  'What is EAS Scan?',
#  'What is Citizen Attestations?',
#  'What is Attest Fest?',
#  'How can I query and submit attestations on Optimism?',
#  'What is the Optimist Score and where can I find it?',
#  'How can I bring web2 user behavior and identity data onchain?',
#  'Is AttestationStation v0 still supported?',
#  'What are the main attributes of an attestation in AttestationStation v0?',
#  'Can different creators use the same key for different purposes in AttestationStation v0?',
#  'How can I search for all attestations about a specific address?',
#  'What information do I need to look for a specific attestation?',
#  'Is there a way to search for attestations without relying on a centralized authority?',
#  'Where can I find the legacy AttestationStation contract in the Optimism monorepo?',
#  'What information is included in the `AttestationCreated` event in Optimism?',
#  'Who can create an attestation in the AttestationStation?',
#  'What are the parameters required for the `attest` function?',
#  'How does Optimism handle the roles of creator, signer, and transaction payer?',
#  'How can I interact with the AttestationStation v1 on the OP Mainnet?',
#  'Where can I find the contract addresses for the AttestationStation v1 on the OP Goerli network?',
#  'Is there a way to index attestations from the AttestationStation v1?',
#  'How can I build decentralized identity apps using attestations?',
#  'What is an attestation in the context of Optimism?',
#  "What should I do if I have a good project idea but can't build it myself?",
#  "How can I ensure users' privacy when collecting personal information on the blockchain?",
#  'Is it safe to store sensitive data on the blockchain?',
#  'What measures should be taken when storing sensitive data offchain?',
#  'Can attestations be used as verifiable credentials?',
#  'How do attestations relate to proof of personhood?',
#  'Why choose attestations over soulbound or non-transferable tokens?',
#  'Who can issue an attestation in a decentralized identity system?',
#  'What is the purpose of the AttestationStation?',
#  'Can anyone create an Optimist Profile?',
#  'What is the purpose of an Optimist Profile?',
#  'Can the Optimist Profile be used for onchain identity purposes?',
#  'What can an Optimist Profile do regarding contributions?',
#  'What is the purpose of the profileMetadataPtr in the Optimist Profile?',
#  'What does the applicationMetadataPtrType indicate in the RetroPGF 3 Application schema?',
#  'How can I find the addresses for RetroPGF badgeholders?',
#  'How can I find the addresses for Optimist Profiles?',
#  'Why do I see multiple applications associated with a single Optimist Profile?',
#  'What can I find in the documentation about schemas?',
#  'Where can I find the schema UID for the Optimist Profile?',
#  'Where can I find the schema UID for Gitcoin Passport V1 scores?',
#  'Where can I find the Superchain Faucet schema UID for Optimism?',
#  'How can I verify the authenticity of a Season 4 Co-grant participant schema UID?',
#  'Where can I find the Governance contribution schema UID?',
#  'How can I verify the attester address for the RetroPGF Badgeholders schema?',
#  'What is the schema UID for the RetroPGF 3 Approved Application?',
#  'Can you explain the main principles behind the design of Optimism?',
#  'Why does Optimism prefer to use existing Ethereum code and infrastructure?',
#  "What are the benefits of Optimism's simplicity in its design?",
#  "How does Optimism's simplicity contribute to its long-term vision?",
#  'How does the design philosophy of Optimism prioritize user and developer needs?',
#  "How does Optimism handle the limitations of its core team's expertise?",
#  'What role does user feedback play in the development of Optimism?',
#  'Why is long-term sustainability important for Optimism?',
#  'How does Optimism ensure that its protocol remains sustainable?',
#  'How is Optimism related to Ethereum?',
#  "Why is the project named 'Optimism'?",
#  'What is the main goal of Optimism?',
#  'Why is Optimism built as an Optimistic Rollup?',
#  'What parent blockchain does OP Mainnet use?',
#  'How are Bedrock L2 blocks saved to the Ethereum blockchain?',
#  'Why is it important to write blocks to L1 in a compressed format?',
#  'What guarantees does OP Mainnet inherit from Ethereum?',
#  'Who manages block production in Optimism?',
#  'What are the two ways transactions can get to the sequencer in Optimism?',
#  'How does the execution engine in Optimism receive blocks?',
#  'What is the difference between the two mechanisms for receiving blocks in Optimism?',
#  'Where can I find more detailed information about the synchronization mechanisms of the execution engine in Optimism?',
#  'Can I transfer ERC20 tokens between Ethereum and Optimism?',
#  ...]

# %%
len(all_questions)
# Out:
# 1514

# %%
len(cleaned_all_questions)
# Out:
# 1422

# %%
# questions that are in cleaned_all_questions and in new_questions
cleaned_new_questions = [q for q in new_questions if q in cleaned_all_questions]
len(cleaned_new_questions)
# Out:
# 185

# %%
final_test_clean = test_clean[test_clean['question'].isin(cleaned_new_questions)]
final_test_clean
# Out:
#      fragment                                           question  \
# 1           0  How can I promote my project once it's deploye...
# 2           0  What should I do if I want to apply for a Gove...
# 3           1  How can I get involved in the Optimism Collect...
# 6           2  How can I start the process of becoming an Opt...
# 8           2  What actions can lead to losing your Ambassado...
# ..        ...                                                ...
# 290       102  How do oracles help blockchain applications ac...
# 292       102  What is the role of the Gas Price Oracle on OP...
# 293       103  Which API providers offer free access to Optim...
# 294       103  Are there any API providers that support both ...
# 295       103  Which API provider offers the highest number o...
#
#                                                 answer  \
# 1    Once your project is deployed on the Superchai...
# 2    If you want to apply for a Governance Grant, f...
# 3    You can get involved in the Optimism Collectiv...
# 6    To start the process of becoming an Optimism A...
# 8    You can lose your Ambassador status due to ina...
# ..                                                 ...
# 290  Oracles provide offchain data onchain, allowin...
# 292  The Gas Price Oracle on OP Mainnet provides in...
# 293  Several API providers offer free access to Opt...
# 294  Yes, several API providers support both OP Mai...
# 295  BlockPI offers the highest number of free API ...
#
#                                          fragment_text  \
# 1    ---\ntitle: How do I get project support (mark...
# 2    ---\ntitle: How do I get project support (mark...
# 3    ---\ntitle: Contribute to Optimism\nlang: en-U...
# 6    ---\ntitle: Ambassador Requirements\nlang: en-...
# 8    ---\ntitle: Ambassador Requirements\nlang: en-...
# ..                                                 ...
# 290  ---\ntitle: Oracles\nlang: en-US\n---  \n[Orac...
# 292  ---\ntitle: Oracles\nlang: en-US\n---  \n[Orac...
# 293  ---\ntitle: Node & API Providers\nlang: en-US\...
# 294  ---\ntitle: Node & API Providers\nlang: en-US\...
# 295  ---\ntitle: Node & API Providers\nlang: en-US\...
#
#                                                cluster
# 1    marketing / promotion / ambassadors / events / PR
# 2                                           governance
# 3    marketing / promotion / ambassadors / events / PR
# 6    marketing / promotion / ambassadors / events / PR
# 8    marketing / promotion / ambassadors / events / PR
# ..                                                 ...
# 290                                 tech documentation
# 292                                 tech documentation
# 293                                 tech documentation
# 294                                 tech documentation
# 295                                 tech documentation
#
# [185 rows x 5 columns]

# %%
# save csv
final_test_clean.to_csv("largefragments_cleaned_test_dataset_with_clusters.csv", index=False)
