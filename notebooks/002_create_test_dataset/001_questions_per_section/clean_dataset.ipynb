# %% [markdown]
# # Cleaning the repeated and repetitive questions from the dataset

# %%
import pandas as pd
import numpy as np
import faiss, random

from langchain_openai import OpenAIEmbeddings

test_brut = pd.read_csv("first_test_dataset_with_fragments.csv")

# openai api key
openai_api_key = input("Enter the OpenAI API key: ")
model_embeddings = "text-embedding-3-small"

# %%
# for the lines that have repeated questions, we will let only the first one
test_clean_dupl = test_brut.drop_duplicates(subset=["question"])
test_clean_dupl
# Out:
#       fragment                                           question  \
# 0            0  How can I get support for my project on Optimism?
# 1            0  Where can I find the Optimism community to dis...
# 2            0  What should I do before deploying my project o...
# 3            1  Where can I find tutorials for developing on O...
# 4            1  How can I get immediate developer support for ...
# ...        ...                                                ...
# 1867       758  Is there a free tier available for using OP Ma...
# 1869       760            Can I access OP Mainnet nodes for free?
# 1870       760  Are there any premium options available for OP...
# 1871       760  Do I need to manage the infrastructure if I us...
# 1873       762  Who provides ERC-4337 account abstraction infr...
#
#                                                  answer  \
# 0     To get support for your project on Optimism, y...
# 1     You can find the Optimism community on their D...
# 2     Before deploying your project on OP Mainnet, y...
# 3     You can find tutorials for developing on Optim...
# 4     For immediate developer support, you can first...
# ...                                                 ...
# 1867  Yes, there is a generous free tier available t...
# 1869  Yes, QuickNode offers access to hosted OP Main...
# 1870  Yes, QuickNode provides an option to upgrade t...
# 1871  No, QuickNode manages the complex infrastructu...
# 1873  Stackup provides ERC-4337 account abstraction ...
#
#                                           fragment_text
# 0     ---\ntitle: How do I get project support (mark...
# 1     ---\ntitle: How do I get project support (mark...
# 2     ---\ntitle: How do I get project support (mark...
# 3     Steps to take if you would like developer supp...
# 4     Steps to take if you would like developer supp...
# ...                                                 ...
# 1867  [Pocket](https://www.portal.pokt.network/) off...
# 1869  [QuickNode](https://www.quicknode.com/) offers...
# 1870  [QuickNode](https://www.quicknode.com/) offers...
# 1871  [QuickNode](https://www.quicknode.com/) offers...
# 1873  [Stackup](https://www.stackup.sh/) provides ER...
#
# [1667 rows x 4 columns]

# %%
# questions df
questions = test_clean_dupl["question"].tolist()

# %%
# project into the embedding space
embeddings = OpenAIEmbeddings(model=model_embeddings, openai_api_key=openai_api_key)
questions_emb = embeddings.embed_documents(questions)
questions_emb = np.array(questions_emb)

# %%
# given a treeshold (in terms of faiss distance in the emb space), we will remove the questions that are too similar
def rm_too_similar_questions(questions, questions_emb, tresh):
    # faiss index
    index = faiss.IndexFlatL2(questions_emb.shape[1])
    index.add(questions_emb)

    # get the 100 nearest neighbors for each question
    dist, ind = index.search(questions_emb, 100)
    dist, ind

    indexes_to_remove = []
    # for each question
    for n in range(len(ind)):
        # closest neighbors indexes
        i = ind[n]
        # closest neighbors distances
        d = dist[n]
        # if the question is not removed yet
        if not i[0] in indexes_to_remove:
            # the too close questions
            small = i[d < tresh]

            if len(small) > 1:
                for s in small:
                    print(questions[s])
                print("----")
                indexes_to_remove.extend(small[1:])
        
    # questions without indexes_to_remove
    questions_clean = [questions[i] for i in range(len(questions)) if i not in indexes_to_remove]
    # questions embeddings without indexes_to_remove
    questions_emb_clean = np.array([questions_emb[i] for i in range(len(questions_emb)) if i not in indexes_to_remove])

    return questions_clean, questions_emb_clean

# remove the questions that are too similar
cleaned_questions, cleaned_questions_emb = rm_too_similar_questions(questions, questions_emb, tresh = 0.4)

# select questions in the cleaned_questions list
test_clean = test_clean_dupl[test_clean_dupl["question"].isin(cleaned_questions)]
test_clean
# Out:
# How can I get support for my project on Optimism?
# Where can I find the Optimism community to discuss my project?
# How can I get support for creating Optimism content?
# How can I get in touch with the Optimism team for support or to contribute?
# How can I gain traction for my project within the Optimism community?
# How can I get immediate developer support for Optimism?
# How can I contribute to the Optimism project?
# ----
# What should I do before deploying my project on OP Mainnet?
# How can I get started with deploying a contract on OP Mainnet?
# How can I start developing on OP Mainnet?
# ----
# Is there a Discord channel for developer support for Optimism?
# How can I join the Optimism community on Discord?
# ----
# How can I get my project listed on the Superchain apps page?
# How can my app be featured on the Superchain apps page?
# ----
# How can I apply for a grant from Optimism?
# How can I get a grant from Optimism?
# ----
# How can I get involved in the Optimism Collective?
# How can I contribute technically to the Optimism Collective?
# What is the Optimism Collective?
# What's the Optimism Collective?
# Who are the members of the Optimism Collective?
# What is the main goal of the Optimism Collective?
# Where can I find inspiration for contributions to the Optimism Collective?
# ----
# What is the Optimism Collective's approach to building public goods?
# How does Optimism plan to fund public goods?
# ----
# What is RetroPGF and why is it important to Optimism?
# What is RetroPGF in the context of Optimism?
# ----
# Is there a way to help improve the Optimism documentation?
# Is there a way to get help from the Optimism community if the documentation doesn't have the answers I need?
# ----
# Are there any community events for Optimism enthusiasts?
# Is there any support available for organizing local events related to Optimism?
# How can I get involved in running local events for the Optimism community?
# ----
# Where can I find ideas for projects to build on Optimism?
# Where can I find project ideas for building on Optimism?
# ----
# How can I contribute directly to the Optimism codebase?
# How can I start contributing to the Optimism codebase?
# How can I contribute to the Optimism project if I'm not a developer?
# How can I contribute to the Optimism project?
# ----
# How can I start getting involved in Optimism's governance?
# How can I participate in general governance discussions for Optimism?
# What should I do if I want to become a delegate in Optimism's governance?
# How can I become a delegate in Optimism Governance?
# How can I register to be a delegate for Optimism Governance?
# ----
# What is the Citizens House in Optimism's governance?
# What's the Citizens' House in Optimism Governance?
# How does the Citizens' House contribute to the governance of the Optimism Collective?
# ----
# What options do I have to market my project within the Optimism community?
# How can I gain traction for my project within the Optimism community?
# Where can I find the Optimism community to discuss my project?
# ----
# Who can become an Ambassador for Optimism?
# How can I become an ambassador for Optimism?
# How do you become an Optimism Ambassador?
# What qualities are important for an Optimism Ambassador?
# How can I start the process of becoming an ambassador for Optimism?
# What are the benefits of becoming an Ambassador for Optimism?
# Who are Optimism Ambassadors and what do they do?
# ----
# What kind of content do Optimism Ambassadors create?
# Who are Optimism Ambassadors and what do they do?
# ----
# What kind of content do I need to create to become an ambassador?
# What kind of collaborative content can you create to become an ambassador?
# ----
# Can I discuss the price of the OP token in my content?
# Is it okay to discuss the price of the OP token?
# ----
# How can I become a support NERD for Optimism?
# How can I become a support NERD in the Optimism community?
# How do I become a `support-NERD` in the Optimism community?
# ----
# What are some ways I can offer support in the Optimism Discord?
# How can I join the Optimism community on Discord?
# ----
# What should be considered when issuing attestations in Optimism Governance?
# How is an attestation represented in Optimism's governance documentation?
# How are attestations stored in Optimism's governance system?
# ----
# Where can developers find specific input and ideas on valuable work within the Optimism Collective?
# Where can I find inspiration for contributions to the Optimism Collective?
# ----
# Do all types of data need to be turned into attestations in Optimism?
# How can I create attestations in Optimism?
# ----
# Why is the issuer important in an attestation?
# What should be considered when choosing an issuer for an attestation?
# ----
# Who can be an issuer of an attestation?
# What should be considered when choosing an issuer for an attestation?
# ----
# Why are schemas important in Optimism Governance?
# What's the purpose of schemas in Optimism Governance?
# How are schemas built for use in Optimism Governance?
# ----
# Where can I find more information about the NumbaNERDs program?
# How can I participate in the NumbaNERDs program?
# ----
# How can I participate in the TechNERDs program?
# Where can I find more information about the TechNERDs program?
# What is the purpose of the TechNERDs program?
# ----
# How can I apply to showcase my dApp on Optimism's Demo Day?
# Do I need to be in the Optimism Discord server to present my dApp on Demo Day?
# ----
# Where can I ask specific questions about Optimism?
# Where can I ask a question if I can't find the information I need in the Optimism documentation?
# ----
# What is the Superchain in Optimism Governance?
# What's the Superchain in the context of Optimism?
# ----
# Why is funding public goods important for Optimism?
# How does funding public goods benefit the Optimism network?
# How does Optimism support public goods?
# How does Optimism plan to fund public goods?
# ----
# What principle does the Optimism Collective follow?
# What is the vision or guiding principle of the Optimism Collective?
# What is the Optimism Collective?
# What's the Optimism Collective?
# What is the main goal of the Optimism Collective?
# Who are the members of the Optimism Collective?
# How does the Optimism Collective approach governance?
# ----
# What is the Optimism ecosystem?
# What benefits do users and community members receive from the Optimism ecosystem?
# ----
# What do I need to know to understand the Superchain?
# What is the Superchain?
# ----
# What's an OP Chain?
# What are the benefits of becoming an OP Chain?
# ----
# What is the Superchain in the context of OP Chains?
# What is the Superchain?
# ----
# Who maintains the OP Stack?
# What is the OP Stack?
# What is the OP Stack used for?
# ----
# Is the OP Stack open source?
# What's the OP Stack chain software?
# ----
# What's an OP Stack Fork?
# What is the OP Stack?
# What is the OP Stack used for?
# ----
# Do OP Stack Forks share security with OP Chains in the Superchain?
# Are OP Stack Forks part of the Superchain?
# ----
# What's OP Mainnet?
# What is OP Mainnet?
# Is there an OP Mainnet?
# What was OP Mainnet previously known as?
# Where can I find the OP Mainnet endpoints?
# How does OP Mainnet differ from other EVM-based chains?
# What's the latest major release of OP Mainnet called?
# What's the latest major release of OP Mainnet?
# Where can I find information about OP Mainnet and test networks?
# How can I connect to OP Mainnet?
# ----
# Are there any rewards for contributing to the Optimism project?
# How can I contribute to the Optimism project?
# ----
# Where can I find resources to deploy a basic contract on OP Mainnet?
# How can I get started with deploying a contract on OP Mainnet?
# ----
# Are there any tools available to make building on OP Mainnet easier?
# Where can I find tools for developing on the OP Mainnet?
# What should I do if I am already familiar with building on OP Mainnet and just need the tools?
# ----
# How can I deploy my contracts to OP Mainnet or OP Goerli?
# How can I deploy a contract on OP Goerli?
# How can I get started with deploying a contract on OP Mainnet?
# ----
# Are there any resources to help me run a local development environment for Optimism?
# How can I set up a local development environment for Optimism?
# What is the purpose of running a local development environment for Optimism?
# Is there a way to set up a development node for Optimism?
# ----
# How can I move tokens from Ethereum to OP Mainnet?
# How can I move tokens between OP Mainnet and Ethereum?
# ----
# What should I do first if I can't find the content I'm looking for in the Optimism documentation?
# Where can I ask a question if I can't find the information I need in the Optimism documentation?
# ----
# What's Bedrock in the context of Optimism?
# What is Bedrock in the context of Optimism?
# What are output roots in the context of Optimism's Bedrock?
# ----
# What are some of the technical improvements in Bedrock?
# What new features does Bedrock support?
# ----
# What improvement does Bedrock bring to the deposit confirmation time in Optimism?
# How did the Bedrock update improve the deposit confirmation time?
# ----
# What is the purpose of abstracting the proof system in Bedrock?
# What is the benefit of Bedrock abstracting the proof system?
# ----
# How does Bedrock compare to Ethereum?
# How similar is Bedrock to Ethereum?
# What are some of the fundamental differences between Bedrock and Ethereum?
# ----
# Does Bedrock use any existing code from Ethereum?
# Does Bedrock use new code or existing code?
# What are some examples of how Bedrock uses existing Ethereum infrastructure?
# What are some examples of how Bedrock uses Ethereum's existing infrastructure?
# ----
# How does Bedrock ensure security in its design?
# How does Bedrock ensure security and reliability?
# ----
# How do rollups derive their data?
# How do rollups derive their data availability source?
# ----
# What is the role of proof systems in rollups?
# What is the role of proof systems in rollup protocols?
# ----
# What's a deposit in the context of Optimism?
# What's a deposit transaction in Optimism?
# What is a deposit contract in Optimism?
# How does the deposit process work in Optimism?
# Why are deposits important in Optimism?
# What are deposit transactions in Optimism?
# What's the difference between a deposit and a withdrawal in Optimism?
# ----
# How does a deposited transaction work in Optimism?
# What are deposit transactions in Optimism?
# What's a deposit transaction in Optimism?
# Who implements the new transaction type for deposited transactions in Optimism?
# How does the deposit process work in Optimism?
# How are transactions processed and posted in Optimism?
# How are deposited transactions represented in the Optimism rollup?
# Why might a deposit transaction fail on Optimism?
# When do deposit transactions become part of the canonical blockchain in Optimism?
# How are transactions stored in Optimism before they are included in a block?
# What role does the execution client play in handling deposited transactions in Optimism?
# ----
# Where can I find more details about the deposit contract in Optimism?
# What is a deposit contract in Optimism?
# How does the deposit process work in Optimism?
# What's a deposit transaction in Optimism?
# ----
# How are withdrawals initiated in the Optimism network?
# How are withdrawals finalized in the Optimism network?
# How do withdrawals work on Optimism?
# What is the difference between withdrawals and deposits in the Optimism network?
# How does a withdrawal work in Optimism?
# How is a withdrawal finalized in Optimism?
# ----
# How does the Bedrock release improve the security of withdrawals in Optimism?
# How does the Bedrock release improve the security of withdrawals?
# What is the main security improvement in the Bedrock update for withdrawals?
# ----
# How does Optimism optimize data compression for transactions?
# How are L2 transactions organized for data compression in Optimism?
# ----
# What is the maximum size of a channel in Optimism?
# What is the initial maximum size for a channel in Optimism?
# ----
# How does the Bedrock protocol ensure the timing of deposits on L1 is respected in the L2 chain?
# What strategies does the Bedrock protocol use to handle L1 and L2 timestamps?
# How does Bedrock handle the synchronization of timestamps between L1 and L2?
# ----
# How does the protocol ensure that deposits are processed in a logical temporal order?
# How does the protocol ensure that deposits are processed in a timely manner?
# ----
# How does the canonical L2 chain process data from the L1 chain?
# How does the canonical L2 chain start processing?
# ----
# Why is data decompressed during the L2 chain processing?
# Why is data decompressed in the L2 chain processing?
# ----
# What is the purpose of output roots in Optimism's Bedrock?
# What are output roots in the context of Optimism's Bedrock?
# ----
# How does Bedrock handle the separation of concerns in the Optimism network?
# How does Bedrock handle the separation of concerns in Optimism?
# ----
# Why does Bedrock have any modifications at all to the Ethereum execution client?
# Why does Bedrock have any modifications to the go-ethereum client?
# ----
# How are sequencer fees determined in Optimism rollups?
# How are sequencer fees determined in Optimism?
# How are the fees calculated for the Sequencer on Optimism?
# ----
# What are data availability fees in Optimism rollups?
# What are data availability fees in Optimism?
# ----
# What is a rollup node in Bedrock?
# What is the role of a rollup node in Bedrock?
# ----
# How does the rollup node communicate with the execution client in Bedrock?
# How does a rollup node communicate with the execution client in Bedrock?
# How do the Rollup Node and Execution Engine communicate in Optimism's Bedrock deployment?
# What is the role of a rollup node in Bedrock?
# ----
# What is a batcher in the context of Optimism?
# What is the role of a batcher in the Optimism network?
# ----
# How does the bridging process work in Optimism's Bedrock?
# What are standard bridges in Optimism's Bedrock?
# ----
# Where can I find more details about the standard bridges in Optimism?
# Where can I find more technical details about the Standard bridge in Optimism?
# What are standard bridges in Optimism?
# How does the standard bridge work in Optimism?
# What are standard bridges in Optimism's Bedrock?
# ----
# Where can I find the technical details of the OP Stack?
# What is the OP Stack?
# ----
# What is the most up-to-date source for understanding the inner workings of the Optimism protocol?
# Where can I find detailed metrics about the Optimism protocol?
# ----
# What does the Bedrock release include?
# What is the Bedrock release?
# ----
# What are the main differences between Ethereum and OP Mainnet regarding EIP-1559 parameters?
# What are the differences in EIP-1559 parameters between Ethereum and OP Mainnet?
# What are the differences between Ethereum and OP Mainnet?
# Are there any differences between Ethereum and OP Mainnet?
# ----
# What new features does EIP-1559 introduce for application developers on Optimism?
# What new features does EIP-1559 introduce for application developers on the Optimism network?
# ----
# How does Bedrock handle block reorganization?
# How does Bedrock handle block reorganization compared to the legacy network?
# ----
# Can Bedrock nodes provide information about blocks, transactions, and receipts from before the Bedrock update?
# Can Bedrock nodes provide information about older blocks and transactions?
# Do Bedrock nodes support pre-Bedrock block data?
# ----
# What is the main security improvement introduced by Bedrock for withdrawals?
# What is the main security improvement in the Bedrock update for withdrawals?
# How does the Bedrock release improve the security of withdrawals?
# ----
# What happens to deposits on the legacy network that haven't been replayed?
# What happens to deposits on the legacy network that have not been replayed?
# What happens to deposits on the legacy network that have not been replayed before the migration?
# ----
# What is the `L2OutputOracle` contract in Optimism?
# What's the purpose of the `L2OutputOracle` contract in Optimism?
# What did the `L2OutputOracle` contract replace in Optimism?
# What did the `L2OutputOracle` contract replace in the Optimism system?
# ----
# How can I send messages between L1 and L2 in Optimism?
# How can I send messages between Layer 1 (L1) and Layer 2 (L2) in Optimism?
# Where can I find more technical details about how messages are transferred between L1 and L2 in Optimism?
# How can I make L1 code communicate with L2 code in Optimism?
# How does an L1 entity send a message to an L2 address in Optimism?
# How many transactions are required for a message to go from L2 to L1 in Optimism?
# ----
# What is the purpose of the OptimismPortal contract?
# Where can I find the OptimismPortal contract?
# ----
# What is the purpose of the L1CrossDomainMessenger contract?
# What is the purpose of the L2CrossDomainMessenger contract?
# What is the purpose of the `L2CrossDomainMessenger` contract?
# What is the address of the L1CrossDomainMessenger contract?
# What is the address of the L1CrossDomainMessenger contract on Goerli?
# ----
# How does the L1StandardBridge contract transfer assets?
# How does the `L1StandardBridge` contract facilitate the transfer of assets between different layers?
# How does the L1StandardBridge contract work?
# What does the L2StandardBridge contract do?
# ----
# How can I find the address of the `L1Block` contract in Optimism?
# How can I find the address of an L2 contract in Optimism?
# Where can I find the address of a specific contract on Optimism?
# ----
# What kind of information can I get from the `L1Block` contract?
# What kind of information can I retrieve from the `L1Block` contract?
# What kind of information can I retrieve using the getter functions of the `L1Block` contract?
# Where can I find the `L1Block` contract code?
# ----
# How does the SequencerFeeVault contract fund the sequencer on L1?
# How are the fees calculated for the SequencerFeeVault contract?
# What mechanism is used to calculate the fees for the SequencerFeeVault contract?
# ----
# How does the `L2ToL1MessagePasser` contract function within the Optimism network?
# How does the `L2ToL1MessagePasser` contract function in the Optimism network?
# Are there different versions of the `L2ToL1MessagePasser` contract in Optimism?
# Are there different versions of the `L2ToL1MessagePasser` contract in Optimism's Bedrock?
# ----
# Why are some contracts kept even if they are no longer relevant?
# Why are some contracts kept as part of the state even if they are no longer relevant?
# Why are some contracts kept even if they have been superseded?
# ----
# What does a withdrawal mean in the context of Optimism?
# How does a withdrawal work in Optimism?
# How is a withdrawal finalized in Optimism?
# How do withdrawals work on Optimism?
# ----
# Will the gas costs for communication between layers change?
# Is there more detailed information available about the new gas costs for communication between layers?
# Are the gas costs for communication between layers in Optimism going to change?
# ----
# Where can I find more information about the new gas costs?
# When will we get more information about the new gas costs?
# ----
# Can you explain what this section of the Optimism documentation is about?
# What's the title of the section in the Optimism Governance Documentation?
# ----
# Where can I find more information about batch submission addresses for L2 blocks?
# Where can I find more information about batch submission addresses?
# ----
# What should I do if my application needs legacy fields from pre-Bedrock JSON-RPC transaction responses?
# What should I do if my application needs certain legacy fields that are no longer available in pre-Bedrock JSON-RPC transaction responses?
# ----
# How can I get the gas price for transactions on Optimism?
# How can I check the current gas prices on Optimism?
# Where can I check the current gas price for Optimism?
# What should I use to get the L2 gas price in Optimism?
# How can I manage the gas fees for my transactions on Optimism?
# ----
# Where can I find more technical details about how messages are transferred in Optimism?
# Where can I find more technical details about how messages are transferred between L1 and L2 in Optimism?
# ----
# How long does it take for a deposit to be confirmed on Optimism?
# How does the deposit process work in Optimism?
# ----
# How can I start developing on OP Mainnet after the Bedrock release?
# How can I start developing on OP Mainnet?
# ----
# How long does it take for deposits to confirm with the new Bedrock update?
# How long did it take for deposits to confirm before the Bedrock update?
# How did the Bedrock update improve the deposit confirmation time?
# ----
# Who is responsible for producing batches in the Optimism network?
# What is the role of a batcher in the Optimism network?
# ----
# How does the bridge in Optimism work?
# How does the standard bridge work in Optimism?
# What are standard bridges in Optimism?
# ----
# How do I enable metrics for the Bedrock `op-node`?
# Can I customize the metrics endpoint for the Bedrock `op-node`?
# ----
# How can I run `op-geth` and `op-node` for Optimism?
# How can I configure `op-geth` for Optimism?
# ----
# How do I initialize `op-geth` for OP Sepolia?
# How do I initialize the data directory for OP Sepolia using `op-geth`?
# ----
# How much disk space do I need for running an OP Mainnet or OP Goerli node?
# What storage capacity is needed for running a node on OP Mainnet?
# ----
# How can I tell if my `op-node` is pointing to the wrong chain?
# What steps should I take to fix my `op-node` if it's pointing to the wrong chain?
# ----
# How can I estimate the cost of a transaction in Optimism?
# Is there a way to estimate the costs of a transaction on Optimism?
# How can I estimate the total fee for a transaction on Optimism?
# How can I estimate the L2 execution fee on Optimism?
# ----
# How are transaction fees structured in OP Mainnet?
# How are transaction fees structured on the OP Mainnet?
# How are transaction fees calculated on OP Mainnet?
# What are the components of transaction fees on OP Mainnet?
# How do transaction fees on OP Mainnet compare to those on Ethereum?
# What are the types of fees I need to pay for a transaction on the OP Mainnet?
# Are there any fees associated with transactions on the OP Mainnet?
# What is the recommendation for displaying transaction fees on OP Mainnet?
# ----
# How can I estimate the total cost of a transaction on OP Mainnet?
# How can I calculate the gas cost of transactions on OP Mainnet?
# How can I display the estimated cost of a transaction to users on OP Mainnet?
# Is there a resource to help me estimate gas fees for OP Mainnet transactions?
# How is the cost of an L2 transaction on OP Mainnet determined?
# ----
# How often are blocks produced on the OP Mainnet?
# How often are blocks produced on OP Mainnet?
# ----
# Why should I specify a higher base fee than the current value when making a transaction?
# Why might the base fee specified in a transaction be higher than the actual base fee paid?
# ----
# Where can I find the current L2 base fee for Optimism?
# How can I estimate the L2 execution fee on Optimism?
# How is the L2 execution fee calculated in Optimism?
# ----
# What is the typical priority fee on OP Mainnet?
# How much should I set for the priority fee on OP Mainnet?
# Where can I check the current priority fee values for OP Mainnet?
# ----
# How can I trigger a contract function on OP Mainnet from Ethereum?
# How can I interact with OP Mainnet contracts?
# How can I interact with OP Mainnet system contracts from another contract?
# ----
# How can I connect my dapp to both Ethereum and OP Mainnet?
# Can a client connect to both Ethereum and OP Mainnet?
# How can I connect to OP Mainnet?
# ----
# How does Optimism ensure decentralization similar to OP Mainnet and Ethereum?
# How does Optimism plan to achieve decentralization?
# ----
# How long does it take for an L1 transaction to update L2 code in Optimism?
# How long do L2 to L1 transactions take on Optimism?
# Is it expensive to make an L1 transaction to update L2 code in Optimism?
# Why is there a waiting period for L2 to L1 transactions on Optimism?
# ----
# Why is sending messages from L2 to L1 more difficult?
# Is it expensive to send messages from L2 to L1?
# ----
# How long does it take to send a message from L2 to L1?
# Is it expensive to send messages from L2 to L1?
# ----
# How do incentives work in Optimism governance?
# Is the incentive mechanism in Optimism governance truly decentralized?
# ----
# Where can I find the addresses of the messenger contracts on Optimism?
# Where can I find the address of a specific contract on Optimism?
# Where can I find the authoritative list of contract addresses for Optimism?
# ----
# Are transactions between Ethereum and OP Mainnet instantaneous?
# How long does it take for a transaction to go from Ethereum to OP Mainnet?
# ----
# What is the transaction challenge period for finalizing an L2 to L1 transaction on Optimism?
# Why is there a waiting period for L2 to L1 transactions on Optimism?
# ----
# How can I deposit ERC20 tokens into Optimism Layer 2?
# How can I deposit ETH into L2 on Optimism?
# ----
# How can I check if a token can use the standard bridge on Optimism?
# How can I add my token to the standard bridge on Optimism?
# ----
# What happens after I deposit ETH into L2 on Optimism?
# How can I deposit ETH into L2 on Optimism?
# How do I withdraw ETH on L2 in Optimism?
# ----
# What address should I use as the L2 token address when withdrawing ETH on Optimism?
# How do I withdraw ETH on L2 in Optimism?
# ----
# How can I add my token to the Superchain token list?
# What do I need to do to add my custom bridge and token to the Superchain token list?
# ----
# How does the cost of using a decentralized application on OP Mainnet compare to using one on L1 Ethereum?
# Can the cost of using decentralized applications on OP Mainnet be reduced further?
# Where can I find the current cost values for using decentralized applications on OP Mainnet?
# ----
# Where can I find the current gas costs for transactions on OP Mainnet?
# Where can I check the current gas prices for OP Mainnet?
# How can I calculate the gas cost of transactions on OP Mainnet?
# How can I find out the gas prices on OP Mainnet?
# Is there a resource to help me estimate gas fees for OP Mainnet transactions?
# What gas price should I use when sending a transaction on OP Mainnet?
# Are gas prices on OP Mainnet higher or lower compared to Ethereum?
# ----
# Why are transaction costs on OP Mainnet different from those on Ethereum?
# How do transaction fees on OP Mainnet compare to those on Ethereum?
# Why is the cost of an OP Mainnet transaction usually low?
# How is the cost of writing a transaction in Ethereum handled on OP Mainnet?
# ----
# Why should I use the local development environment for my application?
# Why might it be more practical to use a local development environment for testing certain features?
# ----
# How do I start the development network for Optimism?
# How can I stop the development network for Optimism?
# ----
# How are transactions processed in Optimism's mempool?
# How are transactions processed and posted in Optimism?
# ----
# Does OP Mainnet use the same API as Ethereum?
# Are there any differences between the OP Mainnet and the Ethereum JSON-RPC API?
# ----
# Are there any additional methods specific to OP Mainnet?
# Is there an OP Mainnet?
# ----
# Are the addresses for infrastructure contracts the same on L1 Ethereum and OP Mainnet?
# Can you give an example of a contract with different addresses on L1 Ethereum and OP Mainnet?
# ----
# What are some reasons I might want to interact with OP Mainnet contracts?
# How can I interact with OP Mainnet contracts?
# How can I interact with OP Mainnet system contracts from another contract?
# How can I interact with the OP Mainnet system contracts from the client side?
# ----
# How do I get the contract addresses for different networks on Optimism?
# Where can I find the authoritative list of contract addresses for Optimism?
# Where can I find the address of a specific contract on Optimism?
# ----
# Where can I find the address of the OP Mainnet system contract I want to interact with?
# How can I interact with OP Mainnet contracts?
# Where can I find the OP Mainnet endpoints?
# How can I interact with OP Mainnet system contracts from another contract?
# How can I interact with the OP Mainnet system contracts from the client side?
# ----
# Where can I find the path to a specific Optimism contract?
# Where can I find the address of a specific contract on Optimism?
# Where can I find the OptimismPortal contract?
# ----
# How can I interact with the OP Mainnet system contracts from a JavaScript or TypeScript project?
# How can I interact with the OP Mainnet system contracts from the client side?
# How can I interact with OP Mainnet contracts?
# How can I interact with OP Mainnet system contracts from another contract?
# ----
# Are there any differences in testing decentralized applications on OP Mainnet compared to Ethereum?
# Are there any differences between Ethereum and OP Mainnet?
# What are the differences between Ethereum and OP Mainnet?
# ----
# Why might some dapps need OP Mainnet-specific features?
# What is an example of a feature that might require OP Mainnet-specific development?
# ----
# Where can I find the current L2 base fee?
# Where can I find the current L2 base fee for OP Mainnet?
# ----
# Why do users on OP Mainnet have to pay an L1 data fee?
# What factors determine the L1 data fee on OP Mainnet?
# ----
# How do I send a transaction on OP Mainnet?
# How can I use OP Mainnet with my wallet?
# How can I connect to OP Mainnet?
# How do I connect to the OP Mainnet?
# ----
# Why can't I just use the gas price and gas limit to estimate fees on OP Mainnet?
# Is there a resource to help me estimate gas fees for OP Mainnet transactions?
# ----
# How can I estimate the L1 data fee on the Optimism network?
# How can I estimate the L2 execution fee on Optimism?
# How can I estimate the total fee for a transaction on Optimism?
# ----
# What are the fees involved when sending ETH on Optimism?
# How can I estimate the total fee for a transaction on Optimism?
# ----
# Why might my transaction on the OP Chain become stuck?
# Is there a way to fix a stuck transaction on the OP Chain?
# ----
# Does setting a high maximum fee per gas increase my transaction cost on Optimism?
# How can I manage the gas fees for my transactions on Optimism?
# ----
# Where can I find governance videos for Optimism?
# Where can I find videos related to governance for Optimism?
# Is there a video related to Optimism Governance that I can watch?
# Where can I find more visual content about Optimism Governance?
# Can you explain what the video in the Optimism Governance Documentation is about?
# What are some of the initiatives mentioned in the video related to Optimism governance?
# Who is featured in the video discussing Optimism governance?
# ----
# How do I get test ETH for development on OP Goerli?
# Where can I get test ETH for the OP Goerli network?
# Where can I obtain ETH and tokens for testing on the OP Goerli network?
# ----
# Did Optimism participate in any events in early 2023?
# Was there an event related to Optimism in early 2023?
# ----
# Who participated in the panel about scaling Ethereum for global adoption?
# Where can I watch the panel discussion on scaling Ethereum for global adoption?
# ----
# What was the main topic of the panel discussion?
# What topics were discussed in the panel?
# ----
# What storage capacity is needed for running a node on OP Sepolia?
# What storage capacity is needed for running a node on OP Mainnet?
# ----
# How do I clone the Optimism Monorepo?
# What should I do to build the packages inside the Optimism Monorepo?
# ----
# How do I install the required modules for the Optimism Monorepo?
# What should I do to build the packages inside the Optimism Monorepo?
# ----
# How do I clone the `op-geth` repository?
# How do I build `op-geth` after cloning it?
# ----
# How can I run the OP Mainnet from source?
# How can I run the OP Testnet from the source code?
# How can I start developing on OP Mainnet?
# How can I use OP Mainnet with my wallet?
# ----
# What should I do if I want to reduce the chance of my data directory being corrupted during the download?
# What tool can I use to reduce the chance of my data directory being corrupted during download?
# ----
# How do I create a new script file in the `scripts` directory?
# How do I create a new script file in the terminal?
# ----
# How can I estimate the synchronization time for my Optimism node?
# How can I estimate the time it will take to synchronize my Optimism node?
# ----
# Why should I start `op-geth` first and shut it down last?
# Why is it recommended to start `op-geth` first and shut it down last?
# ----
# How does Optimism plan to reward those who create or sustain public goods?
# How does Optimism plan to fund public goods?
# How does Optimism support public goods?
# ----
# Why is retroactive public goods funding considered advantageous?
# How does retroactive public goods funding encourage initial investment?
# What is Retroactive Public Goods Funding?
# ----
# What are the components of the Optimism Collective's initial governance model?
# How does the Optimism Collective approach governance?
# How does the governance system of the Optimism Collective work?
# How did the governance of the Optimism Collective start?
# ----
# Has Airdrop 1 been fully distributed?
# When was the distribution of Airdrop 1 completed?
# ----
# Who is eligible for the Optimism Foundation’s Airdrop #1?
# Who was eligible for the Optimism airdrop?
# How can I check if I'm eligible for Airdrop #1 on Optimism?
# ----
# What does 'distinct weeks' mean in the context of Optimism's user activity?
# Why does Optimism use the concept of 'distinct weeks' instead of calendar weeks?
# ----
# Who are the multi-sig signers in the Optimism governance system?
# What types of multisig wallets are included in the Optimism governance system?
# ----
# Who is eligible for retroactive funding from Optimism?
# Who is eligible for Retro Funding in the Optimism ecosystem?
# ----
# How can I get involved in the Optimism community if I'm not a developer?
# How can I contribute to the Optimism project if I'm not a developer?
# How can I get in touch with the Optimism team for support or to contribute?
# ----
# How many OP tokens were distributed in Optimism’s Airdrop #1 and to how many users?
# How many OP tokens were distributed in Optimism’s Airdrop #2?
# ----
# How can I qualify for the Governance Delegation Reward on Optimism?
# How can I earn a Governance Delegation Reward in Optimism?
# ----
# How many addresses qualify for the highest multiplier bonus?
# How many attributes do addresses need to earn the highest multiplier bonus?
# Do all addresses receive a multiplier bonus?
# ----
# What is the multiplier bonus for addresses with 3 attributes?
# How many attributes do addresses need to earn the highest multiplier bonus?
# ----
# What does '54,367 total OP Delegated x Days' mean?
# How is 'OP Delegated x Days' calculated?
# ----
# How many tokens were allocated in Airdrop 3?
# Who received tokens in Airdrop 3?
# ----
# Who was eligible to receive tokens in Airdrop 3?
# Who received tokens in Airdrop 3?
# ----
# How do I calculate my Cumulative Delegated OP for the airdrop?
# What is the minimum Cumulative Delegated OP required to qualify for the airdrop?
# ----
# What is the purpose of Airdrop #4?
# What was special about Airdrop 4?
# ----
# How is the funding allocated within the Optimism Collective?
# How does the Optimism Collective decide what to fund?
# How is the Ecosystem Fund allocated within the Optimism Collective ecosystem?
# ----
# What is the purpose of the Ecosystem Fund in the Optimism Collective?
# How is the Ecosystem Fund allocated within the Optimism Collective ecosystem?
# What is the purpose of the Governance Fund in the Optimism ecosystem?
# ----
# How much of the OP allocation will the Optimism Foundation distribute?
# Who will receive the OP allocation from the Optimism Foundation?
# ----
# How many unique addresses received tokens in Optimism’s Airdrop #2?
# How many OP tokens were distributed in Optimism’s Airdrop #2?
# ----
# Who received tokens in Airdrop 4?
# Who received tokens in Airdrop 3?
# ----
# When did Airdrop 4 take place?
# What was special about Airdrop 4?
# ----
# How much of the OP token supply is reserved for future user airdrops?
# How much of the OP token supply is reserved for future programs and operational services?
# ----
# How much of the OP token supply is dedicated to the first Governance Fund?
# How much of the OP token supply is dedicated to the Seed Fund?
# ----
# What is the purpose of the Partner Fund in the Optimism ecosystem?
# What is the purpose of the Seed Fund in the Optimism ecosystem?
# ----
# How often are Retroactive Public Goods Funding (RetroPGF) rounds expected to occur?
# What is Retroactive Public Goods Funding (RetroPGF)?
# ----
# What is the purpose of RetroPGF rounds?
# What's the purpose of RetroPGF Round 2?
# What was the purpose of RetroPGF Round 3?
# What is RetroPGF and what was achieved in its first round?
# What's RetroPGF Round 3?
# ----
# What is Retroactive Public Goods Funding (Retro Funding) and who decides on its allocation?
# What is Retroactive Public Goods Funding?
# What is Retroactive Public Goods Funding (RetroPGF)?
# What is Retro Funding and who decides which projects receive it?
# ----
# Where does the funding for Retro Funding come from?
# What is Retro Funding?
# What is Retro Funding and who decides which projects receive it?
# ----
# How does Retroactive Public Goods Funding (Retro Funding) work in the Optimism ecosystem?
# What's Retroactive Public Goods Funding (Retro Funding) in the context of Optimism?
# How does Retro Funding benefit builders in the Optimism ecosystem?
# Who is eligible for Retro Funding in the Optimism ecosystem?
# What is the main value behind Optimism's Retro Funding?
# ----
# What was the outcome of the first Retro Funding round?
# When did the first round of Retro Funding take place?
# How much money was allocated in the first round of Retro Funding?
# How many projects were awarded funding in the first round of Retro Funding?
# How many projects were awarded funding in the second round of Retro Funding?
# When is the next Retro Funding round scheduled to take place?
# ----
# What should I know before deciding to become a delegate in Token House governance?
# What is the role of a delegate in Token House governance?
# ----
# Where can I find the delegate responsibilities for Optimism Governance?
# How can I become a delegate in Optimism Governance?
# How can I register to be a delegate for Optimism Governance?
# What should I do if I want to become a delegate in Optimism's governance?
# ----
# Is it necessary to delegate my OP tokens' voting power to myself?
# What happens to my voting power when I delegate my OP tokens?
# ----
# How do contributors and builders benefit from the Optimism ecosystem?
# What benefits do users and community members receive from the Optimism ecosystem?
# How can builders benefit from Optimism's funding mechanisms?
# ----
# What is the role of The Optimism Foundation in the funding process?
# What is the role of the Optimism Foundation?
# What role does the Optimism Foundation play in governance?
# ----
# How is governance structured in the Optimism Foundation?
# What role does the Optimism Foundation play in governance?
# Who governs the Optimism Foundation?
# How does the governance system of the Optimism Collective work?
# How does Optimism governance approach its development?
# How does the Optimism Collective approach governance?
# ----
# How does the Optimism Collective support builders with grants?
# How can builders benefit from Optimism's funding mechanisms?
# ----
# What types of projects have been rewarded in past rounds of Retro Funding?
# How many projects were awarded funding in the first round of Retro Funding?
# How many projects were awarded funding in the second round of Retro Funding?
# How many people and projects were nominated in the second round of Retro Funding?
# ----
# Where can I discuss the Governance Fund for Optimism?
# How can I participate in general governance discussions for Optimism?
# ----
# Is there a video available about Optimism at ETHDenver 2023?
# When did the Optimism event at ETHDenver 2023 take place?
# ----
# What is the main theme of the video about Optimism governance?
# Can you explain what the video in the Optimism Governance Documentation is about?
# Who is featured in the video discussing Optimism governance?
# What are some of the initiatives mentioned in the video related to Optimism governance?
# Is there a video related to Optimism Governance that I can watch?
# ----
# Where can I find Justine's research on DAO governance and policy?
# What did Justine do with her research findings on DAO governance?
# Is there a video presentation of Justine's findings on DAO governance?
# ----
# How can I apply for grant funding from the Governance Fund?
# Where can I find the application form for the Governance Fund?
# ----
# What was the median funding amount received by a project in Retro Funding 1?
# How many projects were awarded funding in the first round of Retro Funding?
# How much money was allocated in the first round of Retro Funding?
# ----
# Who were the badgeholders in RetroPGF Round 1?
# How were the badgeholders for RetroPGF 3 selected?
# ----
# How could someone nominate a project for RetroPGF Round 1?
# How can a project be nominated for RetroPGF Round 2?
# Is there a nomination process for projects to be considered for RetroPGF 3?
# What is the process for projects to participate in RetroPGF Round 2 after being nominated?
# ----
# When did the voting for RetroPGF Round 1 take place?
# When did RetroPGF Round 3 happen?
# How long was the voting period for RetroPGF 3?
# What's RetroPGF Round 3?
# ----
# When did the second round of Retroactive Public Goods Funding take place?
# What is Retroactive Public Goods Funding?
# ----
# Where can I find information about the learnings and reflections from round 2 of Optimism Governance?
# How will the learnings from round 2 be used in Optimism Governance?
# ----
# How long is the project application period for Optimism Governance?
# When does the voting period for Optimism Governance take place?
# ----
# What tools were available for badgeholders to vote in RetroPGF 3?
# How does voting in RetroPGF 3 work?
# ----
# How often does Optimism have voting cycles?
# How often do the voting cycles for Optimism occur?
# What kind of proposals are included in Optimism's voting cycles?
# ----
# Where can I find information about the results of previous voting cycles for Optimism?
# Where can I find information about the different voting cycles for Optimism governance?
# ----
# When did Voting Cycle #8 for Optimism take place?
# How often do the voting cycles for Optimism occur?
# ----
# How many voting cycles have been documented in the Optimism governance forum?
# Where can I find information about the different voting cycles for Optimism governance?
# How often do the voting cycles for Optimism occur?
# What is the purpose of the voting cycle roundups in the Optimism governance documentation?
# ----
# Who or what is the Optimism Foundation?
# What is the role of the Optimism Foundation?
# Who governs the Optimism Foundation?
# ----
# What kind of activities can the Optimism Foundation perform due to its legal status?
# Why is the legal status of the Optimism Foundation important for its operations?
# ----
# Who are the current members of the Board of Directors for the Optimism Foundation?
# Who governs the Optimism Foundation?
# ----
# Where can I find guides for using the OP Mainnet?
# Where can I find information about OP Mainnet and test networks?
# ----
# Where can I get testnet ETH for OP Mainnet?
# How can I get testnet ETH for use on OP Chain testnets?
# ----
# Where can I find information on integrating OP Mainnet with my wallet?
# How can I use OP Mainnet with my wallet?
# ----
# Are there resources for writing a custom bridge for OP Mainnet?
# How can I add a custom bridge to the OP Mainnet?
# Can I create my own custom bridge if the OP Mainnet Standard bridge doesn't meet my needs?
# ----
# Are the ERC-20 contract addresses for tokens the same on OP Mainnet and Ethereum?
# Is the ERC-20 contract address for a token on OP Mainnet the same as on Ethereum?
# How can I find the ERC-20 contract addresses for tokens on OP Mainnet?
# ----
# How can I transfer assets from Ethereum mainnet to Optimism Mainnet?
# How does Optimism handle asset transfers between Ethereum and its own network?
# ----
# Where can I find the contract address for the token OUT-1 on Optimism?
# How can I verify the contract address for the token OUT-3 on Optimism?
# Where can I find the address of a specific contract on Optimism?
# ----
# What is the address of the ERC-721 token contract on OP Goerli?
# What is special about the ERC-721 token contract on OP Goerli?
# ----
# How can I find the ERC-20 contract address for a token on the OP Mainnet?
# How can I find the ERC-20 contract addresses for tokens on OP Mainnet?
# Is the ERC-20 contract address for a token on OP Mainnet the same as on Ethereum?
# ----
# Why is decentralized identity important in the context of Optimism?
# How does Optimism handle decentralized identity?
# What role does decentralized identity play in the Optimism Collective?
# How does decentralized identity contribute to democratic governance in the Optimism Collective?
# ----
# What benefits does decentralized identity provide to individuals?
# How does decentralized identity benefit individuals?
# ----
# How does decentralized identity work on the Superchain?
# What are some applications of decentralized identity on the Superchain?
# ----
# What is the role of the AttestationStation in decentralized identity?
# What's an attestation in the context of decentralized identity?
# ----
# Which applications use the AttestationStation?
# What are some benefits of using the AttestationStation?
# ----
# How can I query and submit attestations on Optimism?
# How can I create attestations in Optimism?
# How do I know when an attestation has been successfully made in Optimism?
# ----
# What are the main attributes of an attestation in AttestationStation v0?
# What are some benefits of using the AttestationStation?
# ----
# Where can I find the legacy AttestationStation contract in the Optimism monorepo?
# What is the address of the legacy AttestationStation contract on the Optimism Mainnet?
# Is the legacy AttestationStation contract also deployed on Optimism Goerli?
# ----
# What information is included in the `AttestationCreated` event in Optimism?
# What information is included in the `AttestationCreated` event?
# ----
# Who can create an attestation in the AttestationStation?
# Who can use the AttestationStation?
# ----
# What are the parameters required for the `attest` function?
# What is the parameter required for the `attest` function?
# ----
# How can I build decentralized identity apps using attestations?
# What are attestations in the context of decentralized identity apps?
# ----
# What is an attestation in the context of Optimism?
# How do I know when an attestation has been successfully made in Optimism?
# How is an attestation represented in Optimism's governance documentation?
# How can I create attestations in Optimism?
# What is the purpose of the AttestationStation in Optimism?
# ----
# Who can issue an attestation in a decentralized identity system?
# What's an attestation in the context of decentralized identity?
# ----
# What is the purpose of the AttestationStation?
# What are some benefits of using the AttestationStation?
# What is the purpose of the AttestationStation in Optimism?
# Who can use the AttestationStation?
# ----
# Can anyone create an Optimist Profile?
# How is an Optimist Profile created?
# How is the Optimist Profile built?
# ----
# What is the purpose of an Optimist Profile?
# How is an Optimist Profile created?
# How is the Optimist Profile built?
# ----
# Where can I find the Superchain Faucet schema UID for Optimism?
# What is the UID for the Superchain Faucet schema in Optimism?
# ----
# Where can I find the Governance contribution schema UID?
# Where can I find the schema UID for the RetroPGF governance contributor?
# ----
# Can you explain the main principles behind the design of Optimism?
# What does the design philosophy of Optimism emphasize?
# How does Optimism work?
# ----
# What are the benefits of Optimism's simplicity in its design?
# Why does Optimism prioritize simplicity in its codebase?
# ----
# How does the design philosophy of Optimism prioritize user and developer needs?
# What does the design philosophy of Optimism emphasize?
# ----
# How does Optimism ensure that its protocol remains sustainable?
# How does Optimism ensure its security?
# ----
# How is Optimism related to Ethereum?
# How does Optimism ensure the validity of state commitments on Ethereum?
# ----
# What is the main goal of Optimism?
# What is the main goal of the Optimism Collective?
# ----
# Why is Optimism built as an Optimistic Rollup?
# What is an Optimistic Rollup?
# ----
# What parent blockchain does OP Mainnet use?
# Is there an OP Mainnet?
# ----
# What tools can be used to perform deposit transactions in Optimism?
# What are deposit transactions in Optimism?
# What's a deposit transaction in Optimism?
# ----
# Is the fault proof mechanism currently active on the OP Mainnet network?
# Does OP Mainnet currently have fault proofs?
# ----
# What is the purpose of the deposit flow in Optimism?
# What are deposit transactions in Optimism?
# What's a deposit transaction in Optimism?
# How does the deposit process work in Optimism?
# ----
# How is the process of a deposit transaction in Optimism similar to networking?
# What's a deposit transaction in Optimism?
# What are deposit transactions in Optimism?
# ----
# How does the `op-node` component handle `TransactionDeposited` events on L1?
# What happens after the `op-node` converts `TransactionDeposited` events into deposit transactions?
# ----
# Who bears the cost of a deposit transaction in Optimism?
# What's a deposit transaction in Optimism?
# What are deposit transactions in Optimism?
# How does the deposit process work in Optimism?
# ----
# What can I do if my deposit transaction fails on Optimism?
# Why might a deposit transaction fail on Optimism?
# What's a deposit transaction in Optimism?
# What are deposit transactions in Optimism?
# How does the deposit process work in Optimism?
# ----
# How does Optimism handle communication between Layer 1 and Layer 2?
# How can I send messages between Layer 1 (L1) and Layer 2 (L2) in Optimism?
# ----
# Which networks are supported by the `L1StandardBridge` for transferring assets?
# How does the `L1StandardBridge` contract facilitate the transfer of assets between different layers?
# ----
# How does the Sequencer get funded on Optimism?
# How are sequencer fees determined in Optimism?
# ----
# Are there different versions of the `L2ToL1MessagePasser` contract?
# Are there different versions of the `L2ToL1MessagePasser` contract in Optimism?
# Are there different versions of the `L2ToL1MessagePasser` contract in Optimism's Bedrock?
# ----
# How does the `L2CrossDomainMessenger` contract function in the Optimism network?
# How does the `sendMessage` function work in Optimism's L2CrossDomainMessenger?
# What is the purpose of the `L2CrossDomainMessenger` contract?
# What is the purpose of the L2CrossDomainMessenger contract?
# ----
# How are assets like ETH and ERC-20 tokens sent in the Optimism network?
# How does Optimism handle asset transfers between Ethereum and its own network?
# ----
# Why am I being redirected when I try to access the sequencing documentation on Optimism's website?
# What is the new URL for the sequencing documentation on Optimism's website?
# ----
# How can I check if my transaction on the Optimism network is finalized?
# What does it mean if my transaction on the Optimism network is neither finalized nor safe?
# ----
# How do I find out if my transaction on the Optimism network is safe?
# What does it mean if my transaction on the Optimism network is neither finalized nor safe?
# ----
# What is `op-geth`?
# Where can I find more information about `op-geth`?
# ----
# What are the steps involved in making a withdrawal from Optimism to Ethereum?
# Do I need to perform multiple transactions to withdraw assets from Optimism to Ethereum?
# ----
# How does the SDK prove a message in Optimism?
# How does the SDK finalize a message in Optimism?
# ----
# How does the SDK get the raw withdrawal fields from an L2 transaction hash?
# How does the SDK retrieve the raw withdrawal fields from an L2 transaction?
# ----
# What is the final step the SDK takes to prove a withdrawal transaction on L1?
# What is the final step the SDK takes to complete a withdrawal transaction on L1?
# ----
# How does the `OptimismPortal.proveWithdrawalTransaction()` function ensure the legitimacy of a withdrawal transaction?
# What happens after the `OptimismPortal.proveWithdrawalTransaction()` function verifies a withdrawal transaction?
# ----
# Does Alchemy provide any tools for interacting with Optimism?
# Does Alchemy offer any free services for developers working with Optimism?
# ----
# How do I bridge ETH to Optimism?
# How can I bridge my Goerli ETH to Optimism?
# ----
# Are there any risks associated with using OP Mainnet?
# Is there an OP Mainnet?
# ----
# Why don't fault proofs improve the security of OP Mainnet?
# What is OP Mainnet's goal regarding fault proofs?
# Does OP Mainnet currently have fault proofs?
# ----
# Are there any bug bounties available for Optimism?
# Has Optimism ever paid out a large bounty for a bug?
# Where can I find more information about a specific bug that Optimism paid a large bounty for?
# Where can I find information about Optimism's bug bounty program?
# ----
# What is the purpose of the bug bounty program in Optimism?
# Where can I find information about Optimism's bug bounty program?
# ----
# How does Optimism handle security?
# How does Optimism ensure its security?
# ----
# Are there any privileged roles in OP Mainnet?
# Why do privileged roles exist in OP Mainnet?
# ----
# What happens if access to the authorized account is lost?
# What are the risks if the authorized account is compromised?
# ----
# Who has the ability to upgrade most of the L1 contracts in Optimism?
# Who controls most of the L2 contracts in Optimism?
# ----
# What could happen if the account controlling the L1 contracts is compromised?
# What happens if the account controlling the L2 contracts is compromised?
# ----
# What is the mainnet address for the OptimismPortal?
# What is the Goerli testnet address for the OptimismPortal?
# ----
# How can I get ETH for deployment gas fees on Optimism?
# How can I manage the gas fees for my transactions on Optimism?
# ----
# Are there any tools to explore blocks and transactions on Optimism?
# How can I monitor transactions and block data on Optimism?
# ----
# Where can I find information on account abstraction infrastructure for my dapp on OP Mainnet?
# Which platforms provide documentation for account abstraction on OP Mainnet?
# ----
# How can I inspect the execution of a transaction on OP Mainnet or OP Goerli?
# Where can I explore transactions on the OP Mainnet?
# ----
# Where can I see events on the OP Mainnet?
# Is there a way to see what's happening on OP Mainnet?
# Where can I explore transactions on the OP Mainnet?
# ----
# What's a block explorer?
# Why would I use a block explorer?
# ----
# How can developers get free testnet ETH for testing their apps on OP Chains?
# How can I get testnet ETH for use on OP Chain testnets?
# ----
# Is there a faucet that provides test ETH for both OP Goerli and OP Sepolia networks?
# Where can I get test ETH for the OP Goerli network?
# ----
# Where can I find resources to learn about onchain development for Optimism?
# Are there any project ideas available for developers familiar with onchain development in the Optimism ecosystem?
# ----
# How do meta-transactions work?
# What are some use cases for meta-transactions?
# ----
# What are the different networks available for Optimism?
# Which networks does Optimism support?
# ----
# Where can I check the status of the OP Mainnet?
# Is there a way to see what's happening on OP Mainnet?
# Where can I find the OP Mainnet endpoints?
# Is there an OP Mainnet?
# ----
# Where can I find detailed information about what's happening on OP Mainnet and OP Goerli?
# Is there a way to see what's happening on OP Mainnet?
# Where can I find information about OP Mainnet and test networks?
# ----
# How can I find dashboards with information about OP Mainnet?
# Are there any recommended dashboards for OP Mainnet?
# Is there a way to see what's happening on OP Mainnet?
# ----
# Can I create my own dashboard for OP Mainnet?
# Are there any recommended dashboards for OP Mainnet?
# ----
# What is the Chain ID for the Optimism network?
# What is the Chain ID for Optimism Goerli?
# ----
# What is the L1 Chain ID for this network?
# What's the L1 Chain ID for the network?
# ----
# Do I need the Legacy Geth Data Directory if I am running an archive only for post-bedrock transactions?
# Do I need the Legacy Geth Data Directory file if I'm only running an archive for post-bedrock transactions?
# ----
# What's the difference between push oracles and pull oracles?
# What are the types of pull oracles?
# ----
# How can I get up-to-date price information on OP Mainnet?
# Where can I check the current gas prices for OP Mainnet?
# How can I find out the gas prices on OP Mainnet?
# ----
# How can I start using BlockSpaces for Web3 infrastructure?
# Is there a cost associated with using BlockSpaces for Web3 infrastructure?
# ----
# Is there an OP Mainnet for Optimism?
# Is there an OP Mainnet?
# ----
# How can I access Optimism nodes for free?
# Is there an option to get more features for accessing Optimism nodes?
# ----
# How can I connect to the OP Mainnet MegaNode for free?
# Can I access OP Mainnet nodes for free?
# ----
# How can I access an OP Mainnet node through NOWNodes?
# Is there a free option to use NOWNodes for accessing the OP Mainnet node?
# ----
# What are the pricing options for using NOWNodes to access the OP Mainnet node?
# Is there a free option to use NOWNodes for accessing the OP Mainnet node?
# ----
#       fragment                                           question  \
# 0            0  How can I get support for my project on Optimism?
# 2            0  What should I do before deploying my project o...
# 3            1  Where can I find tutorials for developing on O...
# 5            1  Is there a Discord channel for developer suppo...
# 6            2  How can I get my project listed on the Superch...
# ...        ...                                                ...
# 1866       758  How can developers access OP Mainnet nodes thr...
# 1867       758  Is there a free tier available for using OP Ma...
# 1870       760  Are there any premium options available for OP...
# 1871       760  Do I need to manage the infrastructure if I us...
# 1873       762  Who provides ERC-4337 account abstraction infr...
#
#                                                  answer  \
# 0     To get support for your project on Optimism, y...
# 2     Before deploying your project on OP Mainnet, y...
# 3     You can find tutorials for developing on Optim...
# 5     Yes, there is a Discord channel for developer ...
# 6     To get your project listed on the Superchain a...
# ...                                                 ...
# 1866  Developers can access OP Mainnet nodes through...
# 1867  Yes, there is a generous free tier available t...
# 1870  Yes, QuickNode provides an option to upgrade t...
# 1871  No, QuickNode manages the complex infrastructu...
# 1873  Stackup provides ERC-4337 account abstraction ...
#
#                                           fragment_text
# 0     ---\ntitle: How do I get project support (mark...
# 2     ---\ntitle: How do I get project support (mark...
# 3     Steps to take if you would like developer supp...
# 5     Steps to take if you would like developer supp...
# 6     When your project is deployed on the Superchai...
# ...                                                 ...
# 1866  [Pocket](https://www.portal.pokt.network/) off...
# 1867  [Pocket](https://www.portal.pokt.network/) off...
# 1870  [QuickNode](https://www.quicknode.com/) offers...
# 1871  [QuickNode](https://www.quicknode.com/) offers...
# 1873  [Stackup](https://www.stackup.sh/) provides ER...
#
# [1270 rows x 4 columns]

# %% [markdown]
# # Clustering questions using hdbscan

# %%
import hdbscan

# cluster the questions
clusterer = hdbscan.HDBSCAN(min_cluster_size=2, min_samples=1, cluster_selection_epsilon=0.5)
clusters = clusterer.fit(cleaned_questions_emb)

cs_q = clusters.labels_

# count the number of elements in each cluster
for c in np.unique(cs_q):
    print(f"cluster {c} has {len(cs_q[cs_q == c])} elements")
# Out:
# cluster -1 has 457 elements
# cluster 0 has 4 elements
# cluster 1 has 2 elements
# cluster 2 has 2 elements
# cluster 3 has 2 elements
# cluster 4 has 2 elements
# cluster 5 has 2 elements
# cluster 6 has 2 elements
# cluster 7 has 4 elements
# cluster 8 has 4 elements
# cluster 9 has 3 elements
# cluster 10 has 2 elements
# cluster 11 has 3 elements
# cluster 12 has 2 elements
# cluster 13 has 3 elements
# cluster 14 has 3 elements
# cluster 15 has 2 elements
# cluster 16 has 2 elements
# cluster 17 has 2 elements
# cluster 18 has 2 elements
# cluster 19 has 2 elements
# cluster 20 has 2 elements
# cluster 21 has 2 elements
# cluster 22 has 2 elements
# cluster 23 has 2 elements
# cluster 24 has 4 elements
# cluster 25 has 3 elements
# cluster 26 has 5 elements
# cluster 27 has 5 elements
# cluster 28 has 2 elements
# cluster 29 has 2 elements
# cluster 30 has 2 elements
# cluster 31 has 2 elements
# cluster 32 has 3 elements
# cluster 33 has 2 elements
# cluster 34 has 2 elements
# cluster 35 has 2 elements
# cluster 36 has 3 elements
# cluster 37 has 2 elements
# cluster 38 has 2 elements
# cluster 39 has 3 elements
# cluster 40 has 2 elements
# cluster 41 has 4 elements
# cluster 42 has 2 elements
# cluster 43 has 3 elements
# cluster 44 has 2 elements
# cluster 45 has 2 elements
# cluster 46 has 2 elements
# cluster 47 has 3 elements
# cluster 48 has 3 elements
# cluster 49 has 3 elements
# cluster 50 has 3 elements
# cluster 51 has 4 elements
# cluster 52 has 2 elements
# cluster 53 has 5 elements
# cluster 54 has 2 elements
# cluster 55 has 2 elements
# cluster 56 has 5 elements
# cluster 57 has 2 elements
# cluster 58 has 4 elements
# cluster 59 has 2 elements
# cluster 60 has 2 elements
# cluster 61 has 2 elements
# cluster 62 has 2 elements
# cluster 63 has 3 elements
# cluster 64 has 2 elements
# cluster 65 has 2 elements
# cluster 66 has 5 elements
# cluster 67 has 2 elements
# cluster 68 has 2 elements
# cluster 69 has 2 elements
# cluster 70 has 2 elements
# cluster 71 has 2 elements
# cluster 72 has 3 elements
# cluster 73 has 3 elements
# cluster 74 has 3 elements
# cluster 75 has 5 elements
# cluster 76 has 2 elements
# cluster 77 has 3 elements
# cluster 78 has 2 elements
# cluster 79 has 14 elements
# cluster 80 has 2 elements
# cluster 81 has 2 elements
# cluster 82 has 4 elements
# cluster 83 has 2 elements
# cluster 84 has 2 elements
# cluster 85 has 2 elements
# cluster 86 has 2 elements
# cluster 87 has 2 elements
# cluster 88 has 2 elements
# cluster 89 has 3 elements
# cluster 90 has 2 elements
# cluster 91 has 3 elements
# cluster 92 has 4 elements
# cluster 93 has 3 elements
# cluster 94 has 2 elements
# cluster 95 has 16 elements
# cluster 96 has 2 elements
# cluster 97 has 6 elements
# cluster 98 has 6 elements
# cluster 99 has 2 elements
# cluster 100 has 2 elements
# cluster 101 has 4 elements
# cluster 102 has 3 elements
# cluster 103 has 2 elements
# cluster 104 has 3 elements
# cluster 105 has 3 elements
# cluster 106 has 2 elements
# cluster 107 has 4 elements
# cluster 108 has 2 elements
# cluster 109 has 2 elements
# cluster 110 has 4 elements
# cluster 111 has 2 elements
# cluster 112 has 2 elements
# cluster 113 has 2 elements
# cluster 114 has 3 elements
# cluster 115 has 3 elements
# cluster 116 has 2 elements
# cluster 117 has 3 elements
# cluster 118 has 3 elements
# cluster 119 has 4 elements
# cluster 120 has 2 elements
# cluster 121 has 2 elements
# cluster 122 has 2 elements
# cluster 123 has 2 elements
# cluster 124 has 2 elements
# cluster 125 has 5 elements
# cluster 126 has 4 elements
# cluster 127 has 2 elements
# cluster 128 has 4 elements
# cluster 129 has 2 elements
# cluster 130 has 3 elements
# cluster 131 has 4 elements
# cluster 132 has 3 elements
# cluster 133 has 3 elements
# cluster 134 has 2 elements
# cluster 135 has 2 elements
# cluster 136 has 2 elements
# cluster 137 has 2 elements
# cluster 138 has 3 elements
# cluster 139 has 2 elements
# cluster 140 has 2 elements
# cluster 141 has 4 elements
# cluster 142 has 5 elements
# cluster 143 has 6 elements
# cluster 144 has 2 elements
# cluster 145 has 6 elements
# cluster 146 has 2 elements
# cluster 147 has 7 elements
# cluster 148 has 2 elements
# cluster 149 has 3 elements
# cluster 150 has 2 elements
# cluster 151 has 2 elements
# cluster 152 has 2 elements
# cluster 153 has 2 elements
# cluster 154 has 6 elements
# cluster 155 has 2 elements
# cluster 156 has 2 elements
# cluster 157 has 7 elements
# cluster 158 has 3 elements
# cluster 159 has 7 elements
# cluster 160 has 2 elements
# cluster 161 has 3 elements
# cluster 162 has 2 elements
# cluster 163 has 3 elements
# cluster 164 has 5 elements
# cluster 165 has 2 elements
# cluster 166 has 4 elements
# cluster 167 has 2 elements
# cluster 168 has 4 elements
# cluster 169 has 3 elements
# cluster 170 has 2 elements
# cluster 171 has 2 elements
# cluster 172 has 3 elements
# cluster 173 has 2 elements
# cluster 174 has 2 elements
# cluster 175 has 2 elements
# cluster 176 has 2 elements
# cluster 177 has 3 elements
# cluster 178 has 2 elements
# cluster 179 has 3 elements
# cluster 180 has 2 elements
# cluster 181 has 3 elements
# cluster 182 has 2 elements
# cluster 183 has 4 elements
# cluster 184 has 2 elements
# cluster 185 has 2 elements
# cluster 186 has 2 elements
# cluster 187 has 2 elements
# cluster 188 has 3 elements
# cluster 189 has 2 elements
# cluster 190 has 6 elements
# cluster 191 has 2 elements
# cluster 192 has 3 elements
# cluster 193 has 4 elements
# cluster 194 has 2 elements
# cluster 195 has 4 elements
# cluster 196 has 2 elements
# cluster 197 has 2 elements
# cluster 198 has 4 elements
# cluster 199 has 3 elements
# cluster 200 has 2 elements
# cluster 201 has 2 elements
# cluster 202 has 5 elements
# cluster 203 has 3 elements
# cluster 204 has 3 elements
# cluster 205 has 3 elements
# cluster 206 has 2 elements
# cluster 207 has 2 elements
# cluster 208 has 3 elements
# cluster 209 has 2 elements
# cluster 210 has 2 elements
# cluster 211 has 5 elements
# cluster 212 has 2 elements
# cluster 213 has 2 elements
# cluster 214 has 3 elements
# cluster 215 has 2 elements
# cluster 216 has 3 elements
# cluster 217 has 2 elements
# cluster 218 has 2 elements
# cluster 219 has 2 elements
# cluster 220 has 2 elements
# cluster 221 has 3 elements
# cluster 222 has 2 elements
# cluster 223 has 3 elements
# cluster 224 has 5 elements
# cluster 225 has 5 elements
# cluster 226 has 5 elements
# cluster 227 has 2 elements
# cluster 228 has 2 elements
# cluster 229 has 5 elements
# cluster 230 has 2 elements
# cluster 231 has 2 elements
# cluster 232 has 4 elements
# cluster 233 has 2 elements
# cluster 234 has 2 elements
# cluster 235 has 2 elements
# cluster 236 has 3 elements
# cluster 237 has 7 elements
# cluster 238 has 4 elements
# cluster 239 has 4 elements
# cluster 240 has 3 elements
# cluster 241 has 3 elements
# cluster 242 has 2 elements
# cluster 243 has 2 elements
# cluster 244 has 4 elements
# cluster 245 has 2 elements
# cluster 246 has 2 elements
# cluster 247 has 2 elements
# cluster 248 has 5 elements
# cluster 249 has 5 elements
# cluster 250 has 2 elements
# cluster 251 has 2 elements
# cluster 252 has 4 elements
# cluster 253 has 2 elements
# cluster 254 has 3 elements
# cluster 255 has 3 elements
# cluster 256 has 2 elements
# cluster 257 has 6 elements
# cluster 258 has 3 elements
# cluster 259 has 5 elements
# cluster 260 has 21 elements
# cluster 261 has 3 elements
# cluster 262 has 3 elements
# cluster 263 has 3 elements
# cluster 264 has 2 elements
# cluster 265 has 4 elements
# cluster 266 has 2 elements
# cluster 267 has 3 elements
# cluster 268 has 4 elements
# cluster 269 has 4 elements
# cluster 270 has 2 elements

# %% [markdown]
# # Clustering fragments using hdbscan

# %%
# get fragments
frags_uniques = test_clean['fragment_text'].unique()

# embeddings of the fragments
fragments_emb = embeddings.embed_documents(frags_uniques)
fragments_emb = np.array(fragments_emb)

# %%
# cluster the fragments
clusterer = hdbscan.HDBSCAN(min_cluster_size=10, min_samples=1, cluster_selection_epsilon=10)
clusters_fragments = clusterer.fit(fragments_emb)

cs_fr = clusters_fragments.labels_

# count the number of elements in each cluster
for c in np.unique(cs_fr):
    print(f"cluster {c} has {len(cs_fr[cs_fr == c])} elements")
# Out:
# cluster -1 has 201 elements
# cluster 0 has 381 elements
# cluster 1 has 14 elements

# %% [markdown]
# # Clustering questions using OpenAI Chat

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
model_chat = "gpt-3.5-turbo-0125"

# select the model
llm = ChatOpenAI(
    model = model_chat,
    temperature = 0,
    max_tokens = None,
    timeout = None,
    max_retries = 2,
    api_key = openai_api_key
)

# create the template for interactions
def answer_template():
    return f""" I'll give you a question about Optimism Documentation. You don't need to answer it, just categorize it (just return the number, one character) into one of the following categories:

1. general information / community engagement;
2. governance;
3. dev / project tech support / tech documentation;
4. marketing / promotion / ambassadors / events / PR;
5. other.

Question: {{question}}
"""

prompt = ChatPromptTemplate.from_template(answer_template())

chain = prompt | llm

# %%
clusters = {}
for q in cleaned_questions:
    cat = chain.invoke({"question": q})
    clusters[q] = cat.content
    print(f"Question: {q}")
    print(f"Category: {cat.content}")

clusters
# Out:
# Question: How can I get support for my project on Optimism?
# Category: 3
# Question: What should I do before deploying my project on OP Mainnet?
# Category: 3
# Question: Where can I find tutorials for developing on Optimism?
# Category: 3
# Question: Is there a Discord channel for developer support for Optimism?
# Category: 3
# Question: How can I get my project listed on the Superchain apps page?
# Category: 3
# Question: Is there a way to promote my app launch through Superchain's marketing channels?
# Category: 4
# Question: How does Optimism support projects that align with its values?
# Category: 2
# Question: How does Optimism decide which tweets to retweet?
# Category: 4
# Question: Can I submit my tweet to Optimism for retweeting?
# Category: 4
# Question: What other interactions does Optimism have with tweets besides retweeting?
# Category: 3
# Question: How can I participate in OP Radio?
# Category: 4
# Question: What is the format of OP Radio?
# Category: 3
# Question: How can I apply for a grant from Optimism?
# Category: 2
# Question: What should I do to deploy my project on Optimism?
# Category: 3
# Question: How can I learn about the origins of Optimism?
# Category: 1
# Question: What are some upcoming changes to the Optimism protocol?
# Category: 3
# Question: Is there a way for developers to deploy their own app-specific rollup on Optimism?
# Category: 3
# Question: How can I get involved in the Optimism Collective?
# Category: 1
# Question: What is the Optimism Collective's approach to building public goods?
# Category: 2
# Question: What is RetroPGF and why is it important to Optimism?
# Category: 3
# Question: How can I contribute to Optimism if I speak more than one language?
# Category: 1
# Question: Is there a way to help improve the Optimism documentation?
# Category: 3
# Question: Are there any community events for Optimism enthusiasts?
# Category: 4
# Question: Where can I find data that Optimism uses for decision making?
# Category: 3
# Question: How can I get involved if I am good with numbers?
# Category: 1
# Question: Are there any resources to help me understand how to contribute to OP rewards analytics?
# Category: 3
# Question: How can I start developing on Optimism if I'm a dapp developer?
# Category: 3
# Question: Where can I find ideas for projects to build on Optimism?
# Category: 3
# Question: How can I contribute directly to the Optimism codebase?
# Category: 3
# Question: How can I start getting involved in Optimism's governance?
# Category: 2
# Question: What is the Citizens House in Optimism's governance?
# Category: 2
# Question: How can I contribute to the Optimism Vision if I have skills in writing or design?
# Category: 3
# Question: What options do I have to market my project within the Optimism community?
# Category: 4
# Question: Who can become an Ambassador for Optimism?
# Category: 4
# Question: Is the Ambassador program documentation final?
# Category: 4
# Question: What kind of content do Optimism Ambassadors create?
# Category: 4
# Question: What sustainability initiatives do Optimism Ambassadors support?
# Category: 4
# Question: What should I do to get up to speed as a wannabe-ambassador?
# Category: 4
# Question: How can I advance to the `ambassador-in-training` role?
# Category: 2
# Question: How does one progress through the ambassador roles in Optimism Governance?
# Category: 2
# Question: What kind of content do I need to create to become an ambassador?
# Category: 4
# Question: Where do I submit my application and content for the ambassador role?
# Category: 4
# Question: How long do you need to be an active ambassador-in-training before becoming an ambassador?
# Category: 2
# Question: What kind of contributions are reviewed when voting on a new ambassador?
# Category: 4
# Question: Can I discuss the price of the OP token in my content?
# Category: 4
# Question: What types of content can I create to demonstrate my understanding of Optimism?
# Category: 3
# Question: Is there a requirement for non-English content submissions?
# Category: 3
# Question: How long can I be inactive before being removed from the program?
# Category: 2
# Question: What happens if I receive multiple warnings?
# Category: 3
# Question: What are the consequences of severe violations?
# Category: 3
# Question: Are there any specific rules for ambassadors in the Optimism community?
# Category: 2
# Question: What happens if an ambassador in the Optimism community gets three warnings?
# Category: 2
# Question: Can I share someone else's content in the Optimism community?
# Category: 1
# Question: Can Optimism Ambassadors share sensitive information they receive before it becomes public?
# Category: 2
# Question: What happens if an Optimism Ambassador impersonates a creator or team member?
# Category: 4
# Question: Is it acceptable for Optimism Ambassadors to engage in pump and dump schemes?
# Category: 2
# Question: How can becoming a support NERD benefit the community?
# Category: 2
# Question: Is the document on becoming a support NERD final and unchanging?
# Category: 3
# Question: Will becoming a support NERD make me famous?
# Category: 4
# Question: How can I become a support NERD for Optimism?
# Category: 3
# Question: What are the key values a support NERD should believe in?
# Category: 3
# Question: How should support NERDs interact with users on Discord?
# Category: 3
# Question: What should I do if I find outdated information or broken links in the Optimism documentation?
# Category: 3
# Question: What are some ways I can offer support in the Optimism Discord?
# Category: 3
# Question: What information should I include when introducing myself to the Optimism community?
# Category: 1
# Question: What should I include in my message when posting proof of meeting the requirements in the `#wannabe-NERD` channel?
# Category: 3
# Question: How long do I need to offer support before becoming a `support-NERD`?
# Category: 3
# Question: Can a NERD lose their role for scamming or spamming?
# Category: 2
# Question: What happens if a NERD is rude to users?
# Category: 5
# Question: Are NERDs given sensitive information?
# Category: 5
# Question: How does the Optimism Foundation view identity and reputation within its community?
# Category: 2
# Question: What is the purpose of the document on identity and attestations?
# Category: 3
# Question: Why is robust user and project identity important for the Optimism Collective?
# Category: 2
# Question: What are some pitfalls to avoid when building an identity/reputation network for the Optimism Collective?
# Category: 2
# Question: What is the approach towards defining Citizenship in Optimism Governance?
# Category: 2
# Question: What should be considered when issuing attestations in Optimism Governance?
# Category: 2
# Question: What is important to avoid when aggregating data in Optimism Governance?
# Category: 2
# Question: How does the identity stack framework help in understanding identity and reputation in Optimism?
# Category: 3
# Question: What is the role of the data interpretation layer in the identity stack framework?
# Category: 3
# Question: Why is the identity layer considered the narrowest point in the identity stack framework?
# Category: 3
# Question: How should developers approach building identity solutions in the Optimism ecosystem?
# Category: 3
# Question: What should developers do if they have an idea that fits within the Optimism identity framework but isn't listed in the current channels?
# Category: 3
# Question: Where can developers find specific input and ideas on valuable work within the Optimism Collective?
# Category: 2
# Question: How does the Optimism Collective capture important data?
# Category: 3
# Question: Who is currently the issuer of attestations about Badgeholders in the Optimism Collective?
# Category: 2
# Question: How can attestations be useful when dealing with off-chain data?
# Category: 3
# Question: What should I consider if I want to make my attestation private?
# Category: 3
# Question: How can I ensure that the data I generate is verifiable by others?
# Category: 3
# Question: Do all types of data need to be turned into attestations in Optimism?
# Category: 3
# Question: Why is it important to issue relevant attestations in the Collective?
# Category: 2
# Question: When is a good moment to issue an attestation?
# Category: 3
# Question: What should you consider if you're unsure about issuing an attestation?
# Category: 3
# Question: Why is the issuer important in an attestation?
# Category: 3
# Question: Who can be an issuer of an attestation?
# Category: 3
# Question: Why are schemas important in Optimism Governance?
# Category: 2
# Question: What should I do before creating a new schema?
# Category: 3
# Question: What are some tips for designing a schema according to the EAS recommendations?
# Category: 3
# Question: What's the difference between onchain and offchain attestations?
# Category: 3
# Question: Can onchain attestations be deleted?
# Category: 3
# Question: Are there any costs associated with onchain attestations?
# Category: 3
# Question: When will the program to support local Optimism events be available?
# Category: 4
# Question: How does the NumbaNERDs program contribute to the Optimism governance?
# Category: 5
# Question: Where can I find more information about the NumbaNERDs program?
# Category: 3
# Question: How can I participate in the TechNERDs program?
# Category: 4
# Question: Is there a beginner-friendly version of the Optimism curriculum available?
# Category: 3
# Question: What is the first step I need to take in the Optimism curriculum?
# Category: 3
# Question: How long does it take to sync an OP Goerli Node?
# Category: 3
# Question: How can I contribute to translating Optimism's User Docs?
# Category: 3
# Question: Is there any reward for translating Optimism's documents?
# Category: 5
# Question: Why does Optimism emphasize translations?
# Category: 3
# Question: What's the title of the document?
# Category: 3
# Question: What language is the document written in?
# Category: 3
# Question: How can I see the latest dApps on Optimism?
# Category: 3
# Question: How can I apply to showcase my dApp on Optimism's Demo Day?
# Category: 4
# Question: Is there a way to get more visibility for my project on Optimism besides Demo Day?
# Category: 4
# Question: What should I do before applying for a demo spot?
# Category: 3
# Question: Are demo spots limited?
# Category: 3
# Question: What should I do if I have never presented in a Discord channel before?
# Category: 3
# Question: When should I be available for an audio/video check before Demo Day?
# Category: 3
# Question: How can I apply for a slot to present my demo?
# Category: 4
# Question: Can I do a giveaway or lotto during my demo?
# Category: 4
# Question: Where can I ask specific questions about Optimism?
# Category: 3
# Question: Who should I contact for press and media inquiries about Optimism?
# Category: 4
# Question: What is the Superchain in Optimism Governance?
# Category: 2
# Question: How does the Superchain benefit public goods?
# Category: 2
# Question: How does Optimism generate revenue?
# Category: 5
# Question: Why is funding public goods important for Optimism?
# Category: 2
# Question: What principle does the Optimism Collective follow?
# Category: 2
# Question: Where can I find the old brand kit for Optimism?
# Category: 3
# Question: What is the Optimism ecosystem?
# Category: 3
# Question: What do I need to know to understand the Superchain?
# Category: 3
# Question: Which networks have opted into the Superchain as of August 1, 2023?
# Category: 3
# Question: Is the Superchain currently operational?
# Category: 3
# Question: What's an OP Chain?
# Category: 3
# Question: What is the Superchain in the context of OP Chains?
# Category: 3
# Question: Who maintains the OP Stack?
# Category: 3
# Question: Is the OP Stack open source?
# Category: 3
# Question: What's an OP Stack Fork?
# Category: 3
# Question: Do OP Stack Forks share security with OP Chains in the Superchain?
# Category: 3
# Question: What's OP Mainnet?
# Category: 3
# Question: Can I refer to the OP token as $OP?
# Category: 3
# Question: Can I refer to OP token grants in terms of their USD value?
# Category: 3
# Question: What skills are needed to maintain and evolve the Optimism codebase?
# Category: 3
# Question: Are there any rewards for contributing to the Optimism project?
# Category: 2
# Question: Where can I find resources to deploy a basic contract on OP Mainnet?
# Category: 3
# Question: Are there any tools available to make building on OP Mainnet easier?
# Category: 3
# Question: Can I find information on building cross-chain apps in the OP Mainnet developer docs?
# Category: 3
# Question: Is deploying a contract on OP Mainnet different from deploying on Ethereum?
# Category: 3
# Question: Are there any resources for someone who is already familiar with OP Mainnet and Ethereum?
# Category: 3
# Question: How can I deploy my contracts to OP Mainnet or OP Goerli?
# Category: 3
# Question: Are there any resources to help me run a local development environment for Optimism?
# Category: 3
# Question: Can I run my own OP Mainnet node?
# Category: 3
# Question: How can I move tokens from Ethereum to OP Mainnet?
# Category: 3
# Question: Is there a way to send data between different chains?
# Category: 3
# Question: Does Optimism use the same infrastructure for its own operations?
# Category: 3
# Question: What should I do first if I can't find the content I'm looking for in the Optimism documentation?
# Category: 3
# Question: What's Bedrock in the context of Optimism?
# Category: 3
# Question: Where can I find guidelines to contribute to the OP Stack?
# Category: 3
# Question: How does Bedrock reduce transaction fees?
# Category: 3
# Question: What improvements does Bedrock make in handling L1 transactions?
# Category: 3
# Question: What are some of the technical improvements in Bedrock?
# Category: 3
# Question: How does Bedrock help in reducing data costs?
# Category: 3
# Question: What is the impact of removing L1 execution gas in Bedrock?
# Category: 3
# Question: How long did it take to confirm deposits in earlier versions of the Optimism protocol?
# Category: 3
# Question: What improvement does Bedrock bring to the deposit confirmation time in Optimism?
# Category: 3
# Question: Does Bedrock support L1 re-orgs in the node software?
# Category: 3
# Question: How does Bedrock handle proof systems in the OP Stack?
# Category: 3
# Question: What is the purpose of abstracting the proof system in Bedrock?
# Category: 3
# Question: What is an example of a system that can be used with Bedrock to prove faults?
# Category: 3
# Question: How has the performance of the node software been improved in the latest version?
# Category: 3
# Question: What changes have been made to reduce technical debt in the new version of the protocol?
# Category: 3
# Question: How does the new model of executing several transactions in a single rollup block benefit the system?
# Category: 3
# Question: How does Bedrock compare to Ethereum?
# Category: 3
# Question: Why was Bedrock built to be modular and upgradeable?
# Category: 3
# Question: Does Bedrock use any existing code from Ethereum?
# Category: 3
# Question: How does Bedrock ensure flexibility in the OP Stack?
# Category: 3
# Question: What are some examples of the modular design in Bedrock?
# Category: 3
# Question: How does Bedrock ensure security in its design?
# Category: 3
# Question: How does Bedrock ensure compatibility with the existing Ethereum developer experience?
# Category: 3
# Question: What is the purpose of the fault proof in Bedrock?
# Category: 3
# Question: How do rollups derive their data?
# Category: 3
# Question: What are deposits and withdrawals in the context of rollups?
# Category: 3
# Question: What is the role of proof systems in rollups?
# Category: 3
# Question: What's a deposit in the context of Optimism?
# Category: 3
# Question: How does a deposited transaction work in Optimism?
# Category: 3
# Question: Where can I find more details about the deposit contract in Optimism?
# Category: 3
# Question: How does the gas burn mechanism work in Optimism's Bedrock?
# Category: 3
# Question: What is 'guaranteed gas' in the context of Optimism's Bedrock?
# Category: 3
# Question: Why is there a hard cap on the amount of gas provided to deposits in a single L1 block in Optimism's Bedrock?
# Category: 3
# Question: How are withdrawals initiated in the Optimism network?
# Category: 3
# Question: How does the Bedrock release improve the security of withdrawals in Optimism?
# Category: 3
# Question: What is the purpose of the 7-day period in the new withdrawal process?
# Category: 3
# Question: Why are withdrawal proof validation bugs significant in the context of bridge hacks?
# Category: 3
# Question: How does Bedrock handle messaging between L1 and L2?
# Category: 3
# Question: Why is the wire format in Bedrock important?
# Category: 3
# Question: How does Optimism optimize data compression for transactions?
# Category: 3
# Question: What is the maximum size of a channel in Optimism?
# Category: 3
# Question: How are channels submitted to the L1 in Optimism?
# Category: 3
# Question: How does Optimism handle large amounts of data when sending it to Ethereum's Layer 1?
# Category: 3
# Question: Why is it beneficial for Optimism to send transactions in parallel to Ethereum's Layer 1?
# Category: 3
# Question: How does Bedrock handle execution gas for L1 system transactions?
# Category: 3
# Question: What happens to invalid batches or individual transactions within a batch in the Bedrock system?
# Category: 3
# Question: What is the impact of Ethereum's upcoming EIP-4844 upgrade on posting data to L1?
# Category: 3
# Question: How does the Bedrock protocol ensure the timing of deposits on L1 is respected in the L2 chain?
# Category: 3
# Question: What is a pure function in the context of the Bedrock protocol?
# Category: 3
# Question: How often are L2 blocks created in the Bedrock release?
# Category: 3
# Question: What is a sequencing epoch in the context of Optimism's Bedrock?
# Category: 3
# Question: How does the protocol ensure that deposits are processed in a logical temporal order?
# Category: 3
# Question: What is a sequencing window in the context of Bedrock?
# Category: 3
# Question: What is the purpose of the max sequencer drift in Bedrock?
# Category: 3
# Question: How does the canonical L2 chain process data from the L1 chain?
# Category: 3
# Question: What is the role of channels in the L2 chain processing?
# Category: 3
# Question: Why is data decompressed during the L2 chain processing?
# Category: 3
# Question: How does Optimism ensure trustless execution of L2-to-L1 messaging?
# Category: 3
# Question: What is the purpose of output roots in Optimism's Bedrock?
# Category: 3
# Question: What future upgrades are planned for the OP Stack regarding output roots?
# Category: 3
# Question: How does Bedrock handle the separation of concerns in the Optimism network?
# Category: 3
# Question: What's an execution client in the context of Optimism?
# Category: 3
# Question: How does Bedrock in the OP Stack relate to Ethereum's execution client?
# Category: 3
# Question: Why does Bedrock have any modifications at all to the Ethereum execution client?
# Category: 3
# Question: What standard does the new transaction type for deposited transactions follow?
# Category: 3
# Question: How are sequencer fees determined in Optimism rollups?
# Category: 3
# Question: What are data availability fees in Optimism rollups?
# Category: 3
# Question: How is the data availability fee determined in Bedrock?
# Category: 3
# Question: How does Bedrock achieve consensus if it doesn't use proof-of-stake like Ethereum?
# Category: 3
# Question: What is a rollup node in Bedrock?
# Category: 3
# Question: How does the rollup node communicate with the execution client in Bedrock?
# Category: 3
# Question: How does a rollup node verify output roots?
# Category: 3
# Question: What is the purpose of the simplest mode of running a rollup node?
# Category: 3
# Question: What does 'finalized' mean in the context of a rollup node?
# Category: 3
# Question: How do rollup nodes participate in a network?
# Category: 3
# Question: What is the difference between the safe L2 head and the unsafe L2 head?
# Category: 3
# Question: When do nodes in the L2 network refer to the unsafe L2 head?
# Category: 3
# Question: How does a rollup node sequence transactions?
# Category: 3
# Question: How many sequencers are there per OP Stack network?
# Category: 3
# Question: What is the sequencer's responsibility in relation to L1?
# Category: 3
# Question: What's the role of a sequencer in the Optimism network?
# Category: 3
# Question: What is a batcher in the context of Optimism?
# Category: 3
# Question: How does the bridging process work in Optimism's Bedrock?
# Category: 3
# Question: Where can I find more details about the standard bridges in Optimism?
# Category: 3
# Question: Where is fault proof construction and verification implemented in Optimism?
# Category: 3
# Question: What are the future milestones for Optimism's fault proof system?
# Category: 3
# Question: Where can I find the technical details of the OP Stack?
# Category: 3
# Question: What is the most up-to-date source for understanding the inner workings of the Optimism protocol?
# Category: 3
# Question: Where can I find detailed information about the differences between Bedrock and previous versions of the protocol?
# Category: 3
# Question: What does the Bedrock release include?
# Category: 3
# Question: Which sections of the Optimism Governance Documentation should a wallet developer focus on?
# Category: 3
# Question: What information is important for a Dapp frontend developer in the Optimism Governance Documentation?
# Category: 3
# Question: What should an infrastructure provider know from the Optimism Governance Documentation?
# Category: 2
# Question: How often are blocks produced in the Bedrock network?
# Category: 3
# Question: What is a system transaction in the Bedrock network?
# Category: 3
# Question: What should I do if my Ethereum client library cannot parse the `null` signature fields in system transactions?
# Category: 3
# Question: How does EIP-1559 affect transaction fees on the Optimism network?
# Category: 3
# Question: What are the main differences between Ethereum and OP Mainnet regarding EIP-1559 parameters?
# Category: 3
# Question: What new features does EIP-1559 introduce for application developers on Optimism?
# Category: 3
# Question: Why was the `L1BLOCKNUMBER` opcode removed in the Bedrock upgrade?
# Category: 3
# Question: How were ETH balances represented in the previous version of the Optimism system?
# Category: 3
# Question: What will happen to the `OVM_ETH` balances during the migration to the Bedrock network?
# Category: 3
# Question: Will the methods on the `OVM_ETH` contract still work after the migration?
# Category: 3
# Question: How does Bedrock handle block reorganization?
# Category: 3
# Question: What are the different states of blocks in Bedrock?
# Category: 3
# Question: How can I query the current state of blocks in Bedrock?
# Category: 3
# Question: Can Bedrock nodes provide information about blocks, transactions, and receipts from before the Bedrock update?
# Category: 3
# Question: Do I need to run any additional software to access historical execution traces?
# Category: 3
# Question: Have any fields been removed from pre-Bedrock JSON-RPC transaction responses?
# Category: 3
# Question: How can I get the gas price on Bedrock?
# Category: 3
# Question: What should I use instead of the `eth_getBlockRange` method on Bedrock?
# Category: 3
# Question: How can I check the sync status of `op-node` on Bedrock?
# Category: 3
# Question: How does Bedrock handle pending transactions?
# Category: 3
# Question: Why is Bedrock's mempool private?
# Category: 3
# Question: How are transactions processed in Bedrock's mempool?
# Category: 3
# Question: How long does it take to finalize a withdrawal on the legacy network?
# Category: 3
# Question: What is the main security improvement introduced by Bedrock for withdrawals?
# Category: 3
# Question: Is the new Bedrock withdrawal process backwards-compatible with the old network?
# Category: 3
# Question: Will the changes in the new network be compatible with the old network?
# Category: 3
# Question: What happens to deposits on the legacy network that haven't been replayed?
# Category: 3
# Question: How many transactions on the mainnet are affected by this change?
# Category: 3
# Question: What is the `L2OutputOracle` contract in Optimism?
# Category: 3
# Question: How can I send messages between L1 and L2 in Optimism?
# Category: 3
# Question: What is the purpose of the OptimismPortal contract?
# Category: 3
# Question: Do I need to modify my dapp to run on Bedrock?
# Category: 3
# Question: What is the purpose of the L1CrossDomainMessenger contract?
# Category: 3
# Question: How does the L1StandardBridge contract transfer assets?
# Category: 3
# Question: How can I find the address of the `L1Block` contract in Optimism?
# Category: 3
# Question: What kind of information can I get from the `L1Block` contract?
# Category: 3
# Question: Why is there a delay in the L1 information provided by the `L1Block` contract?
# Category: 3
# Question: How does the SequencerFeeVault contract fund the sequencer on L1?
# Category: 3
# Question: How does the `L2ToL1MessagePasser` contract function within the Optimism network?
# Category: 3
# Question: What is the purpose of the legacy contract in Optimism's Bedrock version?
# Category: 3
# Question: Why are some contracts kept even if they are no longer relevant?
# Category: 3
# Question: What was the purpose of the DeployerWhitelist contract?
# Category: 3
# Question: What did the OVM_ETH contract do?
# Category: 3
# Question: Do deposits in Optimism always involve transferring assets?
# Category: 3
# Question: What does a withdrawal mean in the context of Optimism?
# Category: 3
# Question: Will the gas costs for communication between layers change?
# Category: 3
# Question: Where can I find more information about the new gas costs?
# Category: 3
# Question: How can I ensure my deposit transaction on Optimism doesn't run out of gas?
# Category: 3
# Question: What happens if the sequencer is down when I make a deposit on Optimism?
# Category: 3
# Question: Why do I need to add a buffer to the gas limit for L1 to L2 transactions on Optimism?
# Category: 3
# Question: Can you explain what this section of the Optimism documentation is about?
# Category: 3
# Question: How are L2 blocks saved to the Ethereum blockchain now?
# Category: 3
# Question: Where can I find more information about batch submission addresses for L2 blocks?
# Category: 3
# Question: Is the block and transaction format the same as before?
# Category: 3
# Question: What should I do if my application needs legacy fields from pre-Bedrock JSON-RPC transaction responses?
# Category: 3
# Question: Where can I find more information about running a Legacy Geth instance for historical execution traces?
# Category: 3
# Question: How can I get the gas price for transactions on Optimism?
# Category: 3
# Question: Is there a way to check the synchronization status of an Optimism node?
# Category: 3
# Question: Do I need to configure anything to submit transactions in Bedrock?
# Category: 3
# Question: Will the changes in the new Bedrock network be compatible with the old network?
# Category: 3
# Question: How many transactions on the mainnet are affected by the need to replay deposits before the migration?
# Category: 3
# Question: Where can I find the code for the `L2ToL1MessagePasser` contract?
# Category: 3
# Question: Where can I find more technical details about how messages are transferred in Optimism?
# Category: 3
# Question: How long does it take for a deposit to be confirmed on Optimism?
# Category: 3
# Question: Are there any recent changes in the internal workings of Optimism?
# Category: 2
# Question: How can I start developing on OP Mainnet after the Bedrock release?
# Category: 3
# Question: How does Bedrock affect L1 execution gas fees?
# Category: 3
# Question: How long does it take for deposits to confirm with the new Bedrock update?
# Category: 3
# Question: What changes have been made to reduce the technical debt in the node software?
# Category: 3
# Question: What are some of the features Bedrock adds to align with Ethereum?
# Category: 3
# Question: What deviations from Ethereum were removed in Bedrock?
# Category: 3
# Question: What are the primary sources of information for a canonical L2 chain in rollup protocols?
# Category: 3
# Question: Are deposits guaranteed to be included in the Layer 2 chain?
# Category: 3
# Question: What happens if an invalid withdrawal proof is detected?
# Category: 3
# Question: Why is there a 7-day waiting period for withdrawals in the Bedrock release?
# Category: 3
# Question: What happens to the channels after they are created in Optimism?
# Category: 3
# Question: Why is it beneficial for channel frames to be mutually independent?
# Category: 3
# Question: What is the role of the sequencer in Optimism's data submission process?
# Category: 3
# Question: What is the batch inbox address in the context of Bedrock?
# Category: 3
# Question: What are the key components involved in the Bedrock protocol's block derivation process?
# Category: 3
# Question: What is the role of L1 blocks in the L2 chain?
# Category: 3
# Question: How are the fees structured in Optimism's Bedrock?
# Category: 3
# Question: What is the purpose of the optimism_outputAtBlock method?
# Category: 3
# Question: Who is responsible for producing batches in the Optimism network?
# Category: 3
# Question: How does the bridge in Optimism work?
# Category: 3
# Question: What are the addresses of the legacy and new `L2ToL1MessagePasser` contracts in Bedrock?
# Category: 3
# Question: What does the WETH9 contract do?
# Category: 3
# Question: How can I monitor the health of the Bedrock `op-node` system?
# Category: 3
# Question: How do I enable metrics for the Bedrock `op-node`?
# Category: 3
# Question: How can I tell if my node is not syncing properly?
# Category: 3
# Question: Why is it important to monitor the number of peers my node is connected to?
# Category: 3
# Question: What should I look at if my node's sync performance is slow?
# Category: 3
# Question: How can I know if the op node has finished starting up?
# Category: 3
# Question: What does the metric 'op_node_default_rpc_server_requests_total' represent?
# Category: 3
# Question: What information does the metric 'op_node_default_refs_number' provide?
# Category: 3
# Question: How can I learn more about how Bedrock works and its motivations?
# Category: 3
# Question: Where can I find instructions to build and run an OP node from source?
# Category: 3
# Question: Can you explain the core components of a Bedrock deployment in Optimism?
# Category: 3
# Question: Is there any additional component needed for OP Mainnet and OP Goerli in Optimism's Bedrock deployment?
# Category: 3
# Question: What are the minimum system requirements to run Bedrock?
# Category: 3
# Question: How can I run `op-geth` and `op-node` for Optimism?
# Category: 3
# Question: Is it possible to compile `op-geth` and `op-node` from source?
# Category: 3
# Question: What version of the old `l2geth` image does Legacy Geth use?
# Category: 3
# Question: How should I configure `op-node` and `op-geth` instances?
# Category: 3
# Question: What are the steps to configure my node?
# Category: 3
# Question: How do I initialize `op-geth` for OP Sepolia?
# Category: 3
# Question: What is the difference between initializing `op-geth` with a Genesis File and a Data Directory?
# Category: 3
# Question: How much disk space do I need for running an OP Mainnet or OP Goerli node?
# Category: 3
# Question: What are the CLI flag requirements for running `op-node` and `op-geth` on OP Sepolia?
# Category: 3
# Question: Is the genesis information for OP Sepolia included in the `op-geth` binary?
# Category: 3
# Question: What format is the preconfigured data directory exported as?
# Category: 3
# Question: What is the purpose of the `--rollup.sequencerhttp` flag?
# Category: 3
# Question: How do I generate a JWT secret file for `op-geth`?
# Category: 3
# Question: How can I control which hosts are allowed to access the authenticated RPC endpoint in Optimism?
# Category: 3
# Question: How do I enable and configure the unauthenticated RPC endpoint in Optimism?
# Category: 3
# Question: What is the purpose of the `--verbosity` flag in Optimism?
# Category: 3
# Question: Where can I find more information on customizing `op-geth`'s behavior?
# Category: 3
# Question: What is the purpose of the `--network` flag in the `op-node` configuration?
# Category: 3
# Question: Can I use environment variables instead of command-line flags to configure `op-node`?
# Category: 3
# Question: How does the `op-node` participate in the network?
# Category: 3
# Question: What is the recommended network setup for running `op-node`?
# Category: 3
# Question: What port needs to be open for the peer-to-peer network, and what protocols should it support?
# Category: 3
# Question: Do I need to run Legacy Geth for all Optimism networks?
# Category: 3
# Question: What is the purpose of the `USING_OVM=true` environment variable?
# Category: 3
# Question: Can I customize the configuration of Legacy Geth?
# Category: 3
# Question: Do I need to run Legacy Geth for all types of RPC methods?
# Category: 3
# Question: What is meant by 'historical execution' in the context of Optimism Governance?
# Category: 2
# Question: If I don't need historical data, do I still need to use Legacy Geth?
# Category: 3
# Question: Why am I seeing a '401 Unauthorized: signature is invalid' error in my `op-node` logs?
# Category: 3
# Question: What should I do if my `op-node` can't find the finalized L2 block?
# Category: 3
# Question: Why am I seeing a '403 Forbidden: invalid host specified' error in `op-node` logs?
# Category: 3
# Question: How can I fix the 'error getting latest header' in `op-node`?
# Category: 3
# Question: Why is my `op-node` application failing with a 'permission denied' error?
# Category: 3
# Question: How can I fix the 'failed to open discovery db: mkdir /p2p: permission denied' error in `op-node`?
# Category: 3
# Question: How can I tell if my `op-node` is pointing to the wrong chain?
# Category: 3
# Question: Where can I find information on what to expect during an upgrade of the Optimism testnet and mainnet?
# Category: 3
# Question: Where can I find information about the Optimism Goerli network?
# Category: 3
# Question: Where can I find more detailed information about Bedrock Mission Control for Optimism?
# Category: 3
# Question: How has the Bedrock release affected wallets?
# Category: 3
# Question: What are the new statuses a transaction can have after the Bedrock release?
# Category: 3
# Question: Do transaction fees need to account for any new standards after the Bedrock release?
# Category: 3
# Question: How can I get the block range information in Optimism?
# Category: 3
# Question: How can I estimate the cost of a transaction in Optimism?
# Category: 3
# Question: How can I check the status of a specific block in Optimism?
# Category: 3
# Question: What do the terms 'unsafe', 'safe', and 'finalized' mean in the context of Optimism blocks?
# Category: 3
# Question: How are transaction fees structured in OP Mainnet?
# Category: 3
# Question: How can I estimate the total cost of a transaction on OP Mainnet?
# Category: 3
# Question: What components make up the L2 execution fee in Bedrock?
# Category: 3
# Question: How often are blocks produced on the OP Mainnet?
# Category: 3
# Question: Why should I specify a higher base fee than the current value when making a transaction?
# Category: 3
# Question: Where can I find the current L2 base fee for Optimism?
# Category: 3
# Question: How low can I set the Max Priority Fee on OP Chains?
# Category: 3
# Question: What is the typical priority fee on OP Mainnet?
# Category: 3
# Question: Why do app developers need to move data and assets between OP Mainnet and Ethereum?
# Category: 3
# Question: What is bridging in the context of OP Mainnet and Ethereum?
# Category: 3
# Question: Is it possible to create L2 representations of existing tokens on Ethereum?
# Category: 3
# Question: Can I send data other than tokens between Ethereum and OP Mainnet?
# Category: 3
# Question: How can I trigger a contract function on OP Mainnet from Ethereum?
# Category: 3
# Question: Is the API for cross-chain function calls difficult to use?
# Category: 3
# Question: Why is the L2 state vulnerable in Optimism?
# Category: 3
# Question: What should I do if I need to rely on the L2 state before the fault challenge period ends?
# Category: 3
# Question: What are the main trade-offs in Dapps' inter-layer communication strategies in Optimism?
# Category: 3
# Question: How can I connect my dapp to both Ethereum and OP Mainnet?
# Category: 3
# Question: What are the benefits of using a centralized server for my dapp?
# Category: 3
# Question: Is it possible for users to run a different client that pretends to be the legitimate one?
# Category: 3
# Question: When can you trust the client for inter-layer communication?
# Category: 3
# Question: How does Optimism ensure decentralization similar to OP Mainnet and Ethereum?
# Category: 2
# Question: Can I trust the messaging infrastructure used by Optimism?
# Category: 3
# Question: How long does it take for an L1 transaction to update L2 code in Optimism?
# Category: 3
# Question: Why is sending messages from L2 to L1 more difficult?
# Category: 3
# Question: How long does it take to send a message from L2 to L1?
# Category: 3
# Question: How do incentives work in Optimism governance?
# Category: 2
# Question: How can apps on OP Mainnet interact with apps on Ethereum?
# Category: 3
# Question: What is a 'call' in the context of Ethereum smart contracts?
# Category: 3
# Question: What is ABI in Solidity and why is it important?
# Category: 3
# Question: How do contracts on Ethereum communicate with contracts on Optimism?
# Category: 3
# Question: What is the `sendMessage` function and how is it used?
# Category: 3
# Question: Where can I find the addresses of the messenger contracts on Optimism?
# Category: 3
# Question: Are transactions between Ethereum and OP Mainnet instantaneous?
# Category: 3
# Question: Do calls between contracts on the same blockchain take the same amount of time as calls between Ethereum and OP Mainnet?
# Category: 3
# Question: Why do transactions from L1 to L2 take about a minute?
# Category: 3
# Question: What is the fault challenge period in Optimism?
# Category: 3
# Question: How do contracts typically restrict access to certain functions?
# Category: 3
# Question: What is the role of the `msg.sender` in contracts?
# Category: 3
# Question: What is the `xDomainMessageSender` function used for?
# Category: 3
# Question: How is the cost of an L1 to L2 transaction determined?
# Category: 3
# Question: What happens if my L1 to L2 transaction requires more than 1.92 million gas on L2?
# Category: 3
# Question: Where can I find the current values for the free L2 gas amount and the L1 to L2 gas exchange rate?
# Category: 3
# Question: Why is the L1 proof transaction considered expensive?
# Category: 3
# Question: What is the transaction challenge period for finalizing an L2 to L1 transaction on Optimism?
# Category: 3
# Question: Why do messages sent from Layer 2 to Layer 1 take a week to be relayed?
# Category: 3
# Question: What is the purpose of the challenge period in Optimistic Rollups?
# Category: 3
# Question: Can the length of the challenge period be changed?
# Category: 3
# Question: How can I transfer ETH and ERC20 tokens between Layer 1 and Layer 2 networks?
# Category: 3
# Question: What are the main components of the Standard Bridge?
# Category: 3
# Question: Where can I find a step-by-step tutorial for using the Standard Bridge?
# Category: 3
# Question: Can I use a smart contract wallet to deposit ETH on OP Mainnet?
# Category: 3
# Question: Are there any restrictions on depositing ERC20 tokens using a smart contract wallet on OP Mainnet?
# Category: 3
# Question: Why are smart contract wallets blocked from calling certain deposit functions on OP Mainnet?
# Category: 3
# Question: How can I deposit ERC20 tokens into Optimism Layer 2?
# Category: 3
# Question: Are there any ERC20 tokens that are not supported by the Optimism bridge?
# Category: 3
# Question: How can I check if a token can use the standard bridge on Optimism?
# Category: 3
# Question: What happens after I deposit ETH into L2 on Optimism?
# Category: 3
# Question: What's the difference between USDC and USDC.e on the OP Mainnet?
# Category: 3
# Question: Why is it important to know the difference between USDC and USDC.e when using deposit functions?
# Category: 3
# Question: Will native USDC liquidity replace bridged USDC liquidity over time?
# Category: 5
# Question: How can I trigger ERC20 withdrawals on Optimism?
# Category: 3
# Question: Where can I find an example of how to use the L2StandardBridge contract for deposits and withdrawals?
# Category: 3
# Question: What address should I use as the L2 token address when withdrawing ETH on Optimism?
# Category: 3
# Question: How can I add my token to the Superchain token list?
# Category: 3
# Question: What is the main portal for moving assets between Layer 1 and Layer 2 on Optimism?
# Category: 3
# Question: Is there a one-to-one mapping between L1 and L2 tokens in the Superchain token list?
# Category: 3
# Question: How does the cost of using a decentralized application on OP Mainnet compare to using one on L1 Ethereum?
# Category: 3
# Question: How can I optimize my contracts for the OP Mainnet environment?
# Category: 3
# Question: Why can the cost of gas on L1 be unpredictable?
# Category: 3
# Question: Where can I find the current gas costs for transactions on OP Mainnet?
# Category: 3
# Question: Why are transaction costs on OP Mainnet different from those on Ethereum?
# Category: 3
# Question: How much does it cost to write one byte to L1 on OP Mainnet?
# Category: 3
# Question: Is it cheaper to write data to storage or to transaction call data on OP Mainnet?
# Category: 3
# Question: Why is the standard ABI not optimal for OP Mainnet?
# Category: 3
# Question: Can I still use the standard ABI for some functions on OP Mainnet?
# Category: 3
# Question: Why should I avoid using `uint256` for storing ETH balances?
# Category: 3
# Question: How can I optimize the storage of values in my smart contracts?
# Category: 3
# Question: What is the benefit of using smaller data types in my smart contracts?
# Category: 3
# Question: Why should I use a local development environment for OP Mainnet?
# Category: 3
# Question: What does the default development environment for OP Mainnet include?
# Category: 3
# Question: Can I use a hosted development node instead of setting up a local environment?
# Category: 3
# Question: Why should I use the local development environment for my application?
# Category: 3
# Question: What should I do if I'm not sure whether to use the local development environment?
# Category: 3
# Question: How do I install the necessary command line utilities for Optimism on Ubuntu 20.04 LTS?
# Category: 3
# Question: How do I start the development network for Optimism?
# Category: 3
# Question: What are the chain IDs for the development node compared to the real-world networks?
# Category: 3
# Question: How is the `block.difficulty` value determined on Optimism?
# Category: 3
# Question: What happens to `tx.origin` in an L1 to L2 transaction on Optimism?
# Category: 3
# Question: What is the behavior of the `CALLER` opcode in an L1 to L2 transaction on Optimism?
# Category: 3
# Question: How can I get information about the latest L1 block in Optimism?
# Category: 3
# Question: How does the `CREATE` opcode behavior affect contract addresses on L1 and L2?
# Category: 3
# Question: What is the difference in the value of `tx.origin` between L1 and L2?
# Category: 3
# Question: Why should `tx.origin` generally not be used for authorization?
# Category: 3
# Question: Why is it a problem to have two identical source addresses for L1 and L2 contracts?
# Category: 3
# Question: How does OP Mainnet protect users like Nimrod from potential scams?
# Category: 3
# Question: What is the significance of the allowance in the context of the Hackswap example?
# Category: 3
# Question: What are the components of the gas cost in Optimism?
# Category: 3
# Question: What are some differences in EIP-1559 parameters between Optimism and Ethereum?
# Category: 3
# Question: How does Optimism minimize MEV (Miner Extractable Value)?
# Category: 3
# Question: How are transactions processed in Optimism's mempool?
# Category: 3
# Question: How often are blocks produced on Optimism Bedrock compared to L1 Ethereum?
# Category: 3
# Question: What is the target size for blocks on Optimism Bedrock?
# Category: 3
# Question: Is there a difference in the maximum block size between L1 Ethereum and Optimism Bedrock?
# Category: 3
# Question: Does OP Mainnet use the same API as Ethereum?
# Category: 3
# Question: Are there any additional methods specific to OP Mainnet?
# Category: 3
# Question: Where can I find more information about the custom JSON-RPC methods for OP Mainnet?
# Category: 3
# Question: Are the addresses for infrastructure contracts the same on L1 Ethereum and OP Mainnet?
# Category: 3
# Question: Does Optimism have an RPC API?
# Category: 3
# Question: What's the name of the rollup node implementation for the OP Mainnet?
# Category: 3
# Question: What does the 'op-node' component do?
# Category: 3
# Question: What information is included in the synchronization status response?
# Category: 3
# Question: What does the 'finalized_l1' field represent in the synchronization status?
# Category: 3
# Question: What kind of information is included in the rollup configuration parameters?
# Category: 3
# Question: What is the block time in the rollup configuration for Optimism?
# Category: 3
# Question: How do rollup nodes share pending L2 blocks with each other?
# Category: 3
# Question: What is the purpose of peer-to-peer synchronization in rollup nodes?
# Category: 3
# Question: What's the name of the execution engine implementation for the OP Mainnet?
# Category: 3
# Question: How does the RPC interface of the execution engine in Optimism compare to the upstream Geth RPC interface?
# Category: 3
# Question: What additional functionality does the execution engine's RPC interface provide?
# Category: 3
# Question: Can the legacy geth be used to send transactions on the blockchain?
# Category: 3
# Question: What kind of methods does the legacy geth implement?
# Category: 3
# Question: What is the purpose of the legacy geth in the context of Optimism?
# Category: 3
# Question: Where can I find the introduction for developers about nodes in the Optimism documentation?
# Category: 3
# Question: What are some reasons I might want to interact with OP Mainnet contracts?
# Category: 3
# Question: Does OP Mainnet involve both L1 and L2 contracts?
# Category: 3
# Question: How do I get the contract addresses for different networks on Optimism?
# Category: 3
# Question: Where can I find the address of the OP Mainnet system contract I want to interact with?
# Category: 3
# Question: How can I use OP Mainnet contracts in my NPM or Yarn project?
# Category: 3
# Question: Is there a specific package for using Optimism contracts in development?
# Category: 3
# Question: Where can I find the path to a specific Optimism contract?
# Category: 3
# Question: Are the addresses of system contracts on the L2 side of the network the same across different networks?
# Category: 3
# Question: Where can I find the addresses of these system contracts?
# Category: 3
# Question: How can I interact with the OP Mainnet system contracts from a JavaScript or TypeScript project?
# Category: 3
# Question: How do I install the `@eth-optimism/contracts` package?
# Category: 3
# Question: How can I obtain the ABI and bytecode for an OP Mainnet contract?
# Category: 3
# Question: Is there a way to get an ethers Interface object for an Optimism contract?
# Category: 3
# Question: Are there any differences in testing decentralized applications on OP Mainnet compared to Ethereum?
# Category: 3
# Question: What will I learn from the article about testing on OP Mainnet?
# Category: 3
# Question: Why is it inefficient to test everything on OP Mainnet or a test network?
# Category: 3
# Question: Where should the majority of tests be run if they do not rely on OP Mainnet-specific features?
# Category: 3
# Question: Why would you want to run some tests on an OP test network?
# Category: 3
# Question: Why might some dapps need OP Mainnet-specific features?
# Category: 3
# Question: Can I use mainnet forking with OP Mainnet?
# Category: 3
# Question: What should I do if my decentralized application requires services from other contracts?
# Category: 3
# Question: Is it possible to test my application on a network other than the mainnet?
# Category: 3
# Question: How is the base fee for a transaction determined?
# Category: 3
# Question: Why should I set my Max Fee to at least 0.1 gwei?
# Category: 3
# Question: Where can I find the current L2 base fee?
# Category: 3
# Question: Why is it important to keep the priority fee low in a transaction?
# Category: 3
# Question: Why do users on OP Mainnet have to pay an L1 data fee?
# Category: 3
# Question: Can users set limits for the L1 data fee on OP Mainnet?
# Category: 3
# ...
#  'Where can I find more information about the total allocation of OP tokens?': '2',
#  'How were the grants distributed in Phase 1 of the Optimism ecosystem?': '2',
#  'Can a project apply for more grants after getting an initial proposal approved?': '2',
#  'How can projects strengthen their case for future proposals?': '4',
#  'How were the projects rewarded in Phase 0 of Optimism Governance chosen?': '2',
#  'Where can I find live tracking information on the Gov Fund allocations for Optimism?': '3',
#  'How can I delegate my tokens in Optimism?': '3',
#  'Can I delegate my voting power in Optimism governance to someone else?': '2',
#  "What if I don't want to delegate my voting power to someone else?": '2',
#  'Is participating in Optimism governance time-consuming?': '2',
#  'How do I choose a delegate for my OP tokens?': '3',
#  'Can I change my delegate after I have chosen one?': '3',
#  'How can I vote with my OP tokens?': '3',
#  'Is there a minimum amount of OP tokens required to vote?': '2',
#  'When is the delegate voting power measured?': '3',
#  'Is the Law of Chains a legally binding contract?': '5',
#  'What should I do if I believe Participant Protections have been violated?': '2',
#  'Does the Law of Chains create any formal relationships like partnerships or employment?': '2',
#  'Are there any videos available for developers?': '3',
#  'Is there a video available about Optimism at ETHDenver 2023?': '4',
#  'What is the main theme of the video about Optimism governance?': '2',
#  "Where can I find Justine's research on DAO governance and policy?": '3',
#  'Who is Ben Jones and what is his role in the Optimism ecosystem?': '3',
#  'How can I learn more about the OP Stack and its role in the Ethereum ecosystem?': '3',
#  'Where can I find the official guidelines for submitting proposals in Optimism governance?': '2',
#  'Is the information in the documentation fragment the most reliable source for governance processes?': '2',
#  'How can I apply for grant funding from the Governance Fund?': '2',
#  'Do I need to hold a minimum amount of tokens to submit a proposal?': '2',
#  'What is required for a non-grant proposal to move to a vote?': '2',
#  'Where can I find the process for submitting non-grant proposals?': '3',
#  'What was the median funding amount received by a project in Retro Funding 1?': '3',
#  'Where can I find a detailed list of all projects and their funding allocations for Retro Funding 1?': '3',
#  'Who were the badgeholders in RetroPGF Round 1?': '3',
#  'How could someone nominate a project for RetroPGF Round 1?': '2',
#  'When did the voting for RetroPGF Round 1 take place?': '3',
#  'When did the second round of Retroactive Public Goods Funding take place?': '5',
#  'How many OP tokens were allocated in RetroPGF Round 2?': '3',
#  'What was the median OP received by a project in RetroPGF 2?': '3',
#  'How are badgeholders selected for RetroPGF Round 2 in Optimism Governance?': '2',
#  'Where can I find information about the learnings and reflections from round 2 of Optimism Governance?': '2',
#  'How long is the project application period for Optimism Governance?': '2',
#  'When will the results and token disbursement be announced for Optimism Governance?': '2',
#  'Where can I find the announcement for the RetroPGF Round 3 recipients?': '4',
#  'What should Retro Funding recipients do if they have questions or problems with the KYC & grant delivery process?': '3',
#  'Is there a place where I can read about the learnings and reflections on RetroPGF 3?': '3',
#  'What tools were available for badgeholders to vote in RetroPGF 3?': '3',
#  'Where can badgeholders find more information relevant to voting?': '3',
#  'Where can I see applications for voting on Retro Funding?': '3',
#  'Where can badgeholders find resources and stay updated?': '3',
#  'Can I apply for RetroPGF 3 if my project received funding from venture capital or the Optimism Token House?': '2',
#  'Do I need to have made my contribution between specific rounds to be considered for RetroPGF 3?': '3',
#  "What's the title of the section that talks about the history of the Token House?": '3',
#  'How often does Token House voting occur?': '2',
#  'What happens during Reflection Periods in Token House governance?': '2',
#  'When do Voting Cycles begin and end?': '3',
#  'How does Optimism handle the budget for the Developer Advisory Board?': '2',
#  'What is the purpose of the Code of Conduct Council in Optimism?': '2',
#  'What is the Grants Council and what are its functions?': '2',
#  'How often does Optimism have voting cycles?': '2',
#  'Where can I find the results or summaries of the grants given during each voting cycle?': '3',
#  'Where can I find the budget proposals for different intents in Optimism Governance?': '2',
#  'How can I participate in the Grants Council Elections for Builders and Growth Experiments in Optimism?': '2',
#  'Is there a proposal for the renewal of the Protocol Delegation Program in Optimism?': '2',
#  'What is the Bedrock Upgrade Proposal?': '2',
#  'What are Grants Cycle Roundups?': '3',
#  'How can I participate in the Protocol Delegation Elections for Optimism?': '2',
#  'What are the different types of Grants Council Elections available?': '2',
#  'What is the Badgeholder Nomination Voting?': '3',
#  'Where can I find information about the results of previous voting cycles for Optimism?': '3',
#  'When did Voting Cycle #8 for Optimism take place?': '3',
#  "What's the reflection period in Optimism governance?": '2',
#  'Where can I find the updated operating manual for Optimism governance?': '3',
#  'What are governance committees in Optimism?': '2',
#  'How many voting cycles have been documented in the Optimism governance forum?': '2',
#  'How long will the Working Constitution of the Optimism Collective be in effect?': '2',
#  "What will happen after the Working Constitution's period ends?": '2',
#  'Where can I find the current governance processes for the Token House?': '2',
#  'Who or what is the Optimism Foundation?': '2',
#  'Can the Optimism Foundation enter into legal contracts with other companies?': '2',
#  'What kind of activities can the Optimism Foundation perform due to its legal status?': '2',
#  'How does the Optimism Foundation support the technical development of the protocol?': '3',
#  'Who are the current members of the Board of Directors for the Optimism Foundation?': '2',
#  'What is the role of the Supervisor in the Optimism Foundation?': '2',
#  'How is the Foundation legally accountable in its operations?': '2',
#  "What types of governance proposals ensure the Foundation's accountability?": '2',
#  "What is the purpose of the 'Rights protections' proposal type?": '3',
#  'How long is the Collective’s Working Constitution intended to last?': '2',
#  "What is the Foundation's plan during the transition period of the Working Constitution?": '2',
#  'What is the ultimate goal of the Foundation and the Collective during the transition period?': '2',
#  'Where can I find guides for using the OP Mainnet?': '3',
#  'Where can I get testnet ETH for OP Mainnet?': '3',
#  'Where can I find information on integrating OP Mainnet with my wallet?': '3',
#  'Is there a guide for getting my token onto the standard bridge?': '3',
#  'Are there resources for writing a custom bridge for OP Mainnet?': '3',
#  'How can I suggest a new use case for Optimism?': '2',
#  'Why should I consider using the standard bridge before developing a custom bridge solution?': '3',
#  'What are some reasons why the standard bridge might not work for me?': '3',
#  'How can I add OP Mainnet to my centralized exchange?': '3',
#  'Should I use public or private endpoints for my project?': '3',
#  'How is ETH used in Optimism compared to L1 Ethereum?': '3',
#  'Are the ERC-20 contract addresses for tokens the same on OP Mainnet and Ethereum?': '3',
#  'How do I get the total SNX balance of a user on OP Mainnet?': '3',
#  'Can I use my existing Ethereum code for transactions on OP Mainnet?': '3',
#  'If I charge my users for withdrawals on OP Mainnet, what should I consider?': '2',
#  'How can I transfer assets from Ethereum mainnet to Optimism Mainnet?': '3',
#  'Why does it take a week to move assets from Optimism back to Ethereum?': '3',
#  'What can I do if an ERC-20 token does not have an equivalent on Optimism Mainnet?': '3',
#  'Where can I find the audit reports for Optimism?': '3',
#  'How is the NFT ecosystem structured on the OP Mainnet?': '3',
#  'Where can I find statistics about NFTs on the OP Mainnet?': '3',
#  'Which tools are available on the OP Mainnet for NFTs?': '3',
#  'Which platforms support ERC-1155 tokens?': '3',
#  'Do any of these platforms offer no-code deployment?': '3',
#  'What are the pricing models for these platforms?': '3',
#  'Where can I find resources or APIs related to NFTs on Optimism?': '3',
#  'What is a good starting point for using the NFT API from Alchemy?': '3',
#  'Where can I find the documentation for using Reservoir with Optimism?': '3',
#  'Where can I buy or trade NFTs on the Optimism network?': '3',
#  'What are some marketplaces that support Optimism for NFT transactions?': '3',
#  'Who or what is Bluesweep?': '5',
#  'Can I use NFTs as collateral on Optimism?': '3',
#  'How can I find the chain ID and supporting information for the OP Goerli test network?': '3',
#  'What additional testing utilities are available for the OP Goerli network?': '3',
#  'How can I get test tokens for testing on Optimism?': '3',
#  'Is there a specific address for WETH on Optimism?': '3',
#  'Where can I find the contract address for the token OUT-1 on Optimism?': '3',
#  'What is the decimal precision for the token OUT-2 on Optimism?': '3',
#  'Is the `OUTb` token supported by the bridge on Goerli?': '3',
#  'Where can I find a tutorial on how to use the `OUTb` token with the bridge?': '3',
#  'How can I obtain NFT tokens on OP Goerli?': '3',
#  'What is the address of the ERC-721 token contract on OP Goerli?': '3',
#  'Why are there fee discrepancies on OP Mainnet?': '3',
#  'What is the purpose of this guide?': '3',
#  'How can I find the ERC-20 contract address for a token on the OP Mainnet?': '3',
#  'How can I know if my transaction on OP Mainnet is final?': '3',
#  'What are the states a transaction can be in on OP Mainnet?': '3',
#  'Is there a way to easily detect when a transaction has been published to Ethereum?': '3',
#  'Can I use my existing code for estimating fees on L1 Ethereum for OP Mainnet?': '3',
#  "How do I ensure my transaction doesn't fail when sending the maximum amount of ETH from my wallet?": '3',
#  'Why do I need to consider both L2 execution fee and L1 data fee when sending ETH?': '3',
#  'Why is decentralized identity important in the context of Optimism?': '3',
#  'What benefits does decentralized identity provide to individuals?': '3',
#  'How does decentralized identity work on the Superchain?': '3',
#  'What is the role of the AttestationStation in decentralized identity?': '3',
#  'Which applications use the AttestationStation?': '3',
#  'What is EAS Scan?': '3',
#  'What is Citizen Attestations?': '3',
#  'What is Attest Fest?': '4',
#  'How can I query and submit attestations on Optimism?': '3',
#  'What is the Optimist Score and where can I find it?': '3',
#  'How can I bring web2 user behavior and identity data onchain?': '3',
#  'Is AttestationStation v0 still supported?': '3',
#  'What are the main attributes of an attestation in AttestationStation v0?': '3',
#  'Can different creators use the same key for different purposes in AttestationStation v0?': '3',
#  'How can I search for all attestations about a specific address?': '3',
#  'What information do I need to look for a specific attestation?': '3',
#  'Is there a way to search for attestations without relying on a centralized authority?': '3',
#  'Where can I find the legacy AttestationStation contract in the Optimism monorepo?': '3',
#  'What information is included in the `AttestationCreated` event in Optimism?': '3',
#  'Who can create an attestation in the AttestationStation?': '3',
#  'What are the parameters required for the `attest` function?': '3',
#  'How does Optimism handle the roles of creator, signer, and transaction payer?': '3',
#  'How can I interact with the AttestationStation v1 on the OP Mainnet?': '3',
#  'Where can I find the contract addresses for the AttestationStation v1 on the OP Goerli network?': '3',
#  'Is there a way to index attestations from the AttestationStation v1?': '3',
#  'How can I build decentralized identity apps using attestations?': '3',
#  'What is an attestation in the context of Optimism?': '3',
#  "What should I do if I have a good project idea but can't build it myself?": '3',
#  "How can I ensure users' privacy when collecting personal information on the blockchain?": '3',
#  'Is it safe to store sensitive data on the blockchain?': '3',
#  'What measures should be taken when storing sensitive data offchain?': '3',
#  'Can attestations be used as verifiable credentials?': '3',
#  'How do attestations relate to proof of personhood?': '3',
#  'Why choose attestations over soulbound or non-transferable tokens?': '3',
#  'Who can issue an attestation in a decentralized identity system?': '3',
#  'What is the purpose of the AttestationStation?': '3',
#  'Can anyone create an Optimist Profile?': '3',
#  'What is the purpose of an Optimist Profile?': '3',
#  'Can the Optimist Profile be used for onchain identity purposes?': '3',
#  'What can an Optimist Profile do regarding contributions?': '3',
#  'What is the purpose of the profileMetadataPtr in the Optimist Profile?': '3',
#  'What does the applicationMetadataPtrType indicate in the RetroPGF 3 Application schema?': '3',
#  'How can I find the addresses for RetroPGF badgeholders?': '3',
#  'How can I find the addresses for Optimist Profiles?': '3',
#  'Why do I see multiple applications associated with a single Optimist Profile?': '3',
#  'What can I find in the documentation about schemas?': '3',
#  'Where can I find the schema UID for the Optimist Profile?': '3',
#  'Where can I find the schema UID for Gitcoin Passport V1 scores?': '3',
#  'Where can I find the Superchain Faucet schema UID for Optimism?': '3',
#  'How can I verify the authenticity of a Season 4 Co-grant participant schema UID?': '3',
#  'Where can I find the Governance contribution schema UID?': '3',
#  'How can I verify the attester address for the RetroPGF Badgeholders schema?': '3',
#  'What is the schema UID for the RetroPGF 3 Approved Application?': '3',
#  'Can you explain the main principles behind the design of Optimism?': '3',
#  'Why does Optimism prefer to use existing Ethereum code and infrastructure?': '3',
#  "What are the benefits of Optimism's simplicity in its design?": '3',
#  "How does Optimism's simplicity contribute to its long-term vision?": '3',
#  'How does the design philosophy of Optimism prioritize user and developer needs?': '3',
#  "How does Optimism handle the limitations of its core team's expertise?": '2',
#  'What role does user feedback play in the development of Optimism?': '3',
#  'Why is long-term sustainability important for Optimism?': '2',
#  'How does Optimism ensure that its protocol remains sustainable?': '2',
#  'How is Optimism related to Ethereum?': '3',
#  "Why is the project named 'Optimism'?": '5',
#  'What is the main goal of Optimism?': '2',
#  'Why is Optimism built as an Optimistic Rollup?': '3',
#  'What parent blockchain does OP Mainnet use?': '3',
#  'How are Bedrock L2 blocks saved to the Ethereum blockchain?': '3',
#  'Why is it important to write blocks to L1 in a compressed format?': '3',
#  'What guarantees does OP Mainnet inherit from Ethereum?': '3',
#  'Who manages block production in Optimism?': '2',
#  'What are the two ways transactions can get to the sequencer in Optimism?': '3',
#  'How does the execution engine in Optimism receive blocks?': '3',
#  'What is the difference between the two mechanisms for receiving blocks in Optimism?': '3',
#  'Where can I find more detailed information about the synchronization mechanisms of the execution engine in Optimism?': '3',
#  'Can I transfer ERC20 tokens between Ethereum and Optimism?': '3',
#  ...}

# %%
# add a column with the cluster to df
test_clean['cluster'] = [clusters[q] for q in test_clean['question']]
test_clean
# Out:
# /var/folders/k0/xzzz067529g7g_xcf607pyx00000gn/T/ipykernel_99359/717358691.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_clean['cluster'] = [clusters[q] for q in test_clean['question']]
#       fragment                                           question  \
# 0            0  How can I get support for my project on Optimism?
# 2            0  What should I do before deploying my project o...
# 3            1  Where can I find tutorials for developing on O...
# 5            1  Is there a Discord channel for developer suppo...
# 6            2  How can I get my project listed on the Superch...
# ...        ...                                                ...
# 1866       758  How can developers access OP Mainnet nodes thr...
# 1867       758  Is there a free tier available for using OP Ma...
# 1870       760  Are there any premium options available for OP...
# 1871       760  Do I need to manage the infrastructure if I us...
# 1873       762  Who provides ERC-4337 account abstraction infr...
#
#                                                  answer  \
# 0     To get support for your project on Optimism, y...
# 2     Before deploying your project on OP Mainnet, y...
# 3     You can find tutorials for developing on Optim...
# 5     Yes, there is a Discord channel for developer ...
# 6     To get your project listed on the Superchain a...
# ...                                                 ...
# 1866  Developers can access OP Mainnet nodes through...
# 1867  Yes, there is a generous free tier available t...
# 1870  Yes, QuickNode provides an option to upgrade t...
# 1871  No, QuickNode manages the complex infrastructu...
# 1873  Stackup provides ERC-4337 account abstraction ...
#
#                                           fragment_text cluster
# 0     ---\ntitle: How do I get project support (mark...       3
# 2     ---\ntitle: How do I get project support (mark...       3
# 3     Steps to take if you would like developer supp...       3
# 5     Steps to take if you would like developer supp...       3
# 6     When your project is deployed on the Superchai...       3
# ...                                                 ...     ...
# 1866  [Pocket](https://www.portal.pokt.network/) off...       3
# 1867  [Pocket](https://www.portal.pokt.network/) off...       3
# 1870  [QuickNode](https://www.quicknode.com/) offers...       3
# 1871  [QuickNode](https://www.quicknode.com/) offers...       3
# 1873  [Stackup](https://www.stackup.sh/) provides ER...       3
#
# [1270 rows x 5 columns]

# %%
test_clean['cluster'].value_counts()
# Out:
# cluster
# 3    1038
# 2     172
# 4      34
# 5      18
# 1       8
# Name: count, dtype: int64

# %%
# select some random questions from cluster 3
cluster_3 = test_clean[test_clean['cluster'] == '3']
random_10 = cluster_3.sample(20).question.tolist()
random_10
# Out:
# ['Where can I find the addresses of the messenger contracts on Optimism?',
#  'Are demo spots limited?',
#  'Can the SystemDictator revert an upgrade?',
#  'Who should I contact if I have questions about the schema or need to share additional data?',
#  'How do I install Go for the Optimism Governance tutorial?',
#  'Why might some dapps need OP Mainnet-specific features?',
#  'Why was Bedrock built to be modular and upgradeable?',
#  'Where can I find a list of OP Mainnet Block Explorers?',
#  'Do I need to have made my contribution between specific rounds to be considered for RetroPGF 3?',
#  'How do I set the gas limit for a transaction on OP Mainnet?',
#  'How can I bring web2 user behavior and identity data onchain?',
#  'What kind of pricing model does BlockPI Network offer?',
#  'Where can I find information on integrating OP Mainnet with my wallet?',
#  'How can I ensure that the data I generate is verifiable by others?',
#  'How many addresses qualify for a 10% bonus?',
#  'How is the state stored and modified in Optimism?',
#  'Do deposits in Optimism always involve transferring assets?',
#  'Can you explain the main principles behind the design of Optimism?',
#  "How do you initialize nodes in Optimism's Migrated and Non-Migrated Networks?",
#  'What is the purpose of the deposit flow in Optimism?']

# %% [markdown]
# ## Second Implementation

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
model_chat = "gpt-3.5-turbo-0125"

# select the model
llm = ChatOpenAI(
    model = model_chat,
    temperature = 0,
    max_tokens = None,
    timeout = None,
    max_retries = 2,
    api_key = openai_api_key
)

# create the template for interactions
def answer_template():
    return f""" I'll give you a question about Optimism Documentation. You don't need to answer it, just categorize it (just return the number, one character) into one of the following categories:

1. project support;
2. governance;
3. dev;
4. tech documentation;
5. general documentation;
6. marketing / promotion / ambassadors / events / PR;
7. other.

Question: {{question}}
"""

prompt = ChatPromptTemplate.from_template(answer_template())

chain = prompt | llm

# %%
clusters = {}
for q in cleaned_questions:
    cat = chain.invoke({"question": q})
    clusters[q] = cat.content
    print(f"Question: {q}")
    print(f"Category: {cat.content}")

# add a column with the cluster to df
test_clean['cluster'] = [clusters[q] for q in test_clean['question']]
test_clean
# Out:
# Question: How can I get support for my project on Optimism?
# Category: 1
# Question: What should I do before deploying my project on OP Mainnet?
# Category: 3
# Question: Where can I find tutorials for developing on Optimism?
# Category: 4
# Question: Is there a Discord channel for developer support for Optimism?
# Category: 3
# Question: How can I get my project listed on the Superchain apps page?
# Category: 6
# Question: Is there a way to promote my app launch through Superchain's marketing channels?
# Category: 6
# Question: How does Optimism support projects that align with its values?
# Category: 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[45], line 3
#       1 clusters = {}
#       2 for q in cleaned_questions:
# ----> 3     cat = chain.invoke({"question": q})
#       4     clusters[q] = cat.content
#       5     print(f"Question: {q}")
#
# File ~/opt/anaconda3/envs/bleu-chatbot/lib/python3.12/site-packages/langchain_core/runnables/base.py:2495, in RunnableSequence.invoke(self, input, config, **kwargs)
#    2493             input = step.invoke(input, config, **kwargs)
#    2494         else:
# -> 2495             input = step.invoke(input, config)
#    2496 # finish the root run
#    2497 except BaseException as e:
#
# File ~/opt/anaconda3/envs/bleu-chatbot/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:170, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     159 def invoke(
#     160     self,
#     161     input: LanguageModelInput,
#    (...)
#     165     **kwargs: Any,
#     166 ) -> BaseMessage:
#     167     config = ensure_config(config)
#     168     return cast(
#     169         ChatGeneration,
# --> 170         self.generate_prompt(
#     171             [self._convert_input(input)],
#     172             stop=stop,
#     173             callbacks=config.get("callbacks"),
#     174             tags=config.get("tags"),
#     175             metadata=config.get("metadata"),
#     176             run_name=config.get("run_name"),
#     177             run_id=config.pop("run_id", None),
#     178             **kwargs,
#     179         ).generations[0][0],
#     180     ).message
#
# File ~/opt/anaconda3/envs/bleu-chatbot/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:599, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     591 def generate_prompt(
#     592     self,
#     593     prompts: List[PromptValue],
#    (...)
#     596     **kwargs: Any,
#     597 ) -> LLMResult:
#     598     prompt_messages = [p.to_messages() for p in prompts]
# --> 599     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/opt/anaconda3/envs/bleu-chatbot/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:456, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     454         if run_managers:
#     455             run_managers[i].on_llm_error(e, response=LLMResult(generations=[]))
# --> 456         raise e
#     457 flattened_outputs = [
#     458     LLMResult(generations=[res.generations], llm_output=res.llm_output)  # type: ignore[list-item]
#     459     for res in results
#     460 ]
#     461 llm_output = self._combine_llm_outputs([res.llm_output for res in results])
#
# File ~/opt/anaconda3/envs/bleu-chatbot/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:446, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     443 for i, m in enumerate(messages):
#     444     try:
#     445         results.append(
# --> 446             self._generate_with_cache(
#     447                 m,
#     448                 stop=stop,
#     449                 run_manager=run_managers[i] if run_managers else None,
#     450                 **kwargs,
#     451             )
#     452         )
#     453     except BaseException as e:
#     454         if run_managers:
#
# File ~/opt/anaconda3/envs/bleu-chatbot/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:671, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     669 else:
#     670     if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 671         result = self._generate(
#     672             messages, stop=stop, run_manager=run_manager, **kwargs
#     673         )
#     674     else:
#     675         result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/opt/anaconda3/envs/bleu-chatbot/lib/python3.12/site-packages/langchain_openai/chat_models/base.py:537, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#     535 message_dicts, params = self._create_message_dicts(messages, stop)
#     536 params = {**params, **kwargs}
# --> 537 response = self.client.create(messages=message_dicts, **params)
#     538 return self._create_chat_result(response)
#
# File ~/opt/anaconda3/envs/bleu-chatbot/lib/python3.12/site-packages/openai/_utils/_utils.py:277, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     275             msg = f"Missing required argument: {quote(missing[0])}"
#     276     raise TypeError(msg)
# --> 277 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/bleu-chatbot/lib/python3.12/site-packages/openai/resources/chat/completions.py:606, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, parallel_tool_calls, presence_penalty, response_format, seed, stop, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     573 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     574 def create(
#     575     self,
#    (...)
#     604     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     605 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
# --> 606     return self._post(
#     607         "/chat/completions",
#     608         body=maybe_transform(
#     609             {
#     610                 "messages": messages,
#     611                 "model": model,
#     612                 "frequency_penalty": frequency_penalty,
#     613                 "function_call": function_call,
#     614                 "functions": functions,
#     615                 "logit_bias": logit_bias,
#     616                 "logprobs": logprobs,
#     617                 "max_tokens": max_tokens,
#     618                 "n": n,
#     619                 "parallel_tool_calls": parallel_tool_calls,
#     620                 "presence_penalty": presence_penalty,
#     621                 "response_format": response_format,
#     622                 "seed": seed,
#     623                 "stop": stop,
#     624                 "stream": stream,
#     625                 "stream_options": stream_options,
#     626                 "temperature": temperature,
#     627                 "tool_choice": tool_choice,
#     628                 "tools": tools,
#     629                 "top_logprobs": top_logprobs,
#     630                 "top_p": top_p,
#     631                 "user": user,
#     632             },
#     633             completion_create_params.CompletionCreateParams,
#     634         ),
#     635         options=make_request_options(
#     636             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     637         ),
#     638         cast_to=ChatCompletion,
#     639         stream=stream or False,
#     640         stream_cls=Stream[ChatCompletionChunk],
#     641     )
#
# File ~/opt/anaconda3/envs/bleu-chatbot/lib/python3.12/site-packages/openai/_base_client.py:1240, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1226 def post(
#    1227     self,
#    1228     path: str,
#    (...)
#    1235     stream_cls: type[_StreamT] | None = None,
#    1236 ) -> ResponseT | _StreamT:
#    1237     opts = FinalRequestOptions.construct(
#    1238         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1239     )
# -> 1240     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/opt/anaconda3/envs/bleu-chatbot/lib/python3.12/site-packages/openai/_base_client.py:921, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     912 def request(
#     913     self,
#     914     cast_to: Type[ResponseT],
#    (...)
#     919     stream_cls: type[_StreamT] | None = None,
#     920 ) -> ResponseT | _StreamT:
# --> 921     return self._request(
#     922         cast_to=cast_to,
#     923         options=options,
#     924         stream=stream,
#     925         stream_cls=stream_cls,
#     926         remaining_retries=remaining_retries,
#     927     )
#
# File ~/opt/anaconda3/envs/bleu-chatbot/lib/python3.12/site-packages/openai/_base_client.py:952, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     949 log.debug("Sending HTTP Request: %s %s", request.method, request.url)
#     951 try:
# --> 952     response = self._client.send(
#     953         request,
#     954         stream=stream or self._should_stream_response_body(request=request),
#     955         **kwargs,
#     956     )
#     957 except httpx.TimeoutException as err:
#     958     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File ~/opt/anaconda3/envs/bleu-chatbot/lib/python3.12/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     906 follow_redirects = (
#     907     self.follow_redirects
#     908     if isinstance(follow_redirects, UseClientDefault)
#     909     else follow_redirects
#     910 )
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~/opt/anaconda3/envs/bleu-chatbot/lib/python3.12/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~/opt/anaconda3/envs/bleu-chatbot/lib/python3.12/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~/opt/anaconda3/envs/bleu-chatbot/lib/python3.12/site-packages/httpx/_client.py:1015, in Client._send_single_request(self, request)
#    1010     raise RuntimeError(
#    1011         "Attempted to send an async request with a sync Client instance."
#    1012     )
#    1014 with request_context(request=request):
# -> 1015     response = transport.handle_request(request)
#    1017 assert isinstance(response.stream, SyncByteStream)
#    1019 response.request = request
#
# File ~/opt/anaconda3/envs/bleu-chatbot/lib/python3.12/site-packages/httpx/_transports/default.py:233, in HTTPTransport.handle_request(self, request)
#     220 req = httpcore.Request(
#     221     method=request.method,
#     222     url=httpcore.URL(
#    (...)
#     230     extensions=request.extensions,
#     231 )
#     232 with map_httpcore_exceptions():
# --> 233     resp = self._pool.handle_request(req)
#     235 assert isinstance(resp.stream, typing.Iterable)
#     237 return Response(
#     238     status_code=resp.status,
#     239     headers=resp.headers,
#     240     stream=ResponseStream(resp.stream),
#     241     extensions=resp.extensions,
#     242 )
#
# File ~/opt/anaconda3/envs/bleu-chatbot/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:216, in ConnectionPool.handle_request(self, request)
#     213         closing = self._assign_requests_to_connections()
#     215     self._close_connections(closing)
# --> 216     raise exc from None
#     218 # Return the response. Note that in this case we still have to manage
#     219 # the point at which the response is closed.
#     220 assert isinstance(response.stream, Iterable)
#
# File ~/opt/anaconda3/envs/bleu-chatbot/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:196, in ConnectionPool.handle_request(self, request)
#     192 connection = pool_request.wait_for_connection(timeout=timeout)
#     194 try:
#     195     # Send the request on the assigned connection.
# --> 196     response = connection.handle_request(
#     197         pool_request.request
#     198     )
#     199 except ConnectionNotAvailable:
#     200     # In some cases a connection may initially be available to
#     201     # handle a request, but then become unavailable.
#     202     #
#     203     # In this case we clear the connection and try again.
#     204     pool_request.clear_connection()
#
# File ~/opt/anaconda3/envs/bleu-chatbot/lib/python3.12/site-packages/httpcore/_sync/connection.py:101, in HTTPConnection.handle_request(self, request)
#      98     self._connect_failed = True
#      99     raise exc
# --> 101 return self._connection.handle_request(request)
#
# File ~/opt/anaconda3/envs/bleu-chatbot/lib/python3.12/site-packages/httpcore/_sync/http11.py:143, in HTTP11Connection.handle_request(self, request)
#     141     with Trace("response_closed", logger, request) as trace:
#     142         self._response_closed()
# --> 143 raise exc
#
# File ~/opt/anaconda3/envs/bleu-chatbot/lib/python3.12/site-packages/httpcore/_sync/http11.py:113, in HTTP11Connection.handle_request(self, request)
#     102     pass
#     104 with Trace(
#     105     "receive_response_headers", logger, request, kwargs
#     106 ) as trace:
#     107     (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112         trailing_data,
# --> 113     ) = self._receive_response_headers(**kwargs)
#     114     trace.return_value = (
#     115         http_version,
#     116         status,
#     117         reason_phrase,
#     118         headers,
#     119     )
#     121 network_stream = self._network_stream
#
# File ~/opt/anaconda3/envs/bleu-chatbot/lib/python3.12/site-packages/httpcore/_sync/http11.py:186, in HTTP11Connection._receive_response_headers(self, request)
#     183 timeout = timeouts.get("read", None)
#     185 while True:
# --> 186     event = self._receive_event(timeout=timeout)
#     187     if isinstance(event, h11.Response):
#     188         break
#
# File ~/opt/anaconda3/envs/bleu-chatbot/lib/python3.12/site-packages/httpcore/_sync/http11.py:224, in HTTP11Connection._receive_event(self, timeout)
#     221     event = self._h11_state.next_event()
#     223 if event is h11.NEED_DATA:
# --> 224     data = self._network_stream.read(
#     225         self.READ_NUM_BYTES, timeout=timeout
#     226     )
#     228     # If we feed this case through h11 we'll raise an exception like:
#     229     #
#     230     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     234     # perspective. Instead we handle this case distinctly and treat
#     235     # it as a ConnectError.
#     236     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/opt/anaconda3/envs/bleu-chatbot/lib/python3.12/site-packages/httpcore/_backends/sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     124 with map_exceptions(exc_map):
#     125     self._sock.settimeout(timeout)
# --> 126     return self._sock.recv(max_bytes)
#
# File ~/opt/anaconda3/envs/bleu-chatbot/lib/python3.12/ssl.py:1233, in SSLSocket.recv(self, buflen, flags)
#    1229     if flags != 0:
#    1230         raise ValueError(
#    1231             "non-zero flags not allowed in calls to recv() on %s" %
#    1232             self.__class__)
# -> 1233     return self.read(buflen)
#    1234 else:
#    1235     return super().recv(buflen, flags)
#
# File ~/opt/anaconda3/envs/bleu-chatbot/lib/python3.12/ssl.py:1106, in SSLSocket.read(self, len, buffer)
#    1104         return self._sslobj.read(len, buffer)
#    1105     else:
# -> 1106         return self._sslobj.read(len)
#    1107 except SSLError as x:
#    1108     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %%
test_clean['cluster'].value_counts()
# Out:
# cluster
# 4                        899
# 2                        153
# 3                         94
# 6                         67
# 5                         29
# 1                         15
# 7                         12
# 4. tech documentation      1
# Name: count, dtype: int64
