# %% [markdown]
# # Notebook for creating local vectorscore DBs from collected data

# %% [markdown]
# ## Paths

# %%
# optimism governance docs
docs_path = "../../data/001-initial-dataset-governance-docs/file.txt"

# optimism governance forum
forum_path = "../../data/002-governance-forum-202406014/dataset/_out.jsonl"

# %% [markdown]
# ## Embeddings and vectorstores that are going to be tested

# %%
# we are going to test the open ai api for embeddings
embedding_models = ["text-embedding-3-small", "text-embedding-3-large", "text-embedding-ada-002"]

# we are going to use faiss
vectorstores = ['faiss']

# %% [markdown]
# ## Imports

# %%
from langchain_openai import OpenAIEmbeddings
# openai api key
openai_api_key = input("Enter the OpenAI API key: ")

if 'faiss' in vectorstores:
    from langchain_community.vectorstores import FAISS

# langchain documents handling
from langchain_core.documents.base import Document
from langchain_text_splitters import MarkdownHeaderTextSplitter

import re, tiktoken, json
import pandas as pd

# %% [markdown]
# ## Load and clean documentation

# %%
# load the documentation
with open(docs_path, "r") as f:
    docs_read = f.read()

# split "==> " and " <==" (to get the name of the files)
docs_read = re.split(r"==> | <==", docs_read)


docs = []
path = []
for d in docs_read:
    if not "\n" in d:
        # if it's a path
        path = d.split("/")
    else:
        # if it's a text document
        docs.append({
            "path": "/".join(path[:-1]),
            "document_name": path[-1],
            "content": d
        })

# remove entries where content is just whitespace or '\n' 
docs = [d for d in docs if d['content'].strip() != '']

# %%
# get repeated content entries
repeated_contents = []
repeated_entries = []
for i, d in enumerate(docs):
    for j, d2 in enumerate(docs):
        if i != j and d['content'] == d2['content']:
            if not d in repeated_entries:
                if not d['content'] in repeated_contents:
                    repeated_contents.append(d['content'])
                    repeated_entries.append(d2)
                else:
                    repeated_entries.append(d)
                    if not d2 in repeated_entries:
                        repeated_entries.append(d2)
            if d['path'] != d2['path']:
                print(f"Repeated content found in PATHS {d['path']} and {d2['path']}")
            else:
                print(f"Repeated content found in {d['path']}: DOCUMENTS {d['document_name']} and {d2['document_name']}")

# remove the repeated entries
docs = [d for d in docs if d not in repeated_entries]
# Out:
# Repeated content found in developers/bedrock: DOCUMENTS README.md and explainer.md
# Repeated content found in developers/bedrock: DOCUMENTS bedrock.md and differences.md
# Repeated content found in developers/bedrock: DOCUMENTS bedrock.md and how-is-bedrock-different.md
# Repeated content found in developers/bedrock: DOCUMENTS differences.md and bedrock.md
# Repeated content found in developers/bedrock: DOCUMENTS differences.md and how-is-bedrock-different.md
# Repeated content found in developers/bedrock: DOCUMENTS explainer.md and README.md
# Repeated content found in developers/bedrock: DOCUMENTS how-is-bedrock-different.md and bedrock.md
# Repeated content found in developers/bedrock: DOCUMENTS how-is-bedrock-different.md and differences.md
# Repeated content found in identity: DOCUMENTS README.md and intro.md
# Repeated content found in identity: DOCUMENTS intro.md and README.md

# %%
full_docs = [
    Document(
        page_content = d['content'],
        metadata = {
            "path": d['path'],
            "document_name": d['document_name']
        }
    ) for d in docs
]

# %%
# split the markdown file into sections
headers_to_split_on = [
    ("##", "header 2"),
    ("###", "header 3"),
    ("####", "header 4"),
    ("#####", "header 5"),
    ("######", "header 6")
]
markdown_splitter = MarkdownHeaderTextSplitter(headers_to_split_on=headers_to_split_on)

# incorporate the doc metadata into the fragments
fragments_docs = []
for d in docs:
    f = markdown_splitter.split_text(d['content'])
    for fragment in f:
        fragment.metadata['path'] = d['path']
        fragment.metadata['document_name'] = d['document_name']
        fragments_docs.append(fragment)

# %% [markdown]
# ## Load and clean the forum

# %%
def load_forum_posts(file_path):
    with open(file_path, 'r') as file:
        boards = {}
        threads = {}
        posts = {}
        for line in file:
            data_line = json.loads(line)
            type_line = data_line['type']
            try:
                id = data_line['item']['data']['id']
                match type_line:
                    case 'board':
                        boards[id] = {
                            'name': data_line['item']['data']['name'],
                            #"created_at": data_line['item']['data']['created_at'],
                            }
                    case 'thread':
                        threads[id] = {
                            'title': data_line['item']['data']['title'],
                            'category_id' : data_line['item']['data']['category_id'],
                            "created_at": data_line['item']['data']['created_at'],
                            "views": data_line['item']['data']['views'],
                            "like_count": data_line['item']['data']['like_count'],
                            }
                    case 'post':
                        posts[id] = {
                            #"cooked": data_line['item']['data']['cooked'],
                            #"url": data_line['item']['data']['url'],
                            #"link_counts": data_line['item']['data']['link_counts'],
                            "created_at": data_line['item']['data']['created_at'],
                            "username": data_line['item']['data']['username'],
                            "score": data_line['item']['data']['score'],
                            "readers_count": data_line['item']['data']['readers_count'],
                            "moderator": data_line['item']['data']['moderator'],
                            "admin": data_line['item']['data']['admin'],
                            "staff": data_line['item']['data']['staff'],
                            "trust_level": data_line['item']['data']['trust_level'],
                            "content": data_line['item']['content'],
                            "creation_time": data_line['item']['creation_time'],
                            "path": data_line['item']['path'],
                            "download_time": data_line['download_time'],
                        }
                    case _:
                        print(f"Unknown type: {type_line}")
            except:
                #print(f"Error processing line: {line}")
                None

    for id_post in posts:
        path = posts[id_post]['path']

        try:
            id_board = int(path[0])
            posts[id_post]['board_name'] = boards[id_board]['name']
            posts[id_post]['board_id'] = id_board
        except:
            posts[id_post]['board_name'] = None
            #print(f"Error processing board for post {id_post}")
        
        try:
            id_thread = int(path[1])
            posts[id_post]['thread_title'] = threads[id_thread]['title']
            posts[id_post]['thread_id'] = id_thread
        except:
            posts[id_post]['thread_title'] = None
            #print(f"Error processing thread for post {id_post}")

    return posts

posts_forum = [
    Document(
        page_content = d['content'],
        metadata = {
            'board_name': d['board_name'],
            'thread_title': d['thread_title'],
            'creation_time': d['creation_time'],
            'username': d['username'],
            'moderator': d['moderator'],
            'admin': d['admin'],
            'staff': d['staff'],
            'trust_level': d['trust_level'],
            'id': ".".join(d['path']) + '.' + str(id)
        }
    ) for id, d in load_forum_posts(forum_path).items()
]

# %%
posts_forum
# Out:
# [Document(page_content='<p><a href="https://calendar.google.com/calendar/u/0/r?cid=Y19mbm10Z3VoNm5vbzZxZ2JuaTJncGVyaWQ0a0Bncm91cC5jYWxlbmRhci5nb29nbGUuY29t">Governance Calendar</a></p>', metadata={'board_name': 'Get  Started 🌱', 'thread_title': 'How to Stay up to Date', 'creation_time': '2023-06-16T11:17:47.837000+00:00', 'username': 'system', 'moderator': True, 'admin': True, 'staff': True, 'trust_level': 4, 'id': '67.6124.26479'}),
#  Document(page_content='', metadata={'board_name': 'Get  Started 🌱', 'thread_title': 'How to Stay up to Date', 'creation_time': '2023-06-16T11:17:56.495000+00:00', 'username': 'lavande', 'moderator': True, 'admin': True, 'staff': True, 'trust_level': 4, 'id': '67.6124.26480'}),
#  Document(page_content='<p>Hello to everyone good to met you all<br>\nThat am in to always up date me for issue concern<br>\nThank you<br>\nFrom marcus safea Brima Togba</p>', metadata={'board_name': 'Get  Started 🌱', 'thread_title': 'How to Stay up to Date', 'creation_time': '2024-03-24T20:07:47.816000+00:00', 'username': '1311832119', 'moderator': False, 'admin': False, 'staff': False, 'trust_level': 1, 'id': '67.6124.35364'}),
#  Document(page_content='<h2><a name="httpsgovoptimismiothow-to-get-a-grant6119-1" class="anchor" href="#httpsgovoptimismiothow-to-get-a-grant6119-1"></a><a href="https://gov.optimism.io/t/how-to-get-a-grant/6119" class="inline-onebox">How to Get a Grant</a></h2>\n<hr>\n<h2><a name="how-to-navigate-the-forum-2" class="anchor" href="#how-to-navigate-the-forum-2"></a>How to Navigate the Forum</h2>\n<ul>\n<li>\n<p><a href="https://gov.optimism.io/c/updates-and-announcements/48">Updates and Announcements:</a> Find information about community calls, weekly governance summaries, and periodic updates from the Foundation and other partners</p>\n</li>\n<li>\n<p><a href="https://gov.optimism.io/c/grants/69">Grants</a>: Key information about Mission Grants.</p>\n</li>\n<li>\n<p><a href="https://gov.optimism.io/c/technical-proposals/47">Technical Proposals</a>: For all non-grant proposals. The Standard Template for non-grant Proposals can be found <a href="https://gov.optimism.io/t/standard-proposal-template-optimism-token-house/5443">here</a>.  The process for submitting a non-grant proposal is outlined in the <a href="https://github.com/ethereum-optimism/OPerating-manual/blob/main/manual.md">Operating Manual.</a></p>\n</li>\n<li>\n<p><a href="https://gov.optimism.io/c/retrofunding/46">Retro Funding</a>: Citizen and Badgeholder discussions relating to the allocation of Retro Funding via specific rounds. Key info about rounds will also be found here.</p>\n</li>\n<li>\n<p><a href="https://gov.optimism.io/c/delegates/">Token House Governance</a>: General governance information as it pertains to delegates, voting cycle round-ups, and delegate communication threads.</p>\n</li>\n<li>\n<p><a href="https://gov.optimism.io/c/accountability/62">Accountability</a>: This category is for posts that increase transparency and accountability around the usage of Governance Fund grants or other topics relevant to members of the Collective. Please keep the information provided here factual. All claims should be supported by verifiable evidence (on-chain, whenever possible) and data.</p>\n</li>\n<li>\n<p><a href="https://gov.optimism.io/c/elected-reps/83">Elected Representatives</a>: This category is for any Elected Representative Structure (i.e., councils).These are the boards, commissions, and councils within the Optimism Collective.</p>\n</li>\n<li>\n<p><a href="https://gov.optimism.io/c/collective-strategy/81">Collective Strategy</a>: This category is for Collective Strategy relating to intents and roadmaps.</p>\n</li>\n<li>\n<p><a href="https://gov.optimism.io/c/citizens/79">Citizens</a>: This category is for all things relating to Citizens!</p>\n</li>\n<li>\n<p><a href="https://gov.optimism.io/c/general/1">General Discussions</a>: General and public discussions that don’t into other categories.</p>\n</li>\n<li>\n<p><a href="https://gov.optimism.io/c/feedback/82">Feedback</a>: This category is for feedback of all kinds!</p>\n</li>\n<li>\n<p><a href="https://gov.optimism.io/c/gov-design/84">Governance Design</a>: This category is for the Collective’s metagovernance strategy! Metagovernance is governance of the governance system, so this category pertains to the design of how the Collective governs the governance system.</p>\n</li>\n</ul>', metadata={'board_name': 'Get  Started 🌱', 'thread_title': 'How to Navigate the Forum', 'creation_time': '2023-06-16T10:29:31.456000+00:00', 'username': 'system', 'moderator': True, 'admin': True, 'staff': True, 'trust_level': 4, 'id': '67.6120.26472'}),
#  Document(page_content='', metadata={'board_name': 'Get  Started 🌱', 'thread_title': 'How to Navigate the Forum', 'creation_time': '2023-06-16T10:31:55.060000+00:00', 'username': 'lavande', 'moderator': True, 'admin': True, 'staff': True, 'trust_level': 4, 'id': '67.6120.26475'}),
#  Document(page_content='<p>This is a good stating point for a newbie to explore the forum. I suggest pinning this up somewhere prominent as a guide for a newbie like me to explore the forum and gain max insights.</p>', metadata={'board_name': 'Get  Started 🌱', 'thread_title': 'How to Navigate the Forum', 'creation_time': '2024-04-30T03:15:08.371000+00:00', 'username': 'sikkha84', 'moderator': False, 'admin': False, 'staff': False, 'trust_level': 0, 'id': '67.6120.36160'}),
#  Document(page_content='<p>Welcome to the Optimism Collective governance forum!</p>\n<p>The forum is where governance participants discuss critical topics relating to the Collective.</p>\n<h3><a name="what-is-the-optimism-collective-1" class="anchor" href="#what-is-the-optimism-collective-1"></a>What is the Optimism Collective?</h3>\n<p>The Optimism Collective is a new model of digital democratic governance. It is a band of communities, companies, and citizens united by the axiom of impact=profit — the principle that positive impact to the Collective should be rewarded to the individual.</p>\n<p>Empowering values. Robust infrastructure. An economy where everyone thrives.</p>\n<p>The foundation for a more equitable digital economy is an interconnected network of blockchains built on a modular, open-source codebase.</p>\n<h3><a name="how-is-this-going-to-be-governed-2" class="anchor" href="#how-is-this-going-to-be-governed-2"></a>How is this going to be governed?</h3>\n<p>The Optimism Collective and the Superchain take an experimental and agile approach to governance, relentlessly iterating towards a system which stands the test of time.</p>\n<p>The Collective’s model of digital democratic governance  consists of two houses: the <em>Token House</em> and the <em>Citizens’ House</em>. These two houses form a bicameral governance system, with the two-house design is intended to help the Collective make better decisions, avoid common pitfalls in token-based governance systems, and have checks and balances.</p>\n<p><strong>What is described here is an initial experiment</strong>. The specifics of this system will evolve as the Collective grows.</p>\n<p><img src="https://europe1.discourse-cdn.com/bc41dd/original/2X/7/7bd2462db8a209ee3f4368a4b1c15f6cb56f9f15.png" alt="image" data-base62-sha1="hFnePbtWeMIsXCMEnxvKqjXW2t7" width="398" height="361"></p>\n<h3><a name="what-is-the-token-house-3" class="anchor" href="#what-is-the-token-house-3"></a>What is the Token House?</h3>\n<p>Governance of the Optimism Collective began with the launch of the OP token and the Token House.</p>\n<p>As Token House members, OP holders are responsible for submitting, deliberating, and voting on various types of governance proposals.</p>\n<p>In carrying out these functions, OP holders may either vote directly, or delegate their OP voting power to someone else.</p>\n<p>Learn <a href="https://community.optimism.io/docs/governance/howto-delegate/">how to delegate your OP tokens</a>. You can delegate to yourself, or anyone else!</p>\n<p>The Token House votes on the proposal types outlined in the <a href="https://github.com/ethereum-optimism/OPerating-manual/blob/main/manual.md#valid-proposal-types">Operating Manual</a>. You can join the discussion by visiting the <a href="https://gov.optimism.io/c/delegates/41">Delegates category</a>.</p>\n<p>You can learn more in the <a href="https://plaid-cement-e44.notion.site/Token-House-Governance-Hub-decae75a0fa248e38f969abe8edef565?pvs=4">Token House Onboarding Hub</a>.</p>\n<h3><a name="what-is-the-citizens-house-4" class="anchor" href="#what-is-the-citizens-house-4"></a>What is the Citizens’ House?</h3>\n<p>The Citizens’ House is a large-scale experiment in a reputation-based governance system (one member = one vote), and is primarily responsible for <a href="https://app.optimism.io/retropgf">Retroactive Public Goods Funding (Retro Funding)</a>.</p>\n<p>Join the discussion by following the <a href="https://gov.optimism.io/c/retrofunding/46">Retro Funding</a> category and the <a href="https://gov.optimism.io/c/citizens/79">Citizens</a> category.</p>\n<h3><a name="but-what-do-they-really-do-5" class="anchor" href="#but-what-do-they-really-do-5"></a>But what do they really do?</h3>\n<p>You can find a more detailed breakdown of responsibilities in this diagram.</p>\n<p><div class="lightbox-wrapper"><a class="lightbox" href="https://europe1.discourse-cdn.com/bc41dd/original/2X/5/51b19f0e723e9aee299bbcec84102528c5f4922c.jpeg"  ...
#  Document(page_content='<p>This is a visual detailed information. Thanks for sharing for a noob like me. Optimism Collective is an initiative with purpose and vision. Love it</p>', metadata={'board_name': 'Get  Started 🌱', 'thread_title': 'About the Optimism Collective', 'creation_time': '2024-05-11T10:16:01.962000+00:00', 'username': 'pikkaeuroman', 'moderator': False, 'admin': False, 'staff': False, 'trust_level': 0, 'id': '67.6118.36718'}),
#  Document(page_content='<p>The Optimism Collective is a large-scale experiment in decentralized governance. Our <a href="https://www.optimism.io/vision">Vision</a> is to sustainably fund those public goods that improve upon the well-being of the Collective and beyond. This Working Constitution enshrines governing provisions and principles that, we hope, are calibrated to the ambition of this Vision. It lays the foundation for a fair, democratic model of decentralized governance that’s built to last.</p>\n<p><em><strong>_____________</strong></em></p>\n<p><strong>1.  This is a “Working” Constitution.</strong>  It is exceedingly unlikely that a fixed model of governing the Optimism Collective, defined at the outset of this experiment, can appropriately navigate the Collective’s future challenges. The problem space is too large. So we start from humility, beginning with a Working Constitution that is:</p>\n<ul>\n<li><strong>A commitment to experimentation.</strong> In its lifetime, the Collective will undertake a series of governance experiments. These experiments should help the Collective understand the balance and power dynamics within its ecosystem, and allow the Collective to define itself, evolve, and grow iteratively over time.</li>\n<li><strong>A transitory document.</strong> The Working Constitution will remain in effect <em>no more than four years</em> from the date of its adoption. After that, authority over governance will be ceded to a permanent Bedrock Constitution (that incorporates the lessons of the Collective’s prior governance experiments).</li>\n</ul>\n<p><strong>2.  OP Citizens and OP Holders will equally coexist within the Collective.</strong>  The governing structure of the Collective must balance short-term incentives with its long-term Vision. Too often today, simple token-based governance systems deteriorate due to misaligned incentives or excessive consolidation of power. The Optimism Collective will implement structural mechanisms to counteract those shortcomings, beginning with a <a href="https://community.optimism.io/docs/governance">bicameral governance system</a> that checks and balances the power of OP Holders and OP Citizens.</p>\n<p><strong>3.  The Optimism Foundation will be a steward of the Optimism Collective and its early governance model.</strong>  The Optimism Foundation is a Cayman Islands organization responsible for guiding the growth and development of the Optimism Collective. Acting through its Board of Directors, the Foundation may:</p>\n<ul>\n<li>Facilitate the administration of Collective governance;</li>\n<li>Allocate treasury assets to fund public goods, incentivize participants in the Optimism ecosystem, or otherwise further its (and the Collective’s) purpose;</li>\n<li>Amend this Working Constitution; and</li>\n<li>Take other actions that are conducive to its stewardship role.</li>\n</ul>\n<p>The Foundation will undertake all these responsibilities in a manner that is consistent with the mission of the Collective, and with a view towards increasingly decentralizing its role over time.</p>\n<p><strong>4. Rights of OP Citizens and OP Holders.</strong>  Subject to the founding legal documents of the Optimism Foundation and the procedures outlined in the Collective’s Operating Manual:</p>\n<ul>\n<li>Future OP Citizens may:\n<ul>\n<li>Allocate Retroactive Public Goods Funding; and</li>\n<li>Exercise such additional rights as are provided to OP Citizens over time.</li>\n</ul>\n</li>\n<li>OP Holders may:\n<ul>\n<li>Remove a director of the Optimism Foundation; and</li>\n<li>Veto changes to the founding documents of the Optimism Foundation, if those changes would reduce the rights of OP Holders in a material way.</li>\n</ul>\n</li>\n</ul>\n<p><strong>5.  Interpretation.</strong>  In interpreting the scope, authority, and meaning of the provisions of this Working Constitution, the following guiding principles apply:</p>\n<ul>\n<li><strong>Governance minimization.</strong> Minimal govern ...
#  Document(page_content='', metadata={'board_name': 'Get  Started 🌱', 'thread_title': 'Working Constitution of the Optimism Collective', 'creation_time': '2022-04-26T01:10:14.068000+00:00', 'username': 'karl', 'moderator': False, 'admin': True, 'staff': True, 'trust_level': 4, 'id': '67.55.70'}),
#  Document(page_content='<p>Proud to be part of the Optimism Collective! Stay Optimistic, WAGMI!</p>', metadata={'board_name': 'Get  Started 🌱', 'thread_title': 'Working Constitution of the Optimism Collective', 'creation_time': '2022-04-26T17:36:03.391000+00:00', 'username': 'BigPPDAO', 'moderator': False, 'admin': False, 'staff': False, 'trust_level': 1, 'id': '67.55.76'}),
#  Document(page_content='<p>excited to see how it will work in practice!</p>', metadata={'board_name': 'Get  Started 🌱', 'thread_title': 'Working Constitution of the Optimism Collective', 'creation_time': '2022-04-27T06:20:54.348000+00:00', 'username': 'cp287', 'moderator': False, 'admin': False, 'staff': False, 'trust_level': 1, 'id': '67.55.107'}),
#  Document(page_content='<p>gm OP friends! can someone explain to me how I can participate in Optimism governance activities? Where is it possible to vote on proposals? ps: the democratic model that has been devised is really original, cool! is very similar to the governance system of cooperatives</p>', metadata={'board_name': 'Get  Started 🌱', 'thread_title': 'Working Constitution of the Optimism Collective', 'creation_time': '2022-04-27T07:32:29.153000+00:00', 'username': 'Firstminister.eth', 'moderator': False, 'admin': False, 'staff': False, 'trust_level': 2, 'id': '67.55.109'}),
#  Document(page_content='<p>This will be the beginning of a new season for Ethereum.<br>\nI’m glad to be here today</p>', metadata={'board_name': 'Get  Started 🌱', 'thread_title': 'Working Constitution of the Optimism Collective', 'creation_time': '2022-04-27T18:26:29.417000+00:00', 'username': 'Masoud_msd', 'moderator': False, 'admin': False, 'staff': False, 'trust_level': 1, 'id': '67.55.132'}),
#  Document(page_content='<p>gm!</p>\n<blockquote>\n<p>can someone explain to me how I can participate in Optimism governance activities?</p>\n</blockquote>\n<p>Before Airdrop <span class="hashtag-raw">#1</span> we’ll post a Discourse thread &amp; docs which describes: how to make proposals, vote on proposals, and commit to being a delegate. Before then the best way to participate is to read the Discourse <img src="https://emoji.discourse-cdn.com/twitter/slight_smile.png?v=12" title=":slight_smile:" class="emoji" alt=":slight_smile:" loading="lazy" width="20" height="20"></p>\n<p>Details on the proposals – We’ll be rolling out proposal types slowly over time. After airdrop <span class="hashtag-raw">#1</span> is released, we will start voting on project incentives and that will be a majority of the governance at first. The OP which is allocated in this way is known as the “Governance Fund”. We’ll release a bunch of details about the Governance Fund shortly!</p>\n<p>Later on we’ll start seeing new proposals roll out which include protocol upgrades and retroPGF. It’s important that we roll out new proposal types slowly over time so that everything we do end up governing is done so in a thoughtful and effective manor.</p>\n<blockquote>\n<p>ps: the democratic model that has been devised is really original, cool!</p>\n</blockquote>\n<p>Yay!!! Really glad you like it!</p>', metadata={'board_name': 'Get  Started 🌱', 'thread_title': 'Working Constitution of the Optimism Collective', 'creation_time': '2022-04-27T18:47:13.109000+00:00', 'username': 'karl', 'moderator': False, 'admin': True, 'staff': True, 'trust_level': 4, 'id': '67.55.135'}),
#  Document(page_content='<aside class="quote no-group" data-username="karl" data-post="7" data-topic="55">\n<div class="title">\n<div class="quote-controls"></div>\n<img loading="lazy" alt="" width="24" height="24" src="https://dub1.discourse-cdn.com/bc41dd/user_avatar/gov.optimism.io/karl/48/10_2.png" class="avatar"> karl:</div>\n<blockquote>\n<p>Before Airdrop <span class="hashtag-raw">#1</span> we’ll post a Discourse thread &amp; docs which describes: how to make proposals, vote on proposals, and commit to being a delegate. Before then the best way to participate is to read the Discourse <img src="https://emoji.discourse-cdn.com/twitter/slight_smile.png?v=12" title=":slight_smile:" class="emoji" alt=":slight_smile:" loading="lazy" width="20" height="20"></p>\n<p>Details on the proposals – We’ll be rolling out proposal types slowly over time. After airdrop <span class="hashtag-raw">#1</span> is released, we will start voting on project incentives and that will be a majority of the governance at first. The OP which is allocated in this way is known as the “Governance Fund”. We’ll release a bunch of details about the Governance Fund shortly!</p>\n<p>Later on we’ll start seeing new proposals roll out which include protocol upgrades and retroPGF. It’s important that we roll out new proposal types slowly over time so that everything we do end up governing is done so in a thoughtful and effective manor.</p>\n</blockquote>\n</aside>\n<p>ok all clear! thanks a lot:)</p>', metadata={'board_name': 'Get  Started 🌱', 'thread_title': 'Working Constitution of the Optimism Collective', 'creation_time': '2022-04-28T08:04:25.284000+00:00', 'username': 'Firstminister.eth', 'moderator': False, 'admin': False, 'staff': False, 'trust_level': 2, 'id': '67.55.190'}),
#  Document(page_content='<p>LFG !</p>\n<p>What’s the future about the Optimism Foundation ?<br>\nWe have a “Working” Constitution for four year but what about the influence of the Optimism Foundation.<br>\nMaybe after four years the members of the foundation could become OP Citizens or the Optimism Collective can vote to employ the Optimism Foundation and continue as is.<br>\nIt would incentive the Optimism Foundation to do well and prove it’s utility and not doom the members of the Optimism Collective if they have less right than the foundation.<br>\nI say that in reference to the Sushiswap drama and also if there is a collective managing a project it must be from A to Z. I understand the time period were we need to build a governance and operation framework but ultimately with just the Optimism Collective we would have a real decentralized network.</p>\n<p>Lots to be done but the future is optimistic</p>', metadata={'board_name': 'Get  Started 🌱', 'thread_title': 'Working Constitution of the Optimism Collective', 'creation_time': '2022-04-28T10:50:39.467000+00:00', 'username': 'CZoin', 'moderator': False, 'admin': False, 'staff': False, 'trust_level': 1, 'id': '67.55.197'}),
#  Document(page_content='<p>Great start. Excited to add value to the collective.</p>', metadata={'board_name': 'Get  Started 🌱', 'thread_title': 'Working Constitution of the Optimism Collective', 'creation_time': '2022-04-29T06:29:27.235000+00:00', 'username': 'TonyStark', 'moderator': False, 'admin': False, 'staff': False, 'trust_level': 1, 'id': '67.55.270'}),
#  Document(page_content='<p>Yes. I completely agree. The bias towards the collective health of citizens while securing a sustainable economy is,<br>\nIn many ways, quite similar to cooperative governance…when it works.</p>\n<p>Curious too if and how to participate going forward in the iterative refinements of the constitution.</p>', metadata={'board_name': 'Get  Started 🌱', 'thread_title': 'Working Constitution of the Optimism Collective', 'creation_time': '2022-05-01T20:53:20.289000+00:00', 'username': 'curlyg', 'moderator': False, 'admin': False, 'staff': False, 'trust_level': 0, 'id': '67.55.322'}),
#  Document(page_content='<p>I’m so happy to be apart of this! This is the future! LFG! I’m an Opti-Maxi all the way.</p>', metadata={'board_name': 'Get  Started 🌱', 'thread_title': 'Working Constitution of the Optimism Collective', 'creation_time': '2022-05-02T14:07:34.833000+00:00', 'username': 'JosephGlaeser', 'moderator': False, 'admin': False, 'staff': False, 'trust_level': 2, 'id': '67.55.334'}),
#  Document(page_content='<p>Super excited to see where everything will go in the future!! Our blockchain club is very interested <img src="https://emoji.discourse-cdn.com/twitter/slight_smile.png?v=12" title=":slight_smile:" class="emoji" alt=":slight_smile:" loading="lazy" width="20" height="20"></p>', metadata={'board_name': 'Get  Started 🌱', 'thread_title': 'Working Constitution of the Optimism Collective', 'creation_time': '2022-05-03T20:15:14.782000+00:00', 'username': 'Juanbug_PGov', 'moderator': False, 'admin': False, 'staff': False, 'trust_level': 2, 'id': '67.55.380'}),
#  Document(page_content='<p>Happy to see the commitment to anti-plutocracy and an approach to values outside of financial stake and simple token governance. I’m very excited to see what public goods funding can become through collective stewardship and co-operation, and to see the redistributive impact of alternative taxation through MEV auction and retroPGF!</p>', metadata={'board_name': 'Get  Started 🌱', 'thread_title': 'Working Constitution of the Optimism Collective', 'creation_time': '2022-05-06T13:41:04.836000+00:00', 'username': 'HomicidalChicken', 'moderator': False, 'admin': False, 'staff': False, 'trust_level': 1, 'id': '67.55.669'}),
#  Document(page_content='<p>OP are on the right path and will become the best L2 project in the future, we have always supported</p>', metadata={'board_name': 'Get  Started 🌱', 'thread_title': 'Working Constitution of the Optimism Collective', 'creation_time': '2022-05-09T18:54:39.309000+00:00', 'username': 'lazeeeerlin', 'moderator': False, 'admin': False, 'staff': False, 'trust_level': 2, 'id': '67.55.828'}),
#  Document(page_content='<p>after the merge OP ecosystem will go crazy!!!</p>', metadata={'board_name': 'Get  Started 🌱', 'thread_title': 'Working Constitution of the Optimism Collective', 'creation_time': '2022-05-10T15:53:38.873000+00:00', 'username': 'Koratboi', 'moderator': False, 'admin': False, 'staff': False, 'trust_level': 0, 'id': '67.55.904'}),
#  Document(page_content='<p>It will be interesting to see how the two houses balance each other out.  In the rare event of a gridlock decision, what steps will follow to mitigate this?</p>', metadata={'board_name': 'Get  Started 🌱', 'thread_title': 'Working Constitution of the Optimism Collective', 'creation_time': '2022-05-12T13:46:45.037000+00:00', 'username': 'Graciouseats', 'moderator': False, 'admin': False, 'staff': False, 'trust_level': 2, 'id': '67.55.947'}),
#  Document(page_content='<p>Stay Optimistic! The best community built project <img src="https://emoji.discourse-cdn.com/twitter/boom.png?v=12" title=":boom:" class="emoji" alt=":boom:" loading="lazy" width="20" height="20"></p>', metadata={'board_name': 'Get  Started 🌱', 'thread_title': 'Working Constitution of the Optimism Collective', 'creation_time': '2022-05-12T18:42:37.891000+00:00', 'username': 'MsuBtc', 'moderator': False, 'admin': False, 'staff': False, 'trust_level': 1, 'id': '67.55.956'}),
#  Document(page_content='<p>I will join Optimism Collective. Best regards</p>', metadata={'board_name': 'Get  Started 🌱', 'thread_title': 'Working Constitution of the Optimism Collective', 'creation_time': '2022-05-13T08:04:15.825000+00:00', 'username': 'yang.eth', 'moderator': False, 'admin': False, 'staff': False, 'trust_level': 1, 'id': '67.55.979'}),
#  Document(page_content='<aside class="quote no-group" data-username="system" data-post="1" data-topic="55">\n<div class="title">\n<div class="quote-controls"></div>\n<img loading="lazy" alt="" width="24" height="24" src="https://europe1.discourse-cdn.com/bc41dd/original/1X/391d6e71a279a9f881f75bfa7df5cdf3cf905b3f.png" class="avatar"> system:</div>\n<blockquote>\n<p>Stay Optimistic <img src="https://emoji.discourse-cdn.com/twitter/red_circle.png?v=12" title=":red_circle:" class="emoji" alt=":red_circle:" loading="lazy" width="20" height="20"><img src="https://emoji.discourse-cdn.com/twitter/sparkles.png?v=12" title=":sparkles:" class="emoji" alt=":sparkles:" loading="lazy" width="20" height="20"></p>\n</blockquote>\n</aside>\n<p>Stay Optimistic <img src="https://emoji.discourse-cdn.com/twitter/red_circle.png?v=12" title=":red_circle:" class="emoji" alt=":red_circle:" loading="lazy" width="20" height="20"><img src="https://emoji.discourse-cdn.com/twitter/sparkles.png?v=12" title=":sparkles:" class="emoji" alt=":sparkles:" loading="lazy" width="20" height="20"></p>', metadata={'board_name': 'Get  Started 🌱', 'thread_title': 'Working Constitution of the Optimism Collective', 'creation_time': '2022-05-13T12:26:27.474000+00:00', 'username': '0xbobns', 'moderator': False, 'admin': False, 'staff': False, 'trust_level': 2, 'id': '67.55.989'}),
#  Document(page_content='<p>great initiative, we have to make people believe that optimism is people’s network and to govern and regulate is their right. optimism is world in making and with collective effort of everyone, everyone will grow and be benefited.</p>', metadata={'board_name': 'Get  Started 🌱', 'thread_title': 'Working Constitution of the Optimism Collective', 'creation_time': '2022-05-14T10:40:29.809000+00:00', 'username': 'brock', 'moderator': False, 'admin': False, 'staff': False, 'trust_level': 1, 'id': '67.55.1004'}),
#  Document(page_content='<p><em>I’m AxlVaz, active member of the DeFiLATAM community. Here is the Spanish (Latin) translation of the “Working Constitution of the Optimism Collective”.</em><br>\n<em>From our community we want to translate these important documents into Spanish for the gov to have more reach and participation.</em></p>\n<p><strong>Constitución de Trabajo de Optimism Collective</strong></p>\n<p><strong>Optimism Collective</strong> es un experimento a gran escala de gobernanza descentralizada. Nuestra <a href="https://mirror.xyz/0x3e4865634EC54dFF742E1a7452a456919B8e277b/G-Ss-W78Vfrckz2MkHHnWiB7wFaH2D5nsbh6KE5c050" rel="noopener nofollow ugc">Visión</a> es financiar de manera sostenible aquellos bienes públicos que mejoran el bienestar del Colectivo y más allá. Esta Constitución de Trabajo consagra disposiciones y principios de gobernanza que, esperamos, estén calibrados para la ambición de esta Visión. Sienta las bases para un modelo justo y democrático de gobernanza descentralizada construida para durar.</p>\n<hr>\n<p><strong>1. Esta es una Constitución “de trabajo”.</strong> Es sumamente improbable que un modelo fijo de gobierno de Optimism Collective, definido al principio de este experimento, pueda navegar apropiadamente por los desafíos futuros del Colectivo. El espacio del problema es demasiado grande. Así que partimos de la humildad, comenzando con una Constitución de Trabajo que es:</p>\n<ul>\n<li>\n<strong>Una apuesta por la experimentación.</strong> Durante su vida, el Colectivo emprenderá una serie de experimentos de gobernanza. Estos experimentos deberían ayudar al Colectivo a comprender el equilibrio y la dinámica de poder dentro de su ecosistema, y \u200b\u200bpermitir que el Colectivo se defina a sí mismo, evolucione y crezca iterativamente con el tiempo.</li>\n<li>\n<strong>Un documento transitorio.</strong> La Constitución de Trabajo permanecerá en vigor no más de cuatro años a partir de la fecha de su adopción. Después de eso, la autoridad sobre el gobierno se cederá a una Constitución Bedrock permanente (que incorpora las experiencias de los experimentos de gobernanza anteriores al Colectivo).</li>\n</ul>\n<p><strong>2. Dentro del Colectivo convivirán por igual Ciudadanos OP y Holders OP.</strong> La estructura de la gobernanza del Colectivo debe equilibrar los incentivos a corto plazo con su Visión a largo plazo. Hoy en día, con demasiada frecuencia, los sistemas de gobernanza simples basados \u200b\u200ben tokens se deterioran debido a incentivos desalineados o una consolidación excesiva del poder. Optimism Collective implementará mecanismos estructurales para contrarrestar esas deficiencias, comenzando con un <a href="https://mirror.xyz/0x3e4865634EC54dFF742E1a7452a456919B8e277b/vqqC7BJqLGuFttA2vYpy-QyJrmoI_-X9LwCffd6Lb6c" rel="noopener nofollow ugc">sistema de gobierno bicameral.</a> que controla y equilibra el poder de los titulares de OP y los ciudadanos de OP.</p>\n<p><strong>3. Optimism Foundation será un administrador de Optimism Collective y su modelo de gobernanza inicial.</strong> Optimism Foundation es una organización de las Islas Caimán responsable de guiar el crecimiento y desarrollo de Optimism Collective. actuando a través de su Consejo de Administración la Fundación podrá:</p>\n<ul>\n<li>Facilitar la administración del Gobierno Colectivo;</li>\n<li>Asignar activos de tesorería para financiar bienes públicos, incentivar a los participantes en el ecosistema de Optimismo o promover su propósito (y el del Colectivo);</li>\n<li>Reformar la presente Constitución de Trabajo; y</li>\n<li>Adoptar otras medidas que conduzcan a su función de administración.</li>\n</ul>\n<p>La Fundación asumirá todas estas responsabilidades de manera coherente con la misión del Colectivo, y con miras a descentralizar cada vez más su papel en el tiempo.</p>\n<p><strong>4. Derechos de los Ciudadanos OP y Holders de OP.</strong> Sujeto a los documentos legales fundacionales de Optimism Foundation y los proce ...
#  Document(page_content='<blockquote>\n<ul>\n<li>OP Holders may:\n<ul>\n<li>Veto changes to the founding documents of the Optimism Foundation, if those changes would reduce the rights of OP Holders in a material way.</li>\n</ul>\n</li>\n</ul>\n</blockquote>\n<p>Hi guys! Can anyone help elaborate more on this? This means that OP Holders can submit a proposal to vote on rights of OP Holders?</p>', metadata={'board_name': 'Get  Started 🌱', 'thread_title': 'Working Constitution of the Optimism Collective', 'creation_time': '2022-05-15T09:43:24.940000+00:00', 'username': 'wcc', 'moderator': False, 'admin': False, 'staff': False, 'trust_level': 2, 'id': '67.55.1033'}),
#  Document(page_content='<p>I understand that OP holders may reject a proposal from the Optimism Foundation, the current administrator of the Optimism Collective, if it infringes on the rights or reduces the discretion of OP holders.</p>', metadata={'board_name': 'Get  Started 🌱', 'thread_title': 'Working Constitution of the Optimism Collective', 'creation_time': '2022-05-15T15:38:42.690000+00:00', 'username': 'AxlVaz', 'moderator': False, 'admin': False, 'staff': False, 'trust_level': 2, 'id': '67.55.1037'}),
#  Document(page_content='<p>Hi <a class="mention" href="/u/wcc">@wcc</a>! We’ll be publishing an “Operating Manual” this week that includes more details about voting mechanics, proposal submission, and approval process.</p>', metadata={'board_name': 'Get  Started 🌱', 'thread_title': 'Working Constitution of the Optimism Collective', 'creation_time': '2022-05-16T18:54:19.794000+00:00', 'username': 'bobby', 'moderator': True, 'admin': True, 'staff': True, 'trust_level': 4, 'id': '67.55.1067'}),
#  Document(page_content='<p>Best of luck on this adventure.</p>', metadata={'board_name': 'Get  Started 🌱', 'thread_title': 'Working Constitution of the Optimism Collective', 'creation_time': '2022-05-17T09:15:49.413000+00:00', 'username': 'FamilyMindSet', 'moderator': False, 'admin': False, 'staff': False, 'trust_level': 0, 'id': '67.55.1084'}),
#  Document(page_content='<p>What a job! Congratulations to the team</p>', metadata={'board_name': 'Get  Started 🌱', 'thread_title': 'Working Constitution of the Optimism Collective', 'creation_time': '2022-05-17T20:33:57.069000+00:00', 'username': 'BenB', 'moderator': False, 'admin': False, 'staff': False, 'trust_level': 1, 'id': '67.55.1111'}),
#  Document(page_content='<p>Very happy to see the governance work charter, cheers OP.</p>', metadata={'board_name': 'Get  Started 🌱', 'thread_title': 'Working Constitution of the Optimism Collective', 'creation_time': '2022-05-17T20:34:06.478000+00:00', 'username': 'baikaishui', 'moderator': False, 'admin': False, 'staff': False, 'trust_level': 0, 'id': '67.55.1114'}),
#  Document(page_content='<p>This is a nicely coherent and compact constitution. I am curious how OP Citizens will be established. Are these members who somehow undertake activities and then are assigned a soulbound NFT that shows their commitment? I’m just curious what distinguishes just a OP token holder and an OP citizen.</p>', metadata={'board_name': 'Get  Started 🌱', 'thread_title': 'Working Constitution of the Optimism Collective', 'creation_time': '2022-05-17T20:50:17.312000+00:00', 'username': 'polarpunklabs', 'moderator': False, 'admin': False, 'staff': False, 'trust_level': 2, 'id': '67.55.1120'}),
#  Document(page_content='<p>Let’s do it。we are very happy to join</p>', metadata={'board_name': 'Get  Started 🌱', 'thread_title': 'Working Constitution of the Optimism Collective', 'creation_time': '2022-05-18T02:46:21.381000+00:00', 'username': 'Chenke', 'moderator': False, 'admin': False, 'staff': False, 'trust_level': 0, 'id': '67.55.1160'}),
#  Document(page_content='<p>Frankly speaking, I feel very confused about Op Citizen. What is the difference between Op Citizien and Op Holder? How to become an Op Citizien? I think it is better to make things more clear</p>', metadata={'board_name': 'Get  Started 🌱', 'thread_title': 'Working Constitution of the Optimism Collective', 'creation_time': '2022-05-18T14:08:29.302000+00:00', 'username': 'chdonger', 'moderator': False, 'admin': False, 'staff': False, 'trust_level': 2, 'id': '67.55.1211'}),
#  Document(page_content='<p>Op Citizien will be launched later. And every citizen will have a NFT.</p>\n<p>Read this article with the latest news about it:</p>\n<aside class="onebox allowlistedgeneric" data-onebox-src="https://optimism.mirror.xyz/r888e4B5iiNQi-3_mO26ixgv-plQ099XWgqEOv9iWKA">\n  <header class="source">\n      <img src="https://europe1.discourse-cdn.com/bc41dd/original/1X/97bbea141e16a4d5982a90e085d6f100946d8527.png" class="site-icon" width="16" height="16">\n\n      <a href="https://optimism.mirror.xyz/r888e4B5iiNQi-3_mO26ixgv-plQ099XWgqEOv9iWKA" target="_blank" rel="noopener nofollow ugc">optimism.mirror.xyz</a>\n  </header>\n\n  <article class="onebox-body">\n    <div class="aspect-image" style="--aspect-ratio:690/345;"><img src="https://europe1.discourse-cdn.com/bc41dd/optimized/1X/e256f9eebe2e1ebc952f0c1b8d412422db6fce96_2_690x345.jpeg" class="thumbnail" width="690" height="345" srcset="https://europe1.discourse-cdn.com/bc41dd/optimized/1X/e256f9eebe2e1ebc952f0c1b8d412422db6fce96_2_690x345.jpeg, https://europe1.discourse-cdn.com/bc41dd/optimized/1X/e256f9eebe2e1ebc952f0c1b8d412422db6fce96_2_1035x517.jpeg 1.5x, https://europe1.discourse-cdn.com/bc41dd/optimized/1X/e256f9eebe2e1ebc952f0c1b8d412422db6fce96_2_1380x690.jpeg 2x" data-small-upload="https://europe1.discourse-cdn.com/bc41dd/optimized/1X/e256f9eebe2e1ebc952f0c1b8d412422db6fce96_2_10x10.png"></div>\n\n<h3><a href="https://optimism.mirror.xyz/r888e4B5iiNQi-3_mO26ixgv-plQ099XWgqEOv9iWKA" target="_blank" rel="noopener nofollow ugc">This Governance Will Self Destruct</a></h3>\n\n  <p>// TL;DR: The Optimism Collective is a large-scale experiment in non-plutocratic governance and funding public goods for a more aligned internet. In this post, we explain our agile approach to governance—relentlessly iterating until we form a system...</p>\n\n\n  </article>\n\n  <div class="onebox-metadata">\n    \n    \n  </div>\n\n  <div style="clear: both"></div>\n</aside>\n', metadata={'board_name': 'Get  Started 🌱', 'thread_title': 'Working Constitution of the Optimism Collective', 'creation_time': '2022-05-18T15:48:20.281000+00:00', 'username': 'AxlVaz', 'moderator': False, 'admin': False, 'staff': False, 'trust_level': 2, 'id': '67.55.1213'}),
#  Document(page_content='<p>Stay Optimistic! <img src="https://emoji.discourse-cdn.com/twitter/red_circle.png?v=12" title=":red_circle:" class="emoji" alt=":red_circle:" loading="lazy" width="20" height="20"><img src="https://emoji.discourse-cdn.com/twitter/sparkles.png?v=12" title=":sparkles:" class="emoji" alt=":sparkles:" loading="lazy" width="20" height="20"></p>\n<p>LFG</p>', metadata={'board_name': 'Get  Started 🌱', 'thread_title': 'Working Constitution of the Optimism Collective', 'creation_time': '2022-05-18T19:33:32.016000+00:00', 'username': '0xWeston', 'moderator': False, 'admin': False, 'staff': False, 'trust_level': 2, 'id': '67.55.1242'}),
#  Document(page_content='<p>我很高兴与此分开！这就是未来！LFG！我一直是 Opti-Maxi。</p>', metadata={'board_name': 'Get  Started 🌱', 'thread_title': 'Working Constitution of the Optimism Collective', 'creation_time': '2022-05-19T02:52:04.905000+00:00', 'username': 'zhangwenwen', 'moderator': False, 'admin': False, 'staff': False, 'trust_level': 0, 'id': '67.55.1260'}),
#  Document(page_content='<p>Very happy to be part of all of this. I follow Optimism from its early stages and hope to see its ecosystem grow and lead the way</p>', metadata={'board_name': 'Get  Started 🌱', 'thread_title': 'Working Constitution of the Optimism Collective', 'creation_time': '2022-05-20T09:39:42.481000+00:00', 'username': 'darwin', 'moderator': False, 'admin': False, 'staff': False, 'trust_level': 2, 'id': '67.55.1369'}),
#  Document(page_content='<p>this is a excellent plan,has a bright future</p>', metadata={'board_name': 'Get  Started 🌱', 'thread_title': 'Working Constitution of the Optimism Collective', 'creation_time': '2022-05-20T10:19:39.364000+00:00', 'username': 'lql869', 'moderator': False, 'admin': False, 'staff': False, 'trust_level': 0, 'id': '67.55.1371'}),
#  Document(page_content='<p>Optimistic vision! LFG - Happy to be a part of this so early!</p>', metadata={'board_name': 'Get  Started 🌱', 'thread_title': 'Working Constitution of the Optimism Collective', 'creation_time': '2022-05-20T11:32:57.525000+00:00', 'username': 'Thedreamweaver', 'moderator': False, 'admin': False, 'staff': False, 'trust_level': 0, 'id': '67.55.1376'}),
#  Document(page_content='<p>Stay optimistic. Great casting</p>', metadata={'board_name': 'Get  Started 🌱', 'thread_title': 'Working Constitution of the Optimism Collective', 'creation_time': '2022-05-21T20:44:28.739000+00:00', 'username': 'Tgtong', 'moderator': False, 'admin': False, 'staff': False, 'trust_level': 0, 'id': '67.55.1479'}),
#  Document(page_content='<aside class="quote no-group" data-username="baikaishui" data-post="29" data-topic="55" data-full="true">\n<div class="title">\n<div class="quote-controls"></div>\n<img loading="lazy" alt="" width="24" height="24" src="https://avatars.discourse-cdn.com/v4/letter/b/e5b9ba/48.png" class="avatar"> baikaishui:</div>\n<blockquote>\n<p>Very happy to see the governance work charter, cheers OP.</p>\n</blockquote>\n</aside>\n<p>Stay Optimistic! <img src="https://emoji.discourse-cdn.com/twitter/red_circle.png?v=12" title=":red_circle:" class="emoji" alt=":red_circle:" loading="lazy" width="20" height="20"><img src="https://emoji.discourse-cdn.com/twitter/sparkles.png?v=12" title=":sparkles:" class="emoji" alt=":sparkles:" loading="lazy" width="20" height="20"></p>', metadata={'board_name': 'Get  Started 🌱', 'thread_title': 'Working Constitution of the Optimism Collective', 'creation_time': '2022-05-21T20:44:31.198000+00:00', 'username': 'Niubite', 'moderator': False, 'admin': False, 'staff': False, 'trust_level': 1, 'id': '67.55.1481'}),
#  Document(page_content='<p>I’ve been interested in token governance ever since it became a thing. However, so far I haven’t been able to participate in this process in a meaningful way. I hope this change with Optimism</p>', metadata={'board_name': 'Get  Started 🌱', 'thread_title': 'Working Constitution of the Optimism Collective', 'creation_time': '2022-05-22T18:57:48.531000+00:00', 'username': 'petar', 'moderator': False, 'admin': False, 'staff': False, 'trust_level': 0, 'id': '67.55.1550'}),
#  Document(page_content='<p>Stay Optimistic! OP is the best L2 solution, excited for on the boat.</p>', metadata={'board_name': 'Get  Started 🌱', 'thread_title': 'Working Constitution of the Optimism Collective', 'creation_time': '2022-05-23T04:44:20.707000+00:00', 'username': 'bradleyni', 'moderator': False, 'admin': False, 'staff': False, 'trust_level': 0, 'id': '67.55.1560'}),
#  Document(page_content='<p>Stay Optimistic! <img src="https://emoji.discourse-cdn.com/twitter/red_circle.png?v=12" title=":red_circle:" class="emoji" alt=":red_circle:" loading="lazy" width="20" height="20"><img src="https://emoji.discourse-cdn.com/twitter/sparkles.png?v=12" title=":sparkles:" class="emoji" alt=":sparkles:" loading="lazy" width="20" height="20"><br>\nThe best chain and community</p>', metadata={'board_name': 'Get  Started 🌱', 'thread_title': 'Working Constitution of the Optimism Collective', 'creation_time': '2022-05-24T03:17:34.233000+00:00', 'username': 'mcbonton', 'moderator': False, 'admin': False, 'staff': False, 'trust_level': 1, 'id': '67.55.1672'}),
#  Document(page_content='<p>i am very happy to join optimism.</p>', metadata={'board_name': 'Get  Started 🌱', 'thread_title': 'Working Constitution of the Optimism Collective', 'creation_time': '2022-05-24T04:42:52.405000+00:00', 'username': 'vivi', 'moderator': False, 'admin': False, 'staff': False, 'trust_level': 0, 'id': '67.55.1698'}),
#  Document(page_content='<p>welcome to the community.</p>', metadata={'board_name': 'Get  Started 🌱', 'thread_title': 'Working Constitution of the Optimism Collective', 'creation_time': '2022-05-24T07:43:19.528000+00:00', 'username': 'OPUser', 'moderator': False, 'admin': False, 'staff': False, 'trust_level': 2, 'id': '67.55.1723'}),
#  Document(page_content='<p>To be an optomistic OP hodler…</p>', metadata={'board_name': 'Get  Started 🌱', 'thread_title': 'Working Constitution of the Optimism Collective', 'creation_time': '2022-05-24T11:24:07.420000+00:00', 'username': 'sicauva3', 'moderator': False, 'admin': False, 'staff': False, 'trust_level': 1, 'id': '67.55.1788'}),
#  Document(page_content='<p>Optimistic is the best L2 solution.<br>\nGood team Good community.</p>', metadata={'board_name': 'Get  Started 🌱', 'thread_title': 'Working Constitution of the Optimism Collective', 'creation_time': '2022-05-24T13:57:32.078000+00:00', 'username': 'calontro26', 'moderator': False, 'admin': False, 'staff': False, 'trust_level': 1, 'id': '67.55.1835'}),
#  Document(page_content='<p>Nice to see the new era of ETH, with my pleasure to be here for the new community in optimism</p>', metadata={'board_name': 'Get  Started 🌱', 'thread_title': 'Working Constitution of the Optimism Collective', 'creation_time': '2022-05-24T19:46:04.234000+00:00', 'username': 'Belter', 'moderator': False, 'admin': False, 'staff': False, 'trust_level': 1, 'id': '67.55.2003'}),
#  Document(page_content='<p>Hi guys!Great news and here are such actions, the community is getting bigger and stronger.Good job keeping it up.</p>', metadata={'board_name': 'Get  Started 🌱', 'thread_title': 'Working Constitution of the Optimism Collective', 'creation_time': '2022-05-24T23:59:33.531000+00:00', 'username': 'maxakyla', 'moderator': False, 'admin': False, 'staff': False, 'trust_level': 0, 'id': '67.55.2051'}),
#  Document(page_content='<p>Continuing the discussion from <a href="https://gov.optimism.io/t/working-constitution-of-the-optimism-collective/55">Working Constitution of the Optimism Collective</a>:</p>\n<p>自豪地成为乐观集体的一员！保持乐观.</p>', metadata={'board_name': 'Get  Started 🌱', 'thread_title': 'Working Constitution of the Optimism Collective', 'creation_time': '2022-05-25T01:05:11.252000+00:00', 'username': 'niexu', 'moderator': False, 'admin': False, 'staff': False, 'trust_level': 0, 'id': '67.55.2092'}),
#  Document(page_content='<p>Can’t wait. Also can’t wait for Etherscan to be back online <img src="https://emoji.discourse-cdn.com/twitter/slight_smile.png?v=12" title=":slight_smile:" class="emoji" alt=":slight_smile:" loading="lazy" width="20" height="20"></p>', metadata={'board_name': 'Get  Started 🌱', 'thread_title': 'Working Constitution of the Optimism Collective', 'creation_time': '2022-05-25T02:11:30.988000+00:00', 'username': '0xWeston', 'moderator': False, 'admin': False, 'staff': False, 'trust_level': 2, 'id': '67.55.2115'}),
#  Document(page_content='<p>I think Op set a benchmark for other L2 protocols. At this moment, most of Cryptos are suffered with short term Speculator. We really need someone to safeguard long term goal</p>', metadata={'board_name': 'Get  Started 🌱', 'thread_title': 'Working Constitution of the Optimism Collective', 'creation_time': '2022-05-25T02:22:27.151000+00:00', 'username': 'chdonger', 'moderator': False, 'admin': False, 'staff': False, 'trust_level': 2, 'id': '67.55.2118'}),
#  Document(page_content='<p>Once Optimism, Always optimism :red_circle</p>', metadata={'board_name': 'Get  Started 🌱', 'thread_title': 'Working Constitution of the Optimism Collective', 'creation_time': '2022-05-25T04:39:59.720000+00:00', 'username': 'Reus', 'moderator': False, 'admin': False, 'staff': False, 'trust_level': 1, 'id': '67.55.2148'}),
#  Document(page_content='<p>I like optimism，It was so generous that they gave us so many airdrops</p>', metadata={'board_name': 'Get  Started 🌱', 'thread_title': 'Working Constitution of the Optimism Collective', 'creation_time': '2022-05-25T05:42:57.296000+00:00', 'username': 'miluo', 'moderator': False, 'admin': False, 'staff': False, 'trust_level': 0, 'id': '67.55.2156'}),
#  Document(page_content='<p>Stay Optimistic <img src="https://emoji.discourse-cdn.com/twitter/red_circle.png?v=12" title=":red_circle:" class="emoji" alt=":red_circle:" loading="lazy" width="20" height="20"><img src="https://emoji.discourse-cdn.com/twitter/sparkles.png?v=12" title=":sparkles:" class="emoji" alt=":sparkles:" loading="lazy" width="20" height="20"> graet</p>', metadata={'board_name': 'Get  Started 🌱', 'thread_title': 'Working Constitution of the Optimism Collective', 'creation_time': '2022-05-25T05:51:10.014000+00:00', 'username': 'nasser215', 'moderator': False, 'admin': False, 'staff': False, 'trust_level': 0, 'id': '67.55.2158'}),
# ...
#  Document(page_content='<p>Below is a summary of recent changes and upcoming deadlines related to the grant programs of the Optimism Collective. For more detailed information, visit <a href="http://optimismgrants.io/" rel="noopener nofollow ugc">optimismgrants.io</a>.</p>\n<h3><a name="nov-18-dec-1-2023-1" class="anchor" href="#nov-18-dec-1-2023-1"></a>Nov 18 - Dec 1, 2023</h3>\n<ul>\n<li><strong>Nov 24, 2023 → First Mission Request draft was posted in the Forum!</strong><br>\nGonna posted a first Mission Request draft (<a href="https://gov.optimism.io/t/draft-real-world-data-storage-mission-request/7141">Real world data storage Mission Request</a>). Other Top 100 Delegates can also create a Delegate Mission Request using <a href="https://gov.optimism.io/t/delegate-guide-how-to-create-a-delegate-mission-request/6898">this</a> template, drafts should be posted to the Forum with the tag <a class="hashtag-cooked" href="/tag/mission-request" data-type="tag" data-slug="mission-request" data-id="72"><span class="hashtag-icon-placeholder"><svg class="fa d-icon d-icon-square-full svg-icon svg-node"><use href="#square-full"></use></svg></span><span>mission-request</span></a> by January 17th. If you are not a Top 100 Delegate but have an idea for a Mission Request, post it <a href="https://gov.optimism.io/t/seeking-mission-request-sponsorship/7130">here</a> so that Top 100 Delegates can review it. If you haven’t yet read it, you may also want to look into the <a href="https://gov.optimism.io/t/missions-v2-season-5/6897/1">Missions v2: Season 5</a> post to get an overview of the new Missions process.</li>\n</ul>\n<h3><a name="upcoming-2" class="anchor" href="#upcoming-2"></a>Upcoming:</h3>\n<ul>\n<li>\n<p><strong>Dec 1, 2023 23:59 GMT → Submission deadline for <a href="https://github.com/ethereum-optimism/ecosystem-contributions/issues/114" rel="noopener nofollow ugc">Foundation Mission Request: Season 5 govNERDs</a></strong></p>\n</li>\n<li>\n<p><strong>Dec 4, 2023 19:00 GMT → Submission deadline for <a href="https://github.com/ethereum-optimism/ecosystem-contributions/issues/116" rel="noopener nofollow ugc">Foundation Mission (RFP) – Superchain Safe (ex. Gnosis Safe)</a></strong><br>\n<em>Note: There are currently 0 applications for this RFP, so it is likely to be extended beyond the initial deadline.</em></p>\n</li>\n<li>\n<p><strong>Dec 7, 2023 → RetroPGF 3 voting ends</strong></p>\n</li>\n<li>\n<p><strong>Dec 8, 2023 19:00 GMT → Submission deadline for <a href="https://github.com/ethereum-optimism/ecosystem-contributions/issues/115" rel="noopener nofollow ugc">Foundation Mission (RFP) – Proof of Attendance Testnet Faucet</a></strong></p>\n</li>\n<li>\n<p><strong>Jan 17, 2024 → Deadline for drafting <a href="https://gov.optimism.io/t/delegate-guide-how-to-create-a-delegate-mission-request/6898">Mission Requests</a></strong></p>\n</li>\n</ul>', metadata={'board_name': 'Grants  🏹', 'thread_title': 'Optimism Grants Changelog', 'creation_time': '2023-12-01T19:06:17.614000+00:00', 'username': 'danftz', 'moderator': False, 'admin': False, 'staff': False, 'trust_level': 2, 'id': '69.6719.31390'}),
#  Document(page_content='<p>Below is a summary of recent changes and upcoming deadlines related to the grant programs of the Optimism Collective. For more detailed information, visit <a href="http://optimismgrants.io/" rel="noopener nofollow ugc">optimismgrants.io</a>.</p>\n<h3><a name="dec-2-dec-8-2023-1" class="anchor" href="#dec-2-dec-8-2023-1"></a>Dec 2 - Dec 8, 2023</h3>\n<ul>\n<li>\n<p><strong>Dec 4, 2023 → Submissions for <a href="https://github.com/ethereum-optimism/ecosystem-contributions/issues/116" rel="noopener nofollow ugc">RFP: Superchain Safe</a> are now closed!</strong></p>\n</li>\n<li>\n<p><strong>Dec 7, 2023 → RetroPGF 3 voting ended!</strong><br>\nThe voting period for RetroPGF Round 3 ended on December 7. In total, more than 100 Lists were created during the one-month voting period and 502 projects (out of 643) reached the quorum of 17 votes.</p>\n</li>\n<li>\n<p><strong>Dec 8, 2023 → Submissions for <a href="https://github.com/ethereum-optimism/ecosystem-contributions/issues/115" rel="noopener nofollow ugc">RFP: Proof of Attendance Testnet Faucet</a> are now closed!</strong></p>\n</li>\n</ul>\n<h3><a name="upcoming-2" class="anchor" href="#upcoming-2"></a>Upcoming:</h3>\n<ul>\n<li>\n<p><strong>Dec 15, 2023 19:00 GMT → Submission deadline for <a href="https://github.com/ethereum-optimism/ecosystem-contributions/issues/117" rel="noopener nofollow ugc">RFP: Superchain Bridge</a></strong></p>\n</li>\n<li>\n<p><strong>Jan 11, 2024 → Announcement of RetroPGF 3 results</strong></p>\n</li>\n<li>\n<p><strong>Jan 17, 2024 → Deadline for drafting <a href="https://gov.optimism.io/t/delegate-guide-how-to-create-a-delegate-mission-request/6898">Delegate Missions</a></strong></p>\n</li>\n</ul>', metadata={'board_name': 'Grants  🏹', 'thread_title': 'Optimism Grants Changelog', 'creation_time': '2023-12-08T23:18:34.340000+00:00', 'username': 'danftz', 'moderator': False, 'admin': False, 'staff': False, 'trust_level': 2, 'id': '69.6719.31622'}),
#  Document(page_content='<p>The Cycle 13 Preliminary Review has been completed. Cycle 13 showed strong turnout: the community submitted 106 proposals (compared to 151 proposals for the entirety of Season 3).</p>\n<p>The Grants Council congratulates the 49 proposers that will be considered for Final Review.</p>\n<p>Here is the list of proposals for Final Review organized by Sub-Committee:</p>\n<p><strong>Builders Sub-Committee Final Review List</strong></p>\n<p><a href="https://app.charmverse.io/op-grants/page-26434470823516043">Aragon</a></p>\n<p><a href="https://app.charmverse.io/op-grants/page-002013077512341477">Atlantis World</a></p>\n<p><a href="https://app.charmverse.io/op-grants/page-28209515081745185">Autonomous World</a></p>\n<p><a href="https://app.charmverse.io/op-grants/page-5416832246367627">Cannon</a></p>\n<p><a href="https://app.charmverse.io/op-grants/page-6441697637715833">Concrete</a></p>\n<p><a href="https://app.charmverse.io/op-grants/page-20247304231858698">Consensus Tax</a></p>\n<p><a href="https://app.charmverse.io/op-grants/page-31849314357430236">DAOstar</a></p>\n<p><a href="https://app.charmverse.io/op-grants/page-05034117397967264">DeSci World</a></p>\n<p><a href="https://app.charmverse.io/op-grants/page-060395295736737964">DRPC.Org</a></p>\n<p><a href="https://app.charmverse.io/op-grants/page-4929520669085159">EAS: Supercharged</a></p>\n<p><a href="https://app.charmverse.io/op-grants/page-5828546513037027">Epoch Protocol</a></p>\n<p><a href="https://app.charmverse.io/op-grants/page-04904066108713878">EVM-Runners</a></p>\n<p><a href="https://app.charmverse.io/op-grants/page-4923039239406415">Hildr</a></p>\n<p><a href="https://app.charmverse.io/op-grants/page-9764402793358298">Infinity Wallet</a></p>\n<p><a href="https://app.charmverse.io/op-grants/page-7286987887515874">Integrating ChainIDE</a></p>\n<p><a href="https://app.charmverse.io/op-grants/page-6074825183189025">JiffyScan</a></p>\n<p><a href="https://app.charmverse.io/op-grants/page-8610956286418354">Karma Grantee</a></p>\n<p><a href="https://app.charmverse.io/op-grants/page-37085606550601957">OS Observer</a></p>\n<p><a href="https://app.charmverse.io/op-grants/page-6399933911131408">Palmera</a></p>\n<p><a href="https://app.charmverse.io/op-grants/page-5841556062470414">Pyth Network</a></p>\n<p><a href="https://app.charmverse.io/op-grants/page-472203923295754">RedStone</a></p>\n<p><a href="https://app.charmverse.io/op-grants/page-4828729837571111">Scry Protocol</a></p>\n<p><a href="https://app.charmverse.io/op-grants/page-3173529621090243">Simple OP Stack Rollup</a></p>\n<p><a href="https://app.charmverse.io/op-grants/page-4760307444952083">Smart LTV</a></p>\n<p><a href="https://app.charmverse.io/op-grants/page-3623118157129741">Unitap</a></p>\n<p><a href="https://app.charmverse.io/op-grants/page-010385540509752822">Unruggable Names</a></p>\n<p><a href="https://app.charmverse.io/op-grants/page-18991441721187385">Upnode</a></p>\n<p><a href="https://app.charmverse.io/op-grants/page-2577520758307277">viaPrize</a></p>\n<p><a href="https://app.charmverse.io/op-grants/page-6418359515324739">Wakeup Labs</a></p>\n<p><strong>Experiments Sub-Committee Final Review List</strong></p>\n<p><a href="https://app.charmverse.io/op-grants/page-7454718202717829">Arcadia Finance</a></p>\n<p><a href="https://app.charmverse.io/op-grants/page-28011280168279695">Aura Finance</a></p>\n<p><a href="https://app.charmverse.io/op-grants/page-8355650350156509">Clique</a></p>\n<p><a href="https://app.charmverse.io/op-grants/page-7188606653226921">deBridge</a></p>\n<p><a href="https://app.charmverse.io/op-grants/page-6021070241317961">Extra Finance</a></p>\n<p><a href="https://app.charmverse.io/op-grants/page-771290143714014">Hypeshot</a></p>\n<p><a href="https://app.charmverse.io/op-grants/page-8726546713200878">Inverse Finance</a></p>\n<p><a href="https://app.charmverse.io/op-grants/page-904584674686645">Invest in Music</a></p>\n<p><a href="https://app.charmverse.io/op-grants ...
#  Document(page_content='<p>Hey there, thanks for your notification.</p>\n<p>Here is JJuunee from OmniBTC. What we should do now is waiting for any updates in <a href="https://app.charmverse.io/op-grants/page-036539591588051756" class="inline-onebox" rel="noopener nofollow ugc">CharmVerse - the all-in-one web3 space</a>, right?</p>\n<p>Besides, how can we update parts of the milestones in it?</p>\n<p>Now it always shows that “Can’t establish a connection to the server. New data WILL NOT be saved. Please refresh the page”.</p>\n<p>Thank you so much.</p>', metadata={'board_name': 'Grants  🏹', 'thread_title': 'Grants Council - Cycle 13 Preliminary Review Roundup', 'creation_time': '2023-07-04T02:53:28.253000+00:00', 'username': 'JJuunee', 'moderator': False, 'admin': False, 'staff': False, 'trust_level': 1, 'id': '69.6351.27719'}),
#  Document(page_content='<p>Hey June. Reviewers will provide feedback to you on Charmverse.</p>\n<p>You should be able to update milestones on the table, if not DM on Discord and I’ll make sure you can.</p>\n<aside class="quote no-group" data-username="JJuunee" data-post="2" data-topic="6351">\n<div class="title">\n<div class="quote-controls"></div>\n<img loading="lazy" alt="" width="24" height="24" src="https://avatars.discourse-cdn.com/v4/letter/j/6bbea6/48.png" class="avatar"> JJuunee:</div>\n<blockquote>\n<p>Now it always shows that “Can’t establish a connection to the server. New data WILL NOT be saved. Please refresh the page”.</p>\n</blockquote>\n</aside>\n<p>The Charmverse team used the long weekend to upload a few new features. They are in constant build mode and this happens once in a while. I am sorry for the inconvenience this can bring.</p>', metadata={'board_name': 'Grants  🏹', 'thread_title': 'Grants Council - Cycle 13 Preliminary Review Roundup', 'creation_time': '2023-07-05T22:08:24.960000+00:00', 'username': 'Gonna.eth', 'moderator': True, 'admin': False, 'staff': True, 'trust_level': 3, 'id': '69.6351.27796'}),
#  Document(page_content='<p>Thanks for your reply Gonna~</p>', metadata={'board_name': 'Grants  🏹', 'thread_title': 'Grants Council - Cycle 13 Preliminary Review Roundup', 'creation_time': '2023-07-06T02:18:06.342000+00:00', 'username': 'JJuunee', 'moderator': False, 'admin': False, 'staff': False, 'trust_level': 1, 'id': '69.6351.27809'}),
#  Document(page_content='<p>Excuse me, Gonna! Could you please unlock OmniBTC proposal so that I can update the finalized proposal.</p>\n<aside class="onebox allowlistedgeneric" data-onebox-src="https://app.charmverse.io/op-grants/page-036539591588051756">\n  <header class="source">\n      <img src="https://europe1.discourse-cdn.com/bc41dd/original/2X/3/3c5ff1e079a3a97de5d809f51cc0d63c0bbc1ba9.png" class="site-icon" data-dominant-color="C3C5C6" width="500" height="500">\n\n      <a href="https://app.charmverse.io/op-grants/page-036539591588051756" target="_blank" rel="noopener nofollow ugc">app.charmverse.io</a>\n  </header>\n\n  <article class="onebox-body">\n    <div class="aspect-image" style="--aspect-ratio:644/499;"><img src="https://europe1.discourse-cdn.com/bc41dd/optimized/2X/2/2ed271296cf85dd4fbc83b28754253613a20b693_2_644x499.png" class="thumbnail" data-dominant-color="DDDEE0" width="644" height="499"></div>\n\n<h3><a href="https://app.charmverse.io/op-grants/page-036539591588051756" target="_blank" rel="noopener nofollow ugc">CharmVerse</a></h3>\n\n  <p>web3 operations platform handling docs, tasks, bounties, proposals, and votes.</p>\n\n\n  </article>\n\n  <div class="onebox-metadata">\n    \n    \n  </div>\n\n  <div style="clear: both"></div>\n</aside>\n', metadata={'board_name': 'Grants  🏹', 'thread_title': 'Grants Council - Cycle 13 Preliminary Review Roundup', 'creation_time': '2023-07-27T06:30:19.558000+00:00', 'username': 'JJuunee', 'moderator': False, 'admin': False, 'staff': False, 'trust_level': 1, 'id': '69.6351.28490'}),
#  Document(page_content='<p>Finalized proposals are locked to keep a record of what the council has voted on. If you want to apply for Cycle 14 and use the same proposals please copy/paste the answers. Keep in mind Cycle 14 form has new questions.</p>', metadata={'board_name': 'Grants  🏹', 'thread_title': 'Grants Council - Cycle 13 Preliminary Review Roundup', 'creation_time': '2023-07-31T18:24:27.399000+00:00', 'username': 'Gonna.eth', 'moderator': True, 'admin': False, 'staff': True, 'trust_level': 3, 'id': '69.6351.28576'}),
#  Document(page_content='<p>Excuse me Gonna, we have finished the critical milestones, what is the next step? We have mailed <a href="mailto:optimismgrant@gmail.com">optimismgrant@gmail.com</a></p>', metadata={'board_name': 'Grants  🏹', 'thread_title': 'Grants Council - Cycle 13 Preliminary Review Roundup', 'creation_time': '2023-10-25T07:23:00.238000+00:00', 'username': 'JJuunee', 'moderator': False, 'admin': False, 'staff': False, 'trust_level': 1, 'id': '69.6351.30594'}),
#  ...]

# %% [markdown]
# ## Create the embeddings and store vectors

# %%
data_sources = {
    "full_docs": full_docs,
    "fragments_docs": fragments_docs,
    "posts_forum": posts_forum
}

# %%
for model_embeddings in embedding_models:
        embeddings = OpenAIEmbeddings(model=model_embeddings, openai_api_key=openai_api_key)
        for store in vectorstores:
            for name, d in data_sources.items():
                if store == 'faiss':
                    db = FAISS.from_documents(d, embeddings)
                    db.save_local(f"dbs/{name}_db/faiss/{model_embeddings}")

# %%
def num_tokens_from_string(string: str) -> int:
    """Returns the number of tokens in a text string."""
    encoding = tiktoken.get_encoding("cl100k_base")
    num_tokens = len(encoding.encode(string))
    return num_tokens

# cost per 1M tokens, from https://openai.com/api/pricing/
cost_rate = {
    "text-embedding-3-small": 0.02,
    "text-embedding-3-large": 0.13,
    "text-embedding-ada-002": 0.10
}

costs = []
# calculate the cost of the embeddings
for model in embedding_models:
    for name, data in data_sources.items():
        cost = {
            "embedding model" : model,
            "data source" : name,
            "num tokens" : sum([num_tokens_from_string(d.page_content) for d in data]),
            "cost ($)" : sum([num_tokens_from_string(d.page_content) for d in data]) * cost_rate[model]/1e6
        }
        costs.append(cost)

pd.DataFrame(costs)
# Out:
#           embedding model     data source  num tokens  cost ($)
# 0  text-embedding-3-small       full_docs      118749  0.002375
# 1  text-embedding-3-small  fragments_docs      114388  0.002288
# 2  text-embedding-3-small     posts_forum     7286582  0.145732
# 3  text-embedding-3-large       full_docs      118749  0.015437
# 4  text-embedding-3-large  fragments_docs      114388  0.014870
# 5  text-embedding-3-large     posts_forum     7286582  0.947256
# 6  text-embedding-ada-002       full_docs      118749  0.011875
# 7  text-embedding-ada-002  fragments_docs      114388  0.011439
# 8  text-embedding-ada-002     posts_forum     7286582  0.728658
